# %% [markdown]
# ## First trial

# %%
import math
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import asyncio
from tqdm.notebook import tqdm
import time
import sys

# Function to split data into batches
def split_into_batches(data, num_batches):
    """
    Splits a list into a specified number of batches.
    """
    batch_size = math.ceil(len(data) / num_batches)
    return [data[i * batch_size:(i + 1) * batch_size] for i in range(num_batches)]

# Async function to fetch links using Selenium
async def fetch_links(driver, county, naics_code):
    try:
        # Step 1: Navigate to the Page
        url = "https://accessnc.nccommerce.com/business/business_custom_search_infogroup.html"
        driver.get(url)

        # Wait for the page to load
        time.sleep(2)

        # Step 2: Switch to "Advanced Search" Tab
        advanced_search_tab = driver.find_element(By.CSS_SELECTOR, "a[href='#Advanced_Search']")
        advanced_search_tab.click()

        # Wait for the Advanced Search section to load
        time.sleep(2)

        # Step 3: Select "Area Type" (e.g., "County")
        area_type_dropdown = Select(driver.find_element(By.ID, "regionCategory"))
        area_type_dropdown.select_by_visible_text("County")

        # Step 4: Select the Area (e.g., "Buncombe")
        area_dropdown = Select(driver.find_element(By.ID, "region"))
        area_dropdown.select_by_visible_text(county)

        # Step 5: Select Industry Group (e.g., NAICS Code)
        industry_dropdown = Select(driver.find_element(By.ID, "IndustryGroup2"))
        industry_dropdown.select_by_value(naics_code)

        # Step 6: Interact with the Submit Button
        submit_button = driver.find_element(By.CSS_SELECTOR, "div.col-sm-10 > button[type='submit'][class='btn btn-primary'][name='submit']")
        driver.execute_script("arguments[0].scrollIntoView(true);", submit_button)
        time.sleep(1)
        driver.execute_script("arguments[0].click();", submit_button)

        # Step 7: Wait for Results to Load and Process the New Tab's HTML
        time.sleep(3)  # Adjust as needed for loading time
        driver.switch_to.window(driver.window_handles[-1])  # Switch to the new tab

        # Parse the HTML using BeautifulSoup
        result_html = driver.page_source
        soup = BeautifulSoup(result_html, 'html.parser')

        # Extract all links where the text is "Detail"
        detail_links = [link.get('href') for link in soup.find_all('a', string="Detail")]
        print(f"{county}-{naics_code}: Extracted {len(detail_links)} links.")

        # Write links to a file
        with open("all_links.txt", "a") as file:
            for link in detail_links:
                file.write(link + "\n")

        # Close the result tab
        driver.close()

        # Switch back to the original tab
        driver.switch_to.window(driver.window_handles[0])

        return detail_links
    except Exception as e:
        print(f"Error processing {county}-{naics_code}: {e}")
        return []

# Async main function
async def main(start_batch, end_batch):
    # Read NAICS codes from the file
    with open("qnaics_codes.txt", 'r') as f:
        codes = [line.strip() for line in f.readlines()]

    # Define counties
    counties = [
        "Alexander", "Alleghany", "Ashe", "Avery", "Buncombe", "Burke",
        "Caldwell", "Catawba", "Clay", "Cleveland", "Gaston", "Haywood",
        "Henderson", "Jackson", "Lincoln", "Macon", "Madison", "McDowell",
        "Mecklenburg", "Mitchell", "Polk", "Rutherford", "Swain",
        "Transylvania", "Watauga", "Wilkes", "Yancey"
    ]

    # Combine counties and NAICS codes into pairs
    tasks_data = [(county, code) for county in counties for code in codes]

    # Split the tasks into 20 batches
    batches = split_into_batches(tasks_data, 20)

    # Validate batch range
    if start_batch < 1 or end_batch > len(batches):
        print(f"Invalid batch range: {start_batch}-{end_batch}. Must be between 1 and {len(batches)}.")
        return

    # Create a WebDriver instance
    driver = webdriver.Chrome()

    try:
        for batch_idx in range(start_batch - 1, end_batch):
            print(f"Processing batch {batch_idx + 1}/{end_batch}...")
            progress_bar = tqdm(total=len(batches[batch_idx]), desc=f"Batch {batch_idx + 1}/{end_batch}")

            # Create tasks for the current batch
            tasks = [
                fetch_links(driver, county, code)
                for county, code in batches[batch_idx]
            ]

            # Run all tasks in the current batch
            await asyncio.gather(*tasks)

            # Update progress bar
            for _ in tasks:
                progress_bar.update(1)

            progress_bar.close()
            print(f"Batch {batch_idx + 1} completed.")
            await asyncio.sleep(5)  # Optional rest between batches

        print(f"All tasks from batch {start_batch} to {end_batch} completed. Links are written to all_links.txt.")
    finally:
        driver.quit()

# %%
await main(start_batch=1, end_batch=5)
# Out:
# Processing batch 1/5...
# Batch 1/5:   0%|          | 0/420 [00:00<?, ?it/s]
# Alexander-1132: Extracted 0 links.
# Alexander-3115: Extracted 0 links.
# Alexander-3362: Extracted 1 links.
# Alexander-5232: Extracted 0 links.
# Alexander-8112: Extracted 0 links.
# Alexander-3132: Extracted 1 links.
# Alexander-4481: Extracted 0 links.
# Alexander-6117: Extracted 1 links.
# Alexander-4243: Extracted 0 links.
# Alexander-5222: Extracted 6 links.
# Alexander-2131: Extracted 0 links.
# Alexander-4811: Extracted 0 links.
# Alexander-3313: Extracted 0 links.
# Alexander-4512: Extracted 0 links.
# Alexander-3361: Extracted 1 links.
# Alexander-4541: Extracted 0 links.
# Alexander-2371: Extracted 1 links.
# Alexander-4872: Extracted 0 links.
# Alexander-4832: Extracted 0 links.
# Alexander-5324: Extracted 0 links.
# Alexander-5182: Extracted 1 links.
# Alexander-3353: Extracted 0 links.
# Alexander-4431: Extracted 0 links.
# Alexander-3371: Extracted 11 links.
# Alexander-4921: Extracted 0 links.
# Alexander-3333: Extracted 0 links.
# Alexander-3379: Extracted 3 links.
# Alexander-4869: Extracted 0 links.
# Alexander-3274: Extracted 0 links.
# Alexander-4232: Extracted 2 links.
# Alexander-3322: Extracted 0 links.
# Alexander-5312: Extracted 25 links.
# Alexander-2123: Extracted 1 links.
# Alexander-3253: Extracted 1 links.
# Alexander-4511: Extracted 0 links.
# Alexander-3344: Extracted 0 links.
# Alexander-4247: Extracted 3 links.
# Alexander-3326: Extracted 0 links.
# Alexander-3342: Extracted 0 links.
# Alexander-3332: Extracted 0 links.
# Alexander-5231: Extracted 0 links.
# Alexander-6115: Extracted 0 links.
# Alexander-1141: Extracted 0 links.
# Alexander-3272: Extracted 0 links.
# Alexander-6112: Extracted 1 links.
# Alexander-3259: Extracted 0 links.
# Alexander-3327: Extracted 2 links.
# Alexander-4421: Extracted 0 links.
# Alexander-1123: Extracted 1 links.
# Alexander-3271: Extracted 0 links.
# Alexander-4855: Extracted 0 links.
# Alexander-6243: Extracted 0 links.
# Alexander-2122: Extracted 0 links.
# Alexander-5419: Extracted 16 links.
# Alexander-4885: Extracted 2 links.
# Alexander-3339: Extracted 1 links.
# Alexander-4471: Extracted 0 links.
# Alexander-5323: Extracted 0 links.
# Alexander-3116: Extracted 1 links.
# Alexander-3119: Extracted 0 links.
# Alexander-3335: Extracted 0 links.
# Alexander-4911: Extracted 4 links.
# Alexander-5414: Extracted 4 links.
# Alexander-7132: Extracted 0 links.
# Alexander-1133: Extracted 0 links.
# Alexander-2372: Extracted 0 links.
# Alexander-6223: Extracted 0 links.
# Alexander-6116: Extracted 3 links.
# Alexander-6232: Extracted 0 links.
# Alexander-4879: Extracted 0 links.
# Alexander-2213: Extracted 0 links.
# Alexander-7121: Extracted 2 links.
# Alexander-2389: Extracted 15 links.
# Alexander-5112: Extracted 0 links.
# Alexander-1121: Extracted 0 links.
# Alexander-7211: Extracted 1 links.
# Alexander-4251: Extracted 1 links.
# Alexander-1122: Extracted 0 links.
# Alexander-4411: Extracted 15 links.
# Alexander-5418: Extracted 3 links.
# Alexander-1152: Extracted 1 links.
# Alexander-6212: Extracted 8 links.
# Alexander-5241: Extracted 0 links.
# Alexander-4881: Extracted 1 links.
# Alexander-4523: Extracted 0 links.
# Alexander-7213: Extracted 0 links.
# Alexander-5411: Extracted 17 links.
# Alexander-3325: Extracted 0 links.
# Alexander-8111: Extracted 30 links.
# Alexander-4842: Extracted 13 links.
# Alexander-3331: Extracted 2 links.
# Alexander-8121: Extracted 26 links.
# Alexander-3328: Extracted 0 links.
# Alexander-6219: Extracted 4 links.
# Alexander-3121: Extracted 2 links.
# Alexander-4522: Extracted 0 links.
# Alexander-5311: Extracted 8 links.
# Alexander-6242: Extracted 1 links.
# Alexander-4852: Extracted 0 links.
# Alexander-4234: Extracted 0 links.
# Alexander-4246: Extracted 0 links.
# Alexander-2379: Extracted 2 links.
# Alexander-3311: Extracted 0 links.
# Alexander-7212: Extracted 1 links.
# Alexander-3117: Extracted 0 links.
# Alexander-6211: Extracted 10 links.
# Alexander-3334: Extracted 1 links.
# Alexander-5331: Extracted 0 links.
# Alexander-5413: Extracted 4 links.
# Alexander-7131: Extracted 0 links.
# Alexander-2362: Extracted 2 links.
# Alexander-8113: Extracted 2 links.
# Alexander-2373: Extracted 7 links.
# Alexander-4239: Extracted 0 links.
# Alexander-4862: Extracted 0 links.
# Alexander-4533: Extracted 0 links.
# Alexander-1125: Extracted 0 links.
# Alexander-3323: Extracted 2 links.
# Alexander-3118: Extracted 3 links.
# Alexander-4532: Extracted 0 links.
# Alexander-3212: Extracted 1 links.
# Alexander-3222: Extracted 0 links.
# Alexander-3372: Extracted 4 links.
# Alexander-5613: Extracted 2 links.
# Alexander-8141: Extracted 0 links.
# Alexander-3364: Extracted 0 links.
# Alexander-5415: Extracted 4 links.
# Alexander-3261: Extracted 0 links.
# Alexander-1129: Extracted 1 links.
# Alexander-5122: Extracted 0 links.
# Alexander-4531: Extracted 0 links.
# Alexander-6213: Extracted 27 links.
# Alexander-3241: Extracted 0 links.
# Alexander-7115: Extracted 1 links.
# Alexander-3262: Extracted 0 links.
# Alexander-5111: Extracted 0 links.
# Alexander-2111: Extracted 0 links.
# Alexander-3321: Extracted 1 links.
# Alexander-5313: Extracted 0 links.
# Alexander-1131: Extracted 0 links.
# Alexander-9221: Extracted 14 links.
# Alexander-3399: Extracted 5 links.
# Alexander-4931: Extracted 0 links.
# Alexander-7112: Extracted 0 links.
# Alexander-4542: Extracted 0 links.
# Alexander-4543: Extracted 0 links.
# Alexander-4244: Extracted 0 links.
# Alexander-3169: Extracted 0 links.
# Alexander-4412: Extracted 5 links.
# Alexander-5612: Extracted 0 links.
# Alexander-4453: Extracted 1 links.
# Alexander-4451: Extracted 16 links.
# Alexander-3336: Extracted 0 links.
# Alexander-5179: Extracted 0 links.
# Alexander-3131: Extracted 0 links.
# Alexander-2212: Extracted 0 links.
# Alexander-1114: Extracted 3 links.
# Alexander-3151: Extracted 0 links.
# Alexander-3252: Extracted 0 links.
# Alexander-5173: Extracted 0 links.
# Alexander-9261: Extracted 3 links.
# Alexander-3113: Extracted 0 links.
# Alexander-3133: Extracted 1 links.
# Alexander-8132: Extracted 1 links.
# Alexander-5211: Extracted 0 links.
# Alexander-4248: Extracted 0 links.
# Alexander-8134: Extracted 6 links.
# Alexander-5619: Extracted 4 links.
# Alexander-5242: Extracted 18 links.
# Alexander-3211: Extracted 2 links.
# Alexander-5251: Extracted 0 links.
# Alexander-3365: Extracted 0 links.
# Alexander-4237: Extracted 2 links.
# Alexander-7225: Extracted 42 links.
# Alexander-4871: Extracted 0 links.
# Alexander-4413: Extracted 9 links.
# Alexander-3255: Extracted 0 links.
# Alexander-5152: Extracted 0 links.
# Alexander-4245: Extracted 0 links.
# Alexander-4882: Extracted 4 links.
# Alexander-3359: Extracted 0 links.
# Alexander-3315: Extracted 0 links.
# Alexander-3231: Extracted 3 links.
# Alexander-5321: Extracted 2 links.
# Alexander-3343: Extracted 0 links.
# Alexander-3312: Extracted 0 links.
# Alexander-3161: Extracted 1 links.
# Alexander-1151: Extracted 1 links.
# Alexander-5621: Extracted 1 links.
# Alexander-9211: Extracted 47 links.
# Alexander-2361: Extracted 18 links.
# Alexander-4441: Extracted 13 links.
# Alexander-3254: Extracted 1 links.
# Alexander-6221: Extracted 1 links.
# Alexander-3149: Extracted 2 links.
# Alexander-6113: Extracted 1 links.
# Alexander-3351: Extracted 0 links.
# Alexander-1142: Extracted 0 links.
# Alexander-3279: Extracted 2 links.
# Alexander-2211: Extracted 0 links.
# Alexander-3346: Extracted 0 links.
# Alexander-4231: Extracted 3 links.
# Alexander-4859: Extracted 1 links.
# Alexander-4238: Extracted 4 links.
# Alexander-4461: Extracted 0 links.
# Alexander-5151: Extracted 0 links.
# Alexander-2121: Extracted 0 links.
# Alexander-5221: Extracted 7 links.
# Alexander-5322: Extracted 1 links.
# Alexander-6111: Extracted 14 links.
# Alexander-3111: Extracted 1 links.
# Alexander-4854: Extracted 0 links.
# Alexander-5616: Extracted 1 links.
# Alexander-4883: Extracted 0 links.
# Alexander-3324: Extracted 0 links.
# Alexander-3141: Extracted 0 links.
# Alexander-3369: Extracted 0 links.
# Alexander-4889: Extracted 0 links.
# Alexander-7139: Extracted 13 links.
# Alexander-5417: Extracted 2 links.
# Alexander-6222: Extracted 3 links.
# Alexander-2383: Extracted 6 links.
# Alexander-5239: Extracted 9 links.
# Alexander-4482: Extracted 0 links.
# Alexander-6241: Extracted 18 links.
# Alexander-8129: Extracted 7 links.
# Alexander-8131: Extracted 80 links.
# Alexander-5614: Extracted 2 links.
# Alexander-1119: Extracted 16 links.
# Alexander-4483: Extracted 0 links.
# Alexander-5617: Extracted 13 links.
# Alexander-3159: Extracted 2 links.
# Alexander-2382: Extracted 17 links.
# Alexander-4235: Extracted 1 links.
# Alexander-3219: Extracted 3 links.
# Alexander-4249: Extracted 2 links.
# Alexander-8133: Extracted 12 links.
# Alexander-6239: Extracted 3 links.
# Alexander-9241: Extracted 1 links.
# Alexander-5174: Extracted 0 links.
# Alexander-5611: Extracted 2 links.
# Alexander-3366: Extracted 0 links.
# Alexander-5511: Extracted 4 links.
# Alexander-4442: Extracted 3 links.
# Alexander-3221: Extracted 0 links.
# Alexander-3363: Extracted 0 links.
# Alexander-3256: Extracted 2 links.
# Alexander-9281: Extracted 1 links.
# Alexander-4841: Extracted 2 links.
# Alexander-3114: Extracted 0 links.
# Alexander-6114: Extracted 0 links.
# Alexander-4884: Extracted 1 links.
# Alexander-7114: Extracted 0 links.
# Alexander-5629: Extracted 0 links.
# Alexander-5223: Extracted 2 links.
# Alexander-1124: Extracted 0 links.
# Alexander-7111: Extracted 0 links.
# Alexander-1111: Extracted 0 links.
# Alexander-9231: Extracted 0 links.
# Alexander-3391: Extracted 2 links.
# Alexander-4422: Extracted 0 links.
# Alexander-5191: Extracted 0 links.
# Alexander-4851: Extracted 0 links.
# Alexander-4831: Extracted 0 links.
# Alexander-4922: Extracted 0 links.
# Alexander-4242: Extracted 0 links.
# Alexander-6215: Extracted 0 links.
# Alexander-7113: Extracted 0 links.
# Alexander-8114: Extracted 3 links.
# Alexander-8122: Extracted 5 links.
# Alexander-6244: Extracted 10 links.
# Alexander-9271: Extracted 0 links.
# Alexander-5615: Extracted 2 links.
# Alexander-4853: Extracted 0 links.
# Alexander-5259: Extracted 0 links.
# Alexander-3251: Extracted 0 links.
# Alexander-3112: Extracted 0 links.
# Alexander-3329: Extracted 4 links.
# Alexander-3162: Extracted 0 links.
# Alexander-1113: Extracted 1 links.
# Alexander-4233: Extracted 1 links.
# Alexander-6216: Extracted 1 links.
# Alexander-3345: Extracted 1 links.
# Alexander-4812: Extracted 0 links.
# Alexander-8123: Extracted 0 links.
# Alexander-3152: Extracted 0 links.
# Alexander-4539: Extracted 0 links.
# Alexander-3352: Extracted 0 links.
# Alexander-3341: Extracted 0 links.
# Alexander-8139: Extracted 7 links.
# Alexander-5412: Extracted 10 links.
# Alexander-4452: Extracted 5 links.
# Alexander-4236: Extracted 3 links.
# Alexander-3314: Extracted 0 links.
# Alexander-1112: Extracted 0 links.
# Alexander-2381: Extracted 12 links.
# Alexander-5622: Extracted 1 links.
# Alexander-3122: Extracted 0 links.
# Alexander-4861: Extracted 0 links.
# Alexander-9251: Extracted 0 links.
# Alexander-7224: Extracted 0 links.
# Alexander-4821: Extracted 1 links.
# Alexander-7223: Extracted 2 links.
# Alexander-5416: Extracted 5 links.
# Alexander-3273: Extracted 0 links.
# Alexander-1153: Extracted 0 links.
# Alexander-4241: Extracted 0 links.
# Alexander-6231: Extracted 3 links.
# Alexander-6214: Extracted 3 links.
# Alexander-6233: Extracted 3 links.
# Alexander-5121: Extracted 1 links.
# Alleghany-1132: Extracted 0 links.
# Alleghany-3115: Extracted 0 links.
# Alleghany-3362: Extracted 0 links.
# Alleghany-5232: Extracted 0 links.
# Alleghany-8112: Extracted 1 links.
# Alleghany-3132: Extracted 0 links.
# Alleghany-4481: Extracted 0 links.
# Alleghany-6117: Extracted 1 links.
# Alleghany-4243: Extracted 0 links.
# Alleghany-5222: Extracted 2 links.
# Alleghany-2131: Extracted 0 links.
# Alleghany-4811: Extracted 0 links.
# Alleghany-3313: Extracted 0 links.
# Alleghany-4512: Extracted 0 links.
# Alleghany-3361: Extracted 0 links.
# Alleghany-4541: Extracted 0 links.
# Alleghany-2371: Extracted 0 links.
# Alleghany-4872: Extracted 0 links.
# Alleghany-4832: Extracted 0 links.
# Alleghany-5324: Extracted 0 links.
# Alleghany-5182: Extracted 1 links.
# Alleghany-3353: Extracted 0 links.
# Alleghany-4431: Extracted 0 links.
# Alleghany-3371: Extracted 1 links.
# Alleghany-4921: Extracted 0 links.
# Alleghany-3333: Extracted 1 links.
# Alleghany-3379: Extracted 0 links.
# Alleghany-4869: Extracted 0 links.
# Alleghany-3274: Extracted 0 links.
# Alleghany-4232: Extracted 0 links.
# Alleghany-3322: Extracted 0 links.
# Alleghany-5312: Extracted 13 links.
# Alleghany-2123: Extracted 1 links.
# Alleghany-3253: Extracted 0 links.
# Alleghany-4511: Extracted 0 links.
# Alleghany-3344: Extracted 0 links.
# Alleghany-4247: Extracted 1 links.
# Alleghany-3326: Extracted 0 links.
# Alleghany-3342: Extracted 0 links.
# Alleghany-3332: Extracted 0 links.
# Alleghany-5231: Extracted 9 links.
# Alleghany-6115: Extracted 0 links.
# Alleghany-1141: Extracted 0 links.
# Alleghany-3272: Extracted 0 links.
# Alleghany-6112: Extracted 1 links.
# Alleghany-3259: Extracted 0 links.
# Alleghany-3327: Extracted 0 links.
# Alleghany-4421: Extracted 0 links.
# Alleghany-1123: Extracted 0 links.
# Alleghany-3271: Extracted 0 links.
# Alleghany-4855: Extracted 0 links.
# Alleghany-6243: Extracted 2 links.
# Alleghany-2122: Extracted 0 links.
# Alleghany-5419: Extracted 8 links.
# Alleghany-4885: Extracted 0 links.
# Alleghany-3339: Extracted 0 links.
# Alleghany-4471: Extracted 0 links.
# Alleghany-5323: Extracted 0 links.
# Alleghany-3116: Extracted 0 links.
# Alleghany-3119: Extracted 1 links.
# Alleghany-3335: Extracted 0 links.
# Alleghany-4911: Extracted 6 links.
# Alleghany-5414: Extracted 2 links.
# Alleghany-7132: Extracted 0 links.
# Alleghany-1133: Extracted 1 links.
# Alleghany-2372: Extracted 1 links.
# Alleghany-6223: Extracted 0 links.
# Alleghany-6116: Extracted 1 links.
# Alleghany-6232: Extracted 0 links.
# Alleghany-4879: Extracted 0 links.
# Alleghany-2213: Extracted 1 links.
# Alleghany-7121: Extracted 5 links.
# Alleghany-2389: Extracted 3 links.
# Alleghany-5112: Extracted 0 links.
# Alleghany-1121: Extracted 1 links.
# Alleghany-7211: Extracted 4 links.
# Alleghany-4251: Extracted 0 links.
# Alleghany-1122: Extracted 0 links.
# Alleghany-4411: Extracted 4 links.
# Alleghany-5418: Extracted 0 links.
# Alleghany-1152: Extracted 1 links.
# Alleghany-6212: Extracted 1 links.
# Alleghany-5241: Extracted 0 links.
# Alleghany-4881: Extracted 0 links.
# Alleghany-4523: Extracted 0 links.
# Alleghany-7213: Extracted 0 links.
# Alleghany-5411: Extracted 3 links.
# Alleghany-3325: Extracted 0 links.
# Alleghany-8111: Extracted 8 links.
# Alleghany-4842: Extracted 3 links.
# Alleghany-3331: Extracted 0 links.
# Alleghany-8121: Extracted 8 links.
# Alleghany-3328: Extracted 0 links.
# Alleghany-6219: Extracted 5 links.
# Alleghany-3121: Extracted 2 links.
# Alleghany-4522: Extracted 0 links.
# Alleghany-5311: Extracted 4 links.
# Alleghany-6242: Extracted 1 links.
# Alleghany-4852: Extracted 0 links.
# Alleghany-4234: Extracted 1 links.
# Alleghany-4246: Extracted 0 links.
# Alleghany-2379: Extracted 0 links.
# Alleghany-3311: Extracted 0 links.
# Alleghany-7212: Extracted 4 links.
# Alleghany-3117: Extracted 0 links.
# Alleghany-6211: Extracted 9 links.
# Alleghany-3334: Extracted 0 links.
# Alleghany-5331: Extracted 0 links.
# Alleghany-5413: Extracted 4 links.
# Batch 1 completed.
# Processing batch 2/5...
# Batch 2/5:   0%|          | 0/420 [00:00<?, ?it/s]
# Alleghany-7131: Extracted 0 links.
# Alleghany-2362: Extracted 6 links.
# Alleghany-8113: Extracted 0 links.
# Alleghany-2373: Extracted 4 links.
# Alleghany-4239: Extracted 1 links.
# Alleghany-4862: Extracted 0 links.
# Alleghany-4533: Extracted 0 links.
# Alleghany-1125: Extracted 0 links.
# Alleghany-3323: Extracted 0 links.
# Alleghany-3118: Extracted 0 links.
# Alleghany-4532: Extracted 0 links.
# Alleghany-3212: Extracted 0 links.
# Alleghany-3222: Extracted 0 links.
# Alleghany-3372: Extracted 0 links.
# Alleghany-5613: Extracted 0 links.
# Alleghany-8141: Extracted 0 links.
# Alleghany-3364: Extracted 0 links.
# Alleghany-5415: Extracted 1 links.
# Alleghany-3261: Extracted 0 links.
# Alleghany-1129: Extracted 0 links.
# Alleghany-5122: Extracted 0 links.
# Alleghany-4531: Extracted 0 links.
# Alleghany-6213: Extracted 10 links.
# Alleghany-3241: Extracted 0 links.
# Alleghany-7115: Extracted 1 links.
# Alleghany-3262: Extracted 1 links.
# Alleghany-5111: Extracted 0 links.
# Alleghany-2111: Extracted 0 links.
# Alleghany-3321: Extracted 0 links.
# Alleghany-5313: Extracted 1 links.
# Alleghany-1131: Extracted 0 links.
# Alleghany-9221: Extracted 8 links.
# Alleghany-3399: Extracted 2 links.
# Alleghany-4931: Extracted 0 links.
# Alleghany-7112: Extracted 0 links.
# Alleghany-4542: Extracted 0 links.
# Alleghany-4543: Extracted 0 links.
# Alleghany-4244: Extracted 1 links.
# Alleghany-3169: Extracted 0 links.
# Alleghany-4412: Extracted 0 links.
# Alleghany-5612: Extracted 0 links.
# Alleghany-4453: Extracted 1 links.
# Alleghany-4451: Extracted 6 links.
# Alleghany-3336: Extracted 0 links.
# Alleghany-5179: Extracted 0 links.
# Alleghany-3131: Extracted 1 links.
# Alleghany-2212: Extracted 0 links.
# Alleghany-1114: Extracted 1 links.
# Alleghany-3151: Extracted 0 links.
# Alleghany-3252: Extracted 0 links.
# Alleghany-5173: Extracted 0 links.
# Alleghany-9261: Extracted 3 links.
# Alleghany-3113: Extracted 0 links.
# Alleghany-3133: Extracted 0 links.
# Alleghany-8132: Extracted 0 links.
# Alleghany-5211: Extracted 0 links.
# Alleghany-4248: Extracted 0 links.
# Alleghany-8134: Extracted 6 links.
# Alleghany-5619: Extracted 1 links.
# Alleghany-5242: Extracted 5 links.
# Alleghany-3211: Extracted 0 links.
# Alleghany-5251: Extracted 0 links.
# Alleghany-3365: Extracted 0 links.
# Alleghany-4237: Extracted 0 links.
# Alleghany-7225: Extracted 20 links.
# Alleghany-4871: Extracted 0 links.
# Alleghany-4413: Extracted 6 links.
# Alleghany-3255: Extracted 0 links.
# Alleghany-5152: Extracted 0 links.
# Alleghany-4245: Extracted 0 links.
# Alleghany-4882: Extracted 1 links.
# Alleghany-3359: Extracted 0 links.
# Alleghany-3315: Extracted 0 links.
# Alleghany-3231: Extracted 3 links.
# Alleghany-5321: Extracted 0 links.
# Alleghany-3343: Extracted 0 links.
# Alleghany-3312: Extracted 0 links.
# Alleghany-3161: Extracted 0 links.
# Alleghany-1151: Extracted 1 links.
# Alleghany-5621: Extracted 2 links.
# Alleghany-9211: Extracted 20 links.
# Alleghany-2361: Extracted 15 links.
# Alleghany-4441: Extracted 5 links.
# Alleghany-3254: Extracted 0 links.
# Alleghany-6221: Extracted 0 links.
# Alleghany-3149: Extracted 0 links.
# Alleghany-6113: Extracted 0 links.
# Alleghany-3351: Extracted 0 links.
# Alleghany-1142: Extracted 1 links.
# Alleghany-3279: Extracted 0 links.
# Alleghany-2211: Extracted 1 links.
# Alleghany-3346: Extracted 0 links.
# Alleghany-4231: Extracted 0 links.
# Alleghany-4859: Extracted 0 links.
# Alleghany-4238: Extracted 0 links.
# Alleghany-4461: Extracted 0 links.
# Alleghany-5151: Extracted 0 links.
# Alleghany-2121: Extracted 0 links.
# Alleghany-5221: Extracted 5 links.
# Alleghany-5322: Extracted 0 links.
# Alleghany-6111: Extracted 5 links.
# Alleghany-3111: Extracted 0 links.
# Alleghany-4854: Extracted 0 links.
# Alleghany-5616: Extracted 0 links.
# Alleghany-4883: Extracted 0 links.
# Alleghany-3324: Extracted 0 links.
# Alleghany-3141: Extracted 0 links.
# Alleghany-3369: Extracted 0 links.
# Alleghany-4889: Extracted 0 links.
# Alleghany-7139: Extracted 9 links.
# Alleghany-5417: Extracted 1 links.
# Alleghany-6222: Extracted 1 links.
# Alleghany-2383: Extracted 8 links.
# Alleghany-5239: Extracted 4 links.
# Alleghany-4482: Extracted 0 links.
# Alleghany-6241: Extracted 2 links.
# Alleghany-8129: Extracted 1 links.
# Alleghany-8131: Extracted 24 links.
# Alleghany-5614: Extracted 0 links.
# Alleghany-1119: Extracted 12 links.
# Alleghany-4483: Extracted 0 links.
# Alleghany-5617: Extracted 6 links.
# Alleghany-3159: Extracted 0 links.
# Alleghany-2382: Extracted 8 links.
# Alleghany-4235: Extracted 0 links.
# Alleghany-3219: Extracted 3 links.
# Alleghany-4249: Extracted 1 links.
# Alleghany-8133: Extracted 1 links.
# Alleghany-6239: Extracted 1 links.
# Alleghany-9241: Extracted 3 links.
# Alleghany-5174: Extracted 0 links.
# Alleghany-5611: Extracted 2 links.
# Alleghany-3366: Extracted 0 links.
# Alleghany-5511: Extracted 0 links.
# Alleghany-4442: Extracted 4 links.
# Alleghany-3221: Extracted 0 links.
# Alleghany-3363: Extracted 0 links.
# Alleghany-3256: Extracted 0 links.
# Alleghany-9281: Extracted 0 links.
# Alleghany-4841: Extracted 0 links.
# Alleghany-3114: Extracted 0 links.
# Alleghany-6114: Extracted 1 links.
# Alleghany-4884: Extracted 1 links.
# Alleghany-7114: Extracted 0 links.
# Alleghany-5629: Extracted 0 links.
# Alleghany-5223: Extracted 0 links.
# Alleghany-1124: Extracted 0 links.
# Alleghany-7111: Extracted 0 links.
# Alleghany-1111: Extracted 0 links.
# Alleghany-9231: Extracted 2 links.
# Alleghany-3391: Extracted 0 links.
# Alleghany-4422: Extracted 0 links.
# Alleghany-5191: Extracted 0 links.
# Alleghany-4851: Extracted 0 links.
# Alleghany-4831: Extracted 0 links.
# Alleghany-4922: Extracted 0 links.
# Alleghany-4242: Extracted 0 links.
# Alleghany-6215: Extracted 0 links.
# Alleghany-7113: Extracted 1 links.
# Alleghany-8114: Extracted 2 links.
# Alleghany-8122: Extracted 2 links.
# Alleghany-6244: Extracted 3 links.
# Alleghany-9271: Extracted 0 links.
# Alleghany-5615: Extracted 0 links.
# Alleghany-4853: Extracted 1 links.
# Alleghany-5259: Extracted 0 links.
# Alleghany-3251: Extracted 0 links.
# Alleghany-3112: Extracted 0 links.
# Alleghany-3329: Extracted 0 links.
# Alleghany-3162: Extracted 0 links.
# Alleghany-1113: Extracted 0 links.
# Alleghany-4233: Extracted 0 links.
# Alleghany-6216: Extracted 2 links.
# Alleghany-3345: Extracted 1 links.
# Alleghany-4812: Extracted 0 links.
# Alleghany-8123: Extracted 0 links.
# Alleghany-3152: Extracted 0 links.
# Alleghany-4539: Extracted 0 links.
# Alleghany-3352: Extracted 0 links.
# Alleghany-3341: Extracted 0 links.
# Alleghany-8139: Extracted 3 links.
# Alleghany-5412: Extracted 4 links.
# Alleghany-4452: Extracted 2 links.
# Alleghany-4236: Extracted 0 links.
# Alleghany-3314: Extracted 0 links.
# Alleghany-1112: Extracted 0 links.
# Alleghany-2381: Extracted 2 links.
# Alleghany-5622: Extracted 0 links.
# Alleghany-3122: Extracted 0 links.
# Alleghany-4861: Extracted 0 links.
# Alleghany-9251: Extracted 0 links.
# Alleghany-7224: Extracted 1 links.
# Alleghany-4821: Extracted 0 links.
# Alleghany-7223: Extracted 1 links.
# Alleghany-5416: Extracted 4 links.
# Alleghany-3273: Extracted 0 links.
# Alleghany-1153: Extracted 0 links.
# Alleghany-4241: Extracted 0 links.
# Alleghany-6231: Extracted 3 links.
# Alleghany-6214: Extracted 1 links.
# Alleghany-6233: Extracted 2 links.
# Alleghany-5121: Extracted 0 links.
# Ashe-1132: Extracted 0 links.
# Ashe-3115: Extracted 0 links.
# Ashe-3362: Extracted 0 links.
# Ashe-5232: Extracted 0 links.
# Ashe-8112: Extracted 1 links.
# Ashe-3132: Extracted 0 links.
# Ashe-4481: Extracted 0 links.
# Ashe-6117: Extracted 2 links.
# Ashe-4243: Extracted 0 links.
# Ashe-5222: Extracted 5 links.
# Ashe-2131: Extracted 0 links.
# Ashe-4811: Extracted 0 links.
# Ashe-3313: Extracted 0 links.
# Ashe-4512: Extracted 0 links.
# Ashe-3361: Extracted 2 links.
# Ashe-4541: Extracted 0 links.
# Ashe-2371: Extracted 5 links.
# Ashe-4872: Extracted 0 links.
# Ashe-4832: Extracted 0 links.
# Ashe-5324: Extracted 0 links.
# Ashe-5182: Extracted 2 links.
# Ashe-3353: Extracted 0 links.
# Ashe-4431: Extracted 0 links.
# Ashe-3371: Extracted 1 links.
# Ashe-4921: Extracted 0 links.
# Ashe-3333: Extracted 0 links.
# Ashe-3379: Extracted 0 links.
# Ashe-4869: Extracted 0 links.
# Ashe-3274: Extracted 0 links.
# Ashe-4232: Extracted 0 links.
# Ashe-3322: Extracted 0 links.
# Ashe-5312: Extracted 33 links.
# Ashe-2123: Extracted 3 links.
# Ashe-3253: Extracted 0 links.
# Ashe-4511: Extracted 0 links.
# Ashe-3344: Extracted 0 links.
# Ashe-4247: Extracted 4 links.
# Ashe-3326: Extracted 0 links.
# Ashe-3342: Extracted 0 links.
# Ashe-3332: Extracted 0 links.
# Ashe-5231: Extracted 9 links.
# Ashe-6115: Extracted 0 links.
# Ashe-1141: Extracted 0 links.
# Ashe-3272: Extracted 1 links.
# Ashe-6112: Extracted 1 links.
# Ashe-3259: Extracted 0 links.
# Ashe-3327: Extracted 0 links.
# Ashe-4421: Extracted 0 links.
# Ashe-1123: Extracted 0 links.
# Ashe-3271: Extracted 0 links.
# Ashe-4855: Extracted 0 links.
# Ashe-6243: Extracted 3 links.
# Ashe-2122: Extracted 0 links.
# Ashe-5419: Extracted 9 links.
# Ashe-4885: Extracted 1 links.
# Ashe-3339: Extracted 0 links.
# Ashe-4471: Extracted 0 links.
# Ashe-5323: Extracted 1 links.
# Ashe-3116: Extracted 0 links.
# Ashe-3119: Extracted 0 links.
# Ashe-3335: Extracted 0 links.
# Ashe-4911: Extracted 10 links.
# Ashe-5414: Extracted 6 links.
# Ashe-7132: Extracted 0 links.
# Ashe-1133: Extracted 2 links.
# Ashe-2372: Extracted 1 links.
# Ashe-6223: Extracted 0 links.
# Ashe-6116: Extracted 2 links.
# Ashe-6232: Extracted 0 links.
# Ashe-4879: Extracted 0 links.
# Ashe-2213: Extracted 0 links.
# Ashe-7121: Extracted 5 links.
# Ashe-2389: Extracted 19 links.
# Ashe-5112: Extracted 0 links.
# Ashe-1121: Extracted 1 links.
# Ashe-7211: Extracted 14 links.
# Ashe-4251: Extracted 1 links.
# Ashe-1122: Extracted 0 links.
# Ashe-4411: Extracted 13 links.
# Ashe-5418: Extracted 5 links.
# Ashe-1152: Extracted 1 links.
# Ashe-6212: Extracted 12 links.
# Ashe-5241: Extracted 0 links.
# Ashe-4881: Extracted 2 links.
# Ashe-4523: Extracted 0 links.
# Ashe-7213: Extracted 0 links.
# Ashe-5411: Extracted 9 links.
# Ashe-3325: Extracted 0 links.
# Ashe-8111: Extracted 24 links.
# Ashe-4842: Extracted 7 links.
# Ashe-3331: Extracted 0 links.
# Ashe-8121: Extracted 19 links.
# Ashe-3328: Extracted 1 links.
# Ashe-6219: Extracted 8 links.
# Ashe-3121: Extracted 4 links.
# Ashe-4522: Extracted 0 links.
# Ashe-5311: Extracted 14 links.
# Ashe-6242: Extracted 2 links.
# Ashe-4852: Extracted 0 links.
# Ashe-4234: Extracted 0 links.
# Ashe-4246: Extracted 0 links.
# Ashe-2379: Extracted 0 links.
# Ashe-3311: Extracted 0 links.
# Ashe-7212: Extracted 5 links.
# Ashe-3117: Extracted 0 links.
# Ashe-6211: Extracted 24 links.
# Ashe-3334: Extracted 0 links.
# Ashe-5331: Extracted 0 links.
# Ashe-5413: Extracted 5 links.
# Ashe-7131: Extracted 0 links.
# Ashe-2362: Extracted 6 links.
# Ashe-8113: Extracted 0 links.
# Ashe-2373: Extracted 8 links.
# Ashe-4239: Extracted 2 links.
# Ashe-4862: Extracted 0 links.
# Ashe-4533: Extracted 0 links.
# Ashe-1125: Extracted 0 links.
# Ashe-3323: Extracted 0 links.
# Ashe-3118: Extracted 2 links.
# Ashe-4532: Extracted 0 links.
# Ashe-3212: Extracted 0 links.
# Ashe-3222: Extracted 0 links.
# Ashe-3372: Extracted 1 links.
# Ashe-5613: Extracted 1 links.
# Ashe-8141: Extracted 0 links.
# Ashe-3364: Extracted 1 links.
# Ashe-5415: Extracted 3 links.
# Ashe-3261: Extracted 0 links.
# Ashe-1129: Extracted 2 links.
# Ashe-5122: Extracted 0 links.
# Ashe-4531: Extracted 0 links.
# Ashe-6213: Extracted 26 links.
# Ashe-3241: Extracted 1 links.
# Ashe-7115: Extracted 0 links.
# Ashe-3262: Extracted 0 links.
# Ashe-5111: Extracted 0 links.
# Ashe-2111: Extracted 0 links.
# Ashe-3321: Extracted 1 links.
# Ashe-5313: Extracted 4 links.
# Ashe-1131: Extracted 1 links.
# Ashe-9221: Extracted 13 links.
# Ashe-3399: Extracted 5 links.
# Ashe-4931: Extracted 5 links.
# Ashe-7112: Extracted 0 links.
# Ashe-4542: Extracted 0 links.
# Ashe-4543: Extracted 0 links.
# Ashe-4244: Extracted 3 links.
# Ashe-3169: Extracted 0 links.
# Ashe-4412: Extracted 1 links.
# Ashe-5612: Extracted 0 links.
# Ashe-4453: Extracted 2 links.
# Ashe-4451: Extracted 17 links.
# Ashe-3336: Extracted 0 links.
# Ashe-5179: Extracted 0 links.
# Ashe-3131: Extracted 0 links.
# Ashe-2212: Extracted 0 links.
# Ashe-1114: Extracted 2 links.
# Ashe-3151: Extracted 0 links.
# Ashe-3252: Extracted 0 links.
# Ashe-5173: Extracted 0 links.
# Ashe-9261: Extracted 3 links.
# Ashe-3113: Extracted 0 links.
# Ashe-3133: Extracted 0 links.
# Ashe-8132: Extracted 0 links.
# Ashe-5211: Extracted 0 links.
# Ashe-4248: Extracted 0 links.
# Ashe-8134: Extracted 5 links.
# Ashe-5619: Extracted 6 links.
# Ashe-5242: Extracted 14 links.
# Ashe-3211: Extracted 1 links.
# Ashe-5251: Extracted 0 links.
# Ashe-3365: Extracted 0 links.
# Ashe-4237: Extracted 0 links.
# Ashe-7225: Extracted 53 links.
# Ashe-4871: Extracted 0 links.
# Ashe-4413: Extracted 11 links.
# Ashe-3255: Extracted 0 links.
# Ashe-5152: Extracted 0 links.
# Ashe-4245: Extracted 0 links.
# Ashe-4882: Extracted 0 links.
# Ashe-3359: Extracted 2 links.
# Ashe-3315: Extracted 0 links.
# Ashe-3231: Extracted 2 links.
# Ashe-5321: Extracted 3 links.
# Ashe-3343: Extracted 0 links.
# Ashe-3312: Extracted 0 links.
# Ashe-3161: Extracted 0 links.
# Ashe-1151: Extracted 0 links.
# Ashe-5621: Extracted 2 links.
# Ashe-9211: Extracted 45 links.
# Ashe-2361: Extracted 33 links.
# Ashe-4441: Extracted 11 links.
# Ashe-3254: Extracted 0 links.
# Ashe-6221: Extracted 2 links.
# Ashe-3149: Extracted 1 links.
# Ashe-6113: Extracted 0 links.
# Ashe-3351: Extracted 1 links.
# Ashe-1142: Extracted 0 links.
# Ashe-3279: Extracted 0 links.
# Ashe-2211: Extracted 3 links.
# Ashe-3346: Extracted 0 links.
# Ashe-4231: Extracted 2 links.
# Ashe-4859: Extracted 1 links.
# Ashe-4238: Extracted 1 links.
# Ashe-4461: Extracted 0 links.
# Ashe-5151: Extracted 0 links.
# Ashe-2121: Extracted 0 links.
# Ashe-5221: Extracted 10 links.
# Ashe-5322: Extracted 3 links.
# Ashe-6111: Extracted 11 links.
# Ashe-3111: Extracted 0 links.
# Ashe-4854: Extracted 0 links.
# Ashe-5616: Extracted 2 links.
# Ashe-4883: Extracted 0 links.
# Ashe-3324: Extracted 0 links.
# Ashe-3141: Extracted 1 links.
# Ashe-3369: Extracted 0 links.
# Ashe-4889: Extracted 0 links.
# Batch 2 completed.
# Processing batch 3/5...
# Batch 3/5:   0%|          | 0/420 [00:00<?, ?it/s]
# Ashe-7139: Extracted 4 links.
# Ashe-5417: Extracted 2 links.
# Ashe-6222: Extracted 0 links.
# Ashe-2383: Extracted 9 links.
# Ashe-5239: Extracted 8 links.
# Ashe-4482: Extracted 0 links.
# Ashe-6241: Extracted 15 links.
# Ashe-8129: Extracted 6 links.
# Ashe-8131: Extracted 67 links.
# Ashe-5614: Extracted 1 links.
# Ashe-1119: Extracted 16 links.
# Ashe-4483: Extracted 0 links.
# Ashe-5617: Extracted 26 links.
# Ashe-3159: Extracted 0 links.
# Ashe-2382: Extracted 27 links.
# Ashe-4235: Extracted 0 links.
# Ashe-3219: Extracted 3 links.
# Ashe-4249: Extracted 4 links.
# Ashe-8133: Extracted 17 links.
# Ashe-6239: Extracted 1 links.
# Ashe-9241: Extracted 2 links.
# Ashe-5174: Extracted 0 links.
# Ashe-5611: Extracted 0 links.
# Ashe-3366: Extracted 0 links.
# Ashe-5511: Extracted 4 links.
# Ashe-4442: Extracted 12 links.
# Ashe-3221: Extracted 0 links.
# Ashe-3363: Extracted 0 links.
# Ashe-3256: Extracted 0 links.
# Ashe-9281: Extracted 0 links.
# Ashe-4841: Extracted 0 links.
# Ashe-3114: Extracted 0 links.
# Ashe-6114: Extracted 0 links.
# Ashe-4884: Extracted 2 links.
# Ashe-7114: Extracted 0 links.
# Ashe-5629: Extracted 0 links.
# Ashe-5223: Extracted 1 links.
# Ashe-1124: Extracted 0 links.
# Ashe-7111: Extracted 0 links.
# Ashe-1111: Extracted 0 links.
# Ashe-9231: Extracted 2 links.
# Ashe-3391: Extracted 1 links.
# Ashe-4422: Extracted 0 links.
# Ashe-5191: Extracted 0 links.
# Ashe-4851: Extracted 0 links.
# Ashe-4831: Extracted 0 links.
# Ashe-4922: Extracted 1 links.
# Ashe-4242: Extracted 0 links.
# Ashe-6215: Extracted 0 links.
# Ashe-7113: Extracted 0 links.
# Ashe-8114: Extracted 9 links.
# Ashe-8122: Extracted 4 links.
# Ashe-6244: Extracted 4 links.
# Ashe-9271: Extracted 0 links.
# Ashe-5615: Extracted 1 links.
# Ashe-4853: Extracted 0 links.
# Ashe-5259: Extracted 0 links.
# Ashe-3251: Extracted 0 links.
# Ashe-3112: Extracted 0 links.
# Ashe-3329: Extracted 0 links.
# Ashe-3162: Extracted 0 links.
# Ashe-1113: Extracted 0 links.
# Ashe-4233: Extracted 1 links.
# Ashe-6216: Extracted 5 links.
# Ashe-3345: Extracted 0 links.
# Ashe-4812: Extracted 0 links.
# Ashe-8123: Extracted 1 links.
# Ashe-3152: Extracted 0 links.
# Ashe-4539: Extracted 0 links.
# Ashe-3352: Extracted 0 links.
# Ashe-3341: Extracted 0 links.
# Ashe-8139: Extracted 7 links.
# Ashe-5412: Extracted 8 links.
# Ashe-4452: Extracted 5 links.
# Ashe-4236: Extracted 2 links.
# Ashe-3314: Extracted 0 links.
# Ashe-1112: Extracted 0 links.
# Ashe-2381: Extracted 14 links.
# Ashe-5622: Extracted 2 links.
# Ashe-3122: Extracted 0 links.
# Ashe-4861: Extracted 0 links.
# Ashe-9251: Extracted 1 links.
# Ashe-7224: Extracted 0 links.
# Ashe-4821: Extracted 0 links.
# Ashe-7223: Extracted 0 links.
# Ashe-5416: Extracted 7 links.
# Ashe-3273: Extracted 0 links.
# Ashe-1153: Extracted 1 links.
# Ashe-4241: Extracted 0 links.
# Ashe-6231: Extracted 4 links.
# Ashe-6214: Extracted 1 links.
# Ashe-6233: Extracted 5 links.
# Ashe-5121: Extracted 2 links.
# Avery-1132: Extracted 0 links.
# Avery-3115: Extracted 0 links.
# Avery-3362: Extracted 0 links.
# Avery-5232: Extracted 0 links.
# Avery-8112: Extracted 0 links.
# Avery-3132: Extracted 0 links.
# Avery-4481: Extracted 0 links.
# Avery-6117: Extracted 0 links.
# Avery-4243: Extracted 0 links.
# Avery-5222: Extracted 2 links.
# Avery-2131: Extracted 1 links.
# Avery-4811: Extracted 0 links.
# Avery-3313: Extracted 0 links.
# Avery-4512: Extracted 0 links.
# Avery-3361: Extracted 0 links.
# Avery-4541: Extracted 0 links.
# Avery-2371: Extracted 1 links.
# Avery-4872: Extracted 0 links.
# Avery-4832: Extracted 0 links.
# Avery-5324: Extracted 0 links.
# Avery-5182: Extracted 1 links.
# Avery-3353: Extracted 0 links.
# Avery-4431: Extracted 0 links.
# Avery-3371: Extracted 5 links.
# Avery-4921: Extracted 0 links.
# Avery-3333: Extracted 0 links.
# Avery-3379: Extracted 0 links.
# Avery-4869: Extracted 0 links.
# Avery-3274: Extracted 0 links.
# Avery-4232: Extracted 0 links.
# Avery-3322: Extracted 0 links.
# Avery-5312: Extracted 29 links.
# Avery-2123: Extracted 1 links.
# Avery-3253: Extracted 0 links.
# Avery-4511: Extracted 0 links.
# Avery-3344: Extracted 0 links.
# Avery-4247: Extracted 2 links.
# Avery-3326: Extracted 0 links.
# Avery-3342: Extracted 0 links.
# Avery-3332: Extracted 0 links.
# Avery-5231: Extracted 2 links.
# Avery-6115: Extracted 0 links.
# Avery-1141: Extracted 0 links.
# Avery-3272: Extracted 0 links.
# Avery-6112: Extracted 1 links.
# Avery-3259: Extracted 0 links.
# Avery-3327: Extracted 0 links.
# Avery-4421: Extracted 0 links.
# Avery-1123: Extracted 0 links.
# Avery-3271: Extracted 0 links.
# Avery-4855: Extracted 0 links.
# Avery-6243: Extracted 1 links.
# Avery-2122: Extracted 0 links.
# Avery-5419: Extracted 9 links.
# Avery-4885: Extracted 1 links.
# Avery-3339: Extracted 0 links.
# Avery-4471: Extracted 0 links.
# Avery-5323: Extracted 2 links.
# Avery-3116: Extracted 0 links.
# Avery-3119: Extracted 1 links.
# Avery-3335: Extracted 0 links.
# Avery-4911: Extracted 9 links.
# Avery-5414: Extracted 4 links.
# Avery-7132: Extracted 0 links.
# Avery-1133: Extracted 0 links.
# Avery-2372: Extracted 4 links.
# Avery-6223: Extracted 0 links.
# Avery-6116: Extracted 1 links.
# Avery-6232: Extracted 0 links.
# Avery-4879: Extracted 0 links.
# Avery-2213: Extracted 0 links.
# Avery-7121: Extracted 8 links.
# Avery-2389: Extracted 12 links.
# Avery-5112: Extracted 0 links.
# Avery-1121: Extracted 0 links.
# Avery-7211: Extracted 28 links.
# Avery-4251: Extracted 0 links.
# Avery-1122: Extracted 0 links.
# Avery-4411: Extracted 9 links.
# Avery-5418: Extracted 3 links.
# Avery-1152: Extracted 1 links.
# Avery-6212: Extracted 10 links.
# Avery-5241: Extracted 0 links.
# Avery-4881: Extracted 0 links.
# Avery-4523: Extracted 0 links.
# Avery-7213: Extracted 0 links.
# Avery-5411: Extracted 11 links.
# Avery-3325: Extracted 0 links.
# Avery-8111: Extracted 17 links.
# Avery-4842: Extracted 5 links.
# Avery-3331: Extracted 0 links.
# Avery-8121: Extracted 26 links.
# Avery-3328: Extracted 0 links.
# Avery-6219: Extracted 4 links.
# Avery-3121: Extracted 1 links.
# Avery-4522: Extracted 0 links.
# Avery-5311: Extracted 8 links.
# Avery-6242: Extracted 1 links.
# Avery-4852: Extracted 0 links.
# Avery-4234: Extracted 1 links.
# Avery-4246: Extracted 0 links.
# Avery-2379: Extracted 1 links.
# Avery-3311: Extracted 0 links.
# Avery-7212: Extracted 9 links.
# Avery-3117: Extracted 0 links.
# Avery-6211: Extracted 17 links.
# Avery-3334: Extracted 0 links.
# Avery-5331: Extracted 0 links.
# Avery-5413: Extracted 4 links.
# Avery-7131: Extracted 0 links.
# Avery-2362: Extracted 12 links.
# Avery-8113: Extracted 0 links.
# Avery-2373: Extracted 4 links.
# Avery-4239: Extracted 3 links.
# Avery-4862: Extracted 0 links.
# Avery-4533: Extracted 0 links.
# Avery-1125: Extracted 0 links.
# Avery-3323: Extracted 3 links.
# Avery-3118: Extracted 1 links.
# Avery-4532: Extracted 0 links.
# Avery-3212: Extracted 0 links.
# Avery-3222: Extracted 0 links.
# Avery-3372: Extracted 0 links.
# Avery-5613: Extracted 1 links.
# Avery-8141: Extracted 0 links.
# Avery-3364: Extracted 0 links.
# Avery-5415: Extracted 3 links.
# Avery-3261: Extracted 0 links.
# Avery-1129: Extracted 0 links.
# Avery-5122: Extracted 0 links.
# Avery-4531: Extracted 0 links.
# Avery-6213: Extracted 25 links.
# Avery-3241: Extracted 2 links.
# Avery-7115: Extracted 1 links.
# Avery-3262: Extracted 0 links.
# Avery-5111: Extracted 0 links.
# Avery-2111: Extracted 0 links.
# Avery-3321: Extracted 0 links.
# Avery-5313: Extracted 5 links.
# Avery-1131: Extracted 0 links.
# Avery-9221: Extracted 13 links.
# Avery-3399: Extracted 5 links.
# Avery-4931: Extracted 2 links.
# Avery-7112: Extracted 0 links.
# Avery-4542: Extracted 0 links.
# Avery-4543: Extracted 0 links.
# Avery-4244: Extracted 1 links.
# Avery-3169: Extracted 0 links.
# Avery-4412: Extracted 0 links.
# Avery-5612: Extracted 0 links.
# Avery-4453: Extracted 1 links.
# Avery-4451: Extracted 10 links.
# Avery-3336: Extracted 0 links.
# Avery-5179: Extracted 0 links.
# Avery-3131: Extracted 0 links.
# Avery-2212: Extracted 3 links.
# Avery-1114: Extracted 1 links.
# Avery-3151: Extracted 0 links.
# Avery-3252: Extracted 0 links.
# Avery-5173: Extracted 0 links.
# Avery-9261: Extracted 4 links.
# Avery-3113: Extracted 0 links.
# Avery-3133: Extracted 0 links.
# Avery-8132: Extracted 0 links.
# Avery-5211: Extracted 0 links.
# Avery-4248: Extracted 0 links.
# Avery-8134: Extracted 11 links.
# Avery-5619: Extracted 3 links.
# Avery-5242: Extracted 10 links.
# Avery-3211: Extracted 1 links.
# Avery-5251: Extracted 0 links.
# Avery-3365: Extracted 0 links.
# Avery-4237: Extracted 0 links.
# Avery-7225: Extracted 49 links.
# Avery-4871: Extracted 0 links.
# Avery-4413: Extracted 7 links.
# Avery-3255: Extracted 0 links.
# Avery-5152: Extracted 0 links.
# Avery-4245: Extracted 0 links.
# Avery-4882: Extracted 0 links.
# Avery-3359: Extracted 0 links.
# Avery-3315: Extracted 0 links.
# Avery-3231: Extracted 0 links.
# Avery-5321: Extracted 3 links.
# Avery-3343: Extracted 0 links.
# Avery-3312: Extracted 0 links.
# Avery-3161: Extracted 0 links.
# Avery-1151: Extracted 1 links.
# Avery-5621: Extracted 2 links.
# Avery-9211: Extracted 37 links.
# Avery-2361: Extracted 20 links.
# Avery-4441: Extracted 10 links.
# Avery-3254: Extracted 0 links.
# Avery-6221: Extracted 3 links.
# Avery-3149: Extracted 0 links.
# Avery-6113: Extracted 1 links.
# Avery-3351: Extracted 0 links.
# Avery-1142: Extracted 0 links.
# Avery-3279: Extracted 1 links.
# Avery-2211: Extracted 3 links.
# Avery-3346: Extracted 0 links.
# Avery-4231: Extracted 1 links.
# Avery-4859: Extracted 0 links.
# Avery-4238: Extracted 2 links.
# Avery-4461: Extracted 0 links.
# Avery-5151: Extracted 0 links.
# Avery-2121: Extracted 0 links.
# Avery-5221: Extracted 7 links.
# Avery-5322: Extracted 1 links.
# Avery-6111: Extracted 15 links.
# Avery-3111: Extracted 0 links.
# Avery-4854: Extracted 0 links.
# Avery-5616: Extracted 1 links.
# Avery-4883: Extracted 0 links.
# Avery-3324: Extracted 0 links.
# Avery-3141: Extracted 0 links.
# Avery-3369: Extracted 0 links.
# Avery-4889: Extracted 0 links.
# Avery-7139: Extracted 12 links.
# Avery-5417: Extracted 1 links.
# Avery-6222: Extracted 1 links.
# Avery-2383: Extracted 8 links.
# Avery-5239: Extracted 7 links.
# Avery-4482: Extracted 0 links.
# Avery-6241: Extracted 15 links.
# Avery-8129: Extracted 5 links.
# Avery-8131: Extracted 42 links.
# Avery-5614: Extracted 0 links.
# Avery-1119: Extracted 5 links.
# Avery-4483: Extracted 0 links.
# Avery-5617: Extracted 26 links.
# Avery-3159: Extracted 0 links.
# Avery-2382: Extracted 18 links.
# Avery-4235: Extracted 0 links.
# Avery-3219: Extracted 2 links.
# Avery-4249: Extracted 3 links.
# Avery-8133: Extracted 8 links.
# Avery-6239: Extracted 2 links.
# Avery-9241: Extracted 3 links.
# Avery-5174: Extracted 0 links.
# Avery-5611: Extracted 0 links.
# Avery-3366: Extracted 0 links.
# Avery-5511: Extracted 3 links.
# Avery-4442: Extracted 8 links.
# Avery-3221: Extracted 0 links.
# Avery-3363: Extracted 0 links.
# Avery-3256: Extracted 2 links.
# Avery-9281: Extracted 0 links.
# Avery-4841: Extracted 1 links.
# Avery-3114: Extracted 0 links.
# Avery-6114: Extracted 0 links.
# Avery-4884: Extracted 1 links.
# Avery-7114: Extracted 0 links.
# Avery-5629: Extracted 0 links.
# Avery-5223: Extracted 2 links.
# Avery-1124: Extracted 0 links.
# Avery-7111: Extracted 2 links.
# Avery-1111: Extracted 0 links.
# Avery-9231: Extracted 1 links.
# Avery-3391: Extracted 0 links.
# Avery-4422: Extracted 0 links.
# Avery-5191: Extracted 0 links.
# Avery-4851: Extracted 0 links.
# Avery-4831: Extracted 0 links.
# Avery-4922: Extracted 0 links.
# Avery-4242: Extracted 1 links.
# Avery-6215: Extracted 0 links.
# Avery-7113: Extracted 3 links.
# Avery-8114: Extracted 4 links.
# Avery-8122: Extracted 2 links.
# Avery-6244: Extracted 4 links.
# Avery-9271: Extracted 0 links.
# Avery-5615: Extracted 2 links.
# Avery-4853: Extracted 0 links.
# Avery-5259: Extracted 0 links.
# Avery-3251: Extracted 0 links.
# Avery-3112: Extracted 0 links.
# Avery-3329: Extracted 0 links.
# Avery-3162: Extracted 0 links.
# Avery-1113: Extracted 0 links.
# Avery-4233: Extracted 3 links.
# Avery-6216: Extracted 5 links.
# Avery-3345: Extracted 0 links.
# Avery-4812: Extracted 0 links.
# Avery-8123: Extracted 3 links.
# Avery-3152: Extracted 0 links.
# Avery-4539: Extracted 0 links.
# Avery-3352: Extracted 0 links.
# Avery-3341: Extracted 0 links.
# Avery-8139: Extracted 7 links.
# Avery-5412: Extracted 6 links.
# Avery-4452: Extracted 2 links.
# Avery-4236: Extracted 1 links.
# Avery-3314: Extracted 0 links.
# Avery-1112: Extracted 0 links.
# Avery-2381: Extracted 4 links.
# Avery-5622: Extracted 0 links.
# Avery-3122: Extracted 0 links.
# Avery-4861: Extracted 0 links.
# Avery-9251: Extracted 0 links.
# Avery-7224: Extracted 1 links.
# Avery-4821: Extracted 0 links.
# Avery-7223: Extracted 3 links.
# Avery-5416: Extracted 3 links.
# Avery-3273: Extracted 0 links.
# Avery-1153: Extracted 0 links.
# Avery-4241: Extracted 0 links.
# Avery-6231: Extracted 4 links.
# Avery-6214: Extracted 1 links.
# Avery-6233: Extracted 1 links.
# Avery-5121: Extracted 0 links.
# Buncombe-1132: Extracted 1 links.
# Buncombe-3115: Extracted 1 links.
# Buncombe-3362: Extracted 1 links.
# Buncombe-5232: Extracted 0 links.
# Buncombe-8112: Extracted 37 links.
# Buncombe-3132: Extracted 0 links.
# Buncombe-4481: Extracted 0 links.
# Buncombe-6117: Extracted 38 links.
# Buncombe-4243: Extracted 2 links.
# Buncombe-5222: Extracted 88 links.
# Buncombe-2131: Extracted 1 links.
# Buncombe-4811: Extracted 0 links.
# Buncombe-3313: Extracted 0 links.
# Buncombe-4512: Extracted 0 links.
# Buncombe-3361: Extracted 0 links.
# Buncombe-4541: Extracted 0 links.
# Batch 3 completed.
# Processing batch 4/5...
# Batch 4/5:   0%|          | 0/420 [00:00<?, ?it/s]
# Buncombe-2371: Extracted 24 links.
# Buncombe-4872: Extracted 1 links.
# Buncombe-4832: Extracted 0 links.
# Buncombe-5324: Extracted 6 links.
# Buncombe-5182: Extracted 23 links.
# Buncombe-3353: Extracted 2 links.
# Buncombe-4431: Extracted 0 links.
# Buncombe-3371: Extracted 33 links.
# Buncombe-4921: Extracted 3 links.
# Buncombe-3333: Extracted 0 links.
# Buncombe-3379: Extracted 1 links.
# Buncombe-4869: Extracted 0 links.
# Buncombe-3274: Extracted 0 links.
# Buncombe-4232: Extracted 4 links.
# Buncombe-3322: Extracted 0 links.
# Buncombe-5312: Extracted 100 links.
# Buncombe-2123: Extracted 4 links.
# Buncombe-3253: Extracted 1 links.
# Buncombe-4511: Extracted 0 links.
# Buncombe-3344: Extracted 0 links.
# Buncombe-4247: Extracted 14 links.
# Buncombe-3326: Extracted 0 links.
# Buncombe-3342: Extracted 2 links.
# Buncombe-3332: Extracted 5 links.
# Buncombe-5231: Extracted 0 links.
# Buncombe-6115: Extracted 9 links.
# Buncombe-1141: Extracted 0 links.
# Buncombe-3272: Extracted 3 links.
# Buncombe-6112: Extracted 4 links.
# Buncombe-3259: Extracted 3 links.
# Buncombe-3327: Extracted 16 links.
# Buncombe-4421: Extracted 0 links.
# Buncombe-1123: Extracted 0 links.
# Buncombe-3271: Extracted 2 links.
# Buncombe-4855: Extracted 4 links.
# Buncombe-6243: Extracted 25 links.
# Buncombe-2122: Extracted 0 links.
# Buncombe-5419: Extracted 100 links.
# Buncombe-4885: Extracted 9 links.
# Buncombe-3339: Extracted 0 links.
# Buncombe-4471: Extracted 0 links.
# Buncombe-5323: Extracted 7 links.
# Buncombe-3116: Extracted 3 links.
# Buncombe-3119: Extracted 8 links.
# Buncombe-3335: Extracted 6 links.
# Buncombe-4911: Extracted 20 links.
# Buncombe-5414: Extracted 57 links.
# Buncombe-7132: Extracted 0 links.
# Buncombe-1133: Extracted 2 links.
# Buncombe-2372: Extracted 11 links.
# Buncombe-6223: Extracted 5 links.
# Buncombe-6116: Extracted 0 links.
# Buncombe-6232: Extracted 2 links.
# Buncombe-4879: Extracted 6 links.
# Buncombe-2213: Extracted 6 links.
# Buncombe-7121: Extracted 55 links.
# Buncombe-2389: Extracted 100 links.
# Buncombe-5112: Extracted 0 links.
# Buncombe-1121: Extracted 2 links.
# Buncombe-7211: Extracted 100 links.
# Buncombe-4251: Extracted 7 links.
# Buncombe-1122: Extracted 0 links.
# Buncombe-4411: Extracted 55 links.
# Buncombe-5418: Extracted 86 links.
# Buncombe-1152: Extracted 7 links.
# Buncombe-6212: Extracted 100 links.
# Buncombe-5241: Extracted 8 links.
# Buncombe-4881: Extracted 3 links.
# Buncombe-4523: Extracted 0 links.
# Buncombe-7213: Extracted 0 links.
# Buncombe-5411: Extracted 100 links.
# Buncombe-3325: Extracted 1 links.
# Buncombe-8111: Extracted 100 links.
# Buncombe-4842: Extracted 55 links.
# Buncombe-3331: Extracted 1 links.
# Buncombe-8121: Extracted 0 links.
# Buncombe-3328: Extracted 10 links.
# Buncombe-6219: Extracted 100 links.
# Buncombe-3121: Extracted 48 links.
# Buncombe-4522: Extracted 0 links.
# Buncombe-5311: Extracted 100 links.
# Buncombe-6242: Extracted 20 links.
# Buncombe-4852: Extracted 0 links.
# Buncombe-4234: Extracted 27 links.
# Buncombe-4246: Extracted 4 links.
# Buncombe-2379: Extracted 5 links.
# Buncombe-3311: Extracted 1 links.
# Buncombe-7212: Extracted 28 links.
# Buncombe-3117: Extracted 0 links.
# Buncombe-6211: Extracted 100 links.
# Buncombe-3334: Extracted 3 links.
# Buncombe-5331: Extracted 2 links.
# Buncombe-5413: Extracted 100 links.
# Buncombe-7131: Extracted 4 links.
# Buncombe-2362: Extracted 100 links.
# Buncombe-8113: Extracted 12 links.
# Buncombe-2373: Extracted 49 links.
# Buncombe-4239: Extracted 28 links.
# Buncombe-4862: Extracted 0 links.
# Buncombe-4533: Extracted 0 links.
# Buncombe-1125: Extracted 0 links.
# Buncombe-3323: Extracted 12 links.
# Buncombe-3118: Extracted 35 links.
# Buncombe-4532: Extracted 0 links.
# Buncombe-3212: Extracted 0 links.
# Buncombe-3222: Extracted 2 links.
# Buncombe-3372: Extracted 3 links.
# Buncombe-5613: Extracted 45 links.
# Buncombe-8141: Extracted 0 links.
# Buncombe-3364: Extracted 5 links.
# Buncombe-5415: Extracted 79 links.
# Buncombe-3261: Extracted 13 links.
# Buncombe-1129: Extracted 5 links.
# Buncombe-5122: Extracted 12 links.
# Buncombe-4531: Extracted 0 links.
# Buncombe-6213: Extracted 100 links.
# Buncombe-3241: Extracted 3 links.
# Buncombe-7115: Extracted 31 links.
# Buncombe-3262: Extracted 0 links.
# Buncombe-5111: Extracted 0 links.
# Buncombe-2111: Extracted 2 links.
# Buncombe-3321: Extracted 1 links.
# Buncombe-5313: Extracted 60 links.
# Buncombe-1131: Extracted 0 links.
# Buncombe-9221: Extracted 73 links.
# Buncombe-3399: Extracted 63 links.
# Buncombe-4931: Extracted 24 links.
# Buncombe-7112: Extracted 6 links.
# Buncombe-4542: Extracted 0 links.
# Buncombe-4543: Extracted 0 links.
# Buncombe-4244: Extracted 27 links.
# Buncombe-3169: Extracted 0 links.
# Buncombe-4412: Extracted 21 links.
# Buncombe-5612: Extracted 3 links.
# Buncombe-4453: Extracted 44 links.
# Buncombe-4451: Extracted 100 links.
# Buncombe-3336: Extracted 3 links.
# Buncombe-5179: Extracted 0 links.
# Buncombe-3131: Extracted 0 links.
# Buncombe-2212: Extracted 3 links.
# Buncombe-1114: Extracted 6 links.
# Buncombe-3151: Extracted 0 links.
# Buncombe-3252: Extracted 0 links.
# Buncombe-5173: Extracted 0 links.
# Buncombe-9261: Extracted 20 links.
# Buncombe-3113: Extracted 0 links.
# Buncombe-3133: Extracted 3 links.
# Buncombe-8132: Extracted 1 links.
# Buncombe-5211: Extracted 0 links.
# Buncombe-4248: Extracted 3 links.
# Buncombe-8134: Extracted 100 links.
# Buncombe-5619: Extracted 46 links.
# Buncombe-5242: Extracted 100 links.
# Buncombe-3211: Extracted 2 links.
# Buncombe-5251: Extracted 1 links.
# Buncombe-3365: Extracted 0 links.
# Buncombe-4237: Extracted 21 links.
# Buncombe-7225: Extracted 100 links.
# Buncombe-4871: Extracted 4 links.
# Buncombe-4413: Extracted 81 links.
# Buncombe-3255: Extracted 0 links.
# Buncombe-5152: Extracted 0 links.
# Buncombe-4245: Extracted 1 links.
# Buncombe-4882: Extracted 17 links.
# Buncombe-3359: Extracted 6 links.
# Buncombe-3315: Extracted 2 links.
# Buncombe-3231: Extracted 43 links.
# Buncombe-5321: Extracted 32 links.
# Buncombe-3343: Extracted 3 links.
# Buncombe-3312: Extracted 0 links.
# Buncombe-3161: Extracted 0 links.
# Buncombe-1151: Extracted 2 links.
# Buncombe-5621: Extracted 14 links.
# Buncombe-9211: Extracted 100 links.
# Buncombe-2361: Extracted 100 links.
# Buncombe-4441: Extracted 100 links.
# Buncombe-3254: Extracted 4 links.
# Buncombe-6221: Extracted 17 links.
# Buncombe-3149: Extracted 6 links.
# Buncombe-6113: Extracted 12 links.
# Buncombe-3351: Extracted 1 links.
# ...
# Burke-4911: Extracted 10 links.
# Burke-5414: Extracted 0 links.
# Burke-7132: Extracted 0 links.
# Burke-1133: Extracted 3 links.
# Burke-2372: Extracted 3 links.
# Burke-6223: Extracted 0 links.
# Burke-6116: Extracted 7 links.
# Burke-6232: Extracted 0 links.
# Burke-4879: Extracted 0 links.
# Burke-2213: Extracted 3 links.
# Burke-7121: Extracted 16 links.
# Burke-2389: Extracted 22 links.
# Burke-5112: Extracted 0 links.
# Burke-1121: Extracted 1 links.
# Burke-7211: Extracted 15 links.
# Burke-4251: Extracted 1 links.
# Burke-1122: Extracted 0 links.
# Burke-4411: Extracted 24 links.
# Burke-5418: Extracted 7 links.
# Burke-1152: Extracted 4 links.
# Burke-6212: Extracted 31 links.
# Burke-5241: Extracted 0 links.
# Burke-4881: Extracted 2 links.
# Burke-4523: Extracted 0 links.
# Burke-7213: Extracted 0 links.
# Burke-5411: Extracted 0 links.
# Burke-3325: Extracted 0 links.
# Burke-8111: Extracted 66 links.
# Burke-4842: Extracted 14 links.
# Burke-3331: Extracted 0 links.
# Burke-8121: Extracted 68 links.
# Burke-3328: Extracted 0 links.
# Burke-6219: Extracted 30 links.
# Burke-3121: Extracted 9 links.
# Burke-4522: Extracted 0 links.
# Burke-5311: Extracted 45 links.
# Burke-6242: Extracted 3 links.
# Burke-4852: Extracted 0 links.
# Burke-4234: Extracted 1 links.
# Burke-4246: Extracted 0 links.
# Burke-2379: Extracted 4 links.
# Burke-3311: Extracted 0 links.
# Burke-7212: Extracted 10 links.
# Burke-3117: Extracted 0 links.
# Burke-6211: Extracted 100 links.
# Burke-3334: Extracted 0 links.
# Burke-5331: Extracted 0 links.
# Burke-5413: Extracted 20 links.
# Burke-7131: Extracted 0 links.
# Burke-2362: Extracted 13 links.
# Burke-8113: Extracted 3 links.
# Burke-2373: Extracted 11 links.
# Burke-4239: Extracted 8 links.
# Burke-4862: Extracted 0 links.
# Burke-4533: Extracted 0 links.
# Burke-1125: Extracted 1 links.
# Burke-3323: Extracted 4 links.
# Burke-3118: Extracted 6 links.
# Burke-4532: Extracted 0 links.
# Burke-3212: Extracted 0 links.
# Burke-3222: Extracted 3 links.
# Burke-3372: Extracted 0 links.
# Burke-5613: Extracted 4 links.
# Burke-8141: Extracted 0 links.
# Batch 4 completed.
# Processing batch 5/5...
# Batch 5/5:   0%|          | 0/420 [00:00<?, ?it/s]
# Burke-3364: Extracted 3 links.
# Burke-5415: Extracted 6 links.
# Burke-3261: Extracted 0 links.
# Burke-1129: Extracted 0 links.
# Burke-5122: Extracted 0 links.
# Burke-4531: Extracted 0 links.
# Burke-6213: Extracted 100 links.
# Burke-3241: Extracted 0 links.
# Burke-7115: Extracted 8 links.
# Burke-3262: Extracted 0 links.
# Burke-5111: Extracted 0 links.
# Burke-2111: Extracted 1 links.
# Burke-3321: Extracted 1 links.
# Burke-5313: Extracted 6 links.
# Burke-1131: Extracted 0 links.
# Burke-9221: Extracted 36 links.
# Burke-3399: Extracted 5 links.
# Burke-4931: Extracted 4 links.
# Burke-7112: Extracted 1 links.
# Burke-4542: Extracted 0 links.
# Burke-4543: Extracted 0 links.
# Burke-4244: Extracted 2 links.
# Burke-3169: Extracted 0 links.
# Burke-4412: Extracted 6 links.
# Burke-5612: Extracted 0 links.
# Burke-4453: Extracted 2 links.
# Burke-4451: Extracted 48 links.
# Burke-3336: Extracted 1 links.
# Burke-5179: Extracted 0 links.
# Burke-3131: Extracted 0 links.
# Burke-2212: Extracted 0 links.
# Burke-1114: Extracted 3 links.
# Burke-3151: Extracted 4 links.
# Burke-3252: Extracted 1 links.
# Burke-5173: Extracted 0 links.
# Burke-9261: Extracted 7 links.
# Burke-3113: Extracted 0 links.
# Burke-3133: Extracted 7 links.
# Burke-8132: Extracted 0 links.
# Burke-5211: Extracted 0 links.
# Burke-4248: Extracted 0 links.
# Burke-8134: Extracted 23 links.
# Burke-5619: Extracted 10 links.
# Burke-5242: Extracted 28 links.
# Burke-3211: Extracted 2 links.
# Burke-5251: Extracted 0 links.
# Burke-3365: Extracted 0 links.
# Burke-4237: Extracted 1 links.
# Burke-7225: Extracted 100 links.
# Burke-4871: Extracted 0 links.
# Burke-4413: Extracted 25 links.
# Burke-3255: Extracted 0 links.
# Burke-5152: Extracted 0 links.
# Burke-4245: Extracted 0 links.
# Burke-4882: Extracted 1 links.
# Burke-3359: Extracted 2 links.
# Burke-3315: Extracted 0 links.
# Burke-3231: Extracted 8 links.
# Burke-5321: Extracted 11 links.
# Burke-3343: Extracted 0 links.
# Burke-3312: Extracted 0 links.
# Burke-3161: Extracted 1 links.
# Burke-1151: Extracted 0 links.
# Burke-5621: Extracted 0 links.
# Burke-9211: Extracted 66 links.
# Burke-2361: Extracted 39 links.
# Burke-4441: Extracted 26 links.
# Burke-3254: Extracted 0 links.
# Burke-6221: Extracted 7 links.
# Burke-3149: Extracted 5 links.
# Burke-6113: Extracted 1 links.
# Burke-3351: Extracted 0 links.
# Burke-1142: Extracted 1 links.
# Burke-3279: Extracted 2 links.
# Burke-2211: Extracted 2 links.
# Burke-3346: Extracted 0 links.
# Burke-4231: Extracted 3 links.
# Burke-4859: Extracted 0 links.
# Burke-4238: Extracted 6 links.
# Burke-4461: Extracted 0 links.
# Burke-5151: Extracted 0 links.
# Burke-2121: Extracted 0 links.
# Burke-5221: Extracted 18 links.
# Burke-5322: Extracted 3 links.
# Burke-6111: Extracted 34 links.
# Burke-3111: Extracted 0 links.
# Burke-4854: Extracted 0 links.
# Burke-5616: Extracted 6 links.
# Burke-4883: Extracted 0 links.
# Burke-3324: Extracted 1 links.
# Burke-3141: Extracted 0 links.
# Burke-3369: Extracted 0 links.
# Burke-4889: Extracted 0 links.
# Burke-7139: Extracted 17 links.
# Burke-5417: Extracted 5 links.
# Burke-6222: Extracted 7 links.
# Burke-2383: Extracted 22 links.
# Burke-5239: Extracted 24 links.
# Burke-4482: Extracted 0 links.
# Burke-6241: Extracted 52 links.
# Burke-8129: Extracted 22 links.
# Burke-8131: Extracted 100 links.
# Burke-5614: Extracted 0 links.
# Burke-1119: Extracted 7 links.
# Burke-4483: Extracted 0 links.
# Burke-5617: Extracted 57 links.
# Burke-3159: Extracted 0 links.
# Burke-2382: Extracted 43 links.
# Burke-4235: Extracted 1 links.
# Burke-3219: Extracted 3 links.
# Burke-4249: Extracted 9 links.
# Burke-8133: Extracted 24 links.
# Burke-6239: Extracted 7 links.
# Burke-9241: Extracted 6 links.
# Burke-5174: Extracted 0 links.
# Burke-5611: Extracted 3 links.
# Burke-3366: Extracted 0 links.
# Burke-5511: Extracted 5 links.
# Burke-4442: Extracted 16 links.
# Burke-3221: Extracted 0 links.
# Burke-3363: Extracted 4 links.
# Burke-3256: Extracted 0 links.
# Burke-9281: Extracted 3 links.
# Burke-4841: Extracted 4 links.
# Burke-3114: Extracted 0 links.
# Burke-6114: Extracted 1 links.
# Burke-4884: Extracted 10 links.
# Burke-7114: Extracted 0 links.
# Burke-5629: Extracted 2 links.
# Burke-5223: Extracted 11 links.
# Burke-1124: Extracted 0 links.
# Burke-7111: Extracted 2 links.
# Burke-1111: Extracted 0 links.
# Burke-9231: Extracted 4 links.
# Burke-3391: Extracted 0 links.
# Burke-4422: Extracted 0 links.
# Burke-5191: Extracted 0 links.
# Burke-4851: Extracted 0 links.
# Burke-4831: Extracted 0 links.
# Burke-4922: Extracted 0 links.
# Burke-4242: Extracted 0 links.
# Burke-6215: Extracted 2 links.
# Burke-7113: Extracted 4 links.
# Burke-8114: Extracted 8 links.
# Burke-8122: Extracted 5 links.
# Burke-6244: Extracted 16 links.
# Burke-9271: Extracted 0 links.
# Burke-5615: Extracted 5 links.
# Burke-4853: Extracted 1 links.
# Burke-5259: Extracted 0 links.
# Burke-3251: Extracted 0 links.
# Burke-3112: Extracted 0 links.
# Burke-3329: Extracted 1 links.
# Burke-3162: Extracted 0 links.
# Burke-1113: Extracted 3 links.
# Burke-4233: Extracted 4 links.
# Burke-6216: Extracted 12 links.
# Burke-3345: Extracted 0 links.
# Burke-4812: Extracted 0 links.
# Burke-8123: Extracted 5 links.
# Burke-3152: Extracted 0 links.
# Burke-4539: Extracted 0 links.
# Burke-3352: Extracted 0 links.
# Burke-3341: Extracted 0 links.
# Burke-8139: Extracted 13 links.
# Burke-5412: Extracted 16 links.
# Burke-4452: Extracted 7 links.
# Burke-4236: Extracted 12 links.
# Burke-3314: Extracted 0 links.
# Burke-1112: Extracted 0 links.
# Burke-2381: Extracted 17 links.
# Burke-5622: Extracted 3 links.
# Burke-3122: Extracted 0 links.
# Burke-4861: Extracted 0 links.
# Burke-9251: Extracted 2 links.
# Burke-7224: Extracted 5 links.
# Burke-4821: Extracted 1 links.
# Burke-7223: Extracted 3 links.
# Burke-5416: Extracted 22 links.
# Burke-3273: Extracted 2 links.
# Burke-1153: Extracted 0 links.
# Burke-4241: Extracted 3 links.
# Burke-6231: Extracted 7 links.
# Burke-6214: Extracted 6 links.
# Burke-6233: Extracted 11 links.
# Burke-5121: Extracted 1 links.
# Caldwell-1132: Extracted 1 links.
# Caldwell-3115: Extracted 0 links.
# Caldwell-3362: Extracted 0 links.
# Caldwell-5232: Extracted 0 links.
# Caldwell-8112: Extracted 6 links.
# Caldwell-3132: Extracted 1 links.
# Caldwell-4481: Extracted 0 links.
# Caldwell-6117: Extracted 2 links.
# Caldwell-4243: Extracted 0 links.
# Caldwell-5222: Extracted 19 links.
# Caldwell-2131: Extracted 0 links.
# Caldwell-4811: Extracted 0 links.
# Caldwell-3313: Extracted 0 links.
# Caldwell-4512: Extracted 0 links.
# Caldwell-3361: Extracted 0 links.
# Caldwell-4541: Extracted 0 links.
# Caldwell-2371: Extracted 6 links.
# Caldwell-4872: Extracted 0 links.
# Caldwell-4832: Extracted 0 links.
# Caldwell-5324: Extracted 1 links.
# Caldwell-5182: Extracted 2 links.
# Caldwell-3353: Extracted 0 links.
# Caldwell-4431: Extracted 0 links.
# Caldwell-3371: Extracted 14 links.
# Caldwell-4921: Extracted 0 links.
# Caldwell-3333: Extracted 0 links.
# Caldwell-3379: Extracted 3 links.
# Caldwell-4869: Extracted 0 links.
# Caldwell-3274: Extracted 0 links.
# Caldwell-4232: Extracted 6 links.
# Caldwell-3322: Extracted 0 links.
# Caldwell-5312: Extracted 43 links.
# Caldwell-2123: Extracted 1 links.
# Caldwell-3253: Extracted 0 links.
# Caldwell-4511: Extracted 0 links.
# Caldwell-3344: Extracted 1 links.
# Caldwell-4247: Extracted 5 links.
# Caldwell-3326: Extracted 1 links.
# Caldwell-3342: Extracted 0 links.
# Caldwell-3332: Extracted 3 links.
# Caldwell-5231: Extracted 10 links.
# Caldwell-6115: Extracted 0 links.
# Caldwell-1141: Extracted 0 links.
# Caldwell-3272: Extracted 1 links.
# Caldwell-6112: Extracted 3 links.
# Caldwell-3259: Extracted 0 links.
# Caldwell-3327: Extracted 4 links.
# Caldwell-4421: Extracted 0 links.
# Caldwell-1123: Extracted 0 links.
# Caldwell-3271: Extracted 0 links.
# Caldwell-4855: Extracted 0 links.
# Caldwell-6243: Extracted 8 links.
# Caldwell-2122: Extracted 0 links.
# Caldwell-5419: Extracted 26 links.
# Caldwell-4885: Extracted 3 links.
# Caldwell-3339: Extracted 3 links.
# Caldwell-4471: Extracted 0 links.
# Caldwell-5323: Extracted 1 links.
# Caldwell-3116: Extracted 0 links.
# Caldwell-3119: Extracted 0 links.
# Caldwell-3335: Extracted 0 links.
# Caldwell-4911: Extracted 6 links.
# Caldwell-5414: Extracted 8 links.
# Caldwell-7132: Extracted 1 links.
# Caldwell-1133: Extracted 1 links.
# Caldwell-2372: Extracted 2 links.
# Caldwell-6223: Extracted 1 links.
# Caldwell-6116: Extracted 5 links.
# Caldwell-6232: Extracted 0 links.
# Caldwell-4879: Extracted 0 links.
# Caldwell-2213: Extracted 1 links.
# Caldwell-7121: Extracted 10 links.
# Caldwell-2389: Extracted 22 links.
# Caldwell-5112: Extracted 0 links.
# Caldwell-1121: Extracted 0 links.
# Caldwell-7211: Extracted 10 links.
# Caldwell-4251: Extracted 3 links.
# Caldwell-1122: Extracted 0 links.
# Caldwell-4411: Extracted 42 links.
# Caldwell-5418: Extracted 15 links.
# Caldwell-1152: Extracted 0 links.
# Caldwell-6212: Extracted 24 links.
# Caldwell-5241: Extracted 3 links.
# Caldwell-4881: Extracted 0 links.
# Caldwell-4523: Extracted 0 links.
# Caldwell-7213: Extracted 0 links.
# Caldwell-5411: Extracted 27 links.
# Caldwell-3325: Extracted 0 links.
# Caldwell-8111: Extracted 67 links.
# Caldwell-4842: Extracted 22 links.
# Caldwell-3331: Extracted 0 links.
# Caldwell-8121: Extracted 63 links.
# Caldwell-3328: Extracted 2 links.
# Caldwell-6219: Extracted 11 links.
# Caldwell-3121: Extracted 6 links.
# Caldwell-4522: Extracted 0 links.
# Caldwell-5311: Extracted 44 links.
# Caldwell-6242: Extracted 5 links.
# Caldwell-4852: Extracted 1 links.
# Caldwell-4234: Extracted 2 links.
# Caldwell-4246: Extracted 3 links.
# Caldwell-2379: Extracted 0 links.
# Caldwell-3311: Extracted 0 links.
# Caldwell-7212: Extracted 6 links.
# Caldwell-3117: Extracted 0 links.
# Caldwell-6211: Extracted 73 links.
# Caldwell-3334: Extracted 0 links.
# Caldwell-5331: Extracted 0 links.
# Caldwell-5413: Extracted 11 links.
# Caldwell-7131: Extracted 0 links.
# Caldwell-2362: Extracted 0 links.
# Caldwell-8113: Extracted 4 links.
# Caldwell-2373: Extracted 14 links.
# Caldwell-4239: Extracted 5 links.
# Caldwell-4862: Extracted 0 links.
# Caldwell-4533: Extracted 0 links.
# Caldwell-1125: Extracted 0 links.
# Caldwell-3323: Extracted 3 links.
# Caldwell-3118: Extracted 2 links.
# Caldwell-4532: Extracted 0 links.
# Caldwell-3212: Extracted 2 links.
# Caldwell-3222: Extracted 3 links.
# Caldwell-3372: Extracted 5 links.
# Caldwell-5613: Extracted 2 links.
# Caldwell-8141: Extracted 0 links.
# Caldwell-3364: Extracted 0 links.
# Caldwell-5415: Extracted 1 links.
# Caldwell-3261: Extracted 2 links.
# Caldwell-1129: Extracted 3 links.
# Caldwell-5122: Extracted 1 links.
# Caldwell-4531: Extracted 0 links.
# Caldwell-6213: Extracted 73 links.
# Caldwell-3241: Extracted 1 links.
# Caldwell-7115: Extracted 2 links.
# Caldwell-3262: Extracted 1 links.
# Caldwell-5111: Extracted 0 links.
# Caldwell-2111: Extracted 0 links.
# Caldwell-3321: Extracted 0 links.
# Caldwell-5313: Extracted 10 links.
# Caldwell-1131: Extracted 0 links.
# Caldwell-9221: Extracted 27 links.
# Caldwell-3399: Extracted 14 links.
# Caldwell-4931: Extracted 4 links.
# Caldwell-7112: Extracted 0 links.
# Caldwell-4542: Extracted 0 links.
# Caldwell-4543: Extracted 0 links.
# Caldwell-4244: Extracted 1 links.
# Caldwell-3169: Extracted 0 links.
# Caldwell-4412: Extracted 7 links.
# Caldwell-5612: Extracted 0 links.
# Caldwell-4453: Extracted 3 links.
# Caldwell-4451: Extracted 46 links.
# Caldwell-3336: Extracted 0 links.
# Caldwell-5179: Extracted 0 links.
# Caldwell-3131: Extracted 0 links.
# Caldwell-2212: Extracted 1 links.
# Caldwell-1114: Extracted 0 links.
# Caldwell-3151: Extracted 3 links.
# Caldwell-3252: Extracted 0 links.
# Caldwell-5173: Extracted 0 links.
# Caldwell-9261: Extracted 2 links.
# Caldwell-3113: Extracted 0 links.
# Caldwell-3133: Extracted 1 links.
# Caldwell-8132: Extracted 0 links.
# Caldwell-5211: Extracted 0 links.
# Caldwell-4248: Extracted 1 links.
# Caldwell-8134: Extracted 20 links.
# Caldwell-5619: Extracted 11 links.
# Caldwell-5242: Extracted 0 links.
# Caldwell-3211: Extracted 0 links.
# Caldwell-5251: Extracted 0 links.
# Caldwell-3365: Extracted 0 links.
# Caldwell-4237: Extracted 1 links.
# Caldwell-7225: Extracted 0 links.
# Caldwell-4871: Extracted 0 links.
# Caldwell-4413: Extracted 26 links.
# Caldwell-3255: Extracted 2 links.
# Caldwell-5152: Extracted 0 links.
# Caldwell-4245: Extracted 0 links.
# Caldwell-4882: Extracted 5 links.
# Caldwell-3359: Extracted 0 links.
# Caldwell-3315: Extracted 0 links.
# Caldwell-3231: Extracted 3 links.
# Caldwell-5321: Extracted 11 links.
# Caldwell-3343: Extracted 0 links.
# Caldwell-3312: Extracted 1 links.
# Caldwell-3161: Extracted 0 links.
# Caldwell-1151: Extracted 0 links.
# Caldwell-5621: Extracted 4 links.
# Caldwell-9211: Extracted 74 links.
# Caldwell-2361: Extracted 34 links.
# Caldwell-4441: Extracted 20 links.
# Caldwell-3254: Extracted 1 links.
# Caldwell-6221: Extracted 3 links.
# Caldwell-3149: Extracted 4 links.
# Caldwell-6113: Extracted 2 links.
# Caldwell-3351: Extracted 0 links.
# Caldwell-1142: Extracted 0 links.
# Caldwell-3279: Extracted 0 links.
# Caldwell-2211: Extracted 4 links.
# Caldwell-3346: Extracted 0 links.
# Caldwell-4231: Extracted 4 links.
# Caldwell-4859: Extracted 1 links.
# Caldwell-4238: Extracted 8 links.
# Caldwell-4461: Extracted 0 links.
# Caldwell-5151: Extracted 0 links.
# Caldwell-2121: Extracted 0 links.
# Caldwell-5221: Extracted 18 links.
# Caldwell-5322: Extracted 4 links.
# Caldwell-6111: Extracted 33 links.
# Caldwell-3111: Extracted 0 links.
# Caldwell-4854: Extracted 1 links.
# Caldwell-5616: Extracted 2 links.
# Caldwell-4883: Extracted 1 links.
# Caldwell-3324: Extracted 1 links.
# Caldwell-3141: Extracted 0 links.
# Caldwell-3369: Extracted 1 links.
# Caldwell-4889: Extracted 1 links.
# Caldwell-7139: Extracted 18 links.
# Caldwell-5417: Extracted 7 links.
# Caldwell-6222: Extracted 4 links.
# Caldwell-2383: Extracted 22 links.
# Caldwell-5239: Extracted 22 links.
# Caldwell-4482: Extracted 0 links.
# Caldwell-6241: Extracted 35 links.
# Caldwell-8129: Extracted 25 links.
# Caldwell-8131: Extracted 0 links.
# Caldwell-5614: Extracted 4 links.
# Caldwell-1119: Extracted 6 links.
# Caldwell-4483: Extracted 0 links.
# Caldwell-5617: Extracted 42 links.
# Caldwell-3159: Extracted 0 links.
# Caldwell-2382: Extracted 37 links.
# Caldwell-4235: Extracted 1 links.
# Batch 5 completed.
# All tasks from batch 1 to 5 completed. Links are written to all_links.txt.

# %%
await main(start_batch=6, end_batch=7)
# Out:
# Processing batch 6/7...
# Batch 6/7:   0%|          | 0/420 [00:00<?, ?it/s]
# Caldwell-9251: Extracted 0 links.
# Caldwell-3274: Extracted 0 links.
# Caldwell-4453: Extracted 3 links.
# Caldwell-2131: Extracted 0 links.
# Caldwell-5414: Extracted 8 links.
# Caldwell-1129: Extracted 3 links.
# Caldwell-7132: Extracted 1 links.
# Caldwell-3219: Extracted 11 links.
# Caldwell-6233: Extracted 4 links.
# Caldwell-6214: Extracted 7 links.
# Caldwell-3118: Extracted 2 links.
# Caldwell-4511: Extracted 0 links.
# Caldwell-3371: Extracted 14 links.
# Caldwell-3254: Extracted 1 links.
# Caldwell-4237: Extracted 0 links.
# Caldwell-3221: Extracted 0 links.
# Caldwell-3116: Extracted 0 links.
# Caldwell-4512: Extracted 0 links.
# Caldwell-6239: Extracted 2 links.
# Caldwell-5411: Extracted 27 links.
# Caldwell-5617: Extracted 42 links.
# Caldwell-3113: Extracted 0 links.
# Caldwell-2382: Extracted 37 links.
# Caldwell-5231: Extracted 10 links.
# Caldwell-5312: Extracted 43 links.
# Caldwell-7112: Extracted 2 links.
# Caldwell-2361: Extracted 34 links.
# Caldwell-4884: Extracted 8 links.
# Caldwell-8131: Extracted 100 links.
# Caldwell-7139: Extracted 18 links.
# Caldwell-3313: Extracted 0 links.
# Caldwell-3271: Extracted 0 links.
# Caldwell-8122: Extracted 10 links.
# Caldwell-4236: Extracted 7 links.
# Caldwell-3339: Extracted 3 links.
# Caldwell-5251: Extracted 0 links.
# Caldwell-3363: Extracted 1 links.
# Caldwell-4421: Extracted 0 links.
# Caldwell-4248: Extracted 1 links.
# Caldwell-4441: Extracted 0 links.
# Caldwell-3259: Extracted 0 links.
# Caldwell-6215: Extracted 0 links.
# Caldwell-3253: Extracted 0 links.
# Caldwell-3324: Extracted 1 links.
# Caldwell-4249: Extracted 5 links.
# Caldwell-6114: Extracted 2 links.
# Caldwell-4821: Extracted 0 links.
# Caldwell-5614: Extracted 4 links.
# Caldwell-5239: Extracted 22 links.
# Caldwell-5211: Extracted 0 links.
# Caldwell-1112: Extracted 0 links.
# Caldwell-7131: Extracted 0 links.
# Caldwell-5152: Extracted 0 links.
# Caldwell-3119: Extracted 2 links.
# Caldwell-2383: Extracted 0 links.
# Caldwell-3342: Extracted 0 links.
# Caldwell-3312: Extracted 1 links.
# Caldwell-3279: Extracted 0 links.
# Caldwell-2373: Extracted 14 links.
# Caldwell-3314: Extracted 0 links.
# Caldwell-4811: Extracted 0 links.
# Caldwell-2389: Extracted 22 links.
# Caldwell-7121: Extracted 10 links.
# Caldwell-2123: Extracted 1 links.
# Caldwell-3255: Extracted 2 links.
# Caldwell-4431: Extracted 0 links.
# Caldwell-3311: Extracted 0 links.
# Caldwell-3365: Extracted 0 links.
# Caldwell-3327: Extracted 4 links.
# Caldwell-9211: Extracted 0 links.
# Caldwell-8112: Extracted 6 links.
# Caldwell-4442: Extracted 12 links.
# Caldwell-2372: Extracted 2 links.
# Caldwell-8129: Extracted 25 links.
# Caldwell-8133: Extracted 22 links.
# Caldwell-5622: Extracted 3 links.
# Caldwell-4247: Extracted 5 links.
# Catawba-4471: Extracted 0 links.
# Catawba-6216: Extracted 29 links.
# Catawba-5331: Extracted 1 links.
# Catawba-4812: Extracted 2 links.
# Catawba-2121: Extracted 0 links.
# Catawba-7224: Extracted 14 links.
# Catawba-9271: Extracted 0 links.
# Catawba-4412: Extracted 0 links.
# Catawba-9281: Extracted 7 links.
# Catawba-6221: Extracted 9 links.
# Catawba-4543: Extracted 0 links.
# Catawba-3132: Extracted 8 links.
# Catawba-4542: Extracted 0 links.
# Catawba-2211: Extracted 6 links.
# Catawba-6222: Extracted 11 links.
# Catawba-5321: Extracted 25 links.
# Catawba-6219: Extracted 31 links.
# Catawba-5615: Extracted 10 links.
# Catawba-9221: Extracted 56 links.
# Catawba-5413: Extracted 41 links.
# Catawba-4882: Extracted 9 links.
# Catawba-1113: Extracted 1 links.
# Catawba-3211: Extracted 0 links.
# Catawba-3379: Extracted 7 links.
# Catawba-4481: Extracted 0 links.
# Catawba-3341: Extracted 2 links.
# Catawba-5324: Extracted 7 links.
# Catawba-7114: Extracted 0 links.
# Catawba-7225: Extracted 100 links.
# Catawba-1132: Extracted 0 links.
# Catawba-3361: Extracted 0 links.
# Catawba-4532: Extracted 0 links.
# Catawba-4881: Extracted 6 links.
# Catawba-1152: Extracted 4 links.
# Catawba-5242: Extracted 100 links.
# Catawba-5191: Extracted 0 links.
# Catawba-5415: Extracted 22 links.
# Catawba-3366: Extracted 0 links.
# Catawba-1122: Extracted 0 links.
# Catawba-3114: Extracted 0 links.
# Catawba-4523: Extracted 0 links.
# Catawba-7223: Extracted 12 links.
# Catawba-4871: Extracted 0 links.
# Catawba-5223: Extracted 10 links.
# Catawba-3322: Extracted 3 links.
# Catawba-6241: Extracted 89 links.
# Catawba-4883: Extracted 3 links.
# Catawba-4921: Extracted 0 links.
# Catawba-5619: Extracted 26 links.
# Catawba-3315: Extracted 0 links.
# Catawba-1123: Extracted 2 links.
# Catawba-1141: Extracted 0 links.
# Catawba-3333: Extracted 0 links.
# Catawba-5621: Extracted 4 links.
# Catawba-3169: Extracted 2 links.
# Catawba-6232: Extracted 0 links.
# Catawba-9231: Extracted 0 links.
# Catawba-1119: Extracted 23 links.
# Catawba-2122: Extracted 0 links.
# Catawba-3115: Extracted 0 links.
# Catawba-5173: Extracted 0 links.
# Catawba-4241: Extracted 0 links.
# Catawba-3325: Extracted 0 links.
# Catawba-8134: Extracted 0 links.
# Catawba-3121: Extracted 0 links.
# Catawba-4862: Extracted 0 links.
# Catawba-3241: Extracted 0 links.
# Catawba-7115: Extracted 5 links.
# Catawba-3399: Extracted 48 links.
# Catawba-3133: Extracted 9 links.
# Catawba-4413: Extracted 0 links.
# Catawba-8141: Extracted 0 links.
# Catawba-4841: Extracted 24 links.
# Catawba-3343: Extracted 0 links.
# Catawba-7211: Extracted 23 links.
# Catawba-4832: Extracted 1 links.
# Catawba-5179: Extracted 0 links.
# Catawba-5322: Extracted 14 links.
# Catawba-4245: Extracted 0 links.
# Catawba-4246: Extracted 4 links.
# Catawba-5241: Extracted 3 links.
# Catawba-4244: Extracted 20 links.
# Catawba-3346: Extracted 0 links.
# Catawba-8123: Extracted 12 links.
# Catawba-1151: Extracted 1 links.
# Catawba-5111: Extracted 0 links.
# Catawba-3351: Extracted 2 links.
# Catawba-1111: Extracted 0 links.
# Catawba-3262: Extracted 2 links.
# Catawba-2213: Extracted 0 links.
# Catawba-6117: Extracted 7 links.
# Catawba-3353: Extracted 4 links.
# Catawba-3117: Extracted 0 links.
# Catawba-7111: Extracted 8 links.
# Catawba-3272: Extracted 1 links.
# Catawba-4233: Extracted 12 links.
# Catawba-4931: Extracted 0 links.
# Catawba-6244: Extracted 36 links.
# Catawba-1142: Extracted 5 links.
# Catawba-3336: Extracted 1 links.
# Catawba-4854: Extracted 1 links.
# Catawba-3141: Extracted 0 links.
# Catawba-3231: Extracted 34 links.
# Catawba-4235: Extracted 3 links.
# Catawba-9241: Extracted 8 links.
# Catawba-1153: Extracted 0 links.
# Catawba-4539: Extracted 0 links.
# Catawba-2362: Extracted 43 links.
# Catawba-4911: Extracted 10 links.
# Catawba-5611: Extracted 8 links.
# Catawba-3251: Extracted 2 links.
# Catawba-7113: Extracted 0 links.
# Catawba-3352: Extracted 2 links.
# Catawba-6213: Extracted 100 links.
# Catawba-1125: Extracted 0 links.
# Catawba-5259: Extracted 1 links.
# Catawba-4422: Extracted 0 links.
# Catawba-6116: Extracted 25 links.
# Catawba-4879: Extracted 1 links.
# Catawba-5221: Extracted 42 links.
# Catawba-5182: Extracted 5 links.
# Catawba-3332: Extracted 6 links.
# Catawba-5222: Extracted 34 links.
# Catawba-7212: Extracted 11 links.
# Catawba-5417: Extracted 14 links.
# Catawba-3369: Extracted 2 links.
# Catawba-3131: Extracted 0 links.
# Catawba-3326: Extracted 3 links.
# Catawba-5311: Extracted 79 links.
# Catawba-3149: Extracted 7 links.
# Catawba-4861: Extracted 0 links.
# Catawba-5174: Extracted 0 links.
# Catawba-5151: Extracted 0 links.
# Catawba-4852: Extracted 2 links.
# Catawba-3359: Extracted 3 links.
# Catawba-3321: Extracted 0 links.
# Catawba-4483: Extracted 0 links.
# Catawba-1133: Extracted 2 links.
# Catawba-3161: Extracted 0 links.
# Catawba-4842: Extracted 62 links.
# Catawba-6111: Extracted 64 links.
# Catawba-9261: Extracted 0 links.
# Catawba-3222: Extracted 10 links.
# Catawba-4853: Extracted 6 links.
# Catawba-5412: Extracted 66 links.
# Catawba-4232: Extracted 15 links.
# Catawba-3329: Extracted 10 links.
# Catawba-4885: Extracted 2 links.
# Catawba-4243: Extracted 5 links.
# Catawba-3112: Extracted 1 links.
# Catawba-2379: Extracted 5 links.
# Catawba-4451: Extracted 96 links.
# Catawba-4889: Extracted 0 links.
# Catawba-3334: Extracted 2 links.
# Catawba-5416: Extracted 85 links.
# Catawba-1124: Extracted 0 links.
# Catawba-3252: Extracted 5 links.
# Catawba-3331: Extracted 4 links.
# Catawba-3256: Extracted 1 links.
# Catawba-4231: Extracted 11 links.
# Catawba-6223: Extracted 2 links.
# Catawba-3152: Extracted 1 links.
# Catawba-5418: Extracted 42 links.
# Catawba-5511: Extracted 28 links.
# Catawba-3151: Extracted 6 links.
# Catawba-1121: Extracted 0 links.
# Catawba-4872: Extracted 0 links.
# Catawba-5112: Extracted 0 links.
# Catawba-8121: Extracted 100 links.
# Catawba-4239: Extracted 15 links.
# Catawba-5613: Extracted 24 links.
# Catawba-6242: Extracted 1 links.
# Catawba-5122: Extracted 1 links.
# Catawba-8111: Extracted 100 links.
# Catawba-3122: Extracted 0 links.
# Catawba-3111: Extracted 1 links.
# Catawba-4452: Extracted 19 links.
# Catawba-4234: Extracted 19 links.
# Catawba-1131: Extracted 0 links.
# Catawba-5121: Extracted 2 links.
# Catawba-4869: Extracted 0 links.
# Catawba-3162: Extracted 0 links.
# Catawba-3328: Extracted 4 links.
# Catawba-5616: Extracted 20 links.
# Catawba-6211: Extracted 100 links.
# Catawba-7213: Extracted 0 links.
# Catawba-3362: Extracted 0 links.
# Catawba-4859: Extracted 6 links.
# Catawba-3273: Extracted 1 links.
# Catawba-5232: Extracted 0 links.
# Catawba-3261: Extracted 10 links.
# Catawba-4482: Extracted 0 links.
# Catawba-4541: Extracted 0 links.
# Catawba-6115: Extracted 1 links.
# Catawba-5323: Extracted 8 links.
# Catawba-4238: Extracted 57 links.
# Catawba-8114: Extracted 49 links.
# Catawba-4922: Extracted 2 links.
# Catawba-5313: Extracted 20 links.
# Catawba-5629: Extracted 6 links.
# Catawba-8139: Extracted 31 links.
# Catawba-2111: Extracted 0 links.
# Catawba-3372: Extracted 15 links.
# Catawba-3364: Extracted 0 links.
# Catawba-3344: Extracted 2 links.
# Catawba-4251: Extracted 2 links.
# Catawba-4851: Extracted 3 links.
# Catawba-4461: Extracted 0 links.
# Catawba-2371: Extracted 19 links.
# Catawba-4522: Extracted 0 links.
# Catawba-3335: Extracted 9 links.
# Catawba-6112: Extracted 4 links.
# Catawba-2212: Extracted 0 links.
# Catawba-4533: Extracted 0 links.
# Catawba-3159: Extracted 3 links.
# Catawba-3345: Extracted 3 links.
# Catawba-5612: Extracted 0 links.
# Catawba-4531: Extracted 0 links.
# Catawba-3212: Extracted 0 links.
# Catawba-4242: Extracted 2 links.
# Catawba-8132: Extracted 0 links.
# Catawba-6231: Extracted 10 links.
# Catawba-6243: Extracted 8 links.
# Catawba-4831: Extracted 0 links.
# Catawba-4855: Extracted 0 links.
# Catawba-3323: Extracted 6 links.
# Catawba-3391: Extracted 13 links.
# Catawba-2381: Extracted 73 links.
# Catawba-1114: Extracted 0 links.
# Catawba-6113: Extracted 3 links.
# Catawba-5419: Extracted 68 links.
# Catawba-6212: Extracted 92 links.
# Catawba-4411: Extracted 0 links.
# Catawba-8113: Extracted 5 links.
# Catawba-9251: Extracted 5 links.
# Catawba-3274: Extracted 0 links.
# Catawba-4453: Extracted 11 links.
# Catawba-2131: Extracted 0 links.
# Catawba-5414: Extracted 18 links.
# Catawba-1129: Extracted 1 links.
# Catawba-7132: Extracted 2 links.
# Catawba-3219: Extracted 8 links.
# Catawba-6233: Extracted 27 links.
# Catawba-6214: Extracted 17 links.
# Catawba-3118: Extracted 11 links.
# Catawba-4511: Extracted 0 links.
# Catawba-3371: Extracted 58 links.
# Catawba-3254: Extracted 2 links.
# Catawba-4237: Extracted 19 links.
# Catawba-3221: Extracted 4 links.
# Catawba-3116: Extracted 5 links.
# Catawba-4512: Extracted 0 links.
# Catawba-6239: Extracted 4 links.
# Catawba-5411: Extracted 100 links.
# Catawba-5617: Extracted 100 links.
# Catawba-3113: Extracted 0 links.
# Catawba-2382: Extracted 100 links.
# Catawba-5231: Extracted 27 links.
# Catawba-5312: Extracted 100 links.
# Catawba-7112: Extracted 5 links.
# Catawba-2361: Extracted 100 links.
# Catawba-4884: Extracted 12 links.
# Catawba-8131: Extracted 100 links.
# Catawba-7139: Extracted 56 links.
# Catawba-3313: Extracted 0 links.
# Catawba-3271: Extracted 3 links.
# Catawba-8122: Extracted 20 links.
# Catawba-4236: Extracted 21 links.
# Catawba-3339: Extracted 8 links.
# Catawba-5251: Extracted 0 links.
# Catawba-3363: Extracted 0 links.
# Catawba-4421: Extracted 0 links.
# Catawba-4248: Extracted 1 links.
# Catawba-4441: Extracted 70 links.
# Catawba-3259: Extracted 4 links.
# Catawba-6215: Extracted 14 links.
# Catawba-3253: Extracted 2 links.
# Catawba-3324: Extracted 1 links.
# Catawba-4249: Extracted 0 links.
# Catawba-6114: Extracted 5 links.
# Catawba-4821: Extracted 0 links.
# Catawba-5614: Extracted 20 links.
# Catawba-5239: Extracted 80 links.
# Catawba-5211: Extracted 0 links.
# Catawba-1112: Extracted 0 links.
# Catawba-7131: Extracted 2 links.
# Catawba-5152: Extracted 0 links.
# Catawba-3119: Extracted 3 links.
# Catawba-2383: Extracted 64 links.
# Catawba-3342: Extracted 9 links.
# Catawba-3312: Extracted 0 links.
# Catawba-3279: Extracted 2 links.
# Catawba-2373: Extracted 18 links.
# Catawba-3314: Extracted 2 links.
# Catawba-4811: Extracted 1 links.
# Catawba-2389: Extracted 64 links.
# Catawba-7121: Extracted 26 links.
# Catawba-2123: Extracted 2 links.
# Catawba-3255: Extracted 0 links.
# Catawba-4431: Extracted 0 links.
# Catawba-3311: Extracted 1 links.
# Catawba-3365: Extracted 0 links.
# Catawba-3327: Extracted 11 links.
# Catawba-9211: Extracted 100 links.
# Catawba-8112: Extracted 17 links.
# Catawba-4442: Extracted 12 links.
# Catawba-2372: Extracted 3 links.
# Catawba-8129: Extracted 35 links.
# Catawba-8133: Extracted 62 links.
# Catawba-5622: Extracted 6 links.
# Catawba-4247: Extracted 7 links.
# Clay-4471: Extracted 0 links.
# Clay-6216: Extracted 3 links.
# Clay-5331: Extracted 0 links.
# Clay-4812: Extracted 0 links.
# Clay-2121: Extracted 0 links.
# Clay-7224: Extracted 1 links.
# Clay-9271: Extracted 0 links.
# Clay-4412: Extracted 2 links.
# Clay-9281: Extracted 0 links.
# Clay-6221: Extracted 0 links.
# Clay-4543: Extracted 0 links.
# Clay-3132: Extracted 0 links.
# Clay-4542: Extracted 0 links.
# Clay-2211: Extracted 1 links.
# Clay-6222: Extracted 0 links.
# Clay-5321: Extracted 0 links.
# Clay-6219: Extracted 5 links.
# Clay-5615: Extracted 0 links.
# Clay-9221: Extracted 6 links.
# Clay-5413: Extracted 3 links.
# Clay-4882: Extracted 1 links.
# Clay-1113: Extracted 0 links.
# Clay-3211: Extracted 0 links.
# Clay-3379: Extracted 0 links.
# Clay-4481: Extracted 0 links.
# Clay-3341: Extracted 0 links.
# Clay-5324: Extracted 0 links.
# Clay-7114: Extracted 0 links.
# Clay-7225: Extracted 25 links.
# Clay-1132: Extracted 0 links.
# Clay-3361: Extracted 0 links.
# Clay-4532: Extracted 0 links.
# Batch 6 completed.
# Processing batch 7/7...
# Batch 7/7:   0%|          | 0/420 [00:00<?, ?it/s]
# Clay-4881: Extracted 0 links.
# Clay-1152: Extracted 2 links.
# Clay-5242: Extracted 7 links.
# Clay-5191: Extracted 0 links.
# Clay-5415: Extracted 1 links.
# Clay-3366: Extracted 0 links.
# Clay-1122: Extracted 0 links.
# Clay-3114: Extracted 0 links.
# Clay-4523: Extracted 0 links.
# Clay-7223: Extracted 3 links.
# Clay-4871: Extracted 0 links.
# Clay-5223: Extracted 0 links.
# Clay-3322: Extracted 0 links.
# Clay-6241: Extracted 10 links.
# Clay-4883: Extracted 0 links.
# Clay-4921: Extracted 0 links.
# Clay-5619: Extracted 4 links.
# Clay-3315: Extracted 0 links.
# Clay-1123: Extracted 0 links.
# Clay-1141: Extracted 0 links.
# Clay-3333: Extracted 0 links.
# Clay-5621: Extracted 1 links.
# Clay-3169: Extracted 0 links.
# Clay-6232: Extracted 0 links.
# Clay-9231: Extracted 2 links.
# Clay-1119: Extracted 3 links.
# Clay-2122: Extracted 0 links.
# Clay-3115: Extracted 0 links.
# Clay-5173: Extracted 0 links.
# Clay-4241: Extracted 0 links.
# Clay-3325: Extracted 0 links.
# Clay-8134: Extracted 4 links.
# Clay-3121: Extracted 4 links.
# Clay-4862: Extracted 0 links.
# Clay-3241: Extracted 0 links.
# Clay-7115: Extracted 0 links.
# Clay-3399: Extracted 5 links.
# Clay-3133: Extracted 0 links.
# Clay-4413: Extracted 5 links.
# Clay-8141: Extracted 0 links.
# Clay-4841: Extracted 2 links.
# Clay-3343: Extracted 0 links.
# Clay-7211: Extracted 5 links.
# Clay-4832: Extracted 0 links.
# Clay-5179: Extracted 0 links.
# Clay-5322: Extracted 0 links.
# Clay-4245: Extracted 0 links.
# Clay-4246: Extracted 0 links.
# Clay-5241: Extracted 0 links.
# Clay-4244: Extracted 0 links.
# Clay-3346: Extracted 0 links.
# Clay-8123: Extracted 0 links.
# Clay-1151: Extracted 1 links.
# Clay-5111: Extracted 0 links.
# Clay-3351: Extracted 0 links.
# Clay-1111: Extracted 0 links.
# Clay-3262: Extracted 0 links.
# Clay-2213: Extracted 1 links.
# Clay-6117: Extracted 2 links.
# Clay-3353: Extracted 0 links.
# Clay-3117: Extracted 0 links.
# Clay-7111: Extracted 3 links.
# Clay-3272: Extracted 0 links.
# Clay-4233: Extracted 0 links.
# Clay-4931: Extracted 4 links.
# Clay-6244: Extracted 5 links.
# Clay-1142: Extracted 0 links.
# Clay-3336: Extracted 0 links.
# Clay-4854: Extracted 0 links.
# Clay-3141: Extracted 0 links.
# Clay-3231: Extracted 3 links.
# Clay-4235: Extracted 0 links.
# Clay-9241: Extracted 1 links.
# Clay-1153: Extracted 0 links.
# Clay-4539: Extracted 0 links.
# Clay-2362: Extracted 3 links.
# Clay-4911: Extracted 3 links.
# Clay-5611: Extracted 0 links.
# Clay-3251: Extracted 0 links.
# Clay-7113: Extracted 0 links.
# Clay-3352: Extracted 0 links.
# Clay-6213: Extracted 14 links.
# Clay-1125: Extracted 0 links.
# Clay-5259: Extracted 0 links.
# Clay-4422: Extracted 0 links.
# Clay-6116: Extracted 1 links.
# Clay-4879: Extracted 0 links.
# Clay-5221: Extracted 4 links.
# Clay-5182: Extracted 1 links.
# Clay-3332: Extracted 0 links.
# Clay-5222: Extracted 1 links.
# Clay-7212: Extracted 3 links.
# Clay-5417: Extracted 0 links.
# Clay-3369: Extracted 0 links.
# Clay-3131: Extracted 0 links.
# Clay-3326: Extracted 0 links.
# Clay-5311: Extracted 4 links.
# Clay-3149: Extracted 0 links.
# Clay-4861: Extracted 0 links.
# Clay-5174: Extracted 0 links.
# Clay-5151: Extracted 0 links.
# Clay-4852: Extracted 0 links.
# Clay-3359: Extracted 1 links.
# Clay-3321: Extracted 1 links.
# Clay-4483: Extracted 0 links.
# Clay-1133: Extracted 0 links.
# Clay-3161: Extracted 0 links.
# Clay-4842: Extracted 5 links.
# Clay-6111: Extracted 5 links.
# Clay-9261: Extracted 0 links.
# Clay-3222: Extracted 0 links.
# Clay-4853: Extracted 0 links.
# Clay-5412: Extracted 5 links.
# Clay-4232: Extracted 0 links.
# Clay-3329: Extracted 0 links.
# Clay-4885: Extracted 0 links.
# Clay-4243: Extracted 0 links.
# Clay-3112: Extracted 0 links.
# Clay-2379: Extracted 0 links.
# Clay-4451: Extracted 4 links.
# Clay-4889: Extracted 0 links.
# Clay-3334: Extracted 0 links.
# Clay-5416: Extracted 4 links.
# Clay-1124: Extracted 0 links.
# Clay-3252: Extracted 0 links.
# Clay-3331: Extracted 0 links.
# Clay-3256: Extracted 0 links.
# Clay-4231: Extracted 2 links.
# Clay-6223: Extracted 0 links.
# Clay-3152: Extracted 0 links.
# Clay-5418: Extracted 1 links.
# Clay-5511: Extracted 3 links.
# Clay-3151: Extracted 0 links.
# Clay-1121: Extracted 0 links.
# Clay-4872: Extracted 0 links.
# Clay-5112: Extracted 0 links.
# Clay-8121: Extracted 11 links.
# Clay-4239: Extracted 1 links.
# Clay-5613: Extracted 0 links.
# Clay-6242: Extracted 2 links.
# Clay-5122: Extracted 0 links.
# Clay-8111: Extracted 16 links.
# Clay-3122: Extracted 0 links.
# Clay-3111: Extracted 0 links.
# Clay-4452: Extracted 1 links.
# Clay-4234: Extracted 0 links.
# Clay-1131: Extracted 0 links.
# Clay-5121: Extracted 0 links.
# Clay-4869: Extracted 0 links.
# Clay-3162: Extracted 0 links.
# Clay-3328: Extracted 0 links.
# Clay-5616: Extracted 0 links.
# Clay-6211: Extracted 7 links.
# Clay-7213: Extracted 0 links.
# Clay-3362: Extracted 0 links.
# Clay-4859: Extracted 1 links.
# Clay-3273: Extracted 0 links.
# Clay-5232: Extracted 0 links.
# Clay-3261: Extracted 0 links.
# Clay-4482: Extracted 0 links.
# Clay-4541: Extracted 0 links.
# Clay-6115: Extracted 0 links.
# Clay-5323: Extracted 2 links.
# Clay-4238: Extracted 1 links.
# Clay-8114: Extracted 5 links.
# Clay-4922: Extracted 0 links.
# Clay-5313: Extracted 1 links.
# Clay-5629: Extracted 1 links.
# Clay-8139: Extracted 3 links.
# Clay-2111: Extracted 0 links.
# Clay-3372: Extracted 0 links.
# Clay-3364: Extracted 0 links.
# Clay-3344: Extracted 0 links.
# Clay-4251: Extracted 0 links.
# Clay-4851: Extracted 0 links.
# Clay-4461: Extracted 0 links.
# Clay-2371: Extracted 2 links.
# Clay-4522: Extracted 0 links.
# Clay-3335: Extracted 0 links.
# Clay-6112: Extracted 1 links.
# Clay-2212: Extracted 0 links.
# Clay-4533: Extracted 0 links.
# Clay-3159: Extracted 0 links.
# Clay-3345: Extracted 1 links.
# Clay-5612: Extracted 0 links.
# Clay-4531: Extracted 0 links.
# Clay-3212: Extracted 0 links.
# Clay-4242: Extracted 0 links.
# Clay-8132: Extracted 0 links.
# Clay-6231: Extracted 1 links.
# Clay-6243: Extracted 1 links.
# Clay-4831: Extracted 0 links.
# Clay-4855: Extracted 0 links.
# Clay-3323: Extracted 0 links.
# Clay-3391: Extracted 2 links.
# Clay-2381: Extracted 3 links.
# Clay-1114: Extracted 0 links.
# Clay-6113: Extracted 0 links.
# Clay-5419: Extracted 4 links.
# Clay-6212: Extracted 5 links.
# Clay-4411: Extracted 2 links.
# Clay-8113: Extracted 0 links.
# Clay-9251: Extracted 0 links.
# Clay-3274: Extracted 0 links.
# Clay-4453: Extracted 0 links.
# Clay-2131: Extracted 0 links.
# Clay-5414: Extracted 2 links.
# Clay-1129: Extracted 2 links.
# Clay-7132: Extracted 0 links.
# Clay-3219: Extracted 0 links.
# Clay-6233: Extracted 2 links.
# Clay-6214: Extracted 0 links.
# Clay-3118: Extracted 0 links.
# Clay-4511: Extracted 0 links.
# Clay-3371: Extracted 1 links.
# Clay-3254: Extracted 0 links.
# Clay-4237: Extracted 1 links.
# Clay-3221: Extracted 0 links.
# Clay-3116: Extracted 0 links.
# Clay-4512: Extracted 0 links.
# Clay-6239: Extracted 1 links.
# Clay-5411: Extracted 7 links.
# Clay-5617: Extracted 11 links.
# Clay-3113: Extracted 0 links.
# Clay-2382: Extracted 10 links.
# Clay-5231: Extracted 1 links.
# Clay-5312: Extracted 20 links.
# Clay-7112: Extracted 2 links.
# Clay-2361: Extracted 10 links.
# Clay-4884: Extracted 2 links.
# Clay-8131: Extracted 34 links.
# Clay-7139: Extracted 10 links.
# Clay-3313: Extracted 0 links.
# Clay-3271: Extracted 0 links.
# Clay-8122: Extracted 2 links.
# Clay-4236: Extracted 3 links.
# Clay-3339: Extracted 0 links.
# Clay-5251: Extracted 0 links.
# Clay-3363: Extracted 0 links.
# Clay-4421: Extracted 0 links.
# Clay-4248: Extracted 0 links.
# Clay-4441: Extracted 7 links.
# Clay-3259: Extracted 0 links.
# Clay-6215: Extracted 0 links.
# Clay-3253: Extracted 0 links.
# Clay-3324: Extracted 0 links.
# Clay-4249: Extracted 3 links.
# Clay-6114: Extracted 0 links.
# Clay-4821: Extracted 0 links.
# Clay-5614: Extracted 1 links.
# Clay-5239: Extracted 5 links.
# Clay-5211: Extracted 0 links.
# Clay-1112: Extracted 0 links.
# Clay-7131: Extracted 0 links.
# Clay-5152: Extracted 0 links.
# Clay-3119: Extracted 0 links.
# Clay-2383: Extracted 4 links.
# Clay-3342: Extracted 0 links.
# Clay-3312: Extracted 1 links.
# Clay-3279: Extracted 0 links.
# Clay-2373: Extracted 5 links.
# Clay-3314: Extracted 0 links.
# Clay-4811: Extracted 0 links.
# Clay-2389: Extracted 6 links.
# Clay-7121: Extracted 2 links.
# Clay-2123: Extracted 0 links.
# Clay-3255: Extracted 0 links.
# Clay-4431: Extracted 0 links.
# Clay-3311: Extracted 0 links.
# Clay-3365: Extracted 0 links.
# Clay-3327: Extracted 1 links.
# Clay-9211: Extracted 17 links.
# Clay-8112: Extracted 1 links.
# Clay-4442: Extracted 3 links.
# Clay-2372: Extracted 1 links.
# Clay-8129: Extracted 3 links.
# Clay-8133: Extracted 9 links.
# Clay-5622: Extracted 0 links.
# Clay-4247: Extracted 1 links.
# Cleveland-4471: Extracted 0 links.
# Cleveland-6216: Extracted 19 links.
# Cleveland-5331: Extracted 0 links.
# Cleveland-4812: Extracted 0 links.
# Cleveland-2121: Extracted 0 links.
# Cleveland-7224: Extracted 4 links.
# Cleveland-9271: Extracted 0 links.
# Cleveland-4412: Extracted 16 links.
# Cleveland-9281: Extracted 4 links.
# Cleveland-6221: Extracted 11 links.
# Cleveland-4543: Extracted 0 links.
# Cleveland-3132: Extracted 2 links.
# Cleveland-4542: Extracted 0 links.
# Cleveland-2211: Extracted 1 links.
# Cleveland-6222: Extracted 8 links.
# Cleveland-5321: Extracted 8 links.
# Cleveland-6219: Extracted 18 links.
# Cleveland-5615: Extracted 6 links.
# Cleveland-9221: Extracted 29 links.
# Cleveland-5413: Extracted 19 links.
# Cleveland-4882: Extracted 3 links.
# Cleveland-1113: Extracted 1 links.
# Cleveland-3211: Extracted 2 links.
# Cleveland-3379: Extracted 0 links.
# Cleveland-4481: Extracted 0 links.
# Cleveland-3341: Extracted 0 links.
# Cleveland-5324: Extracted 2 links.
# Cleveland-7114: Extracted 0 links.
# Cleveland-7225: Extracted 100 links.
# Cleveland-1132: Extracted 0 links.
# Cleveland-3361: Extracted 1 links.
# Cleveland-4532: Extracted 0 links.
# Cleveland-4881: Extracted 1 links.
# Cleveland-1152: Extracted 3 links.
# Cleveland-5242: Extracted 42 links.
# Cleveland-5191: Extracted 0 links.
# Cleveland-5415: Extracted 6 links.
# Cleveland-3366: Extracted 0 links.
# Cleveland-1122: Extracted 0 links.
# Cleveland-3114: Extracted 0 links.
# Cleveland-4523: Extracted 0 links.
# Cleveland-7223: Extracted 5 links.
# Cleveland-4871: Extracted 0 links.
# Cleveland-5223: Extracted 14 links.
# Cleveland-3322: Extracted 0 links.
# Cleveland-6241: Extracted 57 links.
# Cleveland-4883: Extracted 0 links.
# Cleveland-4921: Extracted 0 links.
# Cleveland-5619: Extracted 9 links.
# Cleveland-3315: Extracted 1 links.
# Cleveland-1123: Extracted 1 links.
# Cleveland-1141: Extracted 0 links.
# Cleveland-3333: Extracted 0 links.
# Cleveland-5621: Extracted 0 links.
# Cleveland-3169: Extracted 0 links.
# Cleveland-6232: Extracted 0 links.
# Cleveland-9231: Extracted 3 links.
# Cleveland-1119: Extracted 18 links.
# Cleveland-2122: Extracted 0 links.
# Cleveland-3115: Extracted 0 links.
# Cleveland-5173: Extracted 0 links.
# Cleveland-4241: Extracted 0 links.
# Cleveland-3325: Extracted 0 links.
# Cleveland-8134: Extracted 23 links.
# Cleveland-3121: Extracted 4 links.
# Cleveland-4862: Extracted 0 links.
# Cleveland-3241: Extracted 2 links.
# Cleveland-7115: Extracted 2 links.
# Cleveland-3399: Extracted 7 links.
# Cleveland-3133: Extracted 3 links.
# Cleveland-4413: Extracted 30 links.
# Cleveland-8141: Extracted 0 links.
# Cleveland-4841: Extracted 4 links.
# Cleveland-3343: Extracted 1 links.
# Cleveland-7211: Extracted 19 links.
# Cleveland-4832: Extracted 0 links.
# Cleveland-5179: Extracted 0 links.
# Cleveland-5322: Extracted 4 links.
# Cleveland-4245: Extracted 1 links.
# Cleveland-4246: Extracted 0 links.
# Cleveland-5241: Extracted 1 links.
# Cleveland-4244: Extracted 2 links.
# Cleveland-3346: Extracted 0 links.
# Cleveland-8123: Extracted 6 links.
# Cleveland-1151: Extracted 0 links.
# Cleveland-5111: Extracted 0 links.
# Cleveland-3351: Extracted 0 links.
# Cleveland-1111: Extracted 0 links.
# Cleveland-3262: Extracted 0 links.
# Cleveland-2213: Extracted 2 links.
# Cleveland-6117: Extracted 3 links.
# Cleveland-3353: Extracted 3 links.
# Cleveland-3117: Extracted 0 links.
# Cleveland-7111: Extracted 6 links.
# Cleveland-3272: Extracted 0 links.
# Cleveland-4233: Extracted 0 links.
# Cleveland-4931: Extracted 5 links.
# Cleveland-6244: Extracted 28 links.
# Cleveland-1142: Extracted 3 links.
# Cleveland-3336: Extracted 2 links.
# Cleveland-4854: Extracted 1 links.
# Cleveland-3141: Extracted 3 links.
# Cleveland-3231: Extracted 8 links.
# Cleveland-4235: Extracted 3 links.
# Cleveland-9241: Extracted 7 links.
# Cleveland-1153: Extracted 0 links.
# Cleveland-4539: Extracted 0 links.
# Cleveland-2362: Extracted 26 links.
# Cleveland-4911: Extracted 12 links.
# Cleveland-5611: Extracted 5 links.
# Cleveland-3251: Extracted 3 links.
# Cleveland-7113: Extracted 8 links.
# Cleveland-3352: Extracted 1 links.
# Cleveland-6213: Extracted 100 links.
# Cleveland-1125: Extracted 0 links.
# Cleveland-5259: Extracted 1 links.
# Cleveland-4422: Extracted 0 links.
# Cleveland-6116: Extracted 15 links.
# Cleveland-4879: Extracted 1 links.
# Cleveland-5221: Extracted 25 links.
# Cleveland-5182: Extracted 1 links.
# Cleveland-3332: Extracted 2 links.
# Cleveland-5222: Extracted 17 links.
# Cleveland-7212: Extracted 8 links.
# Cleveland-5417: Extracted 12 links.
# Cleveland-3369: Extracted 1 links.
# Cleveland-3131: Extracted 1 links.
# Cleveland-3326: Extracted 3 links.
# Cleveland-5311: Extracted 57 links.
# Cleveland-3149: Extracted 11 links.
# Cleveland-4861: Extracted 1 links.
# Cleveland-5174: Extracted 0 links.
# Cleveland-5151: Extracted 0 links.
# Cleveland-4852: Extracted 0 links.
# Cleveland-3359: Extracted 2 links.
# Cleveland-3321: Extracted 0 links.
# Cleveland-4483: Extracted 0 links.
# Cleveland-1133: Extracted 1 links.
# Cleveland-3161: Extracted 0 links.
# Cleveland-4842: Extracted 34 links.
# Cleveland-6111: Extracted 38 links.
# Batch 7 completed.
# All tasks from batch 6 to 7 completed. Links are written to all_links.txt.

# %%
await main(start_batch=9, end_batch=10)
# Out:
# Processing batch 9/10...
# Batch 9/10:   0%|          | 0/420 [00:00<?, ?it/s]
# Gaston-3116: Extracted 0 links.
# Gaston-4512: Extracted 0 links.
# Gaston-6239: Extracted 1 links.
# Gaston-5411: Extracted 100 links.
# Gaston-5617: Extracted 100 links.
# Gaston-3113: Extracted 0 links.
# Gaston-2382: Extracted 100 links.
# Gaston-5231: Extracted 35 links.
# Gaston-5312: Extracted 100 links.
# Gaston-7112: Extracted 3 links.
# Gaston-2361: Extracted 100 links.
# Gaston-4884: Extracted 21 links.
# Gaston-8131: Extracted 100 links.
# Gaston-7139: Extracted 59 links.
# Gaston-3313: Extracted 0 links.
# Gaston-3271: Extracted 0 links.
# Gaston-8122: Extracted 26 links.
# Gaston-4236: Extracted 24 links.
# Gaston-3339: Extracted 12 links.
# Gaston-5251: Extracted 0 links.
# Gaston-3363: Extracted 2 links.
# Gaston-4421: Extracted 0 links.
# Gaston-4248: Extracted 0 links.
# Gaston-4441: Extracted 59 links.
# Gaston-3259: Extracted 6 links.
# Gaston-6215: Extracted 0 links.
# Gaston-3253: Extracted 1 links.
# Gaston-3324: Extracted 1 links.
# Gaston-4249: Extracted 6 links.
# Gaston-6114: Extracted 6 links.
# Gaston-4821: Extracted 1 links.
# Gaston-5614: Extracted 6 links.
# Gaston-5239: Extracted 66 links.
# Gaston-5211: Extracted 0 links.
# Gaston-1112: Extracted 0 links.
# Gaston-7131: Extracted 3 links.
# Gaston-5152: Extracted 0 links.
# Gaston-3119: Extracted 2 links.
# Gaston-2383: Extracted 67 links.
# Gaston-3342: Extracted 0 links.
# Gaston-3312: Extracted 0 links.
# Gaston-3279: Extracted 1 links.
# Gaston-2373: Extracted 24 links.
# Gaston-3314: Extracted 2 links.
# Gaston-4811: Extracted 0 links.
# Gaston-2389: Extracted 61 links.
# Gaston-7121: Extracted 31 links.
# Gaston-2123: Extracted 3 links.
# Gaston-3255: Extracted 2 links.
# Gaston-4431: Extracted 0 links.
# Gaston-3311: Extracted 0 links.
# Gaston-3365: Extracted 0 links.
# Gaston-3327: Extracted 66 links.
# Gaston-9211: Extracted 100 links.
# Gaston-8112: Extracted 13 links.
# Gaston-4442: Extracted 0 links.
# Gaston-2372: Extracted 3 links.
# Gaston-8129: Extracted 45 links.
# Gaston-8133: Extracted 69 links.
# Gaston-5622: Extracted 6 links.
# Gaston-4247: Extracted 8 links.
# Haywood-4471: Extracted 0 links.
# Haywood-6216: Extracted 6 links.
# Haywood-5331: Extracted 0 links.
# Haywood-4812: Extracted 0 links.
# Haywood-2121: Extracted 0 links.
# Haywood-7224: Extracted 1 links.
# Haywood-9271: Extracted 0 links.
# Haywood-4412: Extracted 8 links.
# Haywood-9281: Extracted 0 links.
# Haywood-6221: Extracted 0 links.
# Haywood-4543: Extracted 0 links.
# Haywood-3132: Extracted 0 links.
# Haywood-4542: Extracted 0 links.
# Haywood-2211: Extracted 1 links.
# Haywood-6222: Extracted 5 links.
# Haywood-5321: Extracted 5 links.
# Haywood-6219: Extracted 15 links.
# Haywood-5615: Extracted 4 links.
# Haywood-9221: Extracted 32 links.
# Haywood-5413: Extracted 23 links.
# Haywood-4882: Extracted 4 links.
# Haywood-1113: Extracted 0 links.
# Haywood-3211: Extracted 1 links.
# Haywood-3379: Extracted 0 links.
# Haywood-4481: Extracted 0 links.
# Haywood-3341: Extracted 0 links.
# Haywood-5324: Extracted 1 links.
# Haywood-7114: Extracted 0 links.
# Haywood-7225: Extracted 100 links.
# Haywood-1132: Extracted 0 links.
# Haywood-3361: Extracted 0 links.
# Haywood-4532: Extracted 0 links.
# Haywood-4881: Extracted 1 links.
# Haywood-1152: Extracted 1 links.
# Haywood-5242: Extracted 27 links.
# Haywood-5191: Extracted 0 links.
# Haywood-5415: Extracted 11 links.
# Haywood-3366: Extracted 0 links.
# Haywood-1122: Extracted 0 links.
# Haywood-3114: Extracted 1 links.
# Haywood-4523: Extracted 0 links.
# Haywood-7223: Extracted 2 links.
# Haywood-4871: Extracted 0 links.
# Haywood-5223: Extracted 6 links.
# Haywood-3322: Extracted 0 links.
# Haywood-6241: Extracted 45 links.
# Haywood-4883: Extracted 0 links.
# Haywood-4921: Extracted 0 links.
# Haywood-5619: Extracted 5 links.
# Haywood-3315: Extracted 0 links.
# Haywood-1123: Extracted 0 links.
# Haywood-1141: Extracted 0 links.
# Haywood-3333: Extracted 2 links.
# Haywood-5621: Extracted 3 links.
# Haywood-3169: Extracted 0 links.
# Haywood-6232: Extracted 0 links.
# Haywood-9231: Extracted 3 links.
# Haywood-1119: Extracted 9 links.
# Haywood-2122: Extracted 0 links.
# Haywood-3115: Extracted 0 links.
# Haywood-5173: Extracted 0 links.
# Haywood-4241: Extracted 1 links.
# Haywood-3325: Extracted 0 links.
# Haywood-8134: Extracted 21 links.
# Haywood-3121: Extracted 7 links.
# Haywood-4862: Extracted 0 links.
# Haywood-3241: Extracted 0 links.
# Haywood-7115: Extracted 4 links.
# Haywood-3399: Extracted 3 links.
# Haywood-3133: Extracted 0 links.
# Haywood-4413: Extracted 22 links.
# Haywood-8141: Extracted 0 links.
# Haywood-4841: Extracted 5 links.
# Haywood-3343: Extracted 0 links.
# Haywood-7211: Extracted 77 links.
# Haywood-4832: Extracted 0 links.
# Haywood-5179: Extracted 0 links.
# Haywood-5322: Extracted 5 links.
# Haywood-4245: Extracted 4 links.
# Haywood-4246: Extracted 1 links.
# Haywood-5241: Extracted 1 links.
# Haywood-4244: Extracted 6 links.
# Haywood-3346: Extracted 0 links.
# Haywood-8123: Extracted 9 links.
# Haywood-1151: Extracted 0 links.
# Haywood-5111: Extracted 0 links.
# Haywood-3351: Extracted 1 links.
# Haywood-1111: Extracted 0 links.
# Haywood-3262: Extracted 0 links.
# Haywood-2213: Extracted 3 links.
# Haywood-6117: Extracted 2 links.
# Haywood-3353: Extracted 0 links.
# Haywood-3117: Extracted 0 links.
# Haywood-7111: Extracted 0 links.
# Haywood-3272: Extracted 1 links.
# Haywood-4233: Extracted 3 links.
# Haywood-4931: Extracted 6 links.
# Haywood-6244: Extracted 11 links.
# Haywood-1142: Extracted 1 links.
# Haywood-3336: Extracted 1 links.
# Haywood-4854: Extracted 0 links.
# Haywood-3141: Extracted 0 links.
# Haywood-3231: Extracted 3 links.
# Haywood-4235: Extracted 1 links.
# Haywood-9241: Extracted 8 links.
# Haywood-1153: Extracted 1 links.
# Haywood-4539: Extracted 0 links.
# Haywood-2362: Extracted 10 links.
# Haywood-4911: Extracted 6 links.
# Haywood-5611: Extracted 2 links.
# Haywood-3251: Extracted 0 links.
# Haywood-7113: Extracted 0 links.
# Haywood-3352: Extracted 0 links.
# Haywood-6213: Extracted 100 links.
# Haywood-1125: Extracted 1 links.
# Haywood-5259: Extracted 1 links.
# Haywood-4422: Extracted 0 links.
# Haywood-6116: Extracted 7 links.
# Haywood-4879: Extracted 0 links.
# Haywood-5221: Extracted 15 links.
# Haywood-5182: Extracted 5 links.
# Haywood-3332: Extracted 0 links.
# Haywood-5222: Extracted 9 links.
# Haywood-7212: Extracted 20 links.
# Haywood-5417: Extracted 4 links.
# Haywood-3369: Extracted 0 links.
# Haywood-3131: Extracted 0 links.
# Haywood-3326: Extracted 2 links.
# Haywood-5311: Extracted 44 links.
# Haywood-3149: Extracted 0 links.
# Haywood-4861: Extracted 0 links.
# Haywood-5174: Extracted 0 links.
# Haywood-5151: Extracted 0 links.
# Haywood-4852: Extracted 0 links.
# Haywood-3359: Extracted 1 links.
# Haywood-3321: Extracted 1 links.
# Haywood-4483: Extracted 0 links.
# Haywood-1133: Extracted 0 links.
# Haywood-3161: Extracted 0 links.
# Haywood-4842: Extracted 15 links.
# Haywood-6111: Extracted 30 links.
# Haywood-9261: Extracted 0 links.
# Haywood-3222: Extracted 5 links.
# Haywood-4853: Extracted 1 links.
# Haywood-5412: Extracted 18 links.
# Haywood-4232: Extracted 0 links.
# Haywood-3329: Extracted 4 links.
# Haywood-4885: Extracted 1 links.
# Haywood-4243: Extracted 0 links.
# Haywood-3112: Extracted 0 links.
# Haywood-2379: Extracted 0 links.
# Haywood-4451: Extracted 27 links.
# Haywood-4889: Extracted 0 links.
# Haywood-3334: Extracted 1 links.
# Haywood-5416: Extracted 33 links.
# Haywood-1124: Extracted 0 links.
# Haywood-3252: Extracted 0 links.
# Haywood-3331: Extracted 0 links.
# Haywood-3256: Extracted 1 links.
# Haywood-4231: Extracted 4 links.
# Haywood-6223: Extracted 0 links.
# Haywood-3152: Extracted 0 links.
# Haywood-5418: Extracted 15 links.
# Haywood-5511: Extracted 5 links.
# Haywood-3151: Extracted 0 links.
# Haywood-1121: Extracted 0 links.
# Haywood-4872: Extracted 0 links.
# Haywood-5112: Extracted 0 links.
# Haywood-8121: Extracted 0 links.
# Haywood-4239: Extracted 6 links.
# Haywood-5613: Extracted 4 links.
# Haywood-6242: Extracted 0 links.
# Haywood-5122: Extracted 0 links.
# Haywood-8111: Extracted 59 links.
# Haywood-3122: Extracted 0 links.
# Haywood-3111: Extracted 0 links.
# Haywood-4452: Extracted 11 links.
# Haywood-4234: Extracted 2 links.
# Haywood-1131: Extracted 0 links.
# Haywood-5121: Extracted 6 links.
# Haywood-4869: Extracted 0 links.
# Haywood-3162: Extracted 0 links.
# Haywood-3328: Extracted 0 links.
# Haywood-5616: Extracted 9 links.
# Haywood-6211: Extracted 66 links.
# Haywood-7213: Extracted 0 links.
# Haywood-3362: Extracted 0 links.
# Haywood-4859: Extracted 2 links.
# Haywood-3273: Extracted 1 links.
# Haywood-5232: Extracted 0 links.
# Haywood-3261: Extracted 0 links.
# Haywood-4482: Extracted 0 links.
# Haywood-4541: Extracted 0 links.
# Haywood-6115: Extracted 1 links.
# Haywood-5323: Extracted 0 links.
# Haywood-4238: Extracted 4 links.
# Haywood-8114: Extracted 10 links.
# Haywood-4922: Extracted 0 links.
# Haywood-5313: Extracted 0 links.
# Haywood-5629: Extracted 4 links.
# Haywood-8139: Extracted 23 links.
# Haywood-2111: Extracted 0 links.
# Haywood-3372: Extracted 1 links.
# Haywood-3364: Extracted 0 links.
# Haywood-3344: Extracted 0 links.
# Haywood-4251: Extracted 0 links.
# Haywood-4851: Extracted 0 links.
# Haywood-4461: Extracted 0 links.
# Haywood-2371: Extracted 5 links.
# Haywood-4522: Extracted 0 links.
# Haywood-3335: Extracted 0 links.
# Haywood-6112: Extracted 2 links.
# Haywood-2212: Extracted 0 links.
# Haywood-4533: Extracted 0 links.
# Haywood-3159: Extracted 0 links.
# Haywood-3345: Extracted 0 links.
# Haywood-5612: Extracted 0 links.
# Haywood-4531: Extracted 0 links.
# Haywood-3212: Extracted 0 links.
# Haywood-4242: Extracted 0 links.
# Haywood-8132: Extracted 0 links.
# Haywood-6231: Extracted 0 links.
# Haywood-6243: Extracted 0 links.
# Haywood-4831: Extracted 0 links.
# Haywood-4855: Extracted 1 links.
# Haywood-3323: Extracted 0 links.
# Haywood-3391: Extracted 4 links.
# Haywood-2381: Extracted 18 links.
# Haywood-1114: Extracted 0 links.
# Haywood-6113: Extracted 0 links.
# Haywood-5419: Extracted 0 links.
# Haywood-6212: Extracted 29 links.
# Haywood-4411: Extracted 12 links.
# Haywood-8113: Extracted 6 links.
# Haywood-9251: Extracted 0 links.
# Haywood-3274: Extracted 0 links.
# Haywood-4453: Extracted 0 links.
# Haywood-2131: Extracted 0 links.
# Haywood-5414: Extracted 7 links.
# Haywood-1129: Extracted 0 links.
# Haywood-7132: Extracted 0 links.
# Haywood-3219: Extracted 0 links.
# Haywood-6233: Extracted 0 links.
# Haywood-6214: Extracted 0 links.
# Haywood-3118: Extracted 0 links.
# Haywood-4511: Extracted 0 links.
# Haywood-3371: Extracted 8 links.
# Haywood-3254: Extracted 0 links.
# Haywood-4237: Extracted 0 links.
# Haywood-3221: Extracted 0 links.
# Haywood-3116: Extracted 1 links.
# Haywood-4512: Extracted 0 links.
# Haywood-6239: Extracted 0 links.
# Haywood-5411: Extracted 0 links.
# Haywood-5617: Extracted 0 links.
# Haywood-3113: Extracted 0 links.
# Haywood-2382: Extracted 42 links.
# Haywood-5231: Extracted 7 links.
# Haywood-5312: Extracted 74 links.
# Haywood-7112: Extracted 0 links.
# Haywood-2361: Extracted 50 links.
# Haywood-4884: Extracted 11 links.
# Haywood-8131: Extracted 100 links.
# Haywood-7139: Extracted 0 links.
# Haywood-3313: Extracted 0 links.
# Haywood-3271: Extracted 0 links.
# Haywood-8122: Extracted 11 links.
# Haywood-4236: Extracted 0 links.
# Haywood-3339: Extracted 0 links.
# Haywood-5251: Extracted 0 links.
# Haywood-3363: Extracted 0 links.
# Haywood-4421: Extracted 0 links.
# Haywood-4248: Extracted 0 links.
# Haywood-4441: Extracted 17 links.
# Haywood-3259: Extracted 2 links.
# Haywood-6215: Extracted 0 links.
# Haywood-3253: Extracted 0 links.
# Haywood-3324: Extracted 1 links.
# Haywood-4249: Extracted 5 links.
# Haywood-6114: Extracted 3 links.
# Haywood-4821: Extracted 0 links.
# Haywood-5614: Extracted 4 links.
# Haywood-5239: Extracted 25 links.
# Haywood-5211: Extracted 0 links.
# Haywood-1112: Extracted 0 links.
# Haywood-7131: Extracted 0 links.
# Haywood-5152: Extracted 0 links.
# Haywood-3119: Extracted 0 links.
# Haywood-2383: Extracted 24 links.
# Haywood-3342: Extracted 0 links.
# Haywood-3312: Extracted 0 links.
# Haywood-3279: Extracted 0 links.
# Haywood-2373: Extracted 8 links.
# Haywood-3314: Extracted 0 links.
# Haywood-4811: Extracted 0 links.
# Haywood-2389: Extracted 36 links.
# Haywood-7121: Extracted 15 links.
# Haywood-2123: Extracted 2 links.
# Haywood-3255: Extracted 0 links.
# Haywood-4431: Extracted 0 links.
# Haywood-3311: Extracted 0 links.
# Haywood-3365: Extracted 0 links.
# Haywood-3327: Extracted 1 links.
# Haywood-9211: Extracted 56 links.
# Haywood-8112: Extracted 3 links.
# Haywood-4442: Extracted 10 links.
# Haywood-2372: Extracted 2 links.
# Haywood-8129: Extracted 24 links.
# Haywood-8133: Extracted 33 links.
# Haywood-5622: Extracted 1 links.
# Haywood-4247: Extracted 9 links.
# Henderson-4471: Extracted 0 links.
# Henderson-6216: Extracted 12 links.
# Henderson-5331: Extracted 0 links.
# Henderson-4812: Extracted 1 links.
# Henderson-2121: Extracted 0 links.
# Henderson-7224: Extracted 0 links.
# Henderson-9271: Extracted 0 links.
# Henderson-4412: Extracted 18 links.
# Henderson-9281: Extracted 1 links.
# Henderson-6221: Extracted 5 links.
# Henderson-4543: Extracted 0 links.
# Henderson-3132: Extracted 1 links.
# Henderson-4542: Extracted 0 links.
# Henderson-2211: Extracted 0 links.
# Henderson-6222: Extracted 0 links.
# Henderson-5321: Extracted 0 links.
# Henderson-6219: Extracted 0 links.
# Henderson-5615: Extracted 0 links.
# Henderson-9221: Extracted 33 links.
# Henderson-5413: Extracted 0 links.
# Henderson-4882: Extracted 8 links.
# Henderson-1113: Extracted 12 links.
# Henderson-3211: Extracted 0 links.
# Henderson-3379: Extracted 0 links.
# Henderson-4481: Extracted 0 links.
# Henderson-3341: Extracted 0 links.
# Henderson-5324: Extracted 3 links.
# Henderson-7114: Extracted 1 links.
# Henderson-7225: Extracted 100 links.
# Henderson-1132: Extracted 0 links.
# Henderson-3361: Extracted 0 links.
# Henderson-4532: Extracted 0 links.
# Henderson-4881: Extracted 0 links.
# Henderson-1152: Extracted 0 links.
# Henderson-5242: Extracted 41 links.
# Henderson-5191: Extracted 0 links.
# Henderson-5415: Extracted 16 links.
# Henderson-3366: Extracted 0 links.
# Henderson-1122: Extracted 0 links.
# Henderson-3114: Extracted 2 links.
# Henderson-4523: Extracted 0 links.
# Henderson-7223: Extracted 10 links.
# Henderson-4871: Extracted 1 links.
# Henderson-5223: Extracted 5 links.
# Henderson-3322: Extracted 1 links.
# Henderson-6241: Extracted 78 links.
# Henderson-4883: Extracted 0 links.
# Henderson-4921: Extracted 2 links.
# Batch 9 completed.
# Processing batch 10/10...
# Batch 10/10:   0%|          | 0/420 [00:00<?, ?it/s]
# Henderson-5619: Extracted 16 links.
# Henderson-3315: Extracted 0 links.
# Henderson-1123: Extracted 0 links.
# Henderson-1141: Extracted 0 links.
# Henderson-3333: Extracted 4 links.
# Henderson-5621: Extracted 11 links.
# Henderson-3169: Extracted 0 links.
# Henderson-6232: Extracted 0 links.
# Henderson-9231: Extracted 6 links.
# Henderson-1119: Extracted 0 links.
# Henderson-2122: Extracted 0 links.
# Henderson-3115: Extracted 0 links.
# Henderson-5173: Extracted 0 links.
# Henderson-4241: Extracted 1 links.
# Henderson-3325: Extracted 0 links.
# Henderson-8134: Extracted 0 links.
# Henderson-3121: Extracted 19 links.
# Henderson-4862: Extracted 0 links.
# Henderson-3241: Extracted 0 links.
# Henderson-7115: Extracted 0 links.
# Henderson-3399: Extracted 21 links.
# Henderson-3133: Extracted 0 links.
# Henderson-4413: Extracted 25 links.
# Henderson-8141: Extracted 0 links.
# Henderson-4841: Extracted 11 links.
# Henderson-3343: Extracted 0 links.
# Henderson-7211: Extracted 0 links.
# Henderson-4832: Extracted 1 links.
# Henderson-5179: Extracted 0 links.
# Henderson-5322: Extracted 8 links.
# Henderson-4245: Extracted 0 links.
# Henderson-4246: Extracted 1 links.
# Henderson-5241: Extracted 5 links.
# Henderson-4244: Extracted 10 links.
# Henderson-3346: Extracted 0 links.
# Henderson-8123: Extracted 0 links.
# Henderson-1151: Extracted 2 links.
# Henderson-5111: Extracted 0 links.
# Henderson-3351: Extracted 1 links.
# Henderson-1111: Extracted 0 links.
# Henderson-3262: Extracted 0 links.
# Henderson-2213: Extracted 2 links.
# Henderson-6117: Extracted 11 links.
# Henderson-3353: Extracted 1 links.
# Henderson-3117: Extracted 0 links.
# Henderson-7111: Extracted 8 links.
# Henderson-3272: Extracted 0 links.
# Henderson-4233: Extracted 11 links.
# Henderson-4931: Extracted 12 links.
# Henderson-6244: Extracted 0 links.
# Henderson-1142: Extracted 2 links.
# Henderson-3336: Extracted 0 links.
# Henderson-4854: Extracted 0 links.
# Henderson-3141: Extracted 0 links.
# Henderson-3231: Extracted 9 links.
# Henderson-4235: Extracted 5 links.
# Henderson-9241: Extracted 0 links.
# Henderson-1153: Extracted 1 links.
# Henderson-4539: Extracted 0 links.
# Henderson-2362: Extracted 0 links.
# Henderson-4911: Extracted 14 links.
# Henderson-5611: Extracted 0 links.
# Henderson-3251: Extracted 0 links.
# Henderson-7113: Extracted 8 links.
# Henderson-3352: Extracted 1 links.
# Henderson-6213: Extracted 100 links.
# Henderson-1125: Extracted 0 links.
# Henderson-5259: Extracted 0 links.
# Henderson-4422: Extracted 0 links.
# Henderson-6116: Extracted 0 links.
# Henderson-4879: Extracted 0 links.
# Henderson-5221: Extracted 31 links.
# Henderson-5182: Extracted 0 links.
# Henderson-3332: Extracted 2 links.
# Henderson-5222: Extracted 33 links.
# Henderson-7212: Extracted 42 links.
# Henderson-5417: Extracted 16 links.
# Henderson-3369: Extracted 3 links.
# Henderson-3131: Extracted 0 links.
# Henderson-3326: Extracted 0 links.
# Henderson-5311: Extracted 74 links.
# Henderson-3149: Extracted 1 links.
# Henderson-4861: Extracted 0 links.
# Henderson-5174: Extracted 0 links.
# Henderson-5151: Extracted 0 links.
# Henderson-4852: Extracted 1 links.
# Henderson-3359: Extracted 0 links.
# Henderson-3321: Extracted 0 links.
# Henderson-4483: Extracted 0 links.
# Henderson-1133: Extracted 5 links.
# Henderson-3161: Extracted 1 links.
# Henderson-4842: Extracted 28 links.
# Henderson-6111: Extracted 42 links.
# Henderson-9261: Extracted 7 links.
# Henderson-3222: Extracted 0 links.
# Henderson-4853: Extracted 4 links.
# Henderson-5412: Extracted 40 links.
# Henderson-4232: Extracted 3 links.
# Henderson-3329: Extracted 2 links.
# Henderson-4885: Extracted 3 links.
# Henderson-4243: Extracted 0 links.
# Henderson-3112: Extracted 0 links.
# Henderson-2379: Extracted 3 links.
# Henderson-4451: Extracted 41 links.
# Henderson-4889: Extracted 0 links.
# Henderson-3334: Extracted 1 links.
# Henderson-5416: Extracted 72 links.
# Henderson-1124: Extracted 0 links.
# Henderson-3252: Extracted 2 links.
# Henderson-3331: Extracted 0 links.
# Henderson-3256: Extracted 3 links.
# Henderson-4231: Extracted 7 links.
# Henderson-6223: Extracted 2 links.
# Henderson-3152: Extracted 0 links.
# Henderson-5418: Extracted 28 links.
# Henderson-5511: Extracted 14 links.
# Henderson-3151: Extracted 0 links.
# Henderson-1121: Extracted 0 links.
# Henderson-4872: Extracted 0 links.
# Henderson-5112: Extracted 0 links.
# Henderson-8121: Extracted 100 links.
# Henderson-4239: Extracted 6 links.
# Henderson-5613: Extracted 8 links.
# Henderson-6242: Extracted 3 links.
# Henderson-5122: Extracted 1 links.
# Henderson-8111: Extracted 100 links.
# Henderson-3122: Extracted 0 links.
# Henderson-3111: Extracted 0 links.
# Henderson-4452: Extracted 28 links.
# Henderson-4234: Extracted 12 links.
# Henderson-1131: Extracted 0 links.
# Henderson-5121: Extracted 7 links.
# Henderson-4869: Extracted 0 links.
# Henderson-3162: Extracted 0 links.
# Henderson-3328: Extracted 2 links.
# Henderson-5616: Extracted 13 links.
# Henderson-6211: Extracted 100 links.
# Henderson-7213: Extracted 0 links.
# Henderson-3362: Extracted 0 links.
# Henderson-4859: Extracted 1 links.
# Henderson-3273: Extracted 4 links.
# Henderson-5232: Extracted 0 links.
# Henderson-3261: Extracted 6 links.
# Henderson-4482: Extracted 0 links.
# Henderson-4541: Extracted 0 links.
# Henderson-6115: Extracted 1 links.
# Henderson-5323: Extracted 1 links.
# Henderson-4238: Extracted 24 links.
# Henderson-8114: Extracted 37 links.
# Henderson-4922: Extracted 0 links.
# Henderson-5313: Extracted 15 links.
# Henderson-5629: Extracted 4 links.
# Henderson-8139: Extracted 38 links.
# Henderson-2111: Extracted 1 links.
# Henderson-3372: Extracted 0 links.
# Henderson-3364: Extracted 0 links.
# Henderson-3344: Extracted 0 links.
# Henderson-4251: Extracted 3 links.
# Henderson-4851: Extracted 0 links.
# Henderson-4461: Extracted 0 links.
# Henderson-2371: Extracted 7 links.
# Henderson-4522: Extracted 0 links.
# Henderson-3335: Extracted 7 links.
# Henderson-6112: Extracted 1 links.
# Henderson-2212: Extracted 2 links.
# Henderson-4533: Extracted 0 links.
# Henderson-3159: Extracted 0 links.
# Henderson-3345: Extracted 1 links.
# Henderson-5612: Extracted 0 links.
# Henderson-4531: Extracted 0 links.
# Henderson-3212: Extracted 0 links.
# Henderson-4242: Extracted 0 links.
# Henderson-8132: Extracted 2 links.
# Henderson-6231: Extracted 9 links.
# Henderson-6243: Extracted 9 links.
# Henderson-4831: Extracted 0 links.
# Henderson-4855: Extracted 0 links.
# Henderson-3323: Extracted 9 links.
# Henderson-3391: Extracted 8 links.
# Henderson-2381: Extracted 53 links.
# Henderson-1114: Extracted 3 links.
# Henderson-6113: Extracted 3 links.
# Henderson-5419: Extracted 67 links.
# Henderson-6212: Extracted 53 links.
# Henderson-4411: Extracted 35 links.
# Henderson-8113: Extracted 4 links.
# Henderson-9251: Extracted 5 links.
# Henderson-3274: Extracted 1 links.
# Henderson-4453: Extracted 7 links.
# Henderson-2131: Extracted 0 links.
# Henderson-5414: Extracted 19 links.
# Henderson-1129: Extracted 1 links.
# Henderson-7132: Extracted 0 links.
# Henderson-3219: Extracted 6 links.
# Henderson-6233: Extracted 31 links.
# Henderson-6214: Extracted 7 links.
# Henderson-3118: Extracted 11 links.
# Henderson-4511: Extracted 0 links.
# Henderson-3371: Extracted 15 links.
# Henderson-3254: Extracted 2 links.
# Henderson-4237: Extracted 9 links.
# Henderson-3221: Extracted 1 links.
# Henderson-3116: Extracted 1 links.
# Henderson-4512: Extracted 0 links.
# Henderson-6239: Extracted 7 links.
# Henderson-5411: Extracted 70 links.
# Henderson-5617: Extracted 100 links.
# Henderson-3113: Extracted 2 links.
# Henderson-2382: Extracted 91 links.
# Henderson-5231: Extracted 21 links.
# Henderson-5312: Extracted 100 links.
# Henderson-7112: Extracted 1 links.
# Henderson-2361: Extracted 100 links.
# Henderson-4884: Extracted 10 links.
# Henderson-8131: Extracted 100 links.
# Henderson-7139: Extracted 48 links.
# Henderson-3313: Extracted 0 links.
# Henderson-3271: Extracted 0 links.
# Henderson-8122: Extracted 10 links.
# Henderson-4236: Extracted 13 links.
# Henderson-3339: Extracted 5 links.
# Henderson-5251: Extracted 0 links.
# Henderson-3363: Extracted 7 links.
# Henderson-4421: Extracted 0 links.
# Henderson-4248: Extracted 1 links.
# Henderson-4441: Extracted 41 links.
# Henderson-3259: Extracted 1 links.
# Henderson-6215: Extracted 2 links.
# Henderson-3253: Extracted 2 links.
# Henderson-3324: Extracted 0 links.
# Henderson-4249: Extracted 12 links.
# Henderson-6114: Extracted 4 links.
# Henderson-4821: Extracted 0 links.
# Henderson-5614: Extracted 5 links.
# Henderson-5239: Extracted 54 links.
# Henderson-5211: Extracted 0 links.
# Henderson-1112: Extracted 1 links.
# Henderson-7131: Extracted 1 links.
# Henderson-5152: Extracted 0 links.
# Henderson-3119: Extracted 2 links.
# Henderson-2383: Extracted 73 links.
# Henderson-3342: Extracted 0 links.
# Henderson-3312: Extracted 0 links.
# Henderson-3279: Extracted 2 links.
# Henderson-2373: Extracted 27 links.
# Henderson-3314: Extracted 0 links.
# Henderson-4811: Extracted 1 links.
# Henderson-2389: Extracted 42 links.
# Henderson-7121: Extracted 21 links.
# Henderson-2123: Extracted 3 links.
# Henderson-3255: Extracted 0 links.
# Henderson-4431: Extracted 0 links.
# Henderson-3311: Extracted 0 links.
# Henderson-3365: Extracted 0 links.
# Henderson-3327: Extracted 15 links.
# Henderson-9211: Extracted 77 links.
# Henderson-8112: Extracted 8 links.
# Henderson-4442: Extracted 0 links.
# Henderson-2372: Extracted 4 links.
# Henderson-8129: Extracted 50 links.
# Henderson-8133: Extracted 52 links.
# Henderson-5622: Extracted 1 links.
# Henderson-4247: Extracted 4 links.
# Jackson-4471: Extracted 0 links.
# Jackson-6216: Extracted 3 links.
# Jackson-5331: Extracted 0 links.
# Jackson-4812: Extracted 0 links.
# Jackson-2121: Extracted 0 links.
# Jackson-7224: Extracted 3 links.
# Jackson-9271: Extracted 0 links.
# Jackson-4412: Extracted 1 links.
# Jackson-9281: Extracted 2 links.
# Jackson-6221: Extracted 2 links.
# Jackson-4543: Extracted 0 links.
# Jackson-3132: Extracted 0 links.
# Jackson-4542: Extracted 0 links.
# Jackson-2211: Extracted 1 links.
# Jackson-6222: Extracted 1 links.
# Jackson-5321: Extracted 5 links.
# Jackson-6219: Extracted 14 links.
# Jackson-5615: Extracted 2 links.
# Jackson-9221: Extracted 15 links.
# Jackson-5413: Extracted 19 links.
# Jackson-4882: Extracted 1 links.
# Jackson-1113: Extracted 1 links.
# Jackson-3211: Extracted 0 links.
# Jackson-3379: Extracted 0 links.
# Jackson-4481: Extracted 0 links.
# Jackson-3341: Extracted 0 links.
# Jackson-5324: Extracted 0 links.
# Jackson-7114: Extracted 0 links.
# Jackson-7225: Extracted 100 links.
# Jackson-1132: Extracted 2 links.
# Jackson-3361: Extracted 0 links.
# Jackson-4532: Extracted 0 links.
# Jackson-4881: Extracted 1 links.
# Jackson-1152: Extracted 2 links.
# Jackson-5242: Extracted 12 links.
# Jackson-5191: Extracted 0 links.
# Jackson-5415: Extracted 4 links.
# Jackson-3366: Extracted 0 links.
# Jackson-1122: Extracted 0 links.
# Jackson-3114: Extracted 0 links.
# Jackson-4523: Extracted 0 links.
# Jackson-7223: Extracted 1 links.
# Jackson-4871: Extracted 0 links.
# Jackson-5223: Extracted 7 links.
# Jackson-3322: Extracted 0 links.
# Jackson-6241: Extracted 17 links.
# Jackson-4883: Extracted 1 links.
# Jackson-4921: Extracted 0 links.
# Jackson-5619: Extracted 4 links.
# Jackson-3315: Extracted 2 links.
# Jackson-1123: Extracted 0 links.
# Jackson-1141: Extracted 0 links.
# Jackson-3333: Extracted 1 links.
# Jackson-5621: Extracted 2 links.
# Jackson-3169: Extracted 0 links.
# Jackson-6232: Extracted 0 links.
# Jackson-9231: Extracted 2 links.
# Jackson-1119: Extracted 5 links.
# Jackson-2122: Extracted 0 links.
# Jackson-3115: Extracted 0 links.
# Jackson-5173: Extracted 0 links.
# Jackson-4241: Extracted 0 links.
# Jackson-3325: Extracted 0 links.
# Jackson-8134: Extracted 32 links.
# Jackson-3121: Extracted 5 links.
# Jackson-4862: Extracted 0 links.
# Jackson-3241: Extracted 0 links.
# Jackson-7115: Extracted 3 links.
# Jackson-3399: Extracted 4 links.
# Jackson-3133: Extracted 0 links.
# Jackson-4413: Extracted 8 links.
# Jackson-8141: Extracted 0 links.
# Jackson-4841: Extracted 3 links.
# Jackson-3343: Extracted 0 links.
# Jackson-7211: Extracted 37 links.
# Jackson-4832: Extracted 1 links.
# Jackson-5179: Extracted 0 links.
# Jackson-5322: Extracted 2 links.
# Jackson-4245: Extracted 0 links.
# Jackson-4246: Extracted 0 links.
# Jackson-5241: Extracted 0 links.
# Jackson-4244: Extracted 3 links.
# Jackson-3346: Extracted 0 links.
# Jackson-8123: Extracted 4 links.
# Jackson-1151: Extracted 0 links.
# Jackson-5111: Extracted 0 links.
# Jackson-3351: Extracted 0 links.
# Jackson-1111: Extracted 0 links.
# Jackson-3262: Extracted 0 links.
# Jackson-2213: Extracted 3 links.
# Jackson-6117: Extracted 3 links.
# Jackson-3353: Extracted 1 links.
# Jackson-3117: Extracted 0 links.
# Jackson-7111: Extracted 0 links.
# Jackson-3272: Extracted 0 links.
# Jackson-4233: Extracted 2 links.
# Jackson-4931: Extracted 3 links.
# Jackson-6244: Extracted 10 links.
# Jackson-1142: Extracted 0 links.
# Jackson-3336: Extracted 0 links.
# Jackson-4854: Extracted 2 links.
# Jackson-3141: Extracted 0 links.
# Jackson-3231: Extracted 1 links.
# Jackson-4235: Extracted 0 links.
# Jackson-9241: Extracted 2 links.
# Jackson-1153: Extracted 1 links.
# Jackson-4539: Extracted 0 links.
# Jackson-2362: Extracted 19 links.
# Jackson-4911: Extracted 9 links.
# Jackson-5611: Extracted 4 links.
# Jackson-3251: Extracted 0 links.
# Jackson-7113: Extracted 6 links.
# Jackson-3352: Extracted 0 links.
# Jackson-6213: Extracted 100 links.
# Jackson-1125: Extracted 0 links.
# Jackson-5259: Extracted 0 links.
# Jackson-4422: Extracted 0 links.
# Jackson-6116: Extracted 4 links.
# Jackson-4879: Extracted 1 links.
# Jackson-5221: Extracted 14 links.
# Jackson-5182: Extracted 3 links.
# Jackson-3332: Extracted 0 links.
# Jackson-5222: Extracted 5 links.
# Jackson-7212: Extracted 11 links.
# Jackson-5417: Extracted 4 links.
# Jackson-3369: Extracted 0 links.
# Jackson-3131: Extracted 0 links.
# Jackson-3326: Extracted 0 links.
# Jackson-5311: Extracted 32 links.
# Jackson-3149: Extracted 1 links.
# Jackson-4861: Extracted 0 links.
# Jackson-5174: Extracted 0 links.
# Jackson-5151: Extracted 0 links.
# Jackson-4852: Extracted 1 links.
# Jackson-3359: Extracted 0 links.
# Jackson-3321: Extracted 1 links.
# Jackson-4483: Extracted 0 links.
# Jackson-1133: Extracted 2 links.
# Jackson-3161: Extracted 0 links.
# Jackson-4842: Extracted 4 links.
# Jackson-6111: Extracted 16 links.
# Jackson-9261: Extracted 2 links.
# Jackson-3222: Extracted 1 links.
# Jackson-4853: Extracted 3 links.
# Jackson-5412: Extracted 14 links.
# Jackson-4232: Extracted 0 links.
# Jackson-3329: Extracted 0 links.
# Jackson-4885: Extracted 1 links.
# Jackson-4243: Extracted 1 links.
# Jackson-3112: Extracted 0 links.
# Jackson-2379: Extracted 2 links.
# Jackson-4451: Extracted 16 links.
# Jackson-4889: Extracted 0 links.
# Jackson-3334: Extracted 0 links.
# Jackson-5416: Extracted 16 links.
# Jackson-1124: Extracted 1 links.
# Jackson-3252: Extracted 0 links.
# Batch 10 completed.
# All tasks from batch 9 to 10 completed. Links are written to all_links.txt.

# %%
with open("all_links.txt",'r') as f:
    all_links = f.readlines()
len(set(all_links))
# Out:
# 13401

# %%
with open("qnaics_codes.txt", 'r') as f:
    codes = [line.strip() for line in f.readlines()]

    # Define counties
counties = [
        "Alexander", "Alleghany", "Ashe", "Avery", "Buncombe", "Burke",
        "Caldwell", "Catawba", "Clay", "Cleveland", "Gaston", "Haywood",
        "Henderson", "Jackson", "Lincoln", "Macon", "Madison", "McDowell",
        "Mecklenburg", "Mitchell", "Polk", "Rutherford", "Swain",
        "Transylvania", "Watauga", "Wilkes", "Yancey"
    ]

    # Combine counties and NAICS codes into pairs
tasks_data = [(county, code) for county in counties for code in codes]
batches = split_into_batches(tasks_data,20)
batches[18]
# Out:
# [('Watauga', '1125'),
#  ('Watauga', '5621'),
#  ('Watauga', '3345'),
#  ('Watauga', '4872'),
#  ('Watauga', '3379'),
#  ('Watauga', '3118'),
#  ('Watauga', '2361'),
#  ('Watauga', '9231'),
#  ('Watauga', '5416'),
#  ('Watauga', '3314'),
#  ('Watauga', '3122'),
#  ('Watauga', '3369'),
#  ('Watauga', '5322'),
#  ('Watauga', '3131'),
#  ('Watauga', '3336'),
#  ('Watauga', '2121'),
#  ('Watauga', '2372'),
#  ('Watauga', '6215'),
#  ('Watauga', '3353'),
#  ('Watauga', '3149'),
#  ('Watauga', '3399'),
#  ('Watauga', '3121'),
#  ('Watauga', '3256'),
#  ('Watauga', '3279'),
#  ('Watauga', '4821'),
#  ('Watauga', '4859'),
#  ('Watauga', '4241'),
#  ('Watauga', '4452'),
#  ('Watauga', '3259'),
#  ('Watauga', '9261'),
#  ('Watauga', '6213'),
#  ('Watauga', '4853'),
#  ('Watauga', '5231'),
#  ('Watauga', '4841'),
#  ('Watauga', '3115'),
#  ('Watauga', '5112'),
#  ('Watauga', '3152'),
#  ('Watauga', '6233'),
#  ('Watauga', '1122'),
#  ('Watauga', '8121'),
#  ('Watauga', '7212'),
#  ('Watauga', '4812'),
#  ('Watauga', '3151'),
#  ('Watauga', '3325'),
#  ('Watauga', '5173'),
#  ('Watauga', '1111'),
#  ('Watauga', '5321'),
#  ('Watauga', '8122'),
#  ('Watauga', '2373'),
#  ('Watauga', '7115'),
#  ('Watauga', '1119'),
#  ('Watauga', '4871'),
#  ('Watauga', '4855'),
#  ('Watauga', '3253'),
#  ('Watauga', '3332'),
#  ('Watauga', '3362'),
#  ('Watauga', '3241'),
#  ('Watauga', '3261'),
#  ('Watauga', '2131'),
#  ('Watauga', '3161'),
#  ('Watauga', '3341'),
#  ('Watauga', '7112'),
#  ('Watauga', '4543'),
#  ('Watauga', '1123'),
#  ('Watauga', '7121'),
#  ('Watauga', '3334'),
#  ('Watauga', '5619'),
#  ('Watauga', '3159'),
#  ('Watauga', '6114'),
#  ('Watauga', '5182'),
#  ('Watauga', '3252'),
#  ('Watauga', '8141'),
#  ('Watauga', '9281'),
#  ('Watauga', '4243'),
#  ('Watauga', '5323'),
#  ('Watauga', '7211'),
#  ('Watauga', '1152'),
#  ('Watauga', '8123'),
#  ('Watauga', '5331'),
#  ('Watauga', '5121'),
#  ('Watauga', '9221'),
#  ('Watauga', '4862'),
#  ('Watauga', '1142'),
#  ('Watauga', '3251'),
#  ('Watauga', '5311'),
#  ('Watauga', '3324'),
#  ('Watauga', '4881'),
#  ('Watauga', '5151'),
#  ('Watauga', '5174'),
#  ('Watauga', '5413'),
#  ('Watauga', '4539'),
#  ('Watauga', '3342'),
#  ('Watauga', '3255'),
#  ('Watauga', '4249'),
#  ('Watauga', '4852'),
#  ('Watauga', '3117'),
#  ('Watauga', '1141'),
#  ('Watauga', '3322'),
#  ('Watauga', '5251'),
#  ('Watauga', '5211'),
#  ('Watauga', '5312'),
#  ('Watauga', '5223'),
#  ('Watauga', '8113'),
#  ('Watauga', '5179'),
#  ('Watauga', '4842'),
#  ('Watauga', '7225'),
#  ('Watauga', '1113'),
#  ('Watauga', '4882'),
#  ('Watauga', '3141'),
#  ('Watauga', '3114'),
#  ('Watauga', '2382'),
#  ('Watauga', '5411'),
#  ('Watauga', '5222'),
#  ('Watauga', '1124'),
#  ('Watauga', '6116'),
#  ('Watauga', '4869'),
#  ('Watauga', '6222'),
#  ('Watauga', '6239'),
#  ('Watauga', '4246'),
#  ('Watauga', '4811'),
#  ('Watauga', '3328'),
#  ('Watauga', '3162'),
#  ('Watauga', '7113'),
#  ('Watauga', '1132'),
#  ('Watauga', '2362'),
#  ('Watauga', '1112'),
#  ('Watauga', '2371'),
#  ('Watauga', '9251'),
#  ('Watauga', '5414'),
#  ('Watauga', '4431'),
#  ('Watauga', '6243'),
#  ('Watauga', '6112'),
#  ('Watauga', '2383'),
#  ('Watauga', '2379'),
#  ('Watauga', '3116'),
#  ('Watauga', '3169'),
#  ('Watauga', '4879'),
#  ('Watauga', '4413'),
#  ('Watauga', '5419'),
#  ('Watauga', '3133'),
#  ('Watauga', '2211'),
#  ('Watauga', '4453'),
#  ('Watauga', '3366'),
#  ('Watauga', '8134'),
#  ('Watauga', '1153'),
#  ('Watauga', '4542'),
#  ('Watauga', '4532'),
#  ('Watauga', '5417'),
#  ('Watauga', '4239'),
#  ('Watauga', '3312'),
#  ('Watauga', '4248'),
#  ('Watauga', '1131'),
#  ('Watauga', '6212'),
#  ('Watauga', '5616'),
#  ('Watauga', '4242'),
#  ('Watauga', '3327'),
#  ('Watauga', '3346'),
#  ('Watauga', '7132'),
#  ('Watauga', '5415'),
#  ('Watauga', '3274'),
#  ('Watauga', '3315'),
#  ('Watauga', '4481'),
#  ('Watauga', '1114'),
#  ('Watauga', '4854'),
#  ('Watauga', '5122'),
#  ('Watauga', '3364'),
#  ('Watauga', '3262'),
#  ('Watauga', '4931'),
#  ('Watauga', '3359'),
#  ('Watauga', '6242'),
#  ('Watauga', '4861'),
#  ('Watauga', '4471'),
#  ('Watauga', '3311'),
#  ('Watauga', '3222'),
#  ('Watauga', '4482'),
#  ('Watauga', '3339'),
#  ('Watauga', '5617'),
#  ('Watauga', '6113'),
#  ('Watauga', '4832'),
#  ('Watauga', '3331'),
#  ('Watauga', '4921'),
#  ('Watauga', '8112'),
#  ('Watauga', '4461'),
#  ('Watauga', '3273'),
#  ('Watauga', '4523'),
#  ('Watauga', '6211'),
#  ('Watauga', '5111'),
#  ('Watauga', '4247'),
#  ('Watauga', '3271'),
#  ('Watauga', '3343'),
#  ('Watauga', '4522'),
#  ('Watauga', '2381'),
#  ('Watauga', '5152'),
#  ('Watauga', '3372'),
#  ('Watauga', '4245'),
#  ('Watauga', '9271'),
#  ('Watauga', '3113'),
#  ('Watauga', '4922'),
#  ('Watauga', '4236'),
#  ('Watauga', '5259'),
#  ('Watauga', '4889'),
#  ('Watauga', '4531'),
#  ('Watauga', '6214'),
#  ('Watauga', '8114'),
#  ('Watauga', '1129'),
#  ('Watauga', '3272'),
#  ('Watauga', '3323'),
#  ('Watauga', '6115'),
#  ('Watauga', '5611'),
#  ('Watauga', '8131'),
#  ('Watauga', '1133'),
#  ('Watauga', '6219'),
#  ('Watauga', '5614'),
#  ('Watauga', '3231'),
#  ('Watauga', '4251'),
#  ('Wilkes', '3321'),
#  ('Wilkes', '4884'),
#  ('Wilkes', '2122'),
#  ('Wilkes', '3313'),
#  ('Wilkes', '5232'),
#  ('Wilkes', '3132'),
#  ('Wilkes', '3391'),
#  ('Wilkes', '3365'),
#  ('Wilkes', '1151'),
#  ('Wilkes', '5324'),
#  ('Wilkes', '4541'),
#  ('Wilkes', '3344'),
#  ('Wilkes', '4442'),
#  ('Wilkes', '3111'),
#  ('Wilkes', '3112'),
#  ('Wilkes', '4512'),
#  ('Wilkes', '5613'),
#  ('Wilkes', '3333'),
#  ('Wilkes', '6231'),
#  ('Wilkes', '8132'),
#  ('Wilkes', '4231'),
#  ('Wilkes', '3326'),
#  ('Wilkes', '3329'),
#  ('Wilkes', '6223'),
#  ('Wilkes', '5511'),
#  ('Wilkes', '5239'),
#  ('Wilkes', '5615'),
#  ('Wilkes', '8139'),
#  ('Wilkes', '6244'),
#  ('Wilkes', '6221'),
#  ('Wilkes', '5418'),
#  ('Wilkes', '3211'),
#  ('Wilkes', '4235'),
#  ('Wilkes', '5412'),
#  ('Wilkes', '5622'),
#  ('Wilkes', '5612'),
#  ('Wilkes', '4451'),
#  ('Wilkes', '5191'),
#  ('Wilkes', '3254'),
#  ('Wilkes', '3212'),
#  ('Wilkes', '4411'),
#  ('Wilkes', '4233'),
#  ('Wilkes', '6232'),
#  ('Wilkes', '3352'),
#  ('Wilkes', '4483'),
#  ('Wilkes', '7224'),
#  ('Wilkes', '3219'),
#  ('Wilkes', '3361'),
#  ('Wilkes', '5242'),
#  ('Wilkes', '4244'),
#  ('Wilkes', '4851'),
#  ('Wilkes', '5221'),
#  ('Wilkes', '5629'),
#  ('Wilkes', '4533'),
#  ('Wilkes', '4234'),
#  ('Wilkes', '4238'),
#  ('Wilkes', '4911'),
#  ('Wilkes', '7111'),
#  ('Wilkes', '7131'),
#  ('Wilkes', '4441'),
#  ('Wilkes', '2111'),
#  ('Wilkes', '9211'),
#  ('Wilkes', '7114'),
#  ('Wilkes', '5241'),
#  ('Wilkes', '8133'),
#  ('Wilkes', '3119'),
#  ('Wilkes', '6241'),
#  ('Wilkes', '8129'),
#  ('Wilkes', '8111'),
#  ('Wilkes', '3221'),
#  ('Wilkes', '4237'),
#  ('Wilkes', '7223'),
#  ('Wilkes', '2213'),
#  ('Wilkes', '5313'),
#  ('Wilkes', '6111'),
#  ('Wilkes', '4422'),
#  ('Wilkes', '7139'),
#  ('Wilkes', '3335'),
#  ('Wilkes', '4421'),
#  ('Wilkes', '4831'),
#  ('Wilkes', '2212'),
#  ('Wilkes', '4232'),
#  ('Wilkes', '4883'),
#  ('Wilkes', '6117'),
#  ('Wilkes', '2389'),
#  ('Wilkes', '3363'),
#  ('Wilkes', '7213'),
#  ('Wilkes', '4885'),
#  ('Wilkes', '3371'),
#  ('Wilkes', '9241'),
#  ('Wilkes', '2123'),
#  ('Wilkes', '4511'),
#  ('Wilkes', '3351'),
#  ('Wilkes', '4412'),
#  ('Wilkes', '1121'),
#  ('Wilkes', '6216'),
#  ('Wilkes', '1125'),
#  ('Wilkes', '5621'),
#  ('Wilkes', '3345'),
#  ('Wilkes', '4872'),
#  ('Wilkes', '3379'),
#  ('Wilkes', '3118'),
#  ('Wilkes', '2361'),
#  ('Wilkes', '9231'),
#  ('Wilkes', '5416'),
#  ('Wilkes', '3314'),
#  ('Wilkes', '3122'),
#  ('Wilkes', '3369'),
#  ('Wilkes', '5322'),
#  ('Wilkes', '3131'),
#  ('Wilkes', '3336'),
#  ('Wilkes', '2121'),
#  ('Wilkes', '2372'),
#  ('Wilkes', '6215'),
#  ('Wilkes', '3353'),
#  ('Wilkes', '3149'),
#  ('Wilkes', '3399'),
#  ('Wilkes', '3121'),
#  ('Wilkes', '3256'),
#  ('Wilkes', '3279'),
#  ('Wilkes', '4821'),
#  ('Wilkes', '4859'),
#  ('Wilkes', '4241'),
#  ('Wilkes', '4452'),
#  ('Wilkes', '3259'),
#  ('Wilkes', '9261'),
#  ('Wilkes', '6213'),
#  ('Wilkes', '4853'),
#  ('Wilkes', '5231'),
#  ('Wilkes', '4841'),
#  ('Wilkes', '3115'),
#  ('Wilkes', '5112'),
#  ('Wilkes', '3152'),
#  ('Wilkes', '6233'),
#  ('Wilkes', '1122'),
#  ('Wilkes', '8121'),
#  ('Wilkes', '7212'),
#  ('Wilkes', '4812'),
#  ('Wilkes', '3151'),
#  ('Wilkes', '3325'),
#  ('Wilkes', '5173'),
#  ('Wilkes', '1111'),
#  ('Wilkes', '5321'),
#  ('Wilkes', '8122'),
#  ('Wilkes', '2373'),
#  ('Wilkes', '7115'),
#  ('Wilkes', '1119'),
#  ('Wilkes', '4871'),
#  ('Wilkes', '4855'),
#  ('Wilkes', '3253'),
#  ('Wilkes', '3332'),
#  ('Wilkes', '3362'),
#  ('Wilkes', '3241'),
#  ('Wilkes', '3261'),
#  ('Wilkes', '2131'),
#  ('Wilkes', '3161'),
#  ('Wilkes', '3341'),
#  ('Wilkes', '7112'),
#  ('Wilkes', '4543'),
#  ('Wilkes', '1123'),
#  ('Wilkes', '7121'),
#  ('Wilkes', '3334'),
#  ('Wilkes', '5619'),
#  ('Wilkes', '3159'),
#  ('Wilkes', '6114'),
#  ('Wilkes', '5182'),
#  ('Wilkes', '3252'),
#  ('Wilkes', '8141'),
#  ('Wilkes', '9281'),
#  ('Wilkes', '4243'),
#  ('Wilkes', '5323'),
#  ('Wilkes', '7211'),
#  ('Wilkes', '1152'),
#  ('Wilkes', '8123'),
#  ('Wilkes', '5331'),
#  ('Wilkes', '5121'),
#  ('Wilkes', '9221'),
#  ('Wilkes', '4862'),
#  ('Wilkes', '1142'),
#  ('Wilkes', '3251'),
#  ('Wilkes', '5311'),
#  ('Wilkes', '3324'),
#  ('Wilkes', '4881'),
#  ('Wilkes', '5151'),
#  ('Wilkes', '5174'),
#  ('Wilkes', '5413'),
#  ('Wilkes', '4539'),
#  ('Wilkes', '3342'),
#  ('Wilkes', '3255'),
#  ('Wilkes', '4249'),
#  ('Wilkes', '4852'),
#  ('Wilkes', '3117'),
#  ('Wilkes', '1141'),
#  ('Wilkes', '3322'),
#  ('Wilkes', '5251'),
#  ('Wilkes', '5211'),
#  ('Wilkes', '5312'),
#  ('Wilkes', '5223'),
#  ('Wilkes', '8113'),
#  ('Wilkes', '5179'),
#  ('Wilkes', '4842'),
#  ('Wilkes', '7225'),
#  ('Wilkes', '1113'),
#  ('Wilkes', '4882'),
#  ('Wilkes', '3141')]

# %%
with open("tasks_data.txt",'w') as f:
    for i in tasks_data:
        f.write(str(i))
        f.write("\n")

# %%
problematic_counties = ["Caldwell", "Cleveland","Gaston",'Rutherford','Lincoln',"Jackson",
                        "Madison",'Mecklenburg',"McDowell","Rutherford",'Watauga',"Wilkes","Polk"] 
problematic_tasks =  [(county, code) for county in problematic_counties for code in codes]

# %%
len(problematic_tasks)
# Out:
# 4043

# %%
problematic_tasks
# Out:
# [('Caldwell', '3321'),
#  ('Caldwell', '4884'),
#  ('Caldwell', '2122'),
#  ('Caldwell', '3313'),
#  ('Caldwell', '5232'),
#  ('Caldwell', '3132'),
#  ('Caldwell', '3391'),
#  ('Caldwell', '3365'),
#  ('Caldwell', '1151'),
#  ('Caldwell', '5324'),
#  ('Caldwell', '4541'),
#  ('Caldwell', '3344'),
#  ('Caldwell', '4442'),
#  ('Caldwell', '3111'),
#  ('Caldwell', '3112'),
#  ('Caldwell', '4512'),
#  ('Caldwell', '5613'),
#  ('Caldwell', '3333'),
#  ('Caldwell', '6231'),
#  ('Caldwell', '8132'),
#  ('Caldwell', '4231'),
#  ('Caldwell', '3326'),
#  ('Caldwell', '3329'),
#  ('Caldwell', '6223'),
#  ('Caldwell', '5511'),
#  ('Caldwell', '5239'),
#  ('Caldwell', '5615'),
#  ('Caldwell', '8139'),
#  ('Caldwell', '6244'),
#  ('Caldwell', '6221'),
#  ('Caldwell', '5418'),
#  ('Caldwell', '3211'),
#  ('Caldwell', '4235'),
#  ('Caldwell', '5412'),
#  ('Caldwell', '5622'),
#  ('Caldwell', '5612'),
#  ('Caldwell', '4451'),
#  ('Caldwell', '5191'),
#  ('Caldwell', '3254'),
#  ('Caldwell', '3212'),
#  ('Caldwell', '4411'),
#  ('Caldwell', '4233'),
#  ('Caldwell', '6232'),
#  ('Caldwell', '3352'),
#  ('Caldwell', '4483'),
#  ('Caldwell', '7224'),
#  ('Caldwell', '3219'),
#  ('Caldwell', '3361'),
#  ('Caldwell', '5242'),
#  ('Caldwell', '4244'),
#  ('Caldwell', '4851'),
#  ('Caldwell', '5221'),
#  ('Caldwell', '5629'),
#  ('Caldwell', '4533'),
#  ('Caldwell', '4234'),
#  ('Caldwell', '4238'),
#  ('Caldwell', '4911'),
#  ('Caldwell', '7111'),
#  ('Caldwell', '7131'),
#  ('Caldwell', '4441'),
#  ('Caldwell', '2111'),
#  ('Caldwell', '9211'),
#  ('Caldwell', '7114'),
#  ('Caldwell', '5241'),
#  ('Caldwell', '8133'),
#  ('Caldwell', '3119'),
#  ('Caldwell', '6241'),
#  ('Caldwell', '8129'),
#  ('Caldwell', '8111'),
#  ('Caldwell', '3221'),
#  ('Caldwell', '4237'),
#  ('Caldwell', '7223'),
#  ('Caldwell', '2213'),
#  ('Caldwell', '5313'),
#  ('Caldwell', '6111'),
#  ('Caldwell', '4422'),
#  ('Caldwell', '7139'),
#  ('Caldwell', '3335'),
#  ('Caldwell', '4421'),
#  ('Caldwell', '4831'),
#  ('Caldwell', '2212'),
#  ('Caldwell', '4232'),
#  ('Caldwell', '4883'),
#  ('Caldwell', '6117'),
#  ('Caldwell', '2389'),
#  ('Caldwell', '3363'),
#  ('Caldwell', '7213'),
#  ('Caldwell', '4885'),
#  ('Caldwell', '3371'),
#  ('Caldwell', '9241'),
#  ('Caldwell', '2123'),
#  ('Caldwell', '4511'),
#  ('Caldwell', '3351'),
#  ('Caldwell', '4412'),
#  ('Caldwell', '1121'),
#  ('Caldwell', '6216'),
#  ('Caldwell', '1125'),
#  ('Caldwell', '5621'),
#  ('Caldwell', '3345'),
#  ('Caldwell', '4872'),
#  ('Caldwell', '3379'),
#  ('Caldwell', '3118'),
#  ('Caldwell', '2361'),
#  ('Caldwell', '9231'),
#  ('Caldwell', '5416'),
#  ('Caldwell', '3314'),
#  ('Caldwell', '3122'),
#  ('Caldwell', '3369'),
#  ('Caldwell', '5322'),
#  ('Caldwell', '3131'),
#  ('Caldwell', '3336'),
#  ('Caldwell', '2121'),
#  ('Caldwell', '2372'),
#  ('Caldwell', '6215'),
#  ('Caldwell', '3353'),
#  ('Caldwell', '3149'),
#  ('Caldwell', '3399'),
#  ('Caldwell', '3121'),
#  ('Caldwell', '3256'),
#  ('Caldwell', '3279'),
#  ('Caldwell', '4821'),
#  ('Caldwell', '4859'),
#  ('Caldwell', '4241'),
#  ('Caldwell', '4452'),
#  ('Caldwell', '3259'),
#  ('Caldwell', '9261'),
#  ('Caldwell', '6213'),
#  ('Caldwell', '4853'),
#  ('Caldwell', '5231'),
#  ('Caldwell', '4841'),
#  ('Caldwell', '3115'),
#  ('Caldwell', '5112'),
#  ('Caldwell', '3152'),
#  ('Caldwell', '6233'),
#  ('Caldwell', '1122'),
#  ('Caldwell', '8121'),
#  ('Caldwell', '7212'),
#  ('Caldwell', '4812'),
#  ('Caldwell', '3151'),
#  ('Caldwell', '3325'),
#  ('Caldwell', '5173'),
#  ('Caldwell', '1111'),
#  ('Caldwell', '5321'),
#  ('Caldwell', '8122'),
#  ('Caldwell', '2373'),
#  ('Caldwell', '7115'),
#  ('Caldwell', '1119'),
#  ('Caldwell', '4871'),
#  ('Caldwell', '4855'),
#  ('Caldwell', '3253'),
#  ('Caldwell', '3332'),
#  ('Caldwell', '3362'),
#  ('Caldwell', '3241'),
#  ('Caldwell', '3261'),
#  ('Caldwell', '2131'),
#  ('Caldwell', '3161'),
#  ('Caldwell', '3341'),
#  ('Caldwell', '7112'),
#  ('Caldwell', '4543'),
#  ('Caldwell', '1123'),
#  ('Caldwell', '7121'),
#  ('Caldwell', '3334'),
#  ('Caldwell', '5619'),
#  ('Caldwell', '3159'),
#  ('Caldwell', '6114'),
#  ('Caldwell', '5182'),
#  ('Caldwell', '3252'),
#  ('Caldwell', '8141'),
#  ('Caldwell', '9281'),
#  ('Caldwell', '4243'),
#  ('Caldwell', '5323'),
#  ('Caldwell', '7211'),
#  ('Caldwell', '1152'),
#  ('Caldwell', '8123'),
#  ('Caldwell', '5331'),
#  ('Caldwell', '5121'),
#  ('Caldwell', '9221'),
#  ('Caldwell', '4862'),
#  ('Caldwell', '1142'),
#  ('Caldwell', '3251'),
#  ('Caldwell', '5311'),
#  ('Caldwell', '3324'),
#  ('Caldwell', '4881'),
#  ('Caldwell', '5151'),
#  ('Caldwell', '5174'),
#  ('Caldwell', '5413'),
#  ('Caldwell', '4539'),
#  ('Caldwell', '3342'),
#  ('Caldwell', '3255'),
#  ('Caldwell', '4249'),
#  ('Caldwell', '4852'),
#  ('Caldwell', '3117'),
#  ('Caldwell', '1141'),
#  ('Caldwell', '3322'),
#  ('Caldwell', '5251'),
#  ('Caldwell', '5211'),
#  ('Caldwell', '5312'),
#  ('Caldwell', '5223'),
#  ('Caldwell', '8113'),
#  ('Caldwell', '5179'),
#  ('Caldwell', '4842'),
#  ('Caldwell', '7225'),
#  ('Caldwell', '1113'),
#  ('Caldwell', '4882'),
#  ('Caldwell', '3141'),
#  ('Caldwell', '3114'),
#  ('Caldwell', '2382'),
#  ('Caldwell', '5411'),
#  ('Caldwell', '5222'),
#  ('Caldwell', '1124'),
#  ('Caldwell', '6116'),
#  ('Caldwell', '4869'),
#  ('Caldwell', '6222'),
#  ('Caldwell', '6239'),
#  ('Caldwell', '4246'),
#  ('Caldwell', '4811'),
#  ('Caldwell', '3328'),
#  ('Caldwell', '3162'),
#  ('Caldwell', '7113'),
#  ('Caldwell', '1132'),
#  ('Caldwell', '2362'),
#  ('Caldwell', '1112'),
#  ('Caldwell', '2371'),
#  ('Caldwell', '9251'),
#  ('Caldwell', '5414'),
#  ('Caldwell', '4431'),
#  ('Caldwell', '6243'),
#  ('Caldwell', '6112'),
#  ('Caldwell', '2383'),
#  ('Caldwell', '2379'),
#  ('Caldwell', '3116'),
#  ('Caldwell', '3169'),
#  ('Caldwell', '4879'),
#  ('Caldwell', '4413'),
#  ('Caldwell', '5419'),
#  ('Caldwell', '3133'),
#  ('Caldwell', '2211'),
#  ('Caldwell', '4453'),
#  ('Caldwell', '3366'),
#  ('Caldwell', '8134'),
#  ('Caldwell', '1153'),
#  ('Caldwell', '4542'),
#  ('Caldwell', '4532'),
#  ('Caldwell', '5417'),
#  ('Caldwell', '4239'),
#  ('Caldwell', '3312'),
#  ('Caldwell', '4248'),
#  ('Caldwell', '1131'),
#  ('Caldwell', '6212'),
#  ('Caldwell', '5616'),
#  ('Caldwell', '4242'),
#  ('Caldwell', '3327'),
#  ('Caldwell', '3346'),
#  ('Caldwell', '7132'),
#  ('Caldwell', '5415'),
#  ('Caldwell', '3274'),
#  ('Caldwell', '3315'),
#  ('Caldwell', '4481'),
#  ('Caldwell', '1114'),
#  ('Caldwell', '4854'),
#  ('Caldwell', '5122'),
#  ('Caldwell', '3364'),
#  ('Caldwell', '3262'),
#  ('Caldwell', '4931'),
#  ('Caldwell', '3359'),
#  ('Caldwell', '6242'),
#  ('Caldwell', '4861'),
#  ('Caldwell', '4471'),
#  ('Caldwell', '3311'),
#  ('Caldwell', '3222'),
#  ('Caldwell', '4482'),
#  ('Caldwell', '3339'),
#  ('Caldwell', '5617'),
#  ('Caldwell', '6113'),
#  ('Caldwell', '4832'),
#  ('Caldwell', '3331'),
#  ('Caldwell', '4921'),
#  ('Caldwell', '8112'),
#  ('Caldwell', '4461'),
#  ('Caldwell', '3273'),
#  ('Caldwell', '4523'),
#  ('Caldwell', '6211'),
#  ('Caldwell', '5111'),
#  ('Caldwell', '4247'),
#  ('Caldwell', '3271'),
#  ('Caldwell', '3343'),
#  ('Caldwell', '4522'),
#  ('Caldwell', '2381'),
#  ('Caldwell', '5152'),
#  ('Caldwell', '3372'),
#  ('Caldwell', '4245'),
#  ('Caldwell', '9271'),
#  ('Caldwell', '3113'),
#  ('Caldwell', '4922'),
#  ('Caldwell', '4236'),
#  ('Caldwell', '5259'),
#  ('Caldwell', '4889'),
#  ('Caldwell', '4531'),
#  ('Caldwell', '6214'),
#  ('Caldwell', '8114'),
#  ('Caldwell', '1129'),
#  ('Caldwell', '3272'),
#  ('Caldwell', '3323'),
#  ('Caldwell', '6115'),
#  ('Caldwell', '5611'),
#  ('Caldwell', '8131'),
#  ('Caldwell', '1133'),
#  ('Caldwell', '6219'),
#  ('Caldwell', '5614'),
#  ('Caldwell', '3231'),
#  ('Caldwell', '4251'),
#  ('Cleveland', '3321'),
#  ('Cleveland', '4884'),
#  ('Cleveland', '2122'),
#  ('Cleveland', '3313'),
#  ('Cleveland', '5232'),
#  ('Cleveland', '3132'),
#  ('Cleveland', '3391'),
#  ('Cleveland', '3365'),
#  ('Cleveland', '1151'),
#  ('Cleveland', '5324'),
#  ('Cleveland', '4541'),
#  ('Cleveland', '3344'),
#  ('Cleveland', '4442'),
#  ('Cleveland', '3111'),
#  ('Cleveland', '3112'),
#  ('Cleveland', '4512'),
#  ('Cleveland', '5613'),
#  ('Cleveland', '3333'),
#  ('Cleveland', '6231'),
#  ('Cleveland', '8132'),
#  ('Cleveland', '4231'),
#  ('Cleveland', '3326'),
#  ('Cleveland', '3329'),
#  ('Cleveland', '6223'),
#  ('Cleveland', '5511'),
#  ('Cleveland', '5239'),
#  ('Cleveland', '5615'),
#  ('Cleveland', '8139'),
#  ('Cleveland', '6244'),
#  ('Cleveland', '6221'),
#  ('Cleveland', '5418'),
#  ('Cleveland', '3211'),
#  ('Cleveland', '4235'),
#  ('Cleveland', '5412'),
#  ('Cleveland', '5622'),
#  ('Cleveland', '5612'),
#  ('Cleveland', '4451'),
#  ('Cleveland', '5191'),
#  ('Cleveland', '3254'),
#  ('Cleveland', '3212'),
#  ('Cleveland', '4411'),
#  ('Cleveland', '4233'),
#  ('Cleveland', '6232'),
#  ('Cleveland', '3352'),
#  ('Cleveland', '4483'),
#  ('Cleveland', '7224'),
#  ('Cleveland', '3219'),
#  ('Cleveland', '3361'),
#  ('Cleveland', '5242'),
#  ('Cleveland', '4244'),
#  ('Cleveland', '4851'),
#  ('Cleveland', '5221'),
#  ('Cleveland', '5629'),
#  ('Cleveland', '4533'),
#  ('Cleveland', '4234'),
#  ('Cleveland', '4238'),
#  ('Cleveland', '4911'),
#  ('Cleveland', '7111'),
#  ('Cleveland', '7131'),
#  ('Cleveland', '4441'),
#  ('Cleveland', '2111'),
#  ('Cleveland', '9211'),
#  ('Cleveland', '7114'),
#  ('Cleveland', '5241'),
#  ('Cleveland', '8133'),
#  ('Cleveland', '3119'),
#  ('Cleveland', '6241'),
#  ('Cleveland', '8129'),
#  ('Cleveland', '8111'),
#  ('Cleveland', '3221'),
#  ('Cleveland', '4237'),
#  ('Cleveland', '7223'),
#  ('Cleveland', '2213'),
#  ('Cleveland', '5313'),
#  ('Cleveland', '6111'),
#  ('Cleveland', '4422'),
#  ('Cleveland', '7139'),
#  ('Cleveland', '3335'),
#  ('Cleveland', '4421'),
#  ('Cleveland', '4831'),
#  ('Cleveland', '2212'),
#  ('Cleveland', '4232'),
#  ('Cleveland', '4883'),
#  ('Cleveland', '6117'),
#  ('Cleveland', '2389'),
#  ('Cleveland', '3363'),
#  ('Cleveland', '7213'),
#  ('Cleveland', '4885'),
#  ('Cleveland', '3371'),
#  ('Cleveland', '9241'),
#  ('Cleveland', '2123'),
#  ('Cleveland', '4511'),
#  ('Cleveland', '3351'),
#  ('Cleveland', '4412'),
#  ('Cleveland', '1121'),
#  ('Cleveland', '6216'),
#  ('Cleveland', '1125'),
#  ('Cleveland', '5621'),
#  ('Cleveland', '3345'),
#  ('Cleveland', '4872'),
#  ('Cleveland', '3379'),
#  ('Cleveland', '3118'),
#  ('Cleveland', '2361'),
#  ('Cleveland', '9231'),
#  ('Cleveland', '5416'),
#  ('Cleveland', '3314'),
#  ('Cleveland', '3122'),
#  ('Cleveland', '3369'),
#  ('Cleveland', '5322'),
#  ('Cleveland', '3131'),
#  ('Cleveland', '3336'),
#  ('Cleveland', '2121'),
#  ('Cleveland', '2372'),
#  ('Cleveland', '6215'),
#  ('Cleveland', '3353'),
#  ('Cleveland', '3149'),
#  ('Cleveland', '3399'),
#  ('Cleveland', '3121'),
#  ('Cleveland', '3256'),
#  ('Cleveland', '3279'),
#  ('Cleveland', '4821'),
#  ('Cleveland', '4859'),
#  ('Cleveland', '4241'),
#  ('Cleveland', '4452'),
#  ('Cleveland', '3259'),
#  ('Cleveland', '9261'),
#  ('Cleveland', '6213'),
#  ('Cleveland', '4853'),
#  ('Cleveland', '5231'),
#  ('Cleveland', '4841'),
#  ('Cleveland', '3115'),
#  ('Cleveland', '5112'),
#  ('Cleveland', '3152'),
#  ('Cleveland', '6233'),
#  ('Cleveland', '1122'),
#  ('Cleveland', '8121'),
#  ('Cleveland', '7212'),
#  ('Cleveland', '4812'),
#  ('Cleveland', '3151'),
#  ('Cleveland', '3325'),
#  ('Cleveland', '5173'),
#  ('Cleveland', '1111'),
#  ('Cleveland', '5321'),
#  ('Cleveland', '8122'),
#  ('Cleveland', '2373'),
#  ('Cleveland', '7115'),
#  ('Cleveland', '1119'),
#  ('Cleveland', '4871'),
#  ('Cleveland', '4855'),
#  ('Cleveland', '3253'),
#  ('Cleveland', '3332'),
#  ('Cleveland', '3362'),
#  ('Cleveland', '3241'),
#  ('Cleveland', '3261'),
#  ('Cleveland', '2131'),
#  ('Cleveland', '3161'),
#  ('Cleveland', '3341'),
#  ('Cleveland', '7112'),
#  ('Cleveland', '4543'),
#  ('Cleveland', '1123'),
#  ('Cleveland', '7121'),
#  ('Cleveland', '3334'),
#  ('Cleveland', '5619'),
#  ('Cleveland', '3159'),
#  ('Cleveland', '6114'),
#  ('Cleveland', '5182'),
#  ('Cleveland', '3252'),
#  ('Cleveland', '8141'),
#  ('Cleveland', '9281'),
#  ('Cleveland', '4243'),
#  ('Cleveland', '5323'),
#  ('Cleveland', '7211'),
#  ('Cleveland', '1152'),
#  ('Cleveland', '8123'),
#  ('Cleveland', '5331'),
#  ('Cleveland', '5121'),
#  ('Cleveland', '9221'),
#  ('Cleveland', '4862'),
#  ('Cleveland', '1142'),
#  ('Cleveland', '3251'),
#  ('Cleveland', '5311'),
#  ('Cleveland', '3324'),
#  ('Cleveland', '4881'),
#  ('Cleveland', '5151'),
#  ('Cleveland', '5174'),
#  ('Cleveland', '5413'),
#  ('Cleveland', '4539'),
#  ('Cleveland', '3342'),
#  ('Cleveland', '3255'),
#  ('Cleveland', '4249'),
#  ('Cleveland', '4852'),
#  ('Cleveland', '3117'),
#  ('Cleveland', '1141'),
#  ('Cleveland', '3322'),
#  ('Cleveland', '5251'),
#  ('Cleveland', '5211'),
#  ('Cleveland', '5312'),
#  ('Cleveland', '5223'),
#  ('Cleveland', '8113'),
#  ('Cleveland', '5179'),
#  ('Cleveland', '4842'),
#  ('Cleveland', '7225'),
#  ('Cleveland', '1113'),
#  ('Cleveland', '4882'),
#  ('Cleveland', '3141'),
#  ('Cleveland', '3114'),
#  ('Cleveland', '2382'),
#  ('Cleveland', '5411'),
#  ('Cleveland', '5222'),
#  ('Cleveland', '1124'),
#  ('Cleveland', '6116'),
#  ('Cleveland', '4869'),
#  ('Cleveland', '6222'),
#  ('Cleveland', '6239'),
#  ('Cleveland', '4246'),
#  ('Cleveland', '4811'),
#  ('Cleveland', '3328'),
#  ('Cleveland', '3162'),
#  ('Cleveland', '7113'),
#  ('Cleveland', '1132'),
#  ('Cleveland', '2362'),
#  ('Cleveland', '1112'),
#  ('Cleveland', '2371'),
#  ('Cleveland', '9251'),
#  ('Cleveland', '5414'),
#  ('Cleveland', '4431'),
#  ('Cleveland', '6243'),
#  ('Cleveland', '6112'),
#  ('Cleveland', '2383'),
#  ('Cleveland', '2379'),
#  ('Cleveland', '3116'),
#  ('Cleveland', '3169'),
#  ('Cleveland', '4879'),
#  ('Cleveland', '4413'),
#  ('Cleveland', '5419'),
#  ('Cleveland', '3133'),
#  ('Cleveland', '2211'),
#  ('Cleveland', '4453'),
#  ('Cleveland', '3366'),
#  ('Cleveland', '8134'),
#  ('Cleveland', '1153'),
#  ('Cleveland', '4542'),
#  ('Cleveland', '4532'),
#  ('Cleveland', '5417'),
#  ('Cleveland', '4239'),
#  ('Cleveland', '3312'),
#  ('Cleveland', '4248'),
#  ('Cleveland', '1131'),
#  ('Cleveland', '6212'),
#  ('Cleveland', '5616'),
#  ('Cleveland', '4242'),
#  ('Cleveland', '3327'),
#  ('Cleveland', '3346'),
#  ('Cleveland', '7132'),
#  ('Cleveland', '5415'),
#  ('Cleveland', '3274'),
#  ('Cleveland', '3315'),
#  ('Cleveland', '4481'),
#  ('Cleveland', '1114'),
#  ('Cleveland', '4854'),
#  ('Cleveland', '5122'),
#  ('Cleveland', '3364'),
#  ('Cleveland', '3262'),
#  ('Cleveland', '4931'),
#  ('Cleveland', '3359'),
#  ('Cleveland', '6242'),
#  ('Cleveland', '4861'),
#  ('Cleveland', '4471'),
#  ('Cleveland', '3311'),
#  ('Cleveland', '3222'),
#  ('Cleveland', '4482'),
#  ('Cleveland', '3339'),
#  ('Cleveland', '5617'),
#  ('Cleveland', '6113'),
#  ('Cleveland', '4832'),
#  ('Cleveland', '3331'),
#  ('Cleveland', '4921'),
#  ('Cleveland', '8112'),
#  ('Cleveland', '4461'),
#  ('Cleveland', '3273'),
#  ('Cleveland', '4523'),
#  ('Cleveland', '6211'),
#  ('Cleveland', '5111'),
#  ('Cleveland', '4247'),
#  ('Cleveland', '3271'),
#  ('Cleveland', '3343'),
#  ('Cleveland', '4522'),
#  ('Cleveland', '2381'),
#  ('Cleveland', '5152'),
#  ('Cleveland', '3372'),
#  ('Cleveland', '4245'),
#  ('Cleveland', '9271'),
#  ('Cleveland', '3113'),
#  ('Cleveland', '4922'),
#  ('Cleveland', '4236'),
#  ('Cleveland', '5259'),
#  ('Cleveland', '4889'),
#  ('Cleveland', '4531'),
#  ('Cleveland', '6214'),
#  ('Cleveland', '8114'),
#  ('Cleveland', '1129'),
#  ('Cleveland', '3272'),
#  ('Cleveland', '3323'),
#  ('Cleveland', '6115'),
#  ('Cleveland', '5611'),
#  ('Cleveland', '8131'),
#  ('Cleveland', '1133'),
#  ('Cleveland', '6219'),
#  ('Cleveland', '5614'),
#  ('Cleveland', '3231'),
#  ('Cleveland', '4251'),
#  ('Gaston', '3321'),
#  ('Gaston', '4884'),
#  ('Gaston', '2122'),
#  ('Gaston', '3313'),
#  ('Gaston', '5232'),
#  ('Gaston', '3132'),
#  ('Gaston', '3391'),
#  ('Gaston', '3365'),
#  ('Gaston', '1151'),
#  ('Gaston', '5324'),
#  ('Gaston', '4541'),
#  ('Gaston', '3344'),
#  ('Gaston', '4442'),
#  ('Gaston', '3111'),
#  ('Gaston', '3112'),
#  ('Gaston', '4512'),
#  ('Gaston', '5613'),
#  ('Gaston', '3333'),
#  ('Gaston', '6231'),
#  ('Gaston', '8132'),
#  ('Gaston', '4231'),
#  ('Gaston', '3326'),
#  ('Gaston', '3329'),
#  ('Gaston', '6223'),
#  ('Gaston', '5511'),
#  ('Gaston', '5239'),
#  ('Gaston', '5615'),
#  ('Gaston', '8139'),
#  ('Gaston', '6244'),
#  ('Gaston', '6221'),
#  ('Gaston', '5418'),
#  ('Gaston', '3211'),
#  ('Gaston', '4235'),
#  ('Gaston', '5412'),
#  ('Gaston', '5622'),
#  ('Gaston', '5612'),
#  ('Gaston', '4451'),
#  ('Gaston', '5191'),
#  ('Gaston', '3254'),
#  ('Gaston', '3212'),
#  ('Gaston', '4411'),
#  ('Gaston', '4233'),
#  ('Gaston', '6232'),
#  ('Gaston', '3352'),
#  ('Gaston', '4483'),
#  ('Gaston', '7224'),
#  ('Gaston', '3219'),
#  ('Gaston', '3361'),
#  ('Gaston', '5242'),
#  ('Gaston', '4244'),
#  ('Gaston', '4851'),
#  ('Gaston', '5221'),
#  ('Gaston', '5629'),
#  ('Gaston', '4533'),
#  ('Gaston', '4234'),
#  ('Gaston', '4238'),
#  ('Gaston', '4911'),
#  ('Gaston', '7111'),
#  ('Gaston', '7131'),
#  ('Gaston', '4441'),
#  ('Gaston', '2111'),
#  ('Gaston', '9211'),
#  ('Gaston', '7114'),
#  ('Gaston', '5241'),
#  ('Gaston', '8133'),
#  ('Gaston', '3119'),
#  ('Gaston', '6241'),
#  ('Gaston', '8129'),
#  ('Gaston', '8111'),
#  ('Gaston', '3221'),
#  ('Gaston', '4237'),
#  ('Gaston', '7223'),
#  ('Gaston', '2213'),
#  ('Gaston', '5313'),
#  ('Gaston', '6111'),
#  ('Gaston', '4422'),
#  ('Gaston', '7139'),
#  ('Gaston', '3335'),
#  ('Gaston', '4421'),
#  ('Gaston', '4831'),
#  ('Gaston', '2212'),
#  ('Gaston', '4232'),
#  ('Gaston', '4883'),
#  ('Gaston', '6117'),
#  ('Gaston', '2389'),
#  ('Gaston', '3363'),
#  ('Gaston', '7213'),
#  ('Gaston', '4885'),
#  ('Gaston', '3371'),
#  ('Gaston', '9241'),
#  ('Gaston', '2123'),
#  ('Gaston', '4511'),
#  ('Gaston', '3351'),
#  ('Gaston', '4412'),
#  ('Gaston', '1121'),
#  ('Gaston', '6216'),
#  ('Gaston', '1125'),
#  ('Gaston', '5621'),
#  ('Gaston', '3345'),
#  ('Gaston', '4872'),
#  ('Gaston', '3379'),
#  ('Gaston', '3118'),
#  ('Gaston', '2361'),
#  ('Gaston', '9231'),
#  ('Gaston', '5416'),
#  ('Gaston', '3314'),
#  ('Gaston', '3122'),
#  ('Gaston', '3369'),
#  ('Gaston', '5322'),
#  ('Gaston', '3131'),
#  ('Gaston', '3336'),
#  ('Gaston', '2121'),
#  ('Gaston', '2372'),
#  ('Gaston', '6215'),
#  ('Gaston', '3353'),
#  ('Gaston', '3149'),
#  ('Gaston', '3399'),
#  ('Gaston', '3121'),
#  ('Gaston', '3256'),
#  ('Gaston', '3279'),
#  ('Gaston', '4821'),
#  ('Gaston', '4859'),
#  ('Gaston', '4241'),
#  ('Gaston', '4452'),
#  ('Gaston', '3259'),
#  ('Gaston', '9261'),
#  ('Gaston', '6213'),
#  ('Gaston', '4853'),
#  ('Gaston', '5231'),
#  ('Gaston', '4841'),
#  ('Gaston', '3115'),
#  ('Gaston', '5112'),
#  ('Gaston', '3152'),
#  ('Gaston', '6233'),
#  ('Gaston', '1122'),
#  ('Gaston', '8121'),
#  ('Gaston', '7212'),
#  ('Gaston', '4812'),
#  ('Gaston', '3151'),
#  ('Gaston', '3325'),
#  ('Gaston', '5173'),
#  ('Gaston', '1111'),
#  ('Gaston', '5321'),
#  ('Gaston', '8122'),
#  ('Gaston', '2373'),
#  ('Gaston', '7115'),
#  ('Gaston', '1119'),
#  ('Gaston', '4871'),
#  ('Gaston', '4855'),
#  ('Gaston', '3253'),
#  ('Gaston', '3332'),
#  ('Gaston', '3362'),
#  ('Gaston', '3241'),
#  ('Gaston', '3261'),
#  ('Gaston', '2131'),
#  ('Gaston', '3161'),
#  ('Gaston', '3341'),
#  ('Gaston', '7112'),
#  ('Gaston', '4543'),
#  ('Gaston', '1123'),
#  ('Gaston', '7121'),
#  ('Gaston', '3334'),
#  ('Gaston', '5619'),
#  ('Gaston', '3159'),
#  ('Gaston', '6114'),
#  ('Gaston', '5182'),
#  ('Gaston', '3252'),
#  ('Gaston', '8141'),
#  ('Gaston', '9281'),
#  ('Gaston', '4243'),
#  ('Gaston', '5323'),
#  ('Gaston', '7211'),
#  ('Gaston', '1152'),
#  ('Gaston', '8123'),
#  ('Gaston', '5331'),
#  ('Gaston', '5121'),
#  ('Gaston', '9221'),
#  ('Gaston', '4862'),
#  ('Gaston', '1142'),
#  ('Gaston', '3251'),
#  ('Gaston', '5311'),
#  ('Gaston', '3324'),
#  ('Gaston', '4881'),
#  ('Gaston', '5151'),
#  ('Gaston', '5174'),
#  ('Gaston', '5413'),
#  ('Gaston', '4539'),
#  ('Gaston', '3342'),
#  ('Gaston', '3255'),
#  ('Gaston', '4249'),
#  ('Gaston', '4852'),
#  ('Gaston', '3117'),
#  ('Gaston', '1141'),
#  ('Gaston', '3322'),
#  ('Gaston', '5251'),
#  ('Gaston', '5211'),
#  ('Gaston', '5312'),
#  ('Gaston', '5223'),
#  ('Gaston', '8113'),
#  ('Gaston', '5179'),
#  ('Gaston', '4842'),
#  ('Gaston', '7225'),
#  ('Gaston', '1113'),
#  ('Gaston', '4882'),
#  ('Gaston', '3141'),
#  ('Gaston', '3114'),
#  ('Gaston', '2382'),
#  ('Gaston', '5411'),
#  ('Gaston', '5222'),
#  ('Gaston', '1124'),
#  ('Gaston', '6116'),
#  ('Gaston', '4869'),
#  ('Gaston', '6222'),
#  ('Gaston', '6239'),
#  ('Gaston', '4246'),
#  ('Gaston', '4811'),
#  ('Gaston', '3328'),
#  ('Gaston', '3162'),
#  ('Gaston', '7113'),
#  ('Gaston', '1132'),
#  ('Gaston', '2362'),
#  ('Gaston', '1112'),
#  ('Gaston', '2371'),
#  ('Gaston', '9251'),
#  ('Gaston', '5414'),
#  ('Gaston', '4431'),
#  ('Gaston', '6243'),
#  ('Gaston', '6112'),
#  ('Gaston', '2383'),
#  ('Gaston', '2379'),
#  ('Gaston', '3116'),
#  ('Gaston', '3169'),
#  ('Gaston', '4879'),
#  ('Gaston', '4413'),
#  ('Gaston', '5419'),
#  ('Gaston', '3133'),
#  ('Gaston', '2211'),
#  ('Gaston', '4453'),
#  ('Gaston', '3366'),
#  ('Gaston', '8134'),
#  ('Gaston', '1153'),
#  ('Gaston', '4542'),
#  ('Gaston', '4532'),
#  ('Gaston', '5417'),
#  ('Gaston', '4239'),
#  ('Gaston', '3312'),
#  ('Gaston', '4248'),
#  ('Gaston', '1131'),
#  ('Gaston', '6212'),
#  ('Gaston', '5616'),
#  ('Gaston', '4242'),
#  ('Gaston', '3327'),
#  ('Gaston', '3346'),
#  ('Gaston', '7132'),
#  ('Gaston', '5415'),
#  ('Gaston', '3274'),
#  ('Gaston', '3315'),
#  ('Gaston', '4481'),
#  ('Gaston', '1114'),
#  ('Gaston', '4854'),
#  ('Gaston', '5122'),
#  ('Gaston', '3364'),
#  ('Gaston', '3262'),
#  ('Gaston', '4931'),
#  ('Gaston', '3359'),
#  ('Gaston', '6242'),
#  ('Gaston', '4861'),
#  ('Gaston', '4471'),
#  ('Gaston', '3311'),
#  ('Gaston', '3222'),
#  ('Gaston', '4482'),
#  ('Gaston', '3339'),
#  ('Gaston', '5617'),
#  ('Gaston', '6113'),
#  ('Gaston', '4832'),
#  ('Gaston', '3331'),
#  ('Gaston', '4921'),
#  ('Gaston', '8112'),
#  ('Gaston', '4461'),
#  ('Gaston', '3273'),
#  ('Gaston', '4523'),
#  ('Gaston', '6211'),
#  ('Gaston', '5111'),
#  ('Gaston', '4247'),
#  ('Gaston', '3271'),
#  ('Gaston', '3343'),
#  ('Gaston', '4522'),
#  ('Gaston', '2381'),
#  ('Gaston', '5152'),
#  ('Gaston', '3372'),
#  ('Gaston', '4245'),
#  ('Gaston', '9271'),
#  ('Gaston', '3113'),
#  ('Gaston', '4922'),
#  ('Gaston', '4236'),
#  ('Gaston', '5259'),
#  ('Gaston', '4889'),
#  ('Gaston', '4531'),
#  ('Gaston', '6214'),
#  ('Gaston', '8114'),
#  ('Gaston', '1129'),
#  ('Gaston', '3272'),
#  ('Gaston', '3323'),
#  ('Gaston', '6115'),
#  ('Gaston', '5611'),
#  ('Gaston', '8131'),
#  ('Gaston', '1133'),
#  ('Gaston', '6219'),
#  ('Gaston', '5614'),
#  ('Gaston', '3231'),
#  ('Gaston', '4251'),
#  ('Rutherford', '3321'),
#  ('Rutherford', '4884'),
#  ('Rutherford', '2122'),
#  ('Rutherford', '3313'),
#  ('Rutherford', '5232'),
#  ('Rutherford', '3132'),
#  ('Rutherford', '3391'),
#  ('Rutherford', '3365'),
#  ('Rutherford', '1151'),
#  ('Rutherford', '5324'),
#  ('Rutherford', '4541'),
#  ('Rutherford', '3344'),
#  ('Rutherford', '4442'),
#  ('Rutherford', '3111'),
#  ('Rutherford', '3112'),
#  ('Rutherford', '4512'),
#  ('Rutherford', '5613'),
#  ('Rutherford', '3333'),
#  ('Rutherford', '6231'),
#  ('Rutherford', '8132'),
#  ('Rutherford', '4231'),
#  ('Rutherford', '3326'),
#  ('Rutherford', '3329'),
#  ('Rutherford', '6223'),
#  ('Rutherford', '5511'),
#  ('Rutherford', '5239'),
#  ('Rutherford', '5615'),
#  ('Rutherford', '8139'),
#  ('Rutherford', '6244'),
#  ('Rutherford', '6221'),
#  ('Rutherford', '5418'),
#  ('Rutherford', '3211'),
#  ('Rutherford', '4235'),
#  ('Rutherford', '5412'),
#  ('Rutherford', '5622'),
#  ('Rutherford', '5612'),
#  ('Rutherford', '4451'),
#  ('Rutherford', '5191'),
#  ('Rutherford', '3254'),
#  ('Rutherford', '3212'),
#  ('Rutherford', '4411'),
#  ('Rutherford', '4233'),
#  ('Rutherford', '6232'),
#  ('Rutherford', '3352'),
#  ('Rutherford', '4483'),
#  ('Rutherford', '7224'),
#  ('Rutherford', '3219'),
#  ('Rutherford', '3361'),
#  ('Rutherford', '5242'),
#  ('Rutherford', '4244'),
#  ('Rutherford', '4851'),
#  ('Rutherford', '5221'),
#  ('Rutherford', '5629'),
#  ('Rutherford', '4533'),
#  ('Rutherford', '4234'),
#  ('Rutherford', '4238'),
#  ('Rutherford', '4911'),
#  ('Rutherford', '7111'),
#  ('Rutherford', '7131'),
#  ('Rutherford', '4441'),
#  ('Rutherford', '2111'),
#  ('Rutherford', '9211'),
#  ('Rutherford', '7114'),
#  ('Rutherford', '5241'),
#  ('Rutherford', '8133'),
#  ('Rutherford', '3119'),
#  ('Rutherford', '6241'),
#  ...]

# %%
with open("connecting.txt",'r') as f:
    finished_raw = f.readlines()
finished = []
for i in finished_raw:
    county, code = i.split(":")[0].split("-")
    finished.append((county, code))

# %%
res_tasks = []
for i in problematic_tasks:
    if i in finished:
        continue
    res_tasks.append(i)
res_tasks
# Out:
# [('Caldwell', '3391'),
#  ('Caldwell', '3112'),
#  ('Caldwell', '6231'),
#  ('Caldwell', '3329'),
#  ('Caldwell', '5511'),
#  ('Caldwell', '5615'),
#  ('Caldwell', '8139'),
#  ('Caldwell', '6244'),
#  ('Caldwell', '5412'),
#  ('Caldwell', '5191'),
#  ('Caldwell', '4233'),
#  ('Caldwell', '3352'),
#  ('Caldwell', '7224'),
#  ('Caldwell', '4851'),
#  ('Caldwell', '5629'),
#  ('Caldwell', '7111'),
#  ('Caldwell', '7114'),
#  ('Caldwell', '7223'),
#  ('Caldwell', '4422'),
#  ('Caldwell', '4831'),
#  ('Caldwell', '9241'),
#  ('Caldwell', '6216'),
#  ('Caldwell', '3345'),
#  ('Caldwell', '9231'),
#  ('Caldwell', '5416'),
#  ('Caldwell', '3122'),
#  ('Caldwell', '3256'),
#  ('Caldwell', '4241'),
#  ('Caldwell', '4452'),
#  ('Caldwell', '4853'),
#  ('Caldwell', '4841'),
#  ('Caldwell', '3152'),
#  ('Caldwell', '4812'),
#  ('Caldwell', '1111'),
#  ('Caldwell', '3341'),
#  ('Caldwell', '9281'),
#  ('Caldwell', '8123'),
#  ('Caldwell', '5121'),
#  ('Caldwell', '3251'),
#  ('Caldwell', '5174'),
#  ('Caldwell', '4539'),
#  ('Caldwell', '5223'),
#  ('Caldwell', '1113'),
#  ('Caldwell', '3114'),
#  ('Caldwell', '1124'),
#  ('Caldwell', '3162'),
#  ('Caldwell', '7113'),
#  ('Caldwell', '3366'),
#  ('Caldwell', '1153'),
#  ('Caldwell', '4242'),
#  ('Caldwell', '4861'),
#  ('Caldwell', '3273'),
#  ('Caldwell', '2381'),
#  ('Caldwell', '9271'),
#  ('Caldwell', '4922'),
#  ('Caldwell', '5259'),
#  ('Caldwell', '8114'),
#  ('Caldwell', '5611'),
#  ('Cleveland', '4884'),
#  ('Cleveland', '3313'),
#  ('Cleveland', '5232'),
#  ('Cleveland', '3391'),
#  ('Cleveland', '3365'),
#  ('Cleveland', '4541'),
#  ('Cleveland', '3344'),
#  ('Cleveland', '4442'),
#  ('Cleveland', '3111'),
#  ('Cleveland', '3112'),
#  ('Cleveland', '4512'),
#  ('Cleveland', '5613'),
#  ('Cleveland', '6231'),
#  ('Cleveland', '8132'),
#  ('Cleveland', '4231'),
#  ('Cleveland', '3329'),
#  ('Cleveland', '6223'),
#  ('Cleveland', '5511'),
#  ('Cleveland', '5239'),
#  ('Cleveland', '8139'),
#  ('Cleveland', '5418'),
#  ('Cleveland', '5412'),
#  ('Cleveland', '5622'),
#  ('Cleveland', '5612'),
#  ('Cleveland', '4451'),
#  ('Cleveland', '3254'),
#  ('Cleveland', '3212'),
#  ('Cleveland', '4411'),
#  ('Cleveland', '3219'),
#  ('Cleveland', '4851'),
#  ('Cleveland', '5629'),
#  ('Cleveland', '4533'),
#  ('Cleveland', '4234'),
#  ('Cleveland', '4238'),
#  ('Cleveland', '7131'),
#  ('Cleveland', '4441'),
#  ('Cleveland', '2111'),
#  ('Cleveland', '9211'),
#  ('Cleveland', '8133'),
#  ('Cleveland', '3119'),
#  ('Cleveland', '8129'),
#  ('Cleveland', '8111'),
#  ('Cleveland', '3221'),
#  ('Cleveland', '4237'),
#  ('Cleveland', '5313'),
#  ('Cleveland', '7139'),
#  ('Cleveland', '3335'),
#  ('Cleveland', '4421'),
#  ('Cleveland', '4831'),
#  ('Cleveland', '2212'),
#  ('Cleveland', '4232'),
#  ('Cleveland', '2389'),
#  ('Cleveland', '3363'),
#  ('Cleveland', '7213'),
#  ('Cleveland', '4885'),
#  ('Cleveland', '3371'),
#  ('Cleveland', '2123'),
#  ('Cleveland', '4511'),
#  ('Cleveland', '1121'),
#  ('Cleveland', '3345'),
#  ('Cleveland', '4872'),
#  ('Cleveland', '3118'),
#  ('Cleveland', '2361'),
#  ('Cleveland', '5416'),
#  ('Cleveland', '3314'),
#  ('Cleveland', '3122'),
#  ('Cleveland', '2372'),
#  ('Cleveland', '6215'),
#  ('Cleveland', '3256'),
#  ('Cleveland', '3279'),
#  ('Cleveland', '4821'),
#  ('Cleveland', '4859'),
#  ('Cleveland', '4452'),
#  ('Cleveland', '3259'),
#  ('Cleveland', '9261'),
#  ('Cleveland', '4853'),
#  ('Cleveland', '5231'),
#  ('Cleveland', '5112'),
#  ('Cleveland', '3152'),
#  ('Cleveland', '6233'),
#  ('Cleveland', '8121'),
#  ('Cleveland', '3151'),
#  ('Gaston', '4242'),
#  ('Gaston', '3346'),
#  ('Gaston', '7132'),
#  ('Gaston', '5415'),
#  ('Gaston', '3274'),
#  ('Gaston', '3315'),
#  ('Gaston', '4481'),
#  ('Gaston', '1114'),
#  ('Gaston', '4854'),
#  ('Gaston', '5122'),
#  ('Gaston', '3364'),
#  ('Gaston', '3262'),
#  ('Gaston', '4931'),
#  ('Gaston', '3359'),
#  ('Gaston', '6242'),
#  ('Gaston', '4861'),
#  ('Gaston', '4471'),
#  ('Gaston', '3222'),
#  ('Gaston', '4482'),
#  ('Gaston', '6113'),
#  ('Gaston', '4832'),
#  ('Gaston', '3331'),
#  ('Gaston', '4921'),
#  ('Gaston', '4461'),
#  ('Gaston', '3273'),
#  ('Gaston', '4523'),
#  ('Gaston', '6211'),
#  ('Gaston', '5111'),
#  ('Gaston', '3343'),
#  ('Gaston', '4522'),
#  ('Gaston', '2381'),
#  ('Gaston', '3372'),
#  ('Gaston', '4245'),
#  ('Gaston', '9271'),
#  ('Gaston', '4922'),
#  ('Gaston', '5259'),
#  ('Gaston', '4889'),
#  ('Gaston', '4531'),
#  ('Gaston', '6214'),
#  ('Gaston', '8114'),
#  ('Gaston', '1129'),
#  ('Gaston', '3272'),
#  ('Gaston', '3323'),
#  ('Gaston', '6115'),
#  ('Gaston', '5611'),
#  ('Gaston', '1133'),
#  ('Gaston', '6219'),
#  ('Gaston', '3231'),
#  ('Gaston', '4251'),
#  ('Rutherford', '3321'),
#  ('Rutherford', '4884'),
#  ('Rutherford', '2122'),
#  ('Rutherford', '3313'),
#  ('Rutherford', '5232'),
#  ('Rutherford', '3132'),
#  ('Rutherford', '3391'),
#  ('Rutherford', '3365'),
#  ('Rutherford', '1151'),
#  ('Rutherford', '5324'),
#  ('Rutherford', '4541'),
#  ('Rutherford', '3344'),
#  ('Rutherford', '4442'),
#  ('Rutherford', '3111'),
#  ('Rutherford', '3112'),
#  ('Rutherford', '4512'),
#  ('Rutherford', '5613'),
#  ('Rutherford', '3333'),
#  ('Rutherford', '6231'),
#  ('Rutherford', '8132'),
#  ('Rutherford', '4231'),
#  ('Rutherford', '3326'),
#  ('Rutherford', '3329'),
#  ('Rutherford', '6223'),
#  ('Rutherford', '5511'),
#  ('Rutherford', '5239'),
#  ('Rutherford', '5615'),
#  ('Rutherford', '8139'),
#  ('Rutherford', '6244'),
#  ('Rutherford', '6221'),
#  ('Rutherford', '5418'),
#  ('Rutherford', '3211'),
#  ('Rutherford', '4235'),
#  ('Rutherford', '5412'),
#  ('Rutherford', '5622'),
#  ('Rutherford', '5612'),
#  ('Rutherford', '4451'),
#  ('Rutherford', '5191'),
#  ('Rutherford', '3254'),
#  ('Rutherford', '3212'),
#  ('Rutherford', '4411'),
#  ('Rutherford', '4233'),
#  ('Rutherford', '6232'),
#  ('Rutherford', '3352'),
#  ('Rutherford', '4483'),
#  ('Rutherford', '7224'),
#  ('Rutherford', '3219'),
#  ('Rutherford', '3361'),
#  ('Rutherford', '5242'),
#  ('Rutherford', '4244'),
#  ('Rutherford', '4851'),
#  ('Rutherford', '5221'),
#  ('Rutherford', '5629'),
#  ('Rutherford', '4533'),
#  ('Rutherford', '4234'),
#  ('Rutherford', '4238'),
#  ('Rutherford', '4911'),
#  ('Rutherford', '7111'),
#  ('Rutherford', '7131'),
#  ('Rutherford', '4441'),
#  ('Rutherford', '2111'),
#  ('Rutherford', '9211'),
#  ('Rutherford', '7114'),
#  ('Rutherford', '5241'),
#  ('Rutherford', '8133'),
#  ('Rutherford', '3119'),
#  ('Rutherford', '6241'),
#  ('Rutherford', '8129'),
#  ('Rutherford', '8111'),
#  ('Rutherford', '3221'),
#  ('Rutherford', '4237'),
#  ('Rutherford', '7223'),
#  ('Rutherford', '2213'),
#  ('Rutherford', '5313'),
#  ('Rutherford', '6111'),
#  ('Rutherford', '4422'),
#  ('Rutherford', '7139'),
#  ('Rutherford', '3335'),
#  ('Rutherford', '4421'),
#  ('Rutherford', '4831'),
#  ('Rutherford', '2212'),
#  ('Rutherford', '4232'),
#  ('Rutherford', '4883'),
#  ('Rutherford', '6117'),
#  ('Rutherford', '2389'),
#  ('Rutherford', '3363'),
#  ('Rutherford', '7213'),
#  ('Rutherford', '4885'),
#  ('Rutherford', '3371'),
#  ('Rutherford', '9241'),
#  ('Rutherford', '2123'),
#  ('Rutherford', '4511'),
#  ('Rutherford', '3351'),
#  ('Rutherford', '4412'),
#  ('Rutherford', '1121'),
#  ('Rutherford', '6216'),
#  ('Rutherford', '1125'),
#  ('Rutherford', '5621'),
#  ('Rutherford', '3345'),
#  ('Rutherford', '4872'),
#  ('Rutherford', '3379'),
#  ('Rutherford', '3118'),
#  ('Rutherford', '2361'),
#  ('Rutherford', '9231'),
#  ('Rutherford', '5416'),
#  ('Rutherford', '3314'),
#  ('Rutherford', '3122'),
#  ('Rutherford', '3369'),
#  ('Rutherford', '5322'),
#  ('Rutherford', '3131'),
#  ('Rutherford', '3336'),
#  ('Rutherford', '2121'),
#  ('Rutherford', '2372'),
#  ('Rutherford', '6215'),
#  ('Rutherford', '3353'),
#  ('Rutherford', '3149'),
#  ('Rutherford', '3399'),
#  ('Rutherford', '3121'),
#  ('Rutherford', '3256'),
#  ('Rutherford', '3279'),
#  ('Rutherford', '4821'),
#  ('Rutherford', '4859'),
#  ('Rutherford', '4241'),
#  ('Rutherford', '4452'),
#  ('Rutherford', '3259'),
#  ('Rutherford', '9261'),
#  ('Rutherford', '6213'),
#  ('Rutherford', '4853'),
#  ('Rutherford', '5231'),
#  ('Rutherford', '4841'),
#  ('Rutherford', '3115'),
#  ('Rutherford', '5112'),
#  ('Rutherford', '3152'),
#  ('Rutherford', '6233'),
#  ('Rutherford', '1122'),
#  ('Rutherford', '8121'),
#  ('Rutherford', '7212'),
#  ('Rutherford', '4812'),
#  ('Rutherford', '3151'),
#  ('Rutherford', '3325'),
#  ('Rutherford', '5173'),
#  ('Rutherford', '1111'),
#  ('Rutherford', '5321'),
#  ('Rutherford', '8122'),
#  ('Rutherford', '2373'),
#  ('Rutherford', '7115'),
#  ('Rutherford', '1119'),
#  ('Rutherford', '4871'),
#  ('Rutherford', '4855'),
#  ('Rutherford', '3253'),
#  ('Rutherford', '3332'),
#  ('Rutherford', '3362'),
#  ('Rutherford', '3241'),
#  ('Rutherford', '3261'),
#  ('Rutherford', '2131'),
#  ('Rutherford', '3161'),
#  ('Rutherford', '3341'),
#  ('Rutherford', '7112'),
#  ('Rutherford', '4543'),
#  ('Rutherford', '1123'),
#  ('Rutherford', '7121'),
#  ('Rutherford', '3334'),
#  ('Rutherford', '5619'),
#  ('Rutherford', '3159'),
#  ('Rutherford', '6114'),
#  ('Rutherford', '5182'),
#  ('Rutherford', '3252'),
#  ('Rutherford', '8141'),
#  ('Rutherford', '9281'),
#  ('Rutherford', '4243'),
#  ('Rutherford', '5323'),
#  ('Rutherford', '7211'),
#  ('Rutherford', '1152'),
#  ('Rutherford', '8123'),
#  ('Rutherford', '5331'),
#  ('Rutherford', '5121'),
#  ('Rutherford', '9221'),
#  ('Rutherford', '4862'),
#  ('Rutherford', '1142'),
#  ('Rutherford', '3251'),
#  ('Rutherford', '5311'),
#  ('Rutherford', '3324'),
#  ('Rutherford', '4881'),
#  ('Rutherford', '5151'),
#  ('Rutherford', '5174'),
#  ('Rutherford', '5413'),
#  ('Rutherford', '4539'),
#  ('Rutherford', '3342'),
#  ('Rutherford', '3255'),
#  ('Rutherford', '4249'),
#  ('Rutherford', '4852'),
#  ('Rutherford', '3117'),
#  ('Rutherford', '1141'),
#  ('Rutherford', '3322'),
#  ('Rutherford', '5251'),
#  ('Rutherford', '5211'),
#  ('Rutherford', '5312'),
#  ('Rutherford', '5223'),
#  ('Rutherford', '8113'),
#  ('Rutherford', '5179'),
#  ('Rutherford', '4842'),
#  ('Rutherford', '7225'),
#  ('Rutherford', '1113'),
#  ('Rutherford', '4882'),
#  ('Rutherford', '3141'),
#  ('Rutherford', '3114'),
#  ('Rutherford', '2382'),
#  ('Rutherford', '5411'),
#  ('Rutherford', '5222'),
#  ('Rutherford', '1124'),
#  ('Rutherford', '6116'),
#  ('Rutherford', '4869'),
#  ('Rutherford', '6222'),
#  ('Rutherford', '6239'),
#  ('Rutherford', '4246'),
#  ('Rutherford', '4811'),
#  ('Rutherford', '3328'),
#  ('Rutherford', '3162'),
#  ('Rutherford', '7113'),
#  ('Rutherford', '1132'),
#  ('Rutherford', '2362'),
#  ('Rutherford', '1112'),
#  ('Rutherford', '2371'),
#  ('Rutherford', '9251'),
#  ('Rutherford', '5414'),
#  ('Rutherford', '4431'),
#  ('Rutherford', '6243'),
#  ('Rutherford', '6112'),
#  ('Rutherford', '2383'),
#  ('Rutherford', '2379'),
#  ('Rutherford', '3116'),
#  ('Rutherford', '3169'),
#  ('Rutherford', '4879'),
#  ('Rutherford', '4413'),
#  ('Rutherford', '5419'),
#  ('Rutherford', '3133'),
#  ('Rutherford', '2211'),
#  ('Rutherford', '4453'),
#  ('Rutherford', '3366'),
#  ('Rutherford', '8134'),
#  ('Rutherford', '1153'),
#  ('Rutherford', '4542'),
#  ('Rutherford', '4532'),
#  ('Rutherford', '5417'),
#  ('Rutherford', '4239'),
#  ('Rutherford', '3312'),
#  ('Rutherford', '4248'),
#  ('Rutherford', '1131'),
#  ('Rutherford', '6212'),
#  ('Rutherford', '5616'),
#  ('Rutherford', '4242'),
#  ('Rutherford', '3327'),
#  ('Rutherford', '3346'),
#  ('Rutherford', '7132'),
#  ('Rutherford', '5415'),
#  ('Rutherford', '3274'),
#  ('Rutherford', '3315'),
#  ('Rutherford', '4481'),
#  ('Rutherford', '1114'),
#  ('Rutherford', '4854'),
#  ('Rutherford', '5122'),
#  ('Rutherford', '3364'),
#  ('Rutherford', '3262'),
#  ('Rutherford', '4931'),
#  ('Rutherford', '3359'),
#  ('Rutherford', '6242'),
#  ('Rutherford', '4861'),
#  ('Rutherford', '4471'),
#  ('Rutherford', '3311'),
#  ('Rutherford', '3222'),
#  ('Rutherford', '4482'),
#  ('Rutherford', '3339'),
#  ('Rutherford', '5617'),
#  ('Rutherford', '6113'),
#  ('Rutherford', '4832'),
#  ('Rutherford', '3331'),
#  ('Rutherford', '4921'),
#  ('Rutherford', '8112'),
#  ('Rutherford', '4461'),
#  ('Rutherford', '3273'),
#  ('Rutherford', '4523'),
#  ('Rutherford', '6211'),
#  ('Rutherford', '5111'),
#  ('Rutherford', '4247'),
#  ('Rutherford', '3271'),
#  ('Rutherford', '3343'),
#  ('Rutherford', '4522'),
#  ('Rutherford', '2381'),
#  ('Rutherford', '5152'),
#  ('Rutherford', '3372'),
#  ('Rutherford', '4245'),
#  ('Rutherford', '9271'),
#  ('Rutherford', '3113'),
#  ('Rutherford', '4922'),
#  ('Rutherford', '4236'),
#  ('Rutherford', '5259'),
#  ('Rutherford', '4889'),
#  ('Rutherford', '4531'),
#  ('Rutherford', '6214'),
#  ('Rutherford', '8114'),
#  ('Rutherford', '1129'),
#  ('Rutherford', '3272'),
#  ('Rutherford', '3323'),
#  ('Rutherford', '6115'),
#  ('Rutherford', '5611'),
#  ('Rutherford', '8131'),
#  ('Rutherford', '1133'),
#  ('Rutherford', '6219'),
#  ('Rutherford', '5614'),
#  ('Rutherford', '3231'),
#  ('Rutherford', '4251'),
#  ('Jackson', '4884'),
#  ('Jackson', '3313'),
#  ('Jackson', '5232'),
#  ('Jackson', '3391'),
#  ('Jackson', '3365'),
#  ('Jackson', '4541'),
#  ('Jackson', '3344'),
#  ('Jackson', '4442'),
#  ('Jackson', '3111'),
#  ('Jackson', '4512'),
#  ('Jackson', '5613'),
#  ('Jackson', '6231'),
#  ('Jackson', '8132'),
#  ('Jackson', '4231'),
#  ('Jackson', '6223'),
#  ('Jackson', '5511'),
#  ('Jackson', '5239'),
#  ('Jackson', '8139'),
#  ('Jackson', '5418'),
#  ('Jackson', '5622'),
#  ('Jackson', '5612'),
#  ('Jackson', '3254'),
#  ('Jackson', '3212'),
#  ('Jackson', '4411'),
#  ('Jackson', '3219'),
#  ('Jackson', '4851'),
#  ('Jackson', '5629'),
#  ('Jackson', '4533'),
#  ('Jackson', '4234'),
#  ('Jackson', '4238'),
#  ('Jackson', '7131'),
#  ('Jackson', '4441'),
#  ('Jackson', '2111'),
#  ('Jackson', '9211'),
#  ('Jackson', '8133'),
#  ('Jackson', '3119'),
#  ('Jackson', '8129'),
#  ('Jackson', '8111'),
#  ('Jackson', '3221'),
#  ('Jackson', '4237'),
#  ('Jackson', '5313'),
#  ('Jackson', '7139'),
#  ('Jackson', '3335'),
#  ('Jackson', '4421'),
#  ('Jackson', '4831'),
#  ('Jackson', '2212'),
#  ('Jackson', '2389'),
#  ('Jackson', '3363'),
#  ('Jackson', '7213'),
#  ('Jackson', '3371'),
#  ('Jackson', '2123'),
#  ('Jackson', '4511'),
#  ('Jackson', '1121'),
#  ('Jackson', '3345'),
#  ('Jackson', '4872'),
#  ('Jackson', '3118'),
#  ('Jackson', '2361'),
#  ('Jackson', '3314'),
#  ('Jackson', '3122'),
#  ('Jackson', '2372'),
#  ('Jackson', '6215'),
#  ('Jackson', '3256'),
#  ('Jackson', '3279'),
#  ('Jackson', '4821'),
#  ('Jackson', '4859'),
#  ('Jackson', '4452'),
#  ('Jackson', '3259'),
#  ('Jackson', '5231'),
#  ('Jackson', '5112'),
#  ('Jackson', '3152'),
#  ('Jackson', '6233'),
#  ('Jackson', '8121'),
#  ('Jackson', '3151'),
#  ('Jackson', '8122'),
#  ('Jackson', '2373'),
#  ('Jackson', '4855'),
#  ('Jackson', '3253'),
#  ('Jackson', '3362'),
#  ('Jackson', '3261'),
#  ('Jackson', '2131'),
#  ('Madison', '8133'),
#  ('Madison', '8129'),
#  ('Madison', '4237'),
#  ('Madison', '7139'),
#  ('Madison', '9241'),
#  ('Madison', '5621'),
#  ('Madison', '5322'),
#  ('Madison', '3336'),
#  ('Madison', '6215'),
#  ('Madison', '4859'),
#  ('Madison', '4452'),
#  ('Madison', '3152'),
#  ('Madison', '7115'),
#  ('Madison', '1119'),
#  ('Madison', '4871'),
#  ('Madison', '3362'),
#  ('Madison', '2131'),
#  ('Madison', '3161'),
#  ('Madison', '3334'),
#  ('Madison', '5619'),
#  ('Madison', '5323'),
#  ('Madison', '1152'),
#  ('Madison', '5331'),
#  ('Madison', '1142'),
#  ('Madison', '4539'),
#  ('Madison', '4249'),
#  ('Madison', '1141'),
#  ('Madison', '5211'),
#  ('Madison', '5312'),
#  ('Madison', '8113'),
#  ('Madison', '5179'),
#  ('Madison', '1113'),
#  ('Madison', '4882'),
#  ('Madison', '5411'),
#  ('Madison', '6243'),
#  ('Madison', '3116'),
#  ('Madison', '3169'),
#  ('Madison', '1153'),
#  ('Madison', '4239'),
#  ('Madison', '7132'),
#  ('Madison', '6242'),
#  ('Madison', '3222'),
#  ('Madison', '6113'),
#  ('Madison', '6211'),
#  ('Madison', '4247'),
#  ('Madison', '2381'),
#  ('Madison', '5152'),
#  ('Mecklenburg', '3321'),
#  ('Mecklenburg', '4884'),
#  ('Mecklenburg', '2122'),
#  ('Mecklenburg', '3313'),
#  ('Mecklenburg', '5232'),
#  ('Mecklenburg', '3132'),
#  ('Mecklenburg', '3391'),
#  ('Mecklenburg', '3365'),
#  ('Mecklenburg', '1151'),
#  ('Mecklenburg', '5324'),
#  ('Mecklenburg', '4541'),
#  ('Mecklenburg', '3344'),
#  ('Mecklenburg', '4442'),
#  ('Mecklenburg', '3111'),
#  ('Mecklenburg', '3112'),
#  ('Mecklenburg', '4512'),
#  ('Mecklenburg', '5613'),
#  ('Mecklenburg', '3333'),
#  ('Mecklenburg', '6231'),
#  ('Mecklenburg', '8132'),
#  ('Mecklenburg', '4231'),
#  ('Mecklenburg', '3326'),
#  ('Mecklenburg', '3329'),
#  ('Mecklenburg', '6223'),
#  ('Mecklenburg', '5511'),
#  ('Mecklenburg', '5239'),
#  ('Mecklenburg', '5615'),
#  ('Mecklenburg', '8139'),
#  ('Mecklenburg', '6244'),
#  ('Mecklenburg', '6221'),
#  ('Mecklenburg', '5418'),
#  ('Mecklenburg', '3211'),
#  ('Mecklenburg', '4235'),
#  ('Mecklenburg', '5412'),
#  ('Mecklenburg', '5622'),
#  ('Mecklenburg', '5612'),
#  ('Mecklenburg', '4451'),
#  ('Mecklenburg', '5191'),
#  ('Mecklenburg', '3254'),
#  ('Mecklenburg', '3212'),
#  ('Mecklenburg', '4411'),
#  ('Mecklenburg', '4233'),
#  ('Mecklenburg', '6232'),
#  ('Mecklenburg', '3352'),
#  ('Mecklenburg', '4483'),
#  ('Mecklenburg', '7224'),
#  ('Mecklenburg', '3219'),
#  ('Mecklenburg', '3361'),
#  ('Mecklenburg', '5242'),
#  ('Mecklenburg', '4244'),
#  ('Mecklenburg', '4851'),
#  ('Mecklenburg', '5221'),
#  ('Mecklenburg', '5629'),
#  ('Mecklenburg', '4533'),
#  ('Mecklenburg', '4234'),
#  ('Mecklenburg', '4238'),
#  ('Mecklenburg', '4911'),
#  ('Mecklenburg', '7111'),
#  ('Mecklenburg', '7131'),
#  ('Mecklenburg', '4441'),
#  ('Mecklenburg', '2111'),
#  ('Mecklenburg', '9211'),
#  ('Mecklenburg', '7114'),
#  ('Mecklenburg', '5241'),
#  ('Mecklenburg', '8133'),
#  ('Mecklenburg', '3119'),
#  ('Mecklenburg', '6241'),
#  ('Mecklenburg', '8129'),
#  ('Mecklenburg', '8111'),
#  ('Mecklenburg', '3221'),
#  ('Mecklenburg', '4237'),
#  ('Mecklenburg', '7223'),
#  ('Mecklenburg', '2213'),
#  ('Mecklenburg', '5313'),
#  ('Mecklenburg', '6111'),
#  ('Mecklenburg', '4422'),
#  ('Mecklenburg', '7139'),
#  ('Mecklenburg', '3335'),
#  ('Mecklenburg', '4421'),
#  ('Mecklenburg', '4831'),
#  ('Mecklenburg', '2212'),
#  ('Mecklenburg', '4232'),
#  ('Mecklenburg', '4883'),
#  ('Mecklenburg', '6117'),
#  ('Mecklenburg', '2389'),
#  ('Mecklenburg', '3363'),
#  ('Mecklenburg', '7213'),
#  ('Mecklenburg', '4885'),
#  ('Mecklenburg', '3371'),
#  ('Mecklenburg', '9241'),
#  ('Mecklenburg', '2123'),
#  ('Mecklenburg', '4511'),
#  ('Mecklenburg', '3351'),
#  ('Mecklenburg', '4412'),
#  ('Mecklenburg', '1121'),
#  ('Mecklenburg', '6216'),
#  ('Mecklenburg', '1125'),
#  ('Mecklenburg', '5621'),
#  ('Mecklenburg', '3345'),
#  ('Mecklenburg', '4872'),
#  ('Mecklenburg', '3379'),
#  ('Mecklenburg', '3118'),
#  ('Mecklenburg', '2361'),
#  ('Mecklenburg', '9231'),
#  ('Mecklenburg', '5416'),
#  ('Mecklenburg', '3314'),
#  ('Mecklenburg', '3122'),
#  ('Mecklenburg', '3369'),
#  ('Mecklenburg', '5322'),
#  ('Mecklenburg', '3131'),
#  ('Mecklenburg', '3336'),
#  ('Mecklenburg', '2121'),
#  ('Mecklenburg', '2372'),
#  ('Mecklenburg', '6215'),
#  ('Mecklenburg', '3353'),
#  ('Mecklenburg', '3149'),
#  ('Mecklenburg', '3399'),
#  ('Mecklenburg', '3121'),
#  ('Mecklenburg', '3256'),
#  ('Mecklenburg', '3279'),
#  ('Mecklenburg', '4821'),
#  ('Mecklenburg', '4859'),
#  ('Mecklenburg', '4241'),
#  ('Mecklenburg', '4452'),
#  ('Mecklenburg', '3259'),
#  ('Mecklenburg', '9261'),
#  ('Mecklenburg', '6213'),
#  ('Mecklenburg', '4853'),
#  ('Mecklenburg', '5231'),
#  ('Mecklenburg', '4841'),
#  ('Mecklenburg', '3115'),
#  ('Mecklenburg', '5112'),
#  ('Mecklenburg', '3152'),
#  ('Mecklenburg', '6233'),
#  ('Mecklenburg', '1122'),
#  ('Mecklenburg', '8121'),
#  ('Mecklenburg', '7212'),
#  ('Mecklenburg', '4812'),
#  ('Mecklenburg', '3151'),
#  ('Mecklenburg', '3325'),
#  ('Mecklenburg', '5173'),
#  ('Mecklenburg', '1111'),
#  ('Mecklenburg', '5321'),
#  ('Mecklenburg', '8122'),
#  ('Mecklenburg', '2373'),
#  ('Mecklenburg', '7115'),
#  ('Mecklenburg', '1119'),
#  ('Mecklenburg', '4871'),
#  ('Mecklenburg', '4855'),
#  ('Mecklenburg', '3253'),
#  ('Mecklenburg', '3332'),
#  ('Mecklenburg', '3362'),
#  ('Mecklenburg', '3241'),
#  ('Mecklenburg', '3261'),
#  ('Mecklenburg', '2131'),
#  ('Mecklenburg', '3161'),
#  ('Mecklenburg', '3341'),
#  ('Mecklenburg', '7112'),
#  ('Mecklenburg', '4543'),
#  ('Mecklenburg', '1123'),
#  ('Mecklenburg', '7121'),
#  ('Mecklenburg', '3334'),
#  ('Mecklenburg', '5619'),
#  ('Mecklenburg', '3159'),
#  ('Mecklenburg', '6114'),
#  ('Mecklenburg', '5182'),
#  ('Mecklenburg', '3252'),
#  ('Mecklenburg', '8141'),
#  ('Mecklenburg', '9281'),
#  ('Mecklenburg', '4243'),
#  ('Mecklenburg', '5323'),
#  ('Mecklenburg', '7211'),
#  ('Mecklenburg', '1152'),
#  ('Mecklenburg', '8123'),
#  ('Mecklenburg', '5331'),
#  ('Mecklenburg', '5121'),
#  ('Mecklenburg', '9221'),
#  ('Mecklenburg', '4862'),
#  ('Mecklenburg', '1142'),
#  ('Mecklenburg', '3251'),
#  ('Mecklenburg', '5311'),
#  ('Mecklenburg', '3324'),
#  ('Mecklenburg', '4881'),
#  ('Mecklenburg', '5151'),
#  ('Mecklenburg', '5174'),
#  ('Mecklenburg', '5413'),
#  ('Mecklenburg', '4539'),
#  ('Mecklenburg', '3342'),
#  ('Mecklenburg', '3255'),
#  ('Mecklenburg', '4249'),
#  ('Mecklenburg', '4852'),
#  ('Mecklenburg', '3117'),
#  ('Mecklenburg', '1141'),
#  ('Mecklenburg', '3322'),
#  ('Mecklenburg', '5251'),
#  ('Mecklenburg', '5211'),
#  ('Mecklenburg', '5312'),
#  ('Mecklenburg', '5223'),
#  ('Mecklenburg', '8113'),
#  ('Mecklenburg', '5179'),
#  ('Mecklenburg', '4842'),
#  ('Mecklenburg', '7225'),
#  ('Mecklenburg', '1113'),
#  ('Mecklenburg', '4882'),
#  ('Mecklenburg', '3141'),
#  ('Mecklenburg', '3114'),
#  ('Mecklenburg', '2382'),
#  ('Mecklenburg', '5411'),
#  ('Mecklenburg', '5222'),
#  ('Mecklenburg', '1124'),
#  ('Mecklenburg', '6116'),
#  ('Mecklenburg', '4869'),
#  ('Mecklenburg', '6222'),
#  ('Mecklenburg', '6239'),
#  ('Mecklenburg', '4246'),
#  ('Mecklenburg', '4811'),
#  ('Mecklenburg', '3328'),
#  ('Mecklenburg', '3162'),
#  ('Mecklenburg', '7113'),
#  ('Mecklenburg', '1132'),
#  ('Mecklenburg', '2362'),
#  ('Mecklenburg', '1112'),
#  ('Mecklenburg', '2371'),
#  ('Mecklenburg', '9251'),
#  ('Mecklenburg', '5414'),
#  ('Mecklenburg', '4431'),
#  ('Mecklenburg', '6243'),
#  ('Mecklenburg', '6112'),
#  ('Mecklenburg', '2383'),
#  ('Mecklenburg', '2379'),
#  ('Mecklenburg', '3116'),
#  ('Mecklenburg', '3169'),
#  ('Mecklenburg', '4879'),
#  ('Mecklenburg', '4413'),
#  ('Mecklenburg', '5419'),
#  ('Mecklenburg', '3133'),
#  ('Mecklenburg', '2211'),
#  ('Mecklenburg', '4453'),
#  ('Mecklenburg', '3366'),
#  ('Mecklenburg', '8134'),
#  ('Mecklenburg', '1153'),
#  ('Mecklenburg', '4542'),
#  ('Mecklenburg', '4532'),
#  ('Mecklenburg', '5417'),
#  ('Mecklenburg', '4239'),
#  ('Mecklenburg', '3312'),
#  ('Mecklenburg', '4248'),
#  ('Mecklenburg', '1131'),
#  ('Mecklenburg', '6212'),
#  ('Mecklenburg', '5616'),
#  ('Mecklenburg', '4242'),
#  ('Mecklenburg', '3327'),
#  ('Mecklenburg', '3346'),
#  ('Mecklenburg', '7132'),
#  ('Mecklenburg', '5415'),
#  ('Mecklenburg', '3274'),
#  ('Mecklenburg', '3315'),
#  ('Mecklenburg', '4481'),
#  ('Mecklenburg', '1114'),
#  ('Mecklenburg', '4854'),
#  ('Mecklenburg', '5122'),
#  ('Mecklenburg', '3364'),
#  ('Mecklenburg', '3262'),
#  ('Mecklenburg', '4931'),
#  ('Mecklenburg', '3359'),
#  ('Mecklenburg', '6242'),
#  ('Mecklenburg', '4861'),
#  ('Mecklenburg', '4471'),
#  ('Mecklenburg', '3311'),
#  ('Mecklenburg', '3222'),
#  ('Mecklenburg', '4482'),
#  ('Mecklenburg', '3339'),
#  ('Mecklenburg', '5617'),
#  ('Mecklenburg', '6113'),
#  ('Mecklenburg', '4832'),
#  ('Mecklenburg', '3331'),
#  ('Mecklenburg', '4921'),
#  ('Mecklenburg', '8112'),
#  ('Mecklenburg', '4461'),
#  ('Mecklenburg', '3273'),
#  ('Mecklenburg', '4523'),
#  ('Mecklenburg', '6211'),
#  ('Mecklenburg', '5111'),
#  ('Mecklenburg', '4247'),
#  ('Mecklenburg', '3271'),
#  ('Mecklenburg', '3343'),
#  ('Mecklenburg', '4522'),
#  ('Mecklenburg', '2381'),
#  ('Mecklenburg', '5152'),
#  ('Mecklenburg', '3372'),
#  ('Mecklenburg', '4245'),
#  ('Mecklenburg', '9271'),
#  ('Mecklenburg', '3113'),
#  ('Mecklenburg', '4922'),
#  ('Mecklenburg', '4236'),
#  ('Mecklenburg', '5259'),
#  ('Mecklenburg', '4889'),
#  ('Mecklenburg', '4531'),
#  ('Mecklenburg', '6214'),
#  ('Mecklenburg', '8114'),
#  ('Mecklenburg', '1129'),
#  ('Mecklenburg', '3272'),
#  ('Mecklenburg', '3323'),
#  ('Mecklenburg', '6115'),
#  ('Mecklenburg', '5611'),
#  ('Mecklenburg', '8131'),
#  ('Mecklenburg', '1133'),
#  ('Mecklenburg', '6219'),
#  ('Mecklenburg', '5614'),
#  ('Mecklenburg', '3231'),
#  ('Mecklenburg', '4251'),
#  ('McDowell', '2122'),
#  ('McDowell', '3313'),
#  ('McDowell', '5232'),
#  ('McDowell', '3132'),
#  ('McDowell', '1151'),
#  ('McDowell', '4541'),
#  ('McDowell', '3344'),
#  ('McDowell', '5613'),
#  ('McDowell', '3333'),
#  ('McDowell', '8132'),
#  ('McDowell', '3326'),
#  ('McDowell', '3329'),
#  ('McDowell', '5239'),
#  ('McDowell', '5418'),
#  ('McDowell', '3211'),
#  ('McDowell', '4235'),
#  ('McDowell', '5412'),
#  ('McDowell', '3212'),
#  ('McDowell', '4411'),
#  ('McDowell', '3352'),
#  ('McDowell', '7224'),
#  ('McDowell', '5242'),
#  ('McDowell', '4851'),
#  ('McDowell', '5221'),
#  ('McDowell', '4234'),
#  ('McDowell', '7111'),
#  ('McDowell', '7114'),
#  ('McDowell', '3119'),
#  ('McDowell', '8111'),
#  ('McDowell', '3221'),
#  ('McDowell', '2213'),
#  ('McDowell', '4422'),
#  ('McDowell', '3335'),
#  ('McDowell', '4421'),
#  ('McDowell', '4831'),
#  ('McDowell', '4232'),
#  ('McDowell', '4883'),
#  ('McDowell', '4885'),
#  ('McDowell', '3371'),
#  ('McDowell', '3351'),
#  ('McDowell', '4412'),
#  ('McDowell', '1121'),
#  ('McDowell', '6216'),
#  ('McDowell', '1125'),
#  ('McDowell', '3345'),
#  ('McDowell', '9231'),
#  ('McDowell', '5416'),
#  ('McDowell', '3122'),
#  ('McDowell', '3131'),
#  ('McDowell', '2121'),
#  ('McDowell', '2372'),
#  ('McDowell', '3121'),
#  ('McDowell', '4821'),
#  ('McDowell', '4241'),
#  ('McDowell', '3259'),
#  ('McDowell', '9261'),
#  ('McDowell', '6213'),
#  ('McDowell', '4853'),
#  ('McDowell', '5231'),
#  ('McDowell', '4841'),
#  ('McDowell', '7212'),
#  ('McDowell', '3151'),
#  ...]

# %%
with open("res_tasks.txt", "w") as f:
    for i in res_tasks:
        f.write(i[0]+"-"+i[1])
        f.write("\n")

# %% [markdown]
# ## Second trial

# %%
import math
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import asyncio
from tqdm.notebook import tqdm
from datetime import datetime
import nest_asyncio

# Allow nested event loops in Jupyter Notebook
nest_asyncio.apply()

# Function to split data into batches
def split_into_batches(data, num_batches):
    """
    Splits a list into a specified number of batches.
    """
    batch_size = math.ceil(len(data) / num_batches)
    return [data[i * batch_size:(i + 1) * batch_size] for i in range(num_batches)]

# Async function to fetch links for a single NAICS code
async def fetch_links(driver, naics_code):
    """
    Fetch all 'Detail' links for a given NAICS code.
    Handles pagination and logs progress to a worklog file.
    """
    try:
        # Step 1: Navigate to the Page
        url = "https://accessnc.nccommerce.com/business/business_custom_search_infogroup.html"
        driver.get(url)

        # Wait for the page to load
        await asyncio.sleep(1)

        # Step 2: Select Industry Group (e.g., NAICS Code)
        industry_dropdown = Select(driver.find_element(By.ID, "qnaics"))
        industry_dropdown.select_by_value(naics_code)

        # Step 3: Interact with the Submit Button
        submit_button = driver.find_element(By.CSS_SELECTOR, "div.form-group > button[type='submit'][class='btn btn-primary'][name='submit']")
        driver.execute_script("arguments[0].scrollIntoView(true);", submit_button)
        await asyncio.sleep(1)
        driver.execute_script("arguments[0].click();", submit_button)
        print(f"Clicked the Submit button for NAICS: {naics_code}.")

        # Step 4: Wait for Results to Load and Process the New Tab's HTML
        await asyncio.sleep(3)  # Wait to ensure the response page is fully loaded
        driver.switch_to.window(driver.window_handles[-1])  # Switch to the new tab
        print(f"Switched to the new tab for NAICS: {naics_code}.")

        # Initialize an empty list to store all links
        all_detail_links = []
        page_num = 1  # Initialize page counter

        while True:
            # Capture the HTML content of the current page
            result_html = driver.page_source
            soup = BeautifulSoup(result_html, 'html.parser')

            # Extract all links where the text is "Detail"
            detail_links = [link.get('href') for link in soup.find_all('a', string="Detail")]
            all_detail_links.extend(detail_links)
            print(f"NAICS: {naics_code}, Page {page_num}: Extracted {len(detail_links)} links.")

            # Write links to a temporary file
            timestamp = datetime.now()
            tmp_filename = f"tmp_{naics_code}_{timestamp.hour}_{timestamp.minute}.txt"
            with open(tmp_filename, "a") as file:
                for link in detail_links:
                    file.write(link + "\n")
            print(f"NAICS: {naics_code}, Page {page_num}: Wrote {len(detail_links)} links to {tmp_filename}")

            # Log progress to worklog
            with open("worklog.txt", "a") as log_file:
                log_file.write(f"[{timestamp}] NAICS: {naics_code}, Page: {page_num}, Links Extracted: {len(detail_links)}\n")

            # Find and click the "Next" button
            try:
                next_button = driver.find_element(By.CSS_SELECTOR, "a[rel='next']")
                if "disabled" in next_button.get_attribute("class"):
                    print(f"NAICS: {naics_code}, Page {page_num}: No more pages.")
                    break
                next_button.click()
                print(f"NAICS: {naics_code}, Clicked the 'Next' button to go to page {page_num + 1}.")
                page_num += 1
                await asyncio.sleep(2)  # Allow time for the next page to load
            except Exception:
                print(f"NAICS: {naics_code}, No 'Next' button found or an error occurred.")
                break

        print(f"NAICS: {naics_code}: Total links extracted: {len(all_detail_links)}")

        # Log final results
        with open("worklog.txt", "a") as log_file:
            log_file.write(f"[{datetime.now()}] Completed NAICS: {naics_code}. Total Links: {len(all_detail_links)}\n")

        # Close the result tab before returning to the main tab
        driver.close()
        await asyncio.sleep(1)  # Ensure tab closure completes
        driver.switch_to.window(driver.window_handles[0])
        print(f"Closed the result tab for NAICS: {naics_code}.")
    except Exception as e:
        print(f"Error processing NAICS: {naics_code}: {e}")

# Async main function
async def main(start_batch, end_batch):
    # Read NAICS codes from the file
    with open("qnaics_codes.txt", 'r') as f:
        codes = [line.strip() for line in f.readlines()]

    # Split the tasks into batches
    batches = split_into_batches(codes, 20)

    # Validate batch range
    if start_batch < 1 or end_batch > len(batches):
        print(f"Invalid batch range: {start_batch}-{end_batch}. Must be between 1 and {len(batches)}.")
        return

    # Create a WebDriver instance
    driver = webdriver.Chrome()

    try:
        for batch_idx in range(start_batch - 1, end_batch):
            print(f"Processing batch {batch_idx + 1}/{end_batch}...")
            progress_bar = tqdm(total=len(batches[batch_idx]), desc=f"Batch {batch_idx + 1}/{end_batch}")

            # Run tasks sequentially in the current batch to ensure proper tab handling
            for naics_code in batches[batch_idx]:
                await fetch_links(driver, naics_code)
                progress_bar.update(1)

            progress_bar.close()
            print(f"Batch {batch_idx + 1} completed.")
            await asyncio.sleep(5)  # Optional rest between batches

        print(f"All tasks from batch {start_batch} to {end_batch} completed. Links are written to tmp files.")
    finally:
        driver.quit()
        print("Closed the WebDriver.")

# %%
# Run the main function in Jupyter Notebook
await main(start_batch=1, end_batch=20)
# Out:
# Processing batch 1/20...
# Batch 1/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 3321.
# Switched to the new tab for NAICS: 3321.
# NAICS: 3321, Page 1: Extracted 59 links.
# NAICS: 3321, Page 1: Wrote 59 links to tmp_3321_4_2.txt
# NAICS: 3321, No 'Next' button found or an error occurred.
# NAICS: 3321: Total links extracted: 59
# Closed the result tab for NAICS: 3321.
# Clicked the Submit button for NAICS: 4884.
# Switched to the new tab for NAICS: 4884.
# NAICS: 4884, Page 1: Extracted 100 links.
# NAICS: 4884, Page 1: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 2.
# NAICS: 4884, Page 2: Extracted 100 links.
# NAICS: 4884, Page 2: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 3.
# /Users/sean/miniconda3/envs/py38/lib/python3.8/site-packages/bs4/__init__.py:749: RuntimeWarning: coroutine 'main' was never awaited
#   tag = self.element_classes.get(Tag, Tag)(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# NAICS: 4884, Page 3: Extracted 100 links.
# NAICS: 4884, Page 3: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 4.
# NAICS: 4884, Page 4: Extracted 100 links.
# NAICS: 4884, Page 4: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 5.
# NAICS: 4884, Page 5: Extracted 100 links.
# NAICS: 4884, Page 5: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 6.
# NAICS: 4884, Page 6: Extracted 100 links.
# NAICS: 4884, Page 6: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 7.
# NAICS: 4884, Page 7: Extracted 100 links.
# NAICS: 4884, Page 7: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 8.
# NAICS: 4884, Page 8: Extracted 100 links.
# NAICS: 4884, Page 8: Wrote 100 links to tmp_4884_4_2.txt
# NAICS: 4884, Clicked the 'Next' button to go to page 9.
# NAICS: 4884, Page 9: Extracted 54 links.
# NAICS: 4884, Page 9: Wrote 54 links to tmp_4884_4_2.txt
# NAICS: 4884, No 'Next' button found or an error occurred.
# NAICS: 4884: Total links extracted: 854
# Closed the result tab for NAICS: 4884.
# Clicked the Submit button for NAICS: 2122.
# Switched to the new tab for NAICS: 2122.
# NAICS: 2122, Page 1: Extracted 3 links.
# NAICS: 2122, Page 1: Wrote 3 links to tmp_2122_4_3.txt
# NAICS: 2122, No 'Next' button found or an error occurred.
# NAICS: 2122: Total links extracted: 3
# Closed the result tab for NAICS: 2122.
# Clicked the Submit button for NAICS: 3313.
# Switched to the new tab for NAICS: 3313.
# NAICS: 3313, Page 1: Extracted 15 links.
# NAICS: 3313, Page 1: Wrote 15 links to tmp_3313_4_3.txt
# NAICS: 3313, No 'Next' button found or an error occurred.
# NAICS: 3313: Total links extracted: 15
# Closed the result tab for NAICS: 3313.
# Clicked the Submit button for NAICS: 5232.
# Switched to the new tab for NAICS: 5232.
# NAICS: 5232, Page 1: Extracted 4 links.
# NAICS: 5232, Page 1: Wrote 4 links to tmp_5232_4_3.txt
# NAICS: 5232, No 'Next' button found or an error occurred.
# NAICS: 5232: Total links extracted: 4
# Closed the result tab for NAICS: 5232.
# Clicked the Submit button for NAICS: 3132.
# Switched to the new tab for NAICS: 3132.
# NAICS: 3132, Page 1: Extracted 100 links.
# NAICS: 3132, Page 1: Wrote 100 links to tmp_3132_4_3.txt
# NAICS: 3132, No 'Next' button found or an error occurred.
# NAICS: 3132: Total links extracted: 100
# Closed the result tab for NAICS: 3132.
# Clicked the Submit button for NAICS: 3391.
# Switched to the new tab for NAICS: 3391.
# NAICS: 3391, Page 1: Extracted 100 links.
# NAICS: 3391, Page 1: Wrote 100 links to tmp_3391_4_3.txt
# NAICS: 3391, Clicked the 'Next' button to go to page 2.
# NAICS: 3391, Page 2: Extracted 100 links.
# NAICS: 3391, Page 2: Wrote 100 links to tmp_3391_4_3.txt
# NAICS: 3391, Clicked the 'Next' button to go to page 3.
# NAICS: 3391, Page 3: Extracted 100 links.
# NAICS: 3391, Page 3: Wrote 100 links to tmp_3391_4_3.txt
# NAICS: 3391, Clicked the 'Next' button to go to page 4.
# NAICS: 3391, Page 4: Extracted 100 links.
# NAICS: 3391, Page 4: Wrote 100 links to tmp_3391_4_3.txt
# NAICS: 3391, Clicked the 'Next' button to go to page 5.
# NAICS: 3391, Page 5: Extracted 35 links.
# NAICS: 3391, Page 5: Wrote 35 links to tmp_3391_4_3.txt
# NAICS: 3391, No 'Next' button found or an error occurred.
# NAICS: 3391: Total links extracted: 435
# Closed the result tab for NAICS: 3391.
# Clicked the Submit button for NAICS: 3365.
# Switched to the new tab for NAICS: 3365.
# NAICS: 3365, Page 1: Extracted 6 links.
# NAICS: 3365, Page 1: Wrote 6 links to tmp_3365_4_3.txt
# NAICS: 3365, No 'Next' button found or an error occurred.
# NAICS: 3365: Total links extracted: 6
# Closed the result tab for NAICS: 3365.
# Clicked the Submit button for NAICS: 1151.
# Switched to the new tab for NAICS: 1151.
# NAICS: 1151, Page 1: Extracted 100 links.
# NAICS: 1151, Page 1: Wrote 100 links to tmp_1151_4_3.txt
# NAICS: 1151, Clicked the 'Next' button to go to page 2.
# NAICS: 1151, Page 2: Extracted 48 links.
# NAICS: 1151, Page 2: Wrote 48 links to tmp_1151_4_3.txt
# NAICS: 1151, No 'Next' button found or an error occurred.
# NAICS: 1151: Total links extracted: 148
# Closed the result tab for NAICS: 1151.
# Clicked the Submit button for NAICS: 5324.
# Switched to the new tab for NAICS: 5324.
# NAICS: 5324, Page 1: Extracted 100 links.
# NAICS: 5324, Page 1: Wrote 100 links to tmp_5324_4_4.txt
# NAICS: 5324, Clicked the 'Next' button to go to page 2.
# NAICS: 5324, Page 2: Extracted 87 links.
# NAICS: 5324, Page 2: Wrote 87 links to tmp_5324_4_4.txt
# NAICS: 5324, No 'Next' button found or an error occurred.
# NAICS: 5324: Total links extracted: 187
# Closed the result tab for NAICS: 5324.
# Clicked the Submit button for NAICS: 4541.
# Switched to the new tab for NAICS: 4541.
# NAICS: 4541, Page 1: Extracted 0 links.
# NAICS: 4541, Page 1: Wrote 0 links to tmp_4541_4_4.txt
# NAICS: 4541, No 'Next' button found or an error occurred.
# NAICS: 4541: Total links extracted: 0
# Closed the result tab for NAICS: 4541.
# Clicked the Submit button for NAICS: 3344.
# Switched to the new tab for NAICS: 3344.
# NAICS: 3344, Page 1: Extracted 100 links.
# NAICS: 3344, Page 1: Wrote 100 links to tmp_3344_4_4.txt
# NAICS: 3344, Clicked the 'Next' button to go to page 2.
# NAICS: 3344, Page 2: Extracted 28 links.
# NAICS: 3344, Page 2: Wrote 28 links to tmp_3344_4_4.txt
# NAICS: 3344, No 'Next' button found or an error occurred.
# NAICS: 3344: Total links extracted: 128
# Closed the result tab for NAICS: 3344.
# Clicked the Submit button for NAICS: 4442.
# Switched to the new tab for NAICS: 4442.
# NAICS: 4442, Page 1: Extracted 100 links.
# NAICS: 4442, Page 1: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 2.
# NAICS: 4442, Page 2: Extracted 100 links.
# NAICS: 4442, Page 2: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 3.
# NAICS: 4442, Page 3: Extracted 100 links.
# NAICS: 4442, Page 3: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 4.
# NAICS: 4442, Page 4: Extracted 100 links.
# NAICS: 4442, Page 4: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 5.
# NAICS: 4442, Page 5: Extracted 100 links.
# NAICS: 4442, Page 5: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 6.
# NAICS: 4442, Page 6: Extracted 100 links.
# NAICS: 4442, Page 6: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 7.
# NAICS: 4442, Page 7: Extracted 100 links.
# NAICS: 4442, Page 7: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 8.
# NAICS: 4442, Page 8: Extracted 100 links.
# NAICS: 4442, Page 8: Wrote 100 links to tmp_4442_4_4.txt
# NAICS: 4442, Clicked the 'Next' button to go to page 9.
# NAICS: 4442, Page 9: Extracted 95 links.
# NAICS: 4442, Page 9: Wrote 95 links to tmp_4442_4_4.txt
# NAICS: 4442, No 'Next' button found or an error occurred.
# NAICS: 4442: Total links extracted: 895
# Closed the result tab for NAICS: 4442.
# Clicked the Submit button for NAICS: 3111.
# Switched to the new tab for NAICS: 3111.
# NAICS: 3111, Page 1: Extracted 45 links.
# NAICS: 3111, Page 1: Wrote 45 links to tmp_3111_4_5.txt
# NAICS: 3111, No 'Next' button found or an error occurred.
# NAICS: 3111: Total links extracted: 45
# Closed the result tab for NAICS: 3111.
# Clicked the Submit button for NAICS: 3112.
# Switched to the new tab for NAICS: 3112.
# NAICS: 3112, Page 1: Extracted 34 links.
# NAICS: 3112, Page 1: Wrote 34 links to tmp_3112_4_5.txt
# NAICS: 3112, No 'Next' button found or an error occurred.
# NAICS: 3112: Total links extracted: 34
# Closed the result tab for NAICS: 3112.
# Clicked the Submit button for NAICS: 4512.
# Switched to the new tab for NAICS: 4512.
# NAICS: 4512, Page 1: Extracted 0 links.
# NAICS: 4512, Page 1: Wrote 0 links to tmp_4512_4_5.txt
# NAICS: 4512, No 'Next' button found or an error occurred.
# NAICS: 4512: Total links extracted: 0
# Closed the result tab for NAICS: 4512.
# Batch 1 completed.
# Processing batch 2/20...
# Batch 2/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 5613.
# Switched to the new tab for NAICS: 5613.
# NAICS: 5613, Page 1: Extracted 100 links.
# NAICS: 5613, Page 1: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 2.
# NAICS: 5613, Page 2: Extracted 100 links.
# NAICS: 5613, Page 2: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 3.
# NAICS: 5613, Page 3: Extracted 100 links.
# NAICS: 5613, Page 3: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 4.
# NAICS: 5613, Page 4: Extracted 100 links.
# NAICS: 5613, Page 4: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 5.
# NAICS: 5613, Page 5: Extracted 100 links.
# NAICS: 5613, Page 5: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 6.
# NAICS: 5613, Page 6: Extracted 100 links.
# NAICS: 5613, Page 6: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 7.
# NAICS: 5613, Page 7: Extracted 100 links.
# NAICS: 5613, Page 7: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 8.
# NAICS: 5613, Page 8: Extracted 100 links.
# NAICS: 5613, Page 8: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 9.
# NAICS: 5613, Page 9: Extracted 100 links.
# NAICS: 5613, Page 9: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 10.
# NAICS: 5613, Page 10: Extracted 100 links.
# NAICS: 5613, Page 10: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 11.
# NAICS: 5613, Page 11: Extracted 100 links.
# NAICS: 5613, Page 11: Wrote 100 links to tmp_5613_4_5.txt
# NAICS: 5613, Clicked the 'Next' button to go to page 12.
# NAICS: 5613, Page 12: Extracted 71 links.
# NAICS: 5613, Page 12: Wrote 71 links to tmp_5613_4_6.txt
# NAICS: 5613, No 'Next' button found or an error occurred.
# NAICS: 5613: Total links extracted: 1171
# Closed the result tab for NAICS: 5613.
# Clicked the Submit button for NAICS: 3333.
# Switched to the new tab for NAICS: 3333.
# NAICS: 3333, Page 1: Extracted 100 links.
# NAICS: 3333, Page 1: Wrote 100 links to tmp_3333_4_6.txt
# NAICS: 3333, Clicked the 'Next' button to go to page 2.
# NAICS: 3333, Page 2: Extracted 57 links.
# NAICS: 3333, Page 2: Wrote 57 links to tmp_3333_4_6.txt
# NAICS: 3333, No 'Next' button found or an error occurred.
# NAICS: 3333: Total links extracted: 157
# Closed the result tab for NAICS: 3333.
# Clicked the Submit button for NAICS: 6231.
# Switched to the new tab for NAICS: 6231.
# NAICS: 6231, Page 1: Extracted 100 links.
# NAICS: 6231, Page 1: Wrote 100 links to tmp_6231_4_6.txt
# NAICS: 6231, Clicked the 'Next' button to go to page 2.
# NAICS: 6231, Page 2: Extracted 100 links.
# NAICS: 6231, Page 2: Wrote 100 links to tmp_6231_4_6.txt
# NAICS: 6231, Clicked the 'Next' button to go to page 3.
# NAICS: 6231, Page 3: Extracted 100 links.
# NAICS: 6231, Page 3: Wrote 100 links to tmp_6231_4_6.txt
# NAICS: 6231, Clicked the 'Next' button to go to page 4.
# NAICS: 6231, Page 4: Extracted 100 links.
# NAICS: 6231, Page 4: Wrote 100 links to tmp_6231_4_6.txt
# NAICS: 6231, Clicked the 'Next' button to go to page 5.
# NAICS: 6231, Page 5: Extracted 100 links.
# NAICS: 6231, Page 5: Wrote 100 links to tmp_6231_4_6.txt
# NAICS: 6231, Clicked the 'Next' button to go to page 6.
# NAICS: 6231, Page 6: Extracted 100 links.
# NAICS: 6231, Page 6: Wrote 100 links to tmp_6231_4_6.txt
# NAICS: 6231, Clicked the 'Next' button to go to page 7.
# NAICS: 6231, Page 7: Extracted 100 links.
# NAICS: 6231, Page 7: Wrote 100 links to tmp_6231_4_6.txt
# NAICS: 6231, Clicked the 'Next' button to go to page 8.
# NAICS: 6231, Page 8: Extracted 91 links.
# NAICS: 6231, Page 8: Wrote 91 links to tmp_6231_4_6.txt
# NAICS: 6231, No 'Next' button found or an error occurred.
# NAICS: 6231: Total links extracted: 791
# Closed the result tab for NAICS: 6231.
# Clicked the Submit button for NAICS: 8132.
# Switched to the new tab for NAICS: 8132.
# NAICS: 8132, Page 1: Extracted 0 links.
# NAICS: 8132, Page 1: Wrote 0 links to tmp_8132_4_6.txt
# NAICS: 8132, Clicked the 'Next' button to go to page 2.
# NAICS: 8132, Page 2: Extracted 54 links.
# NAICS: 8132, Page 2: Wrote 54 links to tmp_8132_4_6.txt
# NAICS: 8132, No 'Next' button found or an error occurred.
# NAICS: 8132: Total links extracted: 54
# Closed the result tab for NAICS: 8132.
# Clicked the Submit button for NAICS: 4231.
# Switched to the new tab for NAICS: 4231.
# NAICS: 4231, Page 1: Extracted 100 links.
# NAICS: 4231, Page 1: Wrote 100 links to tmp_4231_4_7.txt
# NAICS: 4231, Clicked the 'Next' button to go to page 2.
# NAICS: 4231, Page 2: Extracted 100 links.
# NAICS: 4231, Page 2: Wrote 100 links to tmp_4231_4_7.txt
# NAICS: 4231, Clicked the 'Next' button to go to page 3.
# NAICS: 4231, Page 3: Extracted 100 links.
# NAICS: 4231, Page 3: Wrote 100 links to tmp_4231_4_7.txt
# NAICS: 4231, Clicked the 'Next' button to go to page 4.
# NAICS: 4231, Page 4: Extracted 100 links.
# NAICS: 4231, Page 4: Wrote 100 links to tmp_4231_4_7.txt
# NAICS: 4231, Clicked the 'Next' button to go to page 5.
# NAICS: 4231, Page 5: Extracted 100 links.
# NAICS: 4231, Page 5: Wrote 100 links to tmp_4231_4_7.txt
# NAICS: 4231, Clicked the 'Next' button to go to page 6.
# NAICS: 4231, Page 6: Extracted 100 links.
# NAICS: 4231, Page 6: Wrote 100 links to tmp_4231_4_7.txt
# NAICS: 4231, Clicked the 'Next' button to go to page 7.
# NAICS: 4231, Page 7: Extracted 74 links.
# NAICS: 4231, Page 7: Wrote 74 links to tmp_4231_4_7.txt
# NAICS: 4231, No 'Next' button found or an error occurred.
# NAICS: 4231: Total links extracted: 674
# Closed the result tab for NAICS: 4231.
# Clicked the Submit button for NAICS: 3326.
# Switched to the new tab for NAICS: 3326.
# NAICS: 3326, Page 1: Extracted 57 links.
# NAICS: 3326, Page 1: Wrote 57 links to tmp_3326_4_7.txt
# NAICS: 3326, No 'Next' button found or an error occurred.
# NAICS: 3326: Total links extracted: 57
# Closed the result tab for NAICS: 3326.
# Clicked the Submit button for NAICS: 3329.
# Switched to the new tab for NAICS: 3329.
# NAICS: 3329, Page 1: Extracted 100 links.
# NAICS: 3329, Page 1: Wrote 100 links to tmp_3329_4_7.txt
# NAICS: 3329, Clicked the 'Next' button to go to page 2.
# NAICS: 3329, Page 2: Extracted 100 links.
# NAICS: 3329, Page 2: Wrote 100 links to tmp_3329_4_7.txt
# NAICS: 3329, Clicked the 'Next' button to go to page 3.
# NAICS: 3329, Page 3: Extracted 89 links.
# NAICS: 3329, Page 3: Wrote 89 links to tmp_3329_4_7.txt
# NAICS: 3329, No 'Next' button found or an error occurred.
# NAICS: 3329: Total links extracted: 289
# Closed the result tab for NAICS: 3329.
# Clicked the Submit button for NAICS: 6223.
# Switched to the new tab for NAICS: 6223.
# NAICS: 6223, Page 1: Extracted 63 links.
# NAICS: 6223, Page 1: Wrote 63 links to tmp_6223_4_7.txt
# NAICS: 6223, No 'Next' button found or an error occurred.
# NAICS: 6223: Total links extracted: 63
# Closed the result tab for NAICS: 6223.
# Clicked the Submit button for NAICS: 5511.
# Switched to the new tab for NAICS: 5511.
# NAICS: 5511, Page 1: Extracted 100 links.
# NAICS: 5511, Page 1: Wrote 100 links to tmp_5511_4_7.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 2.
# NAICS: 5511, Page 2: Extracted 100 links.
# NAICS: 5511, Page 2: Wrote 100 links to tmp_5511_4_7.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 3.
# NAICS: 5511, Page 3: Extracted 100 links.
# NAICS: 5511, Page 3: Wrote 100 links to tmp_5511_4_7.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 4.
# NAICS: 5511, Page 4: Extracted 100 links.
# NAICS: 5511, Page 4: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 5.
# NAICS: 5511, Page 5: Extracted 100 links.
# NAICS: 5511, Page 5: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 6.
# NAICS: 5511, Page 6: Extracted 100 links.
# NAICS: 5511, Page 6: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 7.
# NAICS: 5511, Page 7: Extracted 100 links.
# NAICS: 5511, Page 7: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 8.
# NAICS: 5511, Page 8: Extracted 100 links.
# NAICS: 5511, Page 8: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 9.
# NAICS: 5511, Page 9: Extracted 100 links.
# NAICS: 5511, Page 9: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 10.
# NAICS: 5511, Page 10: Extracted 100 links.
# NAICS: 5511, Page 10: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 11.
# NAICS: 5511, Page 11: Extracted 100 links.
# NAICS: 5511, Page 11: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 12.
# NAICS: 5511, Page 12: Extracted 100 links.
# NAICS: 5511, Page 12: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 13.
# NAICS: 5511, Page 13: Extracted 100 links.
# NAICS: 5511, Page 13: Wrote 100 links to tmp_5511_4_8.txt
# NAICS: 5511, Clicked the 'Next' button to go to page 14.
# NAICS: 5511, Page 14: Extracted 52 links.
# NAICS: 5511, Page 14: Wrote 52 links to tmp_5511_4_8.txt
# NAICS: 5511, No 'Next' button found or an error occurred.
# NAICS: 5511: Total links extracted: 1352
# Closed the result tab for NAICS: 5511.
# Clicked the Submit button for NAICS: 5239.
# Switched to the new tab for NAICS: 5239.
# NAICS: 5239, Page 1: Extracted 100 links.
# NAICS: 5239, Page 1: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 2.
# NAICS: 5239, Page 2: Extracted 100 links.
# NAICS: 5239, Page 2: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 3.
# NAICS: 5239, Page 3: Extracted 100 links.
# NAICS: 5239, Page 3: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 4.
# NAICS: 5239, Page 4: Extracted 100 links.
# NAICS: 5239, Page 4: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 5.
# NAICS: 5239, Page 5: Extracted 100 links.
# NAICS: 5239, Page 5: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 6.
# NAICS: 5239, Page 6: Extracted 100 links.
# NAICS: 5239, Page 6: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 7.
# NAICS: 5239, Page 7: Extracted 100 links.
# NAICS: 5239, Page 7: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 8.
# NAICS: 5239, Page 8: Extracted 100 links.
# NAICS: 5239, Page 8: Wrote 100 links to tmp_5239_4_8.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 9.
# NAICS: 5239, Page 9: Extracted 100 links.
# NAICS: 5239, Page 9: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 10.
# NAICS: 5239, Page 10: Extracted 100 links.
# NAICS: 5239, Page 10: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 11.
# NAICS: 5239, Page 11: Extracted 100 links.
# NAICS: 5239, Page 11: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 12.
# NAICS: 5239, Page 12: Extracted 100 links.
# NAICS: 5239, Page 12: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 13.
# NAICS: 5239, Page 13: Extracted 100 links.
# NAICS: 5239, Page 13: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 14.
# NAICS: 5239, Page 14: Extracted 100 links.
# NAICS: 5239, Page 14: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 15.
# NAICS: 5239, Page 15: Extracted 100 links.
# NAICS: 5239, Page 15: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 16.
# NAICS: 5239, Page 16: Extracted 100 links.
# NAICS: 5239, Page 16: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 17.
# NAICS: 5239, Page 17: Extracted 100 links.
# NAICS: 5239, Page 17: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 18.
# NAICS: 5239, Page 18: Extracted 100 links.
# NAICS: 5239, Page 18: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 19.
# NAICS: 5239, Page 19: Extracted 100 links.
# NAICS: 5239, Page 19: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 20.
# NAICS: 5239, Page 20: Extracted 100 links.
# NAICS: 5239, Page 20: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 21.
# NAICS: 5239, Page 21: Extracted 100 links.
# NAICS: 5239, Page 21: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 22.
# NAICS: 5239, Page 22: Extracted 100 links.
# NAICS: 5239, Page 22: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 23.
# NAICS: 5239, Page 23: Extracted 100 links.
# NAICS: 5239, Page 23: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 24.
# NAICS: 5239, Page 24: Extracted 100 links.
# NAICS: 5239, Page 24: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 25.
# NAICS: 5239, Page 25: Extracted 100 links.
# NAICS: 5239, Page 25: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 26.
# NAICS: 5239, Page 26: Extracted 100 links.
# NAICS: 5239, Page 26: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 27.
# NAICS: 5239, Page 27: Extracted 100 links.
# NAICS: 5239, Page 27: Wrote 100 links to tmp_5239_4_9.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 28.
# NAICS: 5239, Page 28: Extracted 100 links.
# NAICS: 5239, Page 28: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 29.
# NAICS: 5239, Page 29: Extracted 100 links.
# NAICS: 5239, Page 29: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 30.
# NAICS: 5239, Page 30: Extracted 100 links.
# NAICS: 5239, Page 30: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 31.
# NAICS: 5239, Page 31: Extracted 100 links.
# NAICS: 5239, Page 31: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 32.
# NAICS: 5239, Page 32: Extracted 100 links.
# NAICS: 5239, Page 32: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 33.
# NAICS: 5239, Page 33: Extracted 100 links.
# NAICS: 5239, Page 33: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 34.
# NAICS: 5239, Page 34: Extracted 100 links.
# NAICS: 5239, Page 34: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 35.
# NAICS: 5239, Page 35: Extracted 100 links.
# NAICS: 5239, Page 35: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 36.
# NAICS: 5239, Page 36: Extracted 100 links.
# NAICS: 5239, Page 36: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 37.
# NAICS: 5239, Page 37: Extracted 100 links.
# NAICS: 5239, Page 37: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 38.
# NAICS: 5239, Page 38: Extracted 100 links.
# NAICS: 5239, Page 38: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 39.
# NAICS: 5239, Page 39: Extracted 100 links.
# NAICS: 5239, Page 39: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 40.
# NAICS: 5239, Page 40: Extracted 100 links.
# NAICS: 5239, Page 40: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 41.
# NAICS: 5239, Page 41: Extracted 100 links.
# NAICS: 5239, Page 41: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 42.
# NAICS: 5239, Page 42: Extracted 100 links.
# NAICS: 5239, Page 42: Wrote 100 links to tmp_5239_4_10.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 43.
# NAICS: 5239, Page 43: Extracted 100 links.
# NAICS: 5239, Page 43: Wrote 100 links to tmp_5239_4_11.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 44.
# NAICS: 5239, Page 44: Extracted 100 links.
# NAICS: 5239, Page 44: Wrote 100 links to tmp_5239_4_11.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 45.
# NAICS: 5239, Page 45: Extracted 100 links.
# NAICS: 5239, Page 45: Wrote 100 links to tmp_5239_4_11.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 46.
# NAICS: 5239, Page 46: Extracted 100 links.
# NAICS: 5239, Page 46: Wrote 100 links to tmp_5239_4_11.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 47.
# NAICS: 5239, Page 47: Extracted 100 links.
# NAICS: 5239, Page 47: Wrote 100 links to tmp_5239_4_11.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 48.
# NAICS: 5239, Page 48: Extracted 100 links.
# NAICS: 5239, Page 48: Wrote 100 links to tmp_5239_4_11.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 49.
# NAICS: 5239, Page 49: Extracted 100 links.
# NAICS: 5239, Page 49: Wrote 100 links to tmp_5239_4_11.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 50.
# NAICS: 5239, Page 50: Extracted 100 links.
# NAICS: 5239, Page 50: Wrote 100 links to tmp_5239_4_12.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 51.
# NAICS: 5239, Page 51: Extracted 100 links.
# NAICS: 5239, Page 51: Wrote 100 links to tmp_5239_4_12.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 52.
# NAICS: 5239, Page 52: Extracted 100 links.
# NAICS: 5239, Page 52: Wrote 100 links to tmp_5239_4_12.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 53.
# NAICS: 5239, Page 53: Extracted 100 links.
# NAICS: 5239, Page 53: Wrote 100 links to tmp_5239_4_12.txt
# NAICS: 5239, Clicked the 'Next' button to go to page 54.
# NAICS: 5239, Page 54: Extracted 24 links.
# NAICS: 5239, Page 54: Wrote 24 links to tmp_5239_4_12.txt
# NAICS: 5239, No 'Next' button found or an error occurred.
# NAICS: 5239: Total links extracted: 5324
# Closed the result tab for NAICS: 5239.
# Clicked the Submit button for NAICS: 5615.
# Switched to the new tab for NAICS: 5615.
# NAICS: 5615, Page 1: Extracted 0 links.
# NAICS: 5615, Page 1: Wrote 0 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 2.
# NAICS: 5615, Page 2: Extracted 100 links.
# NAICS: 5615, Page 2: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 3.
# NAICS: 5615, Page 3: Extracted 100 links.
# NAICS: 5615, Page 3: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 4.
# NAICS: 5615, Page 4: Extracted 100 links.
# NAICS: 5615, Page 4: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 5.
# NAICS: 5615, Page 5: Extracted 100 links.
# NAICS: 5615, Page 5: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 6.
# NAICS: 5615, Page 6: Extracted 100 links.
# NAICS: 5615, Page 6: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 7.
# NAICS: 5615, Page 7: Extracted 100 links.
# NAICS: 5615, Page 7: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 8.
# NAICS: 5615, Page 8: Extracted 100 links.
# NAICS: 5615, Page 8: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 9.
# NAICS: 5615, Page 9: Extracted 100 links.
# NAICS: 5615, Page 9: Wrote 100 links to tmp_5615_4_12.txt
# NAICS: 5615, Clicked the 'Next' button to go to page 10.
# NAICS: 5615, Page 10: Extracted 65 links.
# NAICS: 5615, Page 10: Wrote 65 links to tmp_5615_4_12.txt
# NAICS: 5615, No 'Next' button found or an error occurred.
# NAICS: 5615: Total links extracted: 865
# Closed the result tab for NAICS: 5615.
# Clicked the Submit button for NAICS: 8139.
# Switched to the new tab for NAICS: 8139.
# NAICS: 8139, Page 1: Extracted 0 links.
# NAICS: 8139, Page 1: Wrote 0 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 2.
# NAICS: 8139, Page 2: Extracted 100 links.
# NAICS: 8139, Page 2: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 3.
# NAICS: 8139, Page 3: Extracted 100 links.
# NAICS: 8139, Page 3: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 4.
# NAICS: 8139, Page 4: Extracted 100 links.
# NAICS: 8139, Page 4: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 5.
# NAICS: 8139, Page 5: Extracted 100 links.
# NAICS: 8139, Page 5: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 6.
# NAICS: 8139, Page 6: Extracted 100 links.
# NAICS: 8139, Page 6: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 7.
# NAICS: 8139, Page 7: Extracted 100 links.
# NAICS: 8139, Page 7: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 8.
# NAICS: 8139, Page 8: Extracted 100 links.
# NAICS: 8139, Page 8: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 9.
# NAICS: 8139, Page 9: Extracted 100 links.
# NAICS: 8139, Page 9: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 10.
# NAICS: 8139, Page 10: Extracted 100 links.
# NAICS: 8139, Page 10: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 11.
# NAICS: 8139, Page 11: Extracted 100 links.
# NAICS: 8139, Page 11: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 12.
# NAICS: 8139, Page 12: Extracted 100 links.
# NAICS: 8139, Page 12: Wrote 100 links to tmp_8139_4_13.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 13.
# NAICS: 8139, Page 13: Extracted 100 links.
# NAICS: 8139, Page 13: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 14.
# NAICS: 8139, Page 14: Extracted 100 links.
# NAICS: 8139, Page 14: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 15.
# NAICS: 8139, Page 15: Extracted 100 links.
# NAICS: 8139, Page 15: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 16.
# NAICS: 8139, Page 16: Extracted 100 links.
# NAICS: 8139, Page 16: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 17.
# NAICS: 8139, Page 17: Extracted 100 links.
# NAICS: 8139, Page 17: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 18.
# NAICS: 8139, Page 18: Extracted 100 links.
# NAICS: 8139, Page 18: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 19.
# NAICS: 8139, Page 19: Extracted 100 links.
# NAICS: 8139, Page 19: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 20.
# NAICS: 8139, Page 20: Extracted 100 links.
# NAICS: 8139, Page 20: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 21.
# NAICS: 8139, Page 21: Extracted 100 links.
# NAICS: 8139, Page 21: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 22.
# NAICS: 8139, Page 22: Extracted 100 links.
# NAICS: 8139, Page 22: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 23.
# NAICS: 8139, Page 23: Extracted 100 links.
# NAICS: 8139, Page 23: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 24.
# NAICS: 8139, Page 24: Extracted 100 links.
# NAICS: 8139, Page 24: Wrote 100 links to tmp_8139_4_14.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 25.
# NAICS: 8139, Page 25: Extracted 100 links.
# NAICS: 8139, Page 25: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 26.
# NAICS: 8139, Page 26: Extracted 100 links.
# NAICS: 8139, Page 26: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 27.
# NAICS: 8139, Page 27: Extracted 100 links.
# NAICS: 8139, Page 27: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 28.
# NAICS: 8139, Page 28: Extracted 100 links.
# NAICS: 8139, Page 28: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 29.
# NAICS: 8139, Page 29: Extracted 100 links.
# NAICS: 8139, Page 29: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 30.
# NAICS: 8139, Page 30: Extracted 100 links.
# NAICS: 8139, Page 30: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 31.
# NAICS: 8139, Page 31: Extracted 100 links.
# NAICS: 8139, Page 31: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 32.
# NAICS: 8139, Page 32: Extracted 100 links.
# NAICS: 8139, Page 32: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 33.
# NAICS: 8139, Page 33: Extracted 100 links.
# NAICS: 8139, Page 33: Wrote 100 links to tmp_8139_4_15.txt
# NAICS: 8139, Clicked the 'Next' button to go to page 34.
# NAICS: 8139, Page 34: Extracted 20 links.
# NAICS: 8139, Page 34: Wrote 20 links to tmp_8139_4_15.txt
# NAICS: 8139, No 'Next' button found or an error occurred.
# NAICS: 8139: Total links extracted: 3220
# Closed the result tab for NAICS: 8139.
# Clicked the Submit button for NAICS: 6244.
# Switched to the new tab for NAICS: 6244.
# NAICS: 6244, Page 1: Extracted 0 links.
# NAICS: 6244, Page 1: Wrote 0 links to tmp_6244_4_15.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 2.
# NAICS: 6244, Page 2: Extracted 100 links.
# NAICS: 6244, Page 2: Wrote 100 links to tmp_6244_4_15.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 3.
# NAICS: 6244, Page 3: Extracted 100 links.
# NAICS: 6244, Page 3: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 4.
# NAICS: 6244, Page 4: Extracted 100 links.
# NAICS: 6244, Page 4: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 5.
# NAICS: 6244, Page 5: Extracted 100 links.
# NAICS: 6244, Page 5: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 6.
# NAICS: 6244, Page 6: Extracted 100 links.
# NAICS: 6244, Page 6: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 7.
# NAICS: 6244, Page 7: Extracted 100 links.
# NAICS: 6244, Page 7: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 8.
# NAICS: 6244, Page 8: Extracted 100 links.
# NAICS: 6244, Page 8: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 9.
# NAICS: 6244, Page 9: Extracted 100 links.
# NAICS: 6244, Page 9: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 10.
# NAICS: 6244, Page 10: Extracted 100 links.
# NAICS: 6244, Page 10: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 11.
# NAICS: 6244, Page 11: Extracted 100 links.
# NAICS: 6244, Page 11: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 12.
# NAICS: 6244, Page 12: Extracted 100 links.
# NAICS: 6244, Page 12: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 13.
# NAICS: 6244, Page 13: Extracted 100 links.
# NAICS: 6244, Page 13: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 14.
# NAICS: 6244, Page 14: Extracted 100 links.
# NAICS: 6244, Page 14: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 15.
# NAICS: 6244, Page 15: Extracted 100 links.
# NAICS: 6244, Page 15: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 16.
# NAICS: 6244, Page 16: Extracted 100 links.
# NAICS: 6244, Page 16: Wrote 100 links to tmp_6244_4_16.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 17.
# NAICS: 6244, Page 17: Extracted 100 links.
# NAICS: 6244, Page 17: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 18.
# NAICS: 6244, Page 18: Extracted 100 links.
# NAICS: 6244, Page 18: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 19.
# NAICS: 6244, Page 19: Extracted 100 links.
# NAICS: 6244, Page 19: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 20.
# NAICS: 6244, Page 20: Extracted 100 links.
# NAICS: 6244, Page 20: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 21.
# NAICS: 6244, Page 21: Extracted 100 links.
# NAICS: 6244, Page 21: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 22.
# NAICS: 6244, Page 22: Extracted 100 links.
# NAICS: 6244, Page 22: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 23.
# NAICS: 6244, Page 23: Extracted 100 links.
# NAICS: 6244, Page 23: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 24.
# NAICS: 6244, Page 24: Extracted 100 links.
# NAICS: 6244, Page 24: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 25.
# NAICS: 6244, Page 25: Extracted 100 links.
# NAICS: 6244, Page 25: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 26.
# NAICS: 6244, Page 26: Extracted 100 links.
# NAICS: 6244, Page 26: Wrote 100 links to tmp_6244_4_17.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 27.
# NAICS: 6244, Page 27: Extracted 100 links.
# NAICS: 6244, Page 27: Wrote 100 links to tmp_6244_4_18.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 28.
# NAICS: 6244, Page 28: Extracted 100 links.
# NAICS: 6244, Page 28: Wrote 100 links to tmp_6244_4_18.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 29.
# NAICS: 6244, Page 29: Extracted 100 links.
# NAICS: 6244, Page 29: Wrote 100 links to tmp_6244_4_18.txt
# NAICS: 6244, Clicked the 'Next' button to go to page 30.
# NAICS: 6244, Page 30: Extracted 86 links.
# NAICS: 6244, Page 30: Wrote 86 links to tmp_6244_4_18.txt
# NAICS: 6244, No 'Next' button found or an error occurred.
# NAICS: 6244: Total links extracted: 2886
# Closed the result tab for NAICS: 6244.
# Clicked the Submit button for NAICS: 6221.
# Switched to the new tab for NAICS: 6221.
# NAICS: 6221, Page 1: Extracted 0 links.
# NAICS: 6221, Page 1: Wrote 0 links to tmp_6221_4_18.txt
# NAICS: 6221, Clicked the 'Next' button to go to page 2.
# NAICS: 6221, Page 2: Extracted 100 links.
# NAICS: 6221, Page 2: Wrote 100 links to tmp_6221_4_18.txt
# NAICS: 6221, Clicked the 'Next' button to go to page 3.
# NAICS: 6221, Page 3: Extracted 100 links.
# NAICS: 6221, Page 3: Wrote 100 links to tmp_6221_4_18.txt
# NAICS: 6221, Clicked the 'Next' button to go to page 4.
# NAICS: 6221, Page 4: Extracted 100 links.
# NAICS: 6221, Page 4: Wrote 100 links to tmp_6221_4_18.txt
# NAICS: 6221, Clicked the 'Next' button to go to page 5.
# NAICS: 6221, Page 5: Extracted 100 links.
# NAICS: 6221, Page 5: Wrote 100 links to tmp_6221_4_18.txt
# NAICS: 6221, Clicked the 'Next' button to go to page 6.
# NAICS: 6221, Page 6: Extracted 20 links.
# NAICS: 6221, Page 6: Wrote 20 links to tmp_6221_4_19.txt
# NAICS: 6221, No 'Next' button found or an error occurred.
# NAICS: 6221: Total links extracted: 420
# Closed the result tab for NAICS: 6221.
# Clicked the Submit button for NAICS: 5418.
# Switched to the new tab for NAICS: 5418.
# NAICS: 5418, Page 1: Extracted 100 links.
# NAICS: 5418, Page 1: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 2.
# NAICS: 5418, Page 2: Extracted 100 links.
# NAICS: 5418, Page 2: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 3.
# NAICS: 5418, Page 3: Extracted 100 links.
# NAICS: 5418, Page 3: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 4.
# NAICS: 5418, Page 4: Extracted 100 links.
# NAICS: 5418, Page 4: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 5.
# NAICS: 5418, Page 5: Extracted 100 links.
# NAICS: 5418, Page 5: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 6.
# NAICS: 5418, Page 6: Extracted 100 links.
# NAICS: 5418, Page 6: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 7.
# NAICS: 5418, Page 7: Extracted 100 links.
# NAICS: 5418, Page 7: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 8.
# NAICS: 5418, Page 8: Extracted 100 links.
# NAICS: 5418, Page 8: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 9.
# NAICS: 5418, Page 9: Extracted 100 links.
# NAICS: 5418, Page 9: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 10.
# NAICS: 5418, Page 10: Extracted 100 links.
# NAICS: 5418, Page 10: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 11.
# NAICS: 5418, Page 11: Extracted 100 links.
# NAICS: 5418, Page 11: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 12.
# NAICS: 5418, Page 12: Extracted 100 links.
# NAICS: 5418, Page 12: Wrote 100 links to tmp_5418_4_19.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 13.
# NAICS: 5418, Page 13: Extracted 100 links.
# NAICS: 5418, Page 13: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 14.
# NAICS: 5418, Page 14: Extracted 100 links.
# NAICS: 5418, Page 14: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 15.
# NAICS: 5418, Page 15: Extracted 100 links.
# NAICS: 5418, Page 15: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 16.
# NAICS: 5418, Page 16: Extracted 100 links.
# NAICS: 5418, Page 16: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 17.
# NAICS: 5418, Page 17: Extracted 100 links.
# NAICS: 5418, Page 17: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 18.
# NAICS: 5418, Page 18: Extracted 100 links.
# NAICS: 5418, Page 18: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 19.
# NAICS: 5418, Page 19: Extracted 100 links.
# NAICS: 5418, Page 19: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 20.
# NAICS: 5418, Page 20: Extracted 100 links.
# NAICS: 5418, Page 20: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 21.
# NAICS: 5418, Page 21: Extracted 100 links.
# NAICS: 5418, Page 21: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 22.
# NAICS: 5418, Page 22: Extracted 100 links.
# NAICS: 5418, Page 22: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 23.
# NAICS: 5418, Page 23: Extracted 100 links.
# NAICS: 5418, Page 23: Wrote 100 links to tmp_5418_4_20.txt
# NAICS: 5418, Clicked the 'Next' button to go to page 24.
# NAICS: 5418, Page 24: Extracted 9 links.
# NAICS: 5418, Page 24: Wrote 9 links to tmp_5418_4_20.txt
# NAICS: 5418, No 'Next' button found or an error occurred.
# NAICS: 5418: Total links extracted: 2309
# Closed the result tab for NAICS: 5418.
# Clicked the Submit button for NAICS: 3211.
# Switched to the new tab for NAICS: 3211.
# NAICS: 3211, Page 1: Extracted 0 links.
# NAICS: 3211, Page 1: Wrote 0 links to tmp_3211_4_20.txt
# NAICS: 3211, No 'Next' button found or an error occurred.
# NAICS: 3211: Total links extracted: 0
# Closed the result tab for NAICS: 3211.
# Batch 2 completed.
# Processing batch 3/20...
# Batch 3/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 4235.
# Switched to the new tab for NAICS: 4235.
# NAICS: 4235, Page 1: Extracted 0 links.
# NAICS: 4235, Page 1: Wrote 0 links to tmp_4235_4_20.txt
# NAICS: 4235, Clicked the 'Next' button to go to page 2.
# NAICS: 4235, Page 2: Extracted 93 links.
# NAICS: 4235, Page 2: Wrote 93 links to tmp_4235_4_21.txt
# NAICS: 4235, No 'Next' button found or an error occurred.
# NAICS: 4235: Total links extracted: 93
# Closed the result tab for NAICS: 4235.
# Clicked the Submit button for NAICS: 5412.
# Switched to the new tab for NAICS: 5412.
# NAICS: 5412, Page 1: Extracted 100 links.
# NAICS: 5412, Page 1: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 2.
# NAICS: 5412, Page 2: Extracted 100 links.
# NAICS: 5412, Page 2: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 3.
# NAICS: 5412, Page 3: Extracted 100 links.
# NAICS: 5412, Page 3: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 4.
# NAICS: 5412, Page 4: Extracted 100 links.
# NAICS: 5412, Page 4: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 5.
# NAICS: 5412, Page 5: Extracted 100 links.
# NAICS: 5412, Page 5: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 6.
# NAICS: 5412, Page 6: Extracted 100 links.
# NAICS: 5412, Page 6: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 7.
# NAICS: 5412, Page 7: Extracted 100 links.
# NAICS: 5412, Page 7: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 8.
# NAICS: 5412, Page 8: Extracted 100 links.
# NAICS: 5412, Page 8: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 9.
# NAICS: 5412, Page 9: Extracted 100 links.
# NAICS: 5412, Page 9: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 10.
# NAICS: 5412, Page 10: Extracted 100 links.
# NAICS: 5412, Page 10: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 11.
# NAICS: 5412, Page 11: Extracted 100 links.
# NAICS: 5412, Page 11: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 12.
# NAICS: 5412, Page 12: Extracted 100 links.
# NAICS: 5412, Page 12: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 13.
# NAICS: 5412, Page 13: Extracted 100 links.
# NAICS: 5412, Page 13: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 14.
# NAICS: 5412, Page 14: Extracted 100 links.
# NAICS: 5412, Page 14: Wrote 100 links to tmp_5412_4_21.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 15.
# NAICS: 5412, Page 15: Extracted 100 links.
# NAICS: 5412, Page 15: Wrote 100 links to tmp_5412_4_22.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 16.
# NAICS: 5412, Page 16: Extracted 100 links.
# NAICS: 5412, Page 16: Wrote 100 links to tmp_5412_4_22.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 17.
# NAICS: 5412, Page 17: Extracted 100 links.
# NAICS: 5412, Page 17: Wrote 100 links to tmp_5412_4_22.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 18.
# NAICS: 5412, Page 18: Extracted 100 links.
# NAICS: 5412, Page 18: Wrote 100 links to tmp_5412_4_22.txt
# NAICS: 5412, Clicked the 'Next' button to go to page 19.
# ...
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Error processing NAICS: 6115: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Batch 19 completed.
# Processing batch 20/20...
# Batch 20/20:   0%|          | 0/7 [00:00<?, ?it/s]
# Error processing NAICS: 5611: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Error processing NAICS: 8131: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Error processing NAICS: 1133: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Error processing NAICS: 6219: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Error processing NAICS: 5614: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Error processing NAICS: 3231: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Error processing NAICS: 4251: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.86)
# Stacktrace:
# 0   chromedriver                        0x0000000104817ac4 cxxbridge1$str$ptr + 3651580
# 1   chromedriver                        0x0000000104810314 cxxbridge1$str$ptr + 3620940
# 2   chromedriver                        0x00000001042784b4 cxxbridge1$string$len + 89224
# 3   chromedriver                        0x0000000104253994 core::str::slice_error_fail::ha0e52dbcb60e6bae + 3780
# 4   chromedriver                        0x00000001042e2890 cxxbridge1$string$len + 524388
# 5   chromedriver                        0x00000001042f576c cxxbridge1$string$len + 601920
# 6   chromedriver                        0x00000001042b10b0 cxxbridge1$string$len + 321668
# 7   chromedriver                        0x00000001042b1d00 cxxbridge1$string$len + 324820
# 8   chromedriver                        0x00000001047e2e08 cxxbridge1$str$ptr + 3435328
# 9   chromedriver                        0x00000001047e6120 cxxbridge1$str$ptr + 3448408
# 10  chromedriver                        0x00000001047ca17c cxxbridge1$str$ptr + 3333812
# 11  chromedriver                        0x00000001047e69e0 cxxbridge1$str$ptr + 3450648
# 12  chromedriver                        0x00000001047bb988 cxxbridge1$str$ptr + 3274432
# 13  chromedriver                        0x00000001048010f4 cxxbridge1$str$ptr + 3558956
# 14  chromedriver                        0x0000000104801270 cxxbridge1$str$ptr + 3559336
# 15  chromedriver                        0x000000010480ff88 cxxbridge1$str$ptr + 3620032
# 16  libsystem_pthread.dylib             0x00000001882e32e4 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001882de0fc thread_start + 8
#
# Batch 20 completed.
# All tasks from batch 1 to 20 completed. Links are written to tmp files.
# Closed the WebDriver.

# %%
with open("qnaics_codes.txt", 'r') as f:
        codes = [line.strip() for line in f.readlines()]

    # Split the tasks into batches
batches = split_into_batches(codes, 20)
batches[6]
# Out:
# ['1125',
#  '5621',
#  '3345',
#  '4872',
#  '3379',
#  '3118',
#  '2361',
#  '9231',
#  '5416',
#  '3314',
#  '3122',
#  '3369',
#  '5322',
#  '3131',
#  '3336',
#  '2121']

# %%
await main(start_batch=7,end_batch=20)
# Out:
# Processing batch 7/20...
# Batch 7/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 1125.
# Switched to the new tab for NAICS: 1125.
# NAICS: 1125, Page 1: Extracted 0 links.
# NAICS: 1125, Page 1: Wrote 0 links to tmp_1125_5_45.txt
# NAICS: 1125, No 'Next' button found or an error occurred.
# NAICS: 1125: Total links extracted: 0
# Closed the result tab for NAICS: 1125.
# Clicked the Submit button for NAICS: 5621.
# Switched to the new tab for NAICS: 5621.
# NAICS: 5621, Page 1: Extracted 100 links.
# NAICS: 5621, Page 1: Wrote 100 links to tmp_5621_5_45.txt
# NAICS: 5621, Clicked the 'Next' button to go to page 2.
# NAICS: 5621, Page 2: Extracted 100 links.
# NAICS: 5621, Page 2: Wrote 100 links to tmp_5621_5_45.txt
# NAICS: 5621, Clicked the 'Next' button to go to page 3.
# NAICS: 5621, Page 3: Extracted 100 links.
# NAICS: 5621, Page 3: Wrote 100 links to tmp_5621_5_45.txt
# NAICS: 5621, Clicked the 'Next' button to go to page 4.
# NAICS: 5621, Page 4: Extracted 79 links.
# NAICS: 5621, Page 4: Wrote 79 links to tmp_5621_5_45.txt
# NAICS: 5621, No 'Next' button found or an error occurred.
# NAICS: 5621: Total links extracted: 379
# Closed the result tab for NAICS: 5621.
# Clicked the Submit button for NAICS: 3345.
# Switched to the new tab for NAICS: 3345.
# NAICS: 3345, Page 1: Extracted 0 links.
# NAICS: 3345, Page 1: Wrote 0 links to tmp_3345_5_45.txt
# NAICS: 3345, Clicked the 'Next' button to go to page 2.
# NAICS: 3345, Page 2: Extracted 100 links.
# NAICS: 3345, Page 2: Wrote 100 links to tmp_3345_5_46.txt
# NAICS: 3345, Clicked the 'Next' button to go to page 3.
# NAICS: 3345, Page 3: Extracted 12 links.
# NAICS: 3345, Page 3: Wrote 12 links to tmp_3345_5_46.txt
# NAICS: 3345, No 'Next' button found or an error occurred.
# NAICS: 3345: Total links extracted: 112
# Closed the result tab for NAICS: 3345.
# Clicked the Submit button for NAICS: 4872.
# Switched to the new tab for NAICS: 4872.
# NAICS: 4872, Page 1: Extracted 100 links.
# NAICS: 4872, Page 1: Wrote 100 links to tmp_4872_5_46.txt
# NAICS: 4872, Clicked the 'Next' button to go to page 2.
# NAICS: 4872, Page 2: Extracted 8 links.
# NAICS: 4872, Page 2: Wrote 8 links to tmp_4872_5_46.txt
# NAICS: 4872, No 'Next' button found or an error occurred.
# NAICS: 4872: Total links extracted: 108
# Closed the result tab for NAICS: 4872.
# Clicked the Submit button for NAICS: 3379.
# Switched to the new tab for NAICS: 3379.
# NAICS: 3379, Page 1: Extracted 61 links.
# NAICS: 3379, Page 1: Wrote 61 links to tmp_3379_5_46.txt
# NAICS: 3379, No 'Next' button found or an error occurred.
# NAICS: 3379: Total links extracted: 61
# Closed the result tab for NAICS: 3379.
# Clicked the Submit button for NAICS: 3118.
# Switched to the new tab for NAICS: 3118.
# NAICS: 3118, Page 1: Extracted 100 links.
# NAICS: 3118, Page 1: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 2.
# NAICS: 3118, Page 2: Extracted 100 links.
# NAICS: 3118, Page 2: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 3.
# NAICS: 3118, Page 3: Extracted 100 links.
# NAICS: 3118, Page 3: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 4.
# NAICS: 3118, Page 4: Extracted 100 links.
# NAICS: 3118, Page 4: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 5.
# NAICS: 3118, Page 5: Extracted 100 links.
# NAICS: 3118, Page 5: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 6.
# NAICS: 3118, Page 6: Extracted 100 links.
# NAICS: 3118, Page 6: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 7.
# NAICS: 3118, Page 7: Extracted 100 links.
# NAICS: 3118, Page 7: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 8.
# NAICS: 3118, Page 8: Extracted 100 links.
# NAICS: 3118, Page 8: Wrote 100 links to tmp_3118_5_46.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 9.
# NAICS: 3118, Page 9: Extracted 100 links.
# NAICS: 3118, Page 9: Wrote 100 links to tmp_3118_5_47.txt
# NAICS: 3118, Clicked the 'Next' button to go to page 10.
# NAICS: 3118, Page 10: Extracted 60 links.
# NAICS: 3118, Page 10: Wrote 60 links to tmp_3118_5_47.txt
# NAICS: 3118, No 'Next' button found or an error occurred.
# NAICS: 3118: Total links extracted: 960
# Closed the result tab for NAICS: 3118.
# Clicked the Submit button for NAICS: 2361.
# Switched to the new tab for NAICS: 2361.
# NAICS: 2361, Page 1: Extracted 100 links.
# NAICS: 2361, Page 1: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 2.
# NAICS: 2361, Page 2: Extracted 100 links.
# NAICS: 2361, Page 2: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 3.
# NAICS: 2361, Page 3: Extracted 100 links.
# NAICS: 2361, Page 3: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 4.
# NAICS: 2361, Page 4: Extracted 100 links.
# NAICS: 2361, Page 4: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 5.
# NAICS: 2361, Page 5: Extracted 100 links.
# NAICS: 2361, Page 5: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 6.
# NAICS: 2361, Page 6: Extracted 100 links.
# NAICS: 2361, Page 6: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 7.
# NAICS: 2361, Page 7: Extracted 100 links.
# NAICS: 2361, Page 7: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 8.
# NAICS: 2361, Page 8: Extracted 100 links.
# NAICS: 2361, Page 8: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 9.
# NAICS: 2361, Page 9: Extracted 100 links.
# NAICS: 2361, Page 9: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 10.
# NAICS: 2361, Page 10: Extracted 100 links.
# NAICS: 2361, Page 10: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 11.
# NAICS: 2361, Page 11: Extracted 100 links.
# NAICS: 2361, Page 11: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 12.
# NAICS: 2361, Page 12: Extracted 100 links.
# NAICS: 2361, Page 12: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 13.
# NAICS: 2361, Page 13: Extracted 100 links.
# NAICS: 2361, Page 13: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 14.
# NAICS: 2361, Page 14: Extracted 100 links.
# NAICS: 2361, Page 14: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 15.
# NAICS: 2361, Page 15: Extracted 100 links.
# NAICS: 2361, Page 15: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 16.
# NAICS: 2361, Page 16: Extracted 100 links.
# NAICS: 2361, Page 16: Wrote 100 links to tmp_2361_5_47.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 17.
# NAICS: 2361, Page 17: Extracted 100 links.
# NAICS: 2361, Page 17: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 18.
# NAICS: 2361, Page 18: Extracted 100 links.
# NAICS: 2361, Page 18: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 19.
# NAICS: 2361, Page 19: Extracted 100 links.
# NAICS: 2361, Page 19: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 20.
# NAICS: 2361, Page 20: Extracted 100 links.
# NAICS: 2361, Page 20: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 21.
# NAICS: 2361, Page 21: Extracted 100 links.
# NAICS: 2361, Page 21: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 22.
# NAICS: 2361, Page 22: Extracted 100 links.
# NAICS: 2361, Page 22: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 23.
# NAICS: 2361, Page 23: Extracted 100 links.
# NAICS: 2361, Page 23: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 24.
# NAICS: 2361, Page 24: Extracted 100 links.
# NAICS: 2361, Page 24: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 25.
# NAICS: 2361, Page 25: Extracted 100 links.
# NAICS: 2361, Page 25: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 26.
# NAICS: 2361, Page 26: Extracted 100 links.
# NAICS: 2361, Page 26: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 27.
# NAICS: 2361, Page 27: Extracted 100 links.
# NAICS: 2361, Page 27: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 28.
# NAICS: 2361, Page 28: Extracted 100 links.
# NAICS: 2361, Page 28: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 29.
# NAICS: 2361, Page 29: Extracted 100 links.
# NAICS: 2361, Page 29: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 30.
# NAICS: 2361, Page 30: Extracted 100 links.
# NAICS: 2361, Page 30: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 31.
# NAICS: 2361, Page 31: Extracted 100 links.
# NAICS: 2361, Page 31: Wrote 100 links to tmp_2361_5_48.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 32.
# NAICS: 2361, Page 32: Extracted 100 links.
# NAICS: 2361, Page 32: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 33.
# NAICS: 2361, Page 33: Extracted 100 links.
# NAICS: 2361, Page 33: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 34.
# NAICS: 2361, Page 34: Extracted 100 links.
# NAICS: 2361, Page 34: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 35.
# NAICS: 2361, Page 35: Extracted 100 links.
# NAICS: 2361, Page 35: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 36.
# NAICS: 2361, Page 36: Extracted 100 links.
# NAICS: 2361, Page 36: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 37.
# NAICS: 2361, Page 37: Extracted 100 links.
# NAICS: 2361, Page 37: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 38.
# NAICS: 2361, Page 38: Extracted 100 links.
# NAICS: 2361, Page 38: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 39.
# NAICS: 2361, Page 39: Extracted 100 links.
# NAICS: 2361, Page 39: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 40.
# NAICS: 2361, Page 40: Extracted 100 links.
# NAICS: 2361, Page 40: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 41.
# NAICS: 2361, Page 41: Extracted 100 links.
# NAICS: 2361, Page 41: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 42.
# NAICS: 2361, Page 42: Extracted 100 links.
# NAICS: 2361, Page 42: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 43.
# NAICS: 2361, Page 43: Extracted 100 links.
# NAICS: 2361, Page 43: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 44.
# NAICS: 2361, Page 44: Extracted 100 links.
# NAICS: 2361, Page 44: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 45.
# NAICS: 2361, Page 45: Extracted 100 links.
# NAICS: 2361, Page 45: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 46.
# NAICS: 2361, Page 46: Extracted 100 links.
# NAICS: 2361, Page 46: Wrote 100 links to tmp_2361_5_49.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 47.
# NAICS: 2361, Page 47: Extracted 100 links.
# NAICS: 2361, Page 47: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 48.
# NAICS: 2361, Page 48: Extracted 100 links.
# NAICS: 2361, Page 48: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 49.
# NAICS: 2361, Page 49: Extracted 100 links.
# NAICS: 2361, Page 49: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 50.
# NAICS: 2361, Page 50: Extracted 100 links.
# NAICS: 2361, Page 50: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 51.
# NAICS: 2361, Page 51: Extracted 100 links.
# NAICS: 2361, Page 51: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 52.
# NAICS: 2361, Page 52: Extracted 100 links.
# NAICS: 2361, Page 52: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 53.
# NAICS: 2361, Page 53: Extracted 100 links.
# NAICS: 2361, Page 53: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 54.
# NAICS: 2361, Page 54: Extracted 100 links.
# NAICS: 2361, Page 54: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 55.
# NAICS: 2361, Page 55: Extracted 100 links.
# NAICS: 2361, Page 55: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 56.
# NAICS: 2361, Page 56: Extracted 100 links.
# NAICS: 2361, Page 56: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 57.
# NAICS: 2361, Page 57: Extracted 100 links.
# NAICS: 2361, Page 57: Wrote 100 links to tmp_2361_5_50.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 58.
# NAICS: 2361, Page 58: Extracted 100 links.
# NAICS: 2361, Page 58: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 59.
# NAICS: 2361, Page 59: Extracted 100 links.
# NAICS: 2361, Page 59: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 60.
# NAICS: 2361, Page 60: Extracted 100 links.
# NAICS: 2361, Page 60: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 61.
# NAICS: 2361, Page 61: Extracted 100 links.
# NAICS: 2361, Page 61: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 62.
# NAICS: 2361, Page 62: Extracted 100 links.
# NAICS: 2361, Page 62: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 63.
# NAICS: 2361, Page 63: Extracted 100 links.
# NAICS: 2361, Page 63: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 64.
# NAICS: 2361, Page 64: Extracted 100 links.
# NAICS: 2361, Page 64: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 65.
# NAICS: 2361, Page 65: Extracted 100 links.
# NAICS: 2361, Page 65: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 66.
# NAICS: 2361, Page 66: Extracted 100 links.
# NAICS: 2361, Page 66: Wrote 100 links to tmp_2361_5_51.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 67.
# NAICS: 2361, Page 67: Extracted 100 links.
# NAICS: 2361, Page 67: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 68.
# NAICS: 2361, Page 68: Extracted 100 links.
# NAICS: 2361, Page 68: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 69.
# NAICS: 2361, Page 69: Extracted 100 links.
# NAICS: 2361, Page 69: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 70.
# NAICS: 2361, Page 70: Extracted 100 links.
# NAICS: 2361, Page 70: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 71.
# NAICS: 2361, Page 71: Extracted 100 links.
# NAICS: 2361, Page 71: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 72.
# NAICS: 2361, Page 72: Extracted 100 links.
# NAICS: 2361, Page 72: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 73.
# NAICS: 2361, Page 73: Extracted 100 links.
# NAICS: 2361, Page 73: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 74.
# NAICS: 2361, Page 74: Extracted 100 links.
# NAICS: 2361, Page 74: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 75.
# NAICS: 2361, Page 75: Extracted 100 links.
# NAICS: 2361, Page 75: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 76.
# NAICS: 2361, Page 76: Extracted 100 links.
# NAICS: 2361, Page 76: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 77.
# NAICS: 2361, Page 77: Extracted 100 links.
# NAICS: 2361, Page 77: Wrote 100 links to tmp_2361_5_52.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 78.
# NAICS: 2361, Page 78: Extracted 100 links.
# NAICS: 2361, Page 78: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 79.
# NAICS: 2361, Page 79: Extracted 100 links.
# NAICS: 2361, Page 79: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 80.
# NAICS: 2361, Page 80: Extracted 100 links.
# NAICS: 2361, Page 80: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 81.
# NAICS: 2361, Page 81: Extracted 100 links.
# NAICS: 2361, Page 81: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 82.
# NAICS: 2361, Page 82: Extracted 100 links.
# NAICS: 2361, Page 82: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 83.
# NAICS: 2361, Page 83: Extracted 100 links.
# NAICS: 2361, Page 83: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 84.
# NAICS: 2361, Page 84: Extracted 100 links.
# NAICS: 2361, Page 84: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 85.
# NAICS: 2361, Page 85: Extracted 100 links.
# NAICS: 2361, Page 85: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 86.
# NAICS: 2361, Page 86: Extracted 100 links.
# NAICS: 2361, Page 86: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 87.
# NAICS: 2361, Page 87: Extracted 100 links.
# NAICS: 2361, Page 87: Wrote 100 links to tmp_2361_5_53.txt
# NAICS: 2361, Clicked the 'Next' button to go to page 88.
# NAICS: 2361, Page 88: Extracted 19 links.
# NAICS: 2361, Page 88: Wrote 19 links to tmp_2361_5_53.txt
# NAICS: 2361, No 'Next' button found or an error occurred.
# NAICS: 2361: Total links extracted: 8719
# Closed the result tab for NAICS: 2361.
# Clicked the Submit button for NAICS: 9231.
# Switched to the new tab for NAICS: 9231.
# NAICS: 9231, Page 1: Extracted 0 links.
# NAICS: 9231, Page 1: Wrote 0 links to tmp_9231_5_54.txt
# NAICS: 9231, Clicked the 'Next' button to go to page 2.
# NAICS: 9231, Page 2: Extracted 100 links.
# NAICS: 9231, Page 2: Wrote 100 links to tmp_9231_5_54.txt
# NAICS: 9231, Clicked the 'Next' button to go to page 3.
# NAICS: 9231, Page 3: Extracted 100 links.
# NAICS: 9231, Page 3: Wrote 100 links to tmp_9231_5_54.txt
# NAICS: 9231, Clicked the 'Next' button to go to page 4.
# NAICS: 9231, Page 4: Extracted 100 links.
# NAICS: 9231, Page 4: Wrote 100 links to tmp_9231_5_54.txt
# NAICS: 9231, Clicked the 'Next' button to go to page 5.
# NAICS: 9231, Page 5: Extracted 1 links.
# NAICS: 9231, Page 5: Wrote 1 links to tmp_9231_5_54.txt
# NAICS: 9231, No 'Next' button found or an error occurred.
# NAICS: 9231: Total links extracted: 301
# Closed the result tab for NAICS: 9231.
# Clicked the Submit button for NAICS: 5416.
# Switched to the new tab for NAICS: 5416.
# NAICS: 5416, Page 1: Extracted 100 links.
# NAICS: 5416, Page 1: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 2.
# NAICS: 5416, Page 2: Extracted 100 links.
# NAICS: 5416, Page 2: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 3.
# NAICS: 5416, Page 3: Extracted 100 links.
# NAICS: 5416, Page 3: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 4.
# NAICS: 5416, Page 4: Extracted 100 links.
# NAICS: 5416, Page 4: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 5.
# NAICS: 5416, Page 5: Extracted 100 links.
# NAICS: 5416, Page 5: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 6.
# NAICS: 5416, Page 6: Extracted 100 links.
# NAICS: 5416, Page 6: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 7.
# NAICS: 5416, Page 7: Extracted 100 links.
# NAICS: 5416, Page 7: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 8.
# NAICS: 5416, Page 8: Extracted 100 links.
# NAICS: 5416, Page 8: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 9.
# NAICS: 5416, Page 9: Extracted 100 links.
# NAICS: 5416, Page 9: Wrote 100 links to tmp_5416_5_54.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 10.
# NAICS: 5416, Page 10: Extracted 100 links.
# NAICS: 5416, Page 10: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 11.
# NAICS: 5416, Page 11: Extracted 100 links.
# NAICS: 5416, Page 11: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 12.
# NAICS: 5416, Page 12: Extracted 100 links.
# NAICS: 5416, Page 12: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 13.
# NAICS: 5416, Page 13: Extracted 100 links.
# NAICS: 5416, Page 13: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 14.
# NAICS: 5416, Page 14: Extracted 100 links.
# NAICS: 5416, Page 14: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 15.
# NAICS: 5416, Page 15: Extracted 100 links.
# NAICS: 5416, Page 15: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 16.
# NAICS: 5416, Page 16: Extracted 100 links.
# NAICS: 5416, Page 16: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 17.
# NAICS: 5416, Page 17: Extracted 100 links.
# NAICS: 5416, Page 17: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 18.
# NAICS: 5416, Page 18: Extracted 100 links.
# NAICS: 5416, Page 18: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 19.
# NAICS: 5416, Page 19: Extracted 100 links.
# NAICS: 5416, Page 19: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 20.
# NAICS: 5416, Page 20: Extracted 100 links.
# NAICS: 5416, Page 20: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 21.
# NAICS: 5416, Page 21: Extracted 100 links.
# NAICS: 5416, Page 21: Wrote 100 links to tmp_5416_5_55.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 22.
# NAICS: 5416, Page 22: Extracted 100 links.
# NAICS: 5416, Page 22: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 23.
# NAICS: 5416, Page 23: Extracted 100 links.
# NAICS: 5416, Page 23: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 24.
# NAICS: 5416, Page 24: Extracted 100 links.
# NAICS: 5416, Page 24: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 25.
# NAICS: 5416, Page 25: Extracted 100 links.
# NAICS: 5416, Page 25: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 26.
# NAICS: 5416, Page 26: Extracted 100 links.
# NAICS: 5416, Page 26: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 27.
# NAICS: 5416, Page 27: Extracted 100 links.
# NAICS: 5416, Page 27: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 28.
# NAICS: 5416, Page 28: Extracted 100 links.
# NAICS: 5416, Page 28: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 29.
# NAICS: 5416, Page 29: Extracted 100 links.
# NAICS: 5416, Page 29: Wrote 100 links to tmp_5416_5_56.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 30.
# NAICS: 5416, Page 30: Extracted 100 links.
# NAICS: 5416, Page 30: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 31.
# NAICS: 5416, Page 31: Extracted 100 links.
# NAICS: 5416, Page 31: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 32.
# NAICS: 5416, Page 32: Extracted 100 links.
# NAICS: 5416, Page 32: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 33.
# NAICS: 5416, Page 33: Extracted 100 links.
# NAICS: 5416, Page 33: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 34.
# NAICS: 5416, Page 34: Extracted 100 links.
# NAICS: 5416, Page 34: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 35.
# NAICS: 5416, Page 35: Extracted 100 links.
# NAICS: 5416, Page 35: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 36.
# NAICS: 5416, Page 36: Extracted 100 links.
# NAICS: 5416, Page 36: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 37.
# NAICS: 5416, Page 37: Extracted 100 links.
# NAICS: 5416, Page 37: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 38.
# NAICS: 5416, Page 38: Extracted 100 links.
# NAICS: 5416, Page 38: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 39.
# NAICS: 5416, Page 39: Extracted 100 links.
# NAICS: 5416, Page 39: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 40.
# NAICS: 5416, Page 40: Extracted 100 links.
# NAICS: 5416, Page 40: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 41.
# NAICS: 5416, Page 41: Extracted 100 links.
# NAICS: 5416, Page 41: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 42.
# NAICS: 5416, Page 42: Extracted 100 links.
# NAICS: 5416, Page 42: Wrote 100 links to tmp_5416_5_57.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 43.
# NAICS: 5416, Page 43: Extracted 100 links.
# NAICS: 5416, Page 43: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 44.
# NAICS: 5416, Page 44: Extracted 100 links.
# NAICS: 5416, Page 44: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 45.
# NAICS: 5416, Page 45: Extracted 100 links.
# NAICS: 5416, Page 45: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 46.
# NAICS: 5416, Page 46: Extracted 100 links.
# NAICS: 5416, Page 46: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 47.
# NAICS: 5416, Page 47: Extracted 100 links.
# NAICS: 5416, Page 47: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 48.
# NAICS: 5416, Page 48: Extracted 100 links.
# NAICS: 5416, Page 48: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 49.
# NAICS: 5416, Page 49: Extracted 100 links.
# NAICS: 5416, Page 49: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 50.
# NAICS: 5416, Page 50: Extracted 100 links.
# NAICS: 5416, Page 50: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 51.
# NAICS: 5416, Page 51: Extracted 100 links.
# NAICS: 5416, Page 51: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 52.
# NAICS: 5416, Page 52: Extracted 100 links.
# NAICS: 5416, Page 52: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 53.
# NAICS: 5416, Page 53: Extracted 100 links.
# NAICS: 5416, Page 53: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 54.
# NAICS: 5416, Page 54: Extracted 100 links.
# NAICS: 5416, Page 54: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 55.
# NAICS: 5416, Page 55: Extracted 100 links.
# NAICS: 5416, Page 55: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 56.
# NAICS: 5416, Page 56: Extracted 100 links.
# NAICS: 5416, Page 56: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 57.
# NAICS: 5416, Page 57: Extracted 100 links.
# NAICS: 5416, Page 57: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 58.
# NAICS: 5416, Page 58: Extracted 100 links.
# NAICS: 5416, Page 58: Wrote 100 links to tmp_5416_5_58.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 59.
# NAICS: 5416, Page 59: Extracted 100 links.
# NAICS: 5416, Page 59: Wrote 100 links to tmp_5416_5_59.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 60.
# NAICS: 5416, Page 60: Extracted 100 links.
# NAICS: 5416, Page 60: Wrote 100 links to tmp_5416_5_59.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 61.
# NAICS: 5416, Page 61: Extracted 100 links.
# NAICS: 5416, Page 61: Wrote 100 links to tmp_5416_5_59.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 62.
# NAICS: 5416, Page 62: Extracted 100 links.
# NAICS: 5416, Page 62: Wrote 100 links to tmp_5416_5_59.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 63.
# NAICS: 5416, Page 63: Extracted 100 links.
# NAICS: 5416, Page 63: Wrote 100 links to tmp_5416_5_59.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 64.
# NAICS: 5416, Page 64: Extracted 100 links.
# NAICS: 5416, Page 64: Wrote 100 links to tmp_5416_5_59.txt
# NAICS: 5416, Clicked the 'Next' button to go to page 65.
# NAICS: 5416, Page 65: Extracted 66 links.
# NAICS: 5416, Page 65: Wrote 66 links to tmp_5416_5_59.txt
# NAICS: 5416, No 'Next' button found or an error occurred.
# NAICS: 5416: Total links extracted: 6466
# Closed the result tab for NAICS: 5416.
# Clicked the Submit button for NAICS: 3314.
# Switched to the new tab for NAICS: 3314.
# NAICS: 3314, Page 1: Extracted 16 links.
# NAICS: 3314, Page 1: Wrote 16 links to tmp_3314_5_59.txt
# NAICS: 3314, No 'Next' button found or an error occurred.
# NAICS: 3314: Total links extracted: 16
# Closed the result tab for NAICS: 3314.
# Clicked the Submit button for NAICS: 3122.
# Switched to the new tab for NAICS: 3122.
# NAICS: 3122, Page 1: Extracted 36 links.
# NAICS: 3122, Page 1: Wrote 36 links to tmp_3122_5_59.txt
# NAICS: 3122, No 'Next' button found or an error occurred.
# NAICS: 3122: Total links extracted: 36
# Closed the result tab for NAICS: 3122.
# Clicked the Submit button for NAICS: 3369.
# Switched to the new tab for NAICS: 3369.
# NAICS: 3369, Page 1: Extracted 36 links.
# NAICS: 3369, Page 1: Wrote 36 links to tmp_3369_5_59.txt
# NAICS: 3369, No 'Next' button found or an error occurred.
# NAICS: 3369: Total links extracted: 36
# Closed the result tab for NAICS: 3369.
# Clicked the Submit button for NAICS: 5322.
# Switched to the new tab for NAICS: 5322.
# NAICS: 5322, Page 1: Extracted 100 links.
# NAICS: 5322, Page 1: Wrote 100 links to tmp_5322_5_59.txt
# NAICS: 5322, Clicked the 'Next' button to go to page 2.
# NAICS: 5322, Page 2: Extracted 100 links.
# NAICS: 5322, Page 2: Wrote 100 links to tmp_5322_5_59.txt
# NAICS: 5322, Clicked the 'Next' button to go to page 3.
# NAICS: 5322, Page 3: Extracted 100 links.
# NAICS: 5322, Page 3: Wrote 100 links to tmp_5322_5_59.txt
# NAICS: 5322, Clicked the 'Next' button to go to page 4.
# NAICS: 5322, Page 4: Extracted 100 links.
# NAICS: 5322, Page 4: Wrote 100 links to tmp_5322_5_59.txt
# NAICS: 5322, Clicked the 'Next' button to go to page 5.
# NAICS: 5322, Page 5: Extracted 100 links.
# NAICS: 5322, Page 5: Wrote 100 links to tmp_5322_5_59.txt
# NAICS: 5322, Clicked the 'Next' button to go to page 6.
# NAICS: 5322, Page 6: Extracted 44 links.
# NAICS: 5322, Page 6: Wrote 44 links to tmp_5322_5_59.txt
# NAICS: 5322, No 'Next' button found or an error occurred.
# NAICS: 5322: Total links extracted: 544
# Closed the result tab for NAICS: 5322.
# Clicked the Submit button for NAICS: 3131.
# Switched to the new tab for NAICS: 3131.
# NAICS: 3131, Page 1: Extracted 0 links.
# NAICS: 3131, Page 1: Wrote 0 links to tmp_3131_6_0.txt
# NAICS: 3131, No 'Next' button found or an error occurred.
# NAICS: 3131: Total links extracted: 0
# Closed the result tab for NAICS: 3131.
# Clicked the Submit button for NAICS: 3336.
# Switched to the new tab for NAICS: 3336.
# NAICS: 3336, Page 1: Extracted 54 links.
# NAICS: 3336, Page 1: Wrote 54 links to tmp_3336_6_0.txt
# NAICS: 3336, No 'Next' button found or an error occurred.
# NAICS: 3336: Total links extracted: 54
# Closed the result tab for NAICS: 3336.
# Clicked the Submit button for NAICS: 2121.
# Switched to the new tab for NAICS: 2121.
# NAICS: 2121, Page 1: Extracted 0 links.
# NAICS: 2121, Page 1: Wrote 0 links to tmp_2121_6_0.txt
# NAICS: 2121, No 'Next' button found or an error occurred.
# NAICS: 2121: Total links extracted: 0
# Closed the result tab for NAICS: 2121.
# Batch 7 completed.
# Processing batch 8/20...
# Batch 8/20:   0%|          | 0/16 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 2372.
# Switched to the new tab for NAICS: 2372.
# NAICS: 2372, Page 1: Extracted 100 links.
# NAICS: 2372, Page 1: Wrote 100 links to tmp_2372_6_0.txt
# NAICS: 2372, Clicked the 'Next' button to go to page 2.
# NAICS: 2372, Page 2: Extracted 100 links.
# NAICS: 2372, Page 2: Wrote 100 links to tmp_2372_6_0.txt
# NAICS: 2372, Clicked the 'Next' button to go to page 3.
# NAICS: 2372, Page 3: Extracted 100 links.
# NAICS: 2372, Page 3: Wrote 100 links to tmp_2372_6_0.txt
# NAICS: 2372, Clicked the 'Next' button to go to page 4.
# NAICS: 2372, Page 4: Extracted 83 links.
# NAICS: 2372, Page 4: Wrote 83 links to tmp_2372_6_0.txt
# NAICS: 2372, No 'Next' button found or an error occurred.
# NAICS: 2372: Total links extracted: 383
# Closed the result tab for NAICS: 2372.
# Clicked the Submit button for NAICS: 6215.
# Switched to the new tab for NAICS: 6215.
# NAICS: 6215, Page 1: Extracted 100 links.
# NAICS: 6215, Page 1: Wrote 100 links to tmp_6215_6_0.txt
# NAICS: 6215, Clicked the 'Next' button to go to page 2.
# NAICS: 6215, Page 2: Extracted 100 links.
# NAICS: 6215, Page 2: Wrote 100 links to tmp_6215_6_0.txt
# NAICS: 6215, Clicked the 'Next' button to go to page 3.
# NAICS: 6215, Page 3: Extracted 100 links.
# NAICS: 6215, Page 3: Wrote 100 links to tmp_6215_6_0.txt
# NAICS: 6215, Clicked the 'Next' button to go to page 4.
# NAICS: 6215, Page 4: Extracted 100 links.
# NAICS: 6215, Page 4: Wrote 100 links to tmp_6215_6_0.txt
# NAICS: 6215, Clicked the 'Next' button to go to page 5.
# NAICS: 6215, Page 5: Extracted 100 links.
# NAICS: 6215, Page 5: Wrote 100 links to tmp_6215_6_1.txt
# NAICS: 6215, Clicked the 'Next' button to go to page 6.
# NAICS: 6215, Page 6: Extracted 77 links.
# NAICS: 6215, Page 6: Wrote 77 links to tmp_6215_6_1.txt
# NAICS: 6215, No 'Next' button found or an error occurred.
# NAICS: 6215: Total links extracted: 577
# Closed the result tab for NAICS: 6215.
# Clicked the Submit button for NAICS: 3353.
# Switched to the new tab for NAICS: 3353.
# NAICS: 3353, Page 1: Extracted 0 links.
# NAICS: 3353, Page 1: Wrote 0 links to tmp_3353_6_1.txt
# NAICS: 3353, Clicked the 'Next' button to go to page 2.
# NAICS: 3353, Page 2: Extracted 10 links.
# NAICS: 3353, Page 2: Wrote 10 links to tmp_3353_6_1.txt
# NAICS: 3353, No 'Next' button found or an error occurred.
# NAICS: 3353: Total links extracted: 10
# Closed the result tab for NAICS: 3353.
# Clicked the Submit button for NAICS: 3149.
# Switched to the new tab for NAICS: 3149.
# NAICS: 3149, Page 1: Extracted 0 links.
# NAICS: 3149, Page 1: Wrote 0 links to tmp_3149_6_1.txt
# NAICS: 3149, Clicked the 'Next' button to go to page 2.
# NAICS: 3149, Page 2: Extracted 100 links.
# NAICS: 3149, Page 2: Wrote 100 links to tmp_3149_6_1.txt
# NAICS: 3149, Clicked the 'Next' button to go to page 3.
# NAICS: 3149, Page 3: Extracted 34 links.
# NAICS: 3149, Page 3: Wrote 34 links to tmp_3149_6_1.txt
# NAICS: 3149, No 'Next' button found or an error occurred.
# NAICS: 3149: Total links extracted: 134
# Closed the result tab for NAICS: 3149.
# Clicked the Submit button for NAICS: 3399.
# Switched to the new tab for NAICS: 3399.
# NAICS: 3399, Page 1: Extracted 0 links.
# NAICS: 3399, Page 1: Wrote 0 links to tmp_3399_6_1.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 2.
# NAICS: 3399, Page 2: Extracted 100 links.
# NAICS: 3399, Page 2: Wrote 100 links to tmp_3399_6_1.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 3.
# NAICS: 3399, Page 3: Extracted 100 links.
# NAICS: 3399, Page 3: Wrote 100 links to tmp_3399_6_1.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 4.
# NAICS: 3399, Page 4: Extracted 100 links.
# NAICS: 3399, Page 4: Wrote 100 links to tmp_3399_6_1.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 5.
# NAICS: 3399, Page 5: Extracted 100 links.
# NAICS: 3399, Page 5: Wrote 100 links to tmp_3399_6_1.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 6.
# NAICS: 3399, Page 6: Extracted 100 links.
# NAICS: 3399, Page 6: Wrote 100 links to tmp_3399_6_1.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 7.
# NAICS: 3399, Page 7: Extracted 100 links.
# NAICS: 3399, Page 7: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 8.
# NAICS: 3399, Page 8: Extracted 100 links.
# NAICS: 3399, Page 8: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 9.
# NAICS: 3399, Page 9: Extracted 100 links.
# NAICS: 3399, Page 9: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 10.
# NAICS: 3399, Page 10: Extracted 100 links.
# NAICS: 3399, Page 10: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 11.
# NAICS: 3399, Page 11: Extracted 100 links.
# NAICS: 3399, Page 11: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 12.
# NAICS: 3399, Page 12: Extracted 100 links.
# NAICS: 3399, Page 12: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 13.
# NAICS: 3399, Page 13: Extracted 100 links.
# NAICS: 3399, Page 13: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 14.
# NAICS: 3399, Page 14: Extracted 100 links.
# NAICS: 3399, Page 14: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 15.
# NAICS: 3399, Page 15: Extracted 100 links.
# NAICS: 3399, Page 15: Wrote 100 links to tmp_3399_6_2.txt
# NAICS: 3399, Clicked the 'Next' button to go to page 16.
# NAICS: 3399, Page 16: Extracted 89 links.
# NAICS: 3399, Page 16: Wrote 89 links to tmp_3399_6_2.txt
# NAICS: 3399, No 'Next' button found or an error occurred.
# NAICS: 3399: Total links extracted: 1489
# Closed the result tab for NAICS: 3399.
# Clicked the Submit button for NAICS: 3121.
# Switched to the new tab for NAICS: 3121.
# NAICS: 3121, Page 1: Extracted 100 links.
# NAICS: 3121, Page 1: Wrote 100 links to tmp_3121_6_2.txt
# NAICS: 3121, Clicked the 'Next' button to go to page 2.
# NAICS: 3121, Page 2: Extracted 100 links.
# NAICS: 3121, Page 2: Wrote 100 links to tmp_3121_6_2.txt
# NAICS: 3121, Clicked the 'Next' button to go to page 3.
# NAICS: 3121, Page 3: Extracted 100 links.
# NAICS: 3121, Page 3: Wrote 100 links to tmp_3121_6_3.txt
# NAICS: 3121, Clicked the 'Next' button to go to page 4.
# NAICS: 3121, Page 4: Extracted 100 links.
# NAICS: 3121, Page 4: Wrote 100 links to tmp_3121_6_3.txt
# NAICS: 3121, Clicked the 'Next' button to go to page 5.
# NAICS: 3121, Page 5: Extracted 100 links.
# NAICS: 3121, Page 5: Wrote 100 links to tmp_3121_6_3.txt
# NAICS: 3121, Clicked the 'Next' button to go to page 6.
# NAICS: 3121, Page 6: Extracted 100 links.
# NAICS: 3121, Page 6: Wrote 100 links to tmp_3121_6_3.txt
# NAICS: 3121, Clicked the 'Next' button to go to page 7.
# NAICS: 3121, Page 7: Extracted 2 links.
# NAICS: 3121, Page 7: Wrote 2 links to tmp_3121_6_3.txt
# NAICS: 3121, No 'Next' button found or an error occurred.
# NAICS: 3121: Total links extracted: 602
# Closed the result tab for NAICS: 3121.
# Clicked the Submit button for NAICS: 3256.
# Switched to the new tab for NAICS: 3256.
# NAICS: 3256, Page 1: Extracted 100 links.
# NAICS: 3256, Page 1: Wrote 100 links to tmp_3256_6_3.txt
# NAICS: 3256, Clicked the 'Next' button to go to page 2.
# NAICS: 3256, Page 2: Extracted 11 links.
# NAICS: 3256, Page 2: Wrote 11 links to tmp_3256_6_3.txt
# NAICS: 3256, No 'Next' button found or an error occurred.
# NAICS: 3256: Total links extracted: 111
# Closed the result tab for NAICS: 3256.
# Clicked the Submit button for NAICS: 3279.
# Switched to the new tab for NAICS: 3279.
# NAICS: 3279, Page 1: Extracted 0 links.
# NAICS: 3279, Page 1: Wrote 0 links to tmp_3279_6_3.txt
# NAICS: 3279, Clicked the 'Next' button to go to page 2.
# NAICS: 3279, Page 2: Extracted 6 links.
# NAICS: 3279, Page 2: Wrote 6 links to tmp_3279_6_3.txt
# NAICS: 3279, No 'Next' button found or an error occurred.
# NAICS: 3279: Total links extracted: 6
# Closed the result tab for NAICS: 3279.
# Clicked the Submit button for NAICS: 4821.
# Switched to the new tab for NAICS: 4821.
# NAICS: 4821, Page 1: Extracted 0 links.
# NAICS: 4821, Page 1: Wrote 0 links to tmp_4821_6_3.txt
# NAICS: 4821, No 'Next' button found or an error occurred.
# NAICS: 4821: Total links extracted: 0
# Closed the result tab for NAICS: 4821.
# Clicked the Submit button for NAICS: 4859.
# Switched to the new tab for NAICS: 4859.
# NAICS: 4859, Page 1: Extracted 0 links.
# NAICS: 4859, Page 1: Wrote 0 links to tmp_4859_6_3.txt
# NAICS: 4859, Clicked the 'Next' button to go to page 2.
# NAICS: 4859, Page 2: Extracted 100 links.
# NAICS: 4859, Page 2: Wrote 100 links to tmp_4859_6_3.txt
# NAICS: 4859, Clicked the 'Next' button to go to page 3.
# NAICS: 4859, Page 3: Extracted 80 links.
# NAICS: 4859, Page 3: Wrote 80 links to tmp_4859_6_4.txt
# NAICS: 4859, No 'Next' button found or an error occurred.
# NAICS: 4859: Total links extracted: 180
# Closed the result tab for NAICS: 4859.
# Clicked the Submit button for NAICS: 4241.
# Switched to the new tab for NAICS: 4241.
# NAICS: 4241, Page 1: Extracted 100 links.
# NAICS: 4241, Page 1: Wrote 100 links to tmp_4241_6_4.txt
# NAICS: 4241, Clicked the 'Next' button to go to page 2.
# NAICS: 4241, Page 2: Extracted 98 links.
# NAICS: 4241, Page 2: Wrote 98 links to tmp_4241_6_4.txt
# NAICS: 4241, No 'Next' button found or an error occurred.
# NAICS: 4241: Total links extracted: 198
# Closed the result tab for NAICS: 4241.
# Clicked the Submit button for NAICS: 4452.
# Switched to the new tab for NAICS: 4452.
# NAICS: 4452, Page 1: Extracted 100 links.
# NAICS: 4452, Page 1: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 2.
# NAICS: 4452, Page 2: Extracted 100 links.
# NAICS: 4452, Page 2: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 3.
# NAICS: 4452, Page 3: Extracted 100 links.
# NAICS: 4452, Page 3: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 4.
# NAICS: 4452, Page 4: Extracted 100 links.
# NAICS: 4452, Page 4: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 5.
# NAICS: 4452, Page 5: Extracted 100 links.
# NAICS: 4452, Page 5: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 6.
# NAICS: 4452, Page 6: Extracted 100 links.
# NAICS: 4452, Page 6: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 7.
# NAICS: 4452, Page 7: Extracted 100 links.
# NAICS: 4452, Page 7: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 8.
# NAICS: 4452, Page 8: Extracted 100 links.
# NAICS: 4452, Page 8: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 9.
# NAICS: 4452, Page 9: Extracted 100 links.
# NAICS: 4452, Page 9: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 10.
# NAICS: 4452, Page 10: Extracted 100 links.
# NAICS: 4452, Page 10: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 11.
# NAICS: 4452, Page 11: Extracted 100 links.
# NAICS: 4452, Page 11: Wrote 100 links to tmp_4452_6_4.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 12.
# NAICS: 4452, Page 12: Extracted 100 links.
# NAICS: 4452, Page 12: Wrote 100 links to tmp_4452_6_5.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 13.
# NAICS: 4452, Page 13: Extracted 100 links.
# NAICS: 4452, Page 13: Wrote 100 links to tmp_4452_6_5.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 14.
# NAICS: 4452, Page 14: Extracted 100 links.
# NAICS: 4452, Page 14: Wrote 100 links to tmp_4452_6_5.txt
# NAICS: 4452, Clicked the 'Next' button to go to page 15.
# NAICS: 4452, Page 15: Extracted 39 links.
# NAICS: 4452, Page 15: Wrote 39 links to tmp_4452_6_5.txt
# NAICS: 4452, No 'Next' button found or an error occurred.
# NAICS: 4452: Total links extracted: 1439
# Closed the result tab for NAICS: 4452.
# Clicked the Submit button for NAICS: 3259.
# Switched to the new tab for NAICS: 3259.
# NAICS: 3259, Page 1: Extracted 0 links.
# NAICS: 3259, Page 1: Wrote 0 links to tmp_3259_6_5.txt
# NAICS: 3259, Clicked the 'Next' button to go to page 2.
# NAICS: 3259, Page 2: Extracted 29 links.
# NAICS: 3259, Page 2: Wrote 29 links to tmp_3259_6_5.txt
# NAICS: 3259, No 'Next' button found or an error occurred.
# NAICS: 3259: Total links extracted: 29
# Closed the result tab for NAICS: 3259.
# Clicked the Submit button for NAICS: 9261.
# Switched to the new tab for NAICS: 9261.
# NAICS: 9261, Page 1: Extracted 100 links.
# NAICS: 9261, Page 1: Wrote 100 links to tmp_9261_6_5.txt
# NAICS: 9261, Clicked the 'Next' button to go to page 2.
# NAICS: 9261, Page 2: Extracted 100 links.
# NAICS: 9261, Page 2: Wrote 100 links to tmp_9261_6_5.txt
# NAICS: 9261, Clicked the 'Next' button to go to page 3.
# NAICS: 9261, Page 3: Extracted 100 links.
# NAICS: 9261, Page 3: Wrote 100 links to tmp_9261_6_5.txt
# NAICS: 9261, Clicked the 'Next' button to go to page 4.
# NAICS: 9261, Page 4: Extracted 100 links.
# NAICS: 9261, Page 4: Wrote 100 links to tmp_9261_6_5.txt
# NAICS: 9261, Clicked the 'Next' button to go to page 5.
# NAICS: 9261, Page 5: Extracted 100 links.
# NAICS: 9261, Page 5: Wrote 100 links to tmp_9261_6_5.txt
# NAICS: 9261, Clicked the 'Next' button to go to page 6.
# NAICS: 9261, Page 6: Extracted 100 links.
# NAICS: 9261, Page 6: Wrote 100 links to tmp_9261_6_5.txt
# NAICS: 9261, Clicked the 'Next' button to go to page 7.
# NAICS: 9261, Page 7: Extracted 62 links.
# NAICS: 9261, Page 7: Wrote 62 links to tmp_9261_6_5.txt
# NAICS: 9261, No 'Next' button found or an error occurred.
# NAICS: 9261: Total links extracted: 662
# Closed the result tab for NAICS: 9261.
# Clicked the Submit button for NAICS: 6213.
# Switched to the new tab for NAICS: 6213.
# NAICS: 6213, Page 1: Extracted 0 links.
# NAICS: 6213, Page 1: Wrote 0 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 2.
# NAICS: 6213, Page 2: Extracted 100 links.
# NAICS: 6213, Page 2: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 3.
# NAICS: 6213, Page 3: Extracted 100 links.
# NAICS: 6213, Page 3: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 4.
# NAICS: 6213, Page 4: Extracted 100 links.
# NAICS: 6213, Page 4: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 5.
# NAICS: 6213, Page 5: Extracted 100 links.
# NAICS: 6213, Page 5: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 6.
# NAICS: 6213, Page 6: Extracted 100 links.
# NAICS: 6213, Page 6: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 7.
# NAICS: 6213, Page 7: Extracted 100 links.
# NAICS: 6213, Page 7: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 8.
# NAICS: 6213, Page 8: Extracted 100 links.
# NAICS: 6213, Page 8: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 9.
# NAICS: 6213, Page 9: Extracted 100 links.
# NAICS: 6213, Page 9: Wrote 100 links to tmp_6213_6_6.txt
# NAICS: 6213, Clicked the 'Next' button to go to page 10.
# NAICS: 6213, Page 10: Extracted 100 links.
# NAICS: 6213, Page 10: Wrote 100 links to tmp_6213_6_7.txt
# ...
# NAICS: 8131, Page 134: Extracted 100 links.
# NAICS: 8131, Page 134: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 135.
# NAICS: 8131, Page 135: Extracted 100 links.
# NAICS: 8131, Page 135: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 136.
# NAICS: 8131, Page 136: Extracted 100 links.
# NAICS: 8131, Page 136: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 137.
# NAICS: 8131, Page 137: Extracted 100 links.
# NAICS: 8131, Page 137: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 138.
# NAICS: 8131, Page 138: Extracted 100 links.
# NAICS: 8131, Page 138: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 139.
# NAICS: 8131, Page 139: Extracted 100 links.
# NAICS: 8131, Page 139: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 140.
# NAICS: 8131, Page 140: Extracted 100 links.
# NAICS: 8131, Page 140: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 141.
# NAICS: 8131, Page 141: Extracted 100 links.
# NAICS: 8131, Page 141: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 142.
# NAICS: 8131, Page 142: Extracted 100 links.
# NAICS: 8131, Page 142: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 143.
# NAICS: 8131, Page 143: Extracted 100 links.
# NAICS: 8131, Page 143: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 144.
# NAICS: 8131, Page 144: Extracted 100 links.
# NAICS: 8131, Page 144: Wrote 100 links to tmp_8131_8_22.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 145.
# NAICS: 8131, Page 145: Extracted 100 links.
# NAICS: 8131, Page 145: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 146.
# NAICS: 8131, Page 146: Extracted 100 links.
# NAICS: 8131, Page 146: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 147.
# NAICS: 8131, Page 147: Extracted 100 links.
# NAICS: 8131, Page 147: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 148.
# NAICS: 8131, Page 148: Extracted 100 links.
# NAICS: 8131, Page 148: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 149.
# NAICS: 8131, Page 149: Extracted 100 links.
# NAICS: 8131, Page 149: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 150.
# NAICS: 8131, Page 150: Extracted 100 links.
# NAICS: 8131, Page 150: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 151.
# NAICS: 8131, Page 151: Extracted 100 links.
# NAICS: 8131, Page 151: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 152.
# NAICS: 8131, Page 152: Extracted 100 links.
# NAICS: 8131, Page 152: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 153.
# NAICS: 8131, Page 153: Extracted 100 links.
# NAICS: 8131, Page 153: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 154.
# NAICS: 8131, Page 154: Extracted 100 links.
# NAICS: 8131, Page 154: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 155.
# NAICS: 8131, Page 155: Extracted 100 links.
# NAICS: 8131, Page 155: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 156.
# NAICS: 8131, Page 156: Extracted 100 links.
# NAICS: 8131, Page 156: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 157.
# NAICS: 8131, Page 157: Extracted 100 links.
# NAICS: 8131, Page 157: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 158.
# NAICS: 8131, Page 158: Extracted 100 links.
# NAICS: 8131, Page 158: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 159.
# NAICS: 8131, Page 159: Extracted 100 links.
# NAICS: 8131, Page 159: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 160.
# NAICS: 8131, Page 160: Extracted 100 links.
# NAICS: 8131, Page 160: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 161.
# NAICS: 8131, Page 161: Extracted 100 links.
# NAICS: 8131, Page 161: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 162.
# NAICS: 8131, Page 162: Extracted 100 links.
# NAICS: 8131, Page 162: Wrote 100 links to tmp_8131_8_23.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 163.
# NAICS: 8131, Page 163: Extracted 100 links.
# NAICS: 8131, Page 163: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 164.
# NAICS: 8131, Page 164: Extracted 100 links.
# NAICS: 8131, Page 164: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 165.
# NAICS: 8131, Page 165: Extracted 100 links.
# NAICS: 8131, Page 165: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 166.
# NAICS: 8131, Page 166: Extracted 100 links.
# NAICS: 8131, Page 166: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 167.
# NAICS: 8131, Page 167: Extracted 100 links.
# NAICS: 8131, Page 167: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 168.
# NAICS: 8131, Page 168: Extracted 100 links.
# NAICS: 8131, Page 168: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 169.
# NAICS: 8131, Page 169: Extracted 100 links.
# NAICS: 8131, Page 169: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 170.
# NAICS: 8131, Page 170: Extracted 100 links.
# NAICS: 8131, Page 170: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 171.
# NAICS: 8131, Page 171: Extracted 100 links.
# NAICS: 8131, Page 171: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 172.
# NAICS: 8131, Page 172: Extracted 100 links.
# NAICS: 8131, Page 172: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 173.
# NAICS: 8131, Page 173: Extracted 100 links.
# NAICS: 8131, Page 173: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 174.
# NAICS: 8131, Page 174: Extracted 100 links.
# NAICS: 8131, Page 174: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 175.
# NAICS: 8131, Page 175: Extracted 100 links.
# NAICS: 8131, Page 175: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 176.
# NAICS: 8131, Page 176: Extracted 100 links.
# NAICS: 8131, Page 176: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 177.
# NAICS: 8131, Page 177: Extracted 100 links.
# NAICS: 8131, Page 177: Wrote 100 links to tmp_8131_8_24.txt
# NAICS: 8131, Clicked the 'Next' button to go to page 178.
# NAICS: 8131, Page 178: Extracted 11 links.
# NAICS: 8131, Page 178: Wrote 11 links to tmp_8131_8_24.txt
# NAICS: 8131, No 'Next' button found or an error occurred.
# NAICS: 8131: Total links extracted: 17711
# Closed the result tab for NAICS: 8131.
# Clicked the Submit button for NAICS: 1133.
# Switched to the new tab for NAICS: 1133.
# NAICS: 1133, Page 1: Extracted 100 links.
# NAICS: 1133, Page 1: Wrote 100 links to tmp_1133_8_24.txt
# NAICS: 1133, Clicked the 'Next' button to go to page 2.
# NAICS: 1133, Page 2: Extracted 70 links.
# NAICS: 1133, Page 2: Wrote 70 links to tmp_1133_8_25.txt
# NAICS: 1133, No 'Next' button found or an error occurred.
# NAICS: 1133: Total links extracted: 170
# Closed the result tab for NAICS: 1133.
# Clicked the Submit button for NAICS: 6219.
# Switched to the new tab for NAICS: 6219.
# NAICS: 6219, Page 1: Extracted 100 links.
# NAICS: 6219, Page 1: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 2.
# NAICS: 6219, Page 2: Extracted 100 links.
# NAICS: 6219, Page 2: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 3.
# NAICS: 6219, Page 3: Extracted 100 links.
# NAICS: 6219, Page 3: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 4.
# NAICS: 6219, Page 4: Extracted 100 links.
# NAICS: 6219, Page 4: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 5.
# NAICS: 6219, Page 5: Extracted 100 links.
# NAICS: 6219, Page 5: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 6.
# NAICS: 6219, Page 6: Extracted 100 links.
# NAICS: 6219, Page 6: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 7.
# NAICS: 6219, Page 7: Extracted 100 links.
# NAICS: 6219, Page 7: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 8.
# NAICS: 6219, Page 8: Extracted 100 links.
# NAICS: 6219, Page 8: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 9.
# NAICS: 6219, Page 9: Extracted 100 links.
# NAICS: 6219, Page 9: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 10.
# NAICS: 6219, Page 10: Extracted 100 links.
# NAICS: 6219, Page 10: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 11.
# NAICS: 6219, Page 11: Extracted 100 links.
# NAICS: 6219, Page 11: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 12.
# NAICS: 6219, Page 12: Extracted 100 links.
# NAICS: 6219, Page 12: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 13.
# NAICS: 6219, Page 13: Extracted 100 links.
# NAICS: 6219, Page 13: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 14.
# NAICS: 6219, Page 14: Extracted 100 links.
# NAICS: 6219, Page 14: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 15.
# NAICS: 6219, Page 15: Extracted 100 links.
# NAICS: 6219, Page 15: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 16.
# NAICS: 6219, Page 16: Extracted 100 links.
# NAICS: 6219, Page 16: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 17.
# NAICS: 6219, Page 17: Extracted 100 links.
# NAICS: 6219, Page 17: Wrote 100 links to tmp_6219_8_25.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 18.
# NAICS: 6219, Page 18: Extracted 100 links.
# NAICS: 6219, Page 18: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 19.
# NAICS: 6219, Page 19: Extracted 100 links.
# NAICS: 6219, Page 19: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 20.
# NAICS: 6219, Page 20: Extracted 100 links.
# NAICS: 6219, Page 20: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 21.
# NAICS: 6219, Page 21: Extracted 100 links.
# NAICS: 6219, Page 21: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 22.
# NAICS: 6219, Page 22: Extracted 100 links.
# NAICS: 6219, Page 22: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 23.
# NAICS: 6219, Page 23: Extracted 100 links.
# NAICS: 6219, Page 23: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 24.
# NAICS: 6219, Page 24: Extracted 100 links.
# NAICS: 6219, Page 24: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 25.
# NAICS: 6219, Page 25: Extracted 100 links.
# NAICS: 6219, Page 25: Wrote 100 links to tmp_6219_8_26.txt
# NAICS: 6219, Clicked the 'Next' button to go to page 26.
# NAICS: 6219, Page 26: Extracted 63 links.
# NAICS: 6219, Page 26: Wrote 63 links to tmp_6219_8_26.txt
# NAICS: 6219, No 'Next' button found or an error occurred.
# NAICS: 6219: Total links extracted: 2563
# Closed the result tab for NAICS: 6219.
# Clicked the Submit button for NAICS: 5614.
# Switched to the new tab for NAICS: 5614.
# NAICS: 5614, Page 1: Extracted 100 links.
# NAICS: 5614, Page 1: Wrote 100 links to tmp_5614_8_26.txt
# NAICS: 5614, Clicked the 'Next' button to go to page 2.
# NAICS: 5614, Page 2: Extracted 100 links.
# NAICS: 5614, Page 2: Wrote 100 links to tmp_5614_8_26.txt
# NAICS: 5614, Clicked the 'Next' button to go to page 3.
# NAICS: 5614, Page 3: Extracted 100 links.
# NAICS: 5614, Page 3: Wrote 100 links to tmp_5614_8_26.txt
# NAICS: 5614, Clicked the 'Next' button to go to page 4.
# NAICS: 5614, Page 4: Extracted 100 links.
# NAICS: 5614, Page 4: Wrote 100 links to tmp_5614_8_26.txt
# NAICS: 5614, Clicked the 'Next' button to go to page 5.
# NAICS: 5614, Page 5: Extracted 100 links.
# NAICS: 5614, Page 5: Wrote 100 links to tmp_5614_8_26.txt
# NAICS: 5614, Clicked the 'Next' button to go to page 6.
# NAICS: 5614, Page 6: Extracted 100 links.
# NAICS: 5614, Page 6: Wrote 100 links to tmp_5614_8_26.txt
# NAICS: 5614, Clicked the 'Next' button to go to page 7.
# NAICS: 5614, Page 7: Extracted 100 links.
# NAICS: 5614, Page 7: Wrote 100 links to tmp_5614_8_26.txt
# NAICS: 5614, Clicked the 'Next' button to go to page 8.
# NAICS: 5614, Page 8: Extracted 85 links.
# NAICS: 5614, Page 8: Wrote 85 links to tmp_5614_8_26.txt
# NAICS: 5614, No 'Next' button found or an error occurred.
# NAICS: 5614: Total links extracted: 785
# Closed the result tab for NAICS: 5614.
# Clicked the Submit button for NAICS: 3231.
# Switched to the new tab for NAICS: 3231.
# NAICS: 3231, Page 1: Extracted 100 links.
# NAICS: 3231, Page 1: Wrote 100 links to tmp_3231_8_26.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 2.
# NAICS: 3231, Page 2: Extracted 100 links.
# NAICS: 3231, Page 2: Wrote 100 links to tmp_3231_8_26.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 3.
# NAICS: 3231, Page 3: Extracted 100 links.
# NAICS: 3231, Page 3: Wrote 100 links to tmp_3231_8_27.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 4.
# NAICS: 3231, Page 4: Extracted 100 links.
# NAICS: 3231, Page 4: Wrote 100 links to tmp_3231_8_27.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 5.
# NAICS: 3231, Page 5: Extracted 100 links.
# NAICS: 3231, Page 5: Wrote 100 links to tmp_3231_8_27.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 6.
# NAICS: 3231, Page 6: Extracted 100 links.
# NAICS: 3231, Page 6: Wrote 100 links to tmp_3231_8_27.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 7.
# NAICS: 3231, Page 7: Extracted 100 links.
# NAICS: 3231, Page 7: Wrote 100 links to tmp_3231_8_27.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 8.
# NAICS: 3231, Page 8: Extracted 100 links.
# NAICS: 3231, Page 8: Wrote 100 links to tmp_3231_8_27.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 9.
# NAICS: 3231, Page 9: Extracted 100 links.
# NAICS: 3231, Page 9: Wrote 100 links to tmp_3231_8_27.txt
# NAICS: 3231, Clicked the 'Next' button to go to page 10.
# NAICS: 3231, Page 10: Extracted 77 links.
# NAICS: 3231, Page 10: Wrote 77 links to tmp_3231_8_27.txt
# NAICS: 3231, No 'Next' button found or an error occurred.
# NAICS: 3231: Total links extracted: 977
# Closed the result tab for NAICS: 3231.
# Clicked the Submit button for NAICS: 4251.
# Switched to the new tab for NAICS: 4251.
# NAICS: 4251, Page 1: Extracted 100 links.
# NAICS: 4251, Page 1: Wrote 100 links to tmp_4251_8_27.txt
# NAICS: 4251, Clicked the 'Next' button to go to page 2.
# NAICS: 4251, Page 2: Extracted 100 links.
# NAICS: 4251, Page 2: Wrote 100 links to tmp_4251_8_27.txt
# NAICS: 4251, Clicked the 'Next' button to go to page 3.
# NAICS: 4251, Page 3: Extracted 71 links.
# NAICS: 4251, Page 3: Wrote 71 links to tmp_4251_8_27.txt
# NAICS: 4251, No 'Next' button found or an error occurred.
# NAICS: 4251: Total links extracted: 271
# Closed the result tab for NAICS: 4251.
# Batch 20 completed.
# All tasks from batch 7 to 20 completed. Links are written to tmp files.
# Closed the WebDriver.

# %% [markdown]
# ## Task Eval

# %%
problematic_codes = []
problematic_start_codes = []

# %%
worklist = []
complete_log = []
with open("worklog.txt",'r') as f:
    for line in f.readlines():
        vals = line.strip().split("]")[1]
        vallst = vals.split(',')
        if len(vallst)==1:
            code, linknum = vals.split(".")
            complete_log.append((code,linknum))
            continue
        if len(vallst)!=3:
            print(vallst)
            continue
        naics, page, link_extracted = vals.split(",")
        worklist.append((naics, page, link_extracted))

# %%
for ele in complete_log:
    code, linknum = ele
    code = int(code.split(":")[1])
    linknum = int(linknum.split(":")[1])
    if linknum == 0:
        problematic_codes.append(code)

# %%
for ele in worklist:
    code, page, linknum = ele
    code = int(code.split(":")[1])
    page = int(page.split(":")[1])
    linknum = int(linknum.split(":")[1])
    # exclude already problematic
    if code in problematic_codes:
        continue
    if linknum == 0:
        if page != 1:
            problematic_codes.append(code)
        else:
            problematic_start_codes.append(code)

# %%
problematic_codes
# Out:
# [4541,
#  4512,
#  3211,
#  5612,
#  5191,
#  6232,
#  3352,
#  4483,
#  4533,
#  2111,
#  4422,
#  4421,
#  7213,
#  4511,
#  3351,
#  1125,
#  1125,
#  3131,
#  2121,
#  4821,
#  5112,
#  5173,
#  4543,
#  8141,
#  4862,
#  5151,
#  4539,
#  3255,
#  3117,
#  5211,
#  5179,
#  4431,
#  4542,
#  4532,
#  3274,
#  4481,
#  4471,
#  4482,
#  4461,
#  4523,
#  5111,
#  4522,
#  5152,
#  4531,
#  6241]

# %%
with open ("problematic_codes.txt",'w') as f:
    for c in problematic_codes:
        f.write(str(c))
        f.write("\n")

# %% [markdown]
# ## Problematic_tasks

# %%
import math
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import asyncio
from tqdm.notebook import tqdm
from datetime import datetime
import nest_asyncio

# Allow nested event loops in Jupyter Notebook
nest_asyncio.apply()

# Function to split data into batches
def split_into_batches(data, num_batches):
    """
    Splits a list into a specified number of batches.
    """
    batch_size = math.ceil(len(data) / num_batches)
    return [data[i * batch_size:(i + 1) * batch_size] for i in range(num_batches)]

# Async function to fetch links for a single NAICS code
async def fetch_links(driver, naics_code):
    """
    Fetch all 'Detail' links for a given NAICS code.
    Handles pagination and logs progress to a worklog file.
    """
    try:
        # Step 1: Navigate to the Page
        url = "https://accessnc.nccommerce.com/business/business_custom_search_infogroup.html"
        driver.get(url)

        # Wait for the page to load
        await asyncio.sleep(1)

        # Step 2: Select Industry Group (e.g., NAICS Code)
        industry_dropdown = Select(driver.find_element(By.ID, "qnaics"))
        industry_dropdown.select_by_value(naics_code)

        # Step 3: Interact with the Submit Button
        submit_button = driver.find_element(By.CSS_SELECTOR, "div.form-group > button[type='submit'][class='btn btn-primary'][name='submit']")
        driver.execute_script("arguments[0].scrollIntoView(true);", submit_button)
        await asyncio.sleep(1)
        driver.execute_script("arguments[0].click();", submit_button)
        print(f"Clicked the Submit button for NAICS: {naics_code}.")

        # Step 4: Wait for Results to Load and Process the New Tab's HTML
        await asyncio.sleep(5)  # Wait to ensure the response page is fully loaded
        driver.switch_to.window(driver.window_handles[-1])  # Switch to the new tab
        print(f"Switched to the new tab for NAICS: {naics_code}.")

        # Initialize an empty list to store all links
        all_detail_links = []
        page_num = 1  # Initialize page counter

        while True:
            # Capture the HTML content of the current page
            result_html = driver.page_source
            soup = BeautifulSoup(result_html, 'html.parser')

            # Extract all links where the text is "Detail"
            detail_links = [link.get('href') for link in soup.find_all('a', string="Detail")]
            all_detail_links.extend(detail_links)
            print(f"NAICS: {naics_code}, Page {page_num}: Extracted {len(detail_links)} links.")

            # Write links to a temporary file
            timestamp = datetime.now()
            tmp_filename = f"problematic_{naics_code}_{timestamp.hour}_{timestamp.minute}.txt"
            with open(tmp_filename, "a") as file:
                for link in detail_links:
                    file.write(link + "\n")
            print(f"NAICS: {naics_code}, Page {page_num}: Wrote {len(detail_links)} links to {tmp_filename}")

            # Log progress to worklog
            with open("worklog.txt", "a") as log_file:
                log_file.write(f"[{timestamp}] NAICS: {naics_code}, Page: {page_num}, Links Extracted: {len(detail_links)}\n")

            # Find and click the "Next" button
            try:
                next_button = driver.find_element(By.CSS_SELECTOR, "a[rel='next']")
                if "disabled" in next_button.get_attribute("class"):
                    print(f"NAICS: {naics_code}, Page {page_num}: No more pages.")
                    break
                next_button.click()
                print(f"NAICS: {naics_code}, Clicked the 'Next' button to go to page {page_num + 1}.")
                page_num += 1
                await asyncio.sleep(2)  # Allow time for the next page to load
            except Exception:
                print(f"NAICS: {naics_code}, No 'Next' button found or an error occurred.")
                break

        print(f"NAICS: {naics_code}: Total links extracted: {len(all_detail_links)}")

        # Log final results
        with open("worklog.txt", "a") as log_file:
            log_file.write(f"[{datetime.now()}] Completed NAICS: {naics_code}. Total Links: {len(all_detail_links)}\n")

        # Close the result tab before returning to the main tab
        driver.close()
        await asyncio.sleep(1)  # Ensure tab closure completes
        driver.switch_to.window(driver.window_handles[0])
        print(f"Closed the result tab for NAICS: {naics_code}.")
    except Exception as e:
        print(f"Error processing NAICS: {naics_code}: {e}")

# Async main function
async def main(start_batch, end_batch):
    # Read NAICS codes from the file
    with open("problematic_codes.txt", 'r') as f:
        codes = [line.strip() for line in f.readlines()]

    # Split the tasks into batches
    batches = split_into_batches(codes, 4)

    # Validate batch range
    if start_batch < 1 or end_batch > len(batches):
        print(f"Invalid batch range: {start_batch}-{end_batch}. Must be between 1 and {len(batches)}.")
        return

    # Create a WebDriver instance
    driver = webdriver.Chrome()

    try:
        for batch_idx in range(start_batch - 1, end_batch):
            print(f"Processing batch {batch_idx + 1}/{end_batch}...")
            progress_bar = tqdm(total=len(batches[batch_idx]), desc=f"Batch {batch_idx + 1}/{end_batch}")

            # Run tasks sequentially in the current batch to ensure proper tab handling
            for naics_code in batches[batch_idx]:
                await fetch_links(driver, naics_code)
                progress_bar.update(1)

            progress_bar.close()
            print(f"Batch {batch_idx + 1} completed.")
            await asyncio.sleep(5)  # Optional rest between batches

        print(f"All tasks from batch {start_batch} to {end_batch} completed. Links are written to tmp files.")
    finally:
        driver.quit()
        print("Closed the WebDriver.")

# %%
split_into_batches(problematic_codes, 4)
# Out:
# [[4541, 4512, 3211, 5612, 5191, 6232, 3352, 4483, 4533, 2111, 4422, 4421],
#  [7213, 4511, 3351, 1125, 1125, 3131, 2121, 4821, 5112, 5173, 4543, 8141],
#  [4862, 5151, 4539, 3255, 3117, 5211, 5179, 4431, 4542, 4532, 3274, 4481],
#  [4471, 4482, 4461, 4523, 5111, 4522, 5152, 4531, 6241]]

# %%
await main(start_batch=1, end_batch=4)
# Out:
# Processing batch 1/4...
# Batch 1/4:   0%|          | 0/12 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 4541.
# Switched to the new tab for NAICS: 4541.
# NAICS: 4541, Page 1: Extracted 0 links.
# NAICS: 4541, Page 1: Wrote 0 links to problematic_4541_11_51.txt
# NAICS: 4541, No 'Next' button found or an error occurred.
# NAICS: 4541: Total links extracted: 0
# Closed the result tab for NAICS: 4541.
# Clicked the Submit button for NAICS: 4512.
# Switched to the new tab for NAICS: 4512.
# NAICS: 4512, Page 1: Extracted 0 links.
# NAICS: 4512, Page 1: Wrote 0 links to problematic_4512_11_51.txt
# NAICS: 4512, No 'Next' button found or an error occurred.
# NAICS: 4512: Total links extracted: 0
# Closed the result tab for NAICS: 4512.
# Clicked the Submit button for NAICS: 3211.
# Switched to the new tab for NAICS: 3211.
# NAICS: 3211, Page 1: Extracted 62 links.
# NAICS: 3211, Page 1: Wrote 62 links to problematic_3211_11_51.txt
# NAICS: 3211, No 'Next' button found or an error occurred.
# NAICS: 3211: Total links extracted: 62
# Closed the result tab for NAICS: 3211.
# Clicked the Submit button for NAICS: 5612.
# Switched to the new tab for NAICS: 5612.
# NAICS: 5612, Page 1: Extracted 45 links.
# NAICS: 5612, Page 1: Wrote 45 links to problematic_5612_11_51.txt
# NAICS: 5612, No 'Next' button found or an error occurred.
# NAICS: 5612: Total links extracted: 45
# Closed the result tab for NAICS: 5612.
# Clicked the Submit button for NAICS: 5191.
# Switched to the new tab for NAICS: 5191.
# NAICS: 5191, Page 1: Extracted 0 links.
# NAICS: 5191, Page 1: Wrote 0 links to problematic_5191_11_51.txt
# NAICS: 5191, No 'Next' button found or an error occurred.
# NAICS: 5191: Total links extracted: 0
# Closed the result tab for NAICS: 5191.
# Clicked the Submit button for NAICS: 6232.
# Switched to the new tab for NAICS: 6232.
# NAICS: 6232, Page 1: Extracted 26 links.
# NAICS: 6232, Page 1: Wrote 26 links to problematic_6232_11_52.txt
# NAICS: 6232, No 'Next' button found or an error occurred.
# NAICS: 6232: Total links extracted: 26
# Closed the result tab for NAICS: 6232.
# Clicked the Submit button for NAICS: 3352.
# Switched to the new tab for NAICS: 3352.
# NAICS: 3352, Page 1: Extracted 39 links.
# NAICS: 3352, Page 1: Wrote 39 links to problematic_3352_11_52.txt
# NAICS: 3352, No 'Next' button found or an error occurred.
# NAICS: 3352: Total links extracted: 39
# Closed the result tab for NAICS: 3352.
# Clicked the Submit button for NAICS: 4483.
# Switched to the new tab for NAICS: 4483.
# NAICS: 4483, Page 1: Extracted 0 links.
# NAICS: 4483, Page 1: Wrote 0 links to problematic_4483_11_52.txt
# NAICS: 4483, No 'Next' button found or an error occurred.
# NAICS: 4483: Total links extracted: 0
# Closed the result tab for NAICS: 4483.
# Clicked the Submit button for NAICS: 4533.
# Switched to the new tab for NAICS: 4533.
# NAICS: 4533, Page 1: Extracted 0 links.
# NAICS: 4533, Page 1: Wrote 0 links to problematic_4533_11_52.txt
# NAICS: 4533, No 'Next' button found or an error occurred.
# NAICS: 4533: Total links extracted: 0
# Closed the result tab for NAICS: 4533.
# Clicked the Submit button for NAICS: 2111.
# Switched to the new tab for NAICS: 2111.
# NAICS: 2111, Page 1: Extracted 79 links.
# NAICS: 2111, Page 1: Wrote 79 links to problematic_2111_11_52.txt
# NAICS: 2111, No 'Next' button found or an error occurred.
# NAICS: 2111: Total links extracted: 79
# Closed the result tab for NAICS: 2111.
# Clicked the Submit button for NAICS: 4422.
# Switched to the new tab for NAICS: 4422.
# NAICS: 4422, Page 1: Extracted 0 links.
# NAICS: 4422, Page 1: Wrote 0 links to problematic_4422_11_52.txt
# NAICS: 4422, No 'Next' button found or an error occurred.
# NAICS: 4422: Total links extracted: 0
# Closed the result tab for NAICS: 4422.
# Clicked the Submit button for NAICS: 4421.
# Switched to the new tab for NAICS: 4421.
# NAICS: 4421, Page 1: Extracted 0 links.
# NAICS: 4421, Page 1: Wrote 0 links to problematic_4421_11_52.txt
# NAICS: 4421, No 'Next' button found or an error occurred.
# NAICS: 4421: Total links extracted: 0
# Closed the result tab for NAICS: 4421.
# Batch 1 completed.
# Processing batch 2/4...
# Batch 2/4:   0%|          | 0/12 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 7213.
# Switched to the new tab for NAICS: 7213.
# NAICS: 7213, Page 1: Extracted 95 links.
# NAICS: 7213, Page 1: Wrote 95 links to problematic_7213_11_53.txt
# NAICS: 7213, No 'Next' button found or an error occurred.
# NAICS: 7213: Total links extracted: 95
# Closed the result tab for NAICS: 7213.
# Clicked the Submit button for NAICS: 4511.
# Switched to the new tab for NAICS: 4511.
# NAICS: 4511, Page 1: Extracted 0 links.
# NAICS: 4511, Page 1: Wrote 0 links to problematic_4511_11_53.txt
# NAICS: 4511, No 'Next' button found or an error occurred.
# NAICS: 4511: Total links extracted: 0
# Closed the result tab for NAICS: 4511.
# Clicked the Submit button for NAICS: 3351.
# Switched to the new tab for NAICS: 3351.
# NAICS: 3351, Page 1: Extracted 33 links.
# NAICS: 3351, Page 1: Wrote 33 links to problematic_3351_11_53.txt
# NAICS: 3351, No 'Next' button found or an error occurred.
# NAICS: 3351: Total links extracted: 33
# Closed the result tab for NAICS: 3351.
# Clicked the Submit button for NAICS: 1125.
# Switched to the new tab for NAICS: 1125.
# NAICS: 1125, Page 1: Extracted 42 links.
# NAICS: 1125, Page 1: Wrote 42 links to problematic_1125_11_53.txt
# NAICS: 1125, No 'Next' button found or an error occurred.
# NAICS: 1125: Total links extracted: 42
# Closed the result tab for NAICS: 1125.
# Clicked the Submit button for NAICS: 1125.
# Switched to the new tab for NAICS: 1125.
# NAICS: 1125, Page 1: Extracted 42 links.
# NAICS: 1125, Page 1: Wrote 42 links to problematic_1125_11_53.txt
# NAICS: 1125, No 'Next' button found or an error occurred.
# NAICS: 1125: Total links extracted: 42
# Closed the result tab for NAICS: 1125.
# Clicked the Submit button for NAICS: 3131.
# Switched to the new tab for NAICS: 3131.
# NAICS: 3131, Page 1: Extracted 40 links.
# NAICS: 3131, Page 1: Wrote 40 links to problematic_3131_11_53.txt
# NAICS: 3131, No 'Next' button found or an error occurred.
# NAICS: 3131: Total links extracted: 40
# Closed the result tab for NAICS: 3131.
# Clicked the Submit button for NAICS: 2121.
# Switched to the new tab for NAICS: 2121.
# NAICS: 2121, Page 1: Extracted 1 links.
# NAICS: 2121, Page 1: Wrote 1 links to problematic_2121_11_53.txt
# NAICS: 2121, No 'Next' button found or an error occurred.
# NAICS: 2121: Total links extracted: 1
# Closed the result tab for NAICS: 2121.
# Clicked the Submit button for NAICS: 4821.
# Switched to the new tab for NAICS: 4821.
# NAICS: 4821, Page 1: Extracted 48 links.
# NAICS: 4821, Page 1: Wrote 48 links to problematic_4821_11_54.txt
# NAICS: 4821, No 'Next' button found or an error occurred.
# NAICS: 4821: Total links extracted: 48
# Closed the result tab for NAICS: 4821.
# Clicked the Submit button for NAICS: 5112.
# Switched to the new tab for NAICS: 5112.
# NAICS: 5112, Page 1: Extracted 0 links.
# NAICS: 5112, Page 1: Wrote 0 links to problematic_5112_11_54.txt
# NAICS: 5112, No 'Next' button found or an error occurred.
# NAICS: 5112: Total links extracted: 0
# Closed the result tab for NAICS: 5112.
# Clicked the Submit button for NAICS: 5173.
# Switched to the new tab for NAICS: 5173.
# NAICS: 5173, Page 1: Extracted 0 links.
# NAICS: 5173, Page 1: Wrote 0 links to problematic_5173_11_54.txt
# NAICS: 5173, No 'Next' button found or an error occurred.
# NAICS: 5173: Total links extracted: 0
# Closed the result tab for NAICS: 5173.
# Clicked the Submit button for NAICS: 4543.
# Switched to the new tab for NAICS: 4543.
# NAICS: 4543, Page 1: Extracted 0 links.
# NAICS: 4543, Page 1: Wrote 0 links to problematic_4543_11_54.txt
# NAICS: 4543, No 'Next' button found or an error occurred.
# NAICS: 4543: Total links extracted: 0
# Closed the result tab for NAICS: 4543.
# Clicked the Submit button for NAICS: 8141.
# Switched to the new tab for NAICS: 8141.
# NAICS: 8141, Page 1: Extracted 0 links.
# NAICS: 8141, Page 1: Wrote 0 links to problematic_8141_11_54.txt
# NAICS: 8141, No 'Next' button found or an error occurred.
# NAICS: 8141: Total links extracted: 0
# Closed the result tab for NAICS: 8141.
# Batch 2 completed.
# Processing batch 3/4...
# Batch 3/4:   0%|          | 0/12 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 4862.
# Switched to the new tab for NAICS: 4862.
# NAICS: 4862, Page 1: Extracted 0 links.
# NAICS: 4862, Page 1: Wrote 0 links to problematic_4862_11_54.txt
# NAICS: 4862, No 'Next' button found or an error occurred.
# NAICS: 4862: Total links extracted: 0
# Closed the result tab for NAICS: 4862.
# Clicked the Submit button for NAICS: 5151.
# Switched to the new tab for NAICS: 5151.
# NAICS: 5151, Page 1: Extracted 0 links.
# NAICS: 5151, Page 1: Wrote 0 links to problematic_5151_11_54.txt
# NAICS: 5151, No 'Next' button found or an error occurred.
# NAICS: 5151: Total links extracted: 0
# Closed the result tab for NAICS: 5151.
# Clicked the Submit button for NAICS: 4539.
# Switched to the new tab for NAICS: 4539.
# NAICS: 4539, Page 1: Extracted 0 links.
# NAICS: 4539, Page 1: Wrote 0 links to problematic_4539_11_55.txt
# NAICS: 4539, No 'Next' button found or an error occurred.
# NAICS: 4539: Total links extracted: 0
# Closed the result tab for NAICS: 4539.
# Clicked the Submit button for NAICS: 3255.
# Switched to the new tab for NAICS: 3255.
# NAICS: 3255, Page 1: Extracted 44 links.
# NAICS: 3255, Page 1: Wrote 44 links to problematic_3255_11_55.txt
# NAICS: 3255, No 'Next' button found or an error occurred.
# NAICS: 3255: Total links extracted: 44
# Closed the result tab for NAICS: 3255.
# Clicked the Submit button for NAICS: 3117.
# Switched to the new tab for NAICS: 3117.
# NAICS: 3117, Page 1: Extracted 20 links.
# NAICS: 3117, Page 1: Wrote 20 links to problematic_3117_11_55.txt
# NAICS: 3117, No 'Next' button found or an error occurred.
# NAICS: 3117: Total links extracted: 20
# Closed the result tab for NAICS: 3117.
# Clicked the Submit button for NAICS: 5211.
# Switched to the new tab for NAICS: 5211.
# NAICS: 5211, Page 1: Extracted 0 links.
# NAICS: 5211, Page 1: Wrote 0 links to problematic_5211_11_55.txt
# NAICS: 5211, No 'Next' button found or an error occurred.
# NAICS: 5211: Total links extracted: 0
# Closed the result tab for NAICS: 5211.
# Clicked the Submit button for NAICS: 5179.
# Switched to the new tab for NAICS: 5179.
# NAICS: 5179, Page 1: Extracted 0 links.
# NAICS: 5179, Page 1: Wrote 0 links to problematic_5179_11_55.txt
# NAICS: 5179, No 'Next' button found or an error occurred.
# NAICS: 5179: Total links extracted: 0
# Closed the result tab for NAICS: 5179.
# Clicked the Submit button for NAICS: 4431.
# Switched to the new tab for NAICS: 4431.
# NAICS: 4431, Page 1: Extracted 0 links.
# NAICS: 4431, Page 1: Wrote 0 links to problematic_4431_11_55.txt
# NAICS: 4431, No 'Next' button found or an error occurred.
# NAICS: 4431: Total links extracted: 0
# Closed the result tab for NAICS: 4431.
# Clicked the Submit button for NAICS: 4542.
# Switched to the new tab for NAICS: 4542.
# NAICS: 4542, Page 1: Extracted 0 links.
# NAICS: 4542, Page 1: Wrote 0 links to problematic_4542_11_55.txt
# NAICS: 4542, No 'Next' button found or an error occurred.
# NAICS: 4542: Total links extracted: 0
# Closed the result tab for NAICS: 4542.
# Clicked the Submit button for NAICS: 4532.
# Switched to the new tab for NAICS: 4532.
# NAICS: 4532, Page 1: Extracted 0 links.
# NAICS: 4532, Page 1: Wrote 0 links to problematic_4532_11_56.txt
# NAICS: 4532, No 'Next' button found or an error occurred.
# NAICS: 4532: Total links extracted: 0
# Closed the result tab for NAICS: 4532.
# Clicked the Submit button for NAICS: 3274.
# Switched to the new tab for NAICS: 3274.
# NAICS: 3274, Page 1: Extracted 10 links.
# NAICS: 3274, Page 1: Wrote 10 links to problematic_3274_11_56.txt
# NAICS: 3274, No 'Next' button found or an error occurred.
# NAICS: 3274: Total links extracted: 10
# Closed the result tab for NAICS: 3274.
# Clicked the Submit button for NAICS: 4481.
# Switched to the new tab for NAICS: 4481.
# NAICS: 4481, Page 1: Extracted 0 links.
# NAICS: 4481, Page 1: Wrote 0 links to problematic_4481_11_56.txt
# NAICS: 4481, No 'Next' button found or an error occurred.
# NAICS: 4481: Total links extracted: 0
# Closed the result tab for NAICS: 4481.
# Batch 3 completed.
# Processing batch 4/4...
# Batch 4/4:   0%|          | 0/9 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 4471.
# Switched to the new tab for NAICS: 4471.
# NAICS: 4471, Page 1: Extracted 0 links.
# NAICS: 4471, Page 1: Wrote 0 links to problematic_4471_11_56.txt
# NAICS: 4471, No 'Next' button found or an error occurred.
# NAICS: 4471: Total links extracted: 0
# Closed the result tab for NAICS: 4471.
# Clicked the Submit button for NAICS: 4482.
# Switched to the new tab for NAICS: 4482.
# NAICS: 4482, Page 1: Extracted 0 links.
# NAICS: 4482, Page 1: Wrote 0 links to problematic_4482_11_56.txt
# NAICS: 4482, No 'Next' button found or an error occurred.
# NAICS: 4482: Total links extracted: 0
# Closed the result tab for NAICS: 4482.
# Clicked the Submit button for NAICS: 4461.
# Switched to the new tab for NAICS: 4461.
# NAICS: 4461, Page 1: Extracted 0 links.
# NAICS: 4461, Page 1: Wrote 0 links to problematic_4461_11_56.txt
# NAICS: 4461, No 'Next' button found or an error occurred.
# NAICS: 4461: Total links extracted: 0
# Closed the result tab for NAICS: 4461.
# Clicked the Submit button for NAICS: 4523.
# Switched to the new tab for NAICS: 4523.
# NAICS: 4523, Page 1: Extracted 0 links.
# NAICS: 4523, Page 1: Wrote 0 links to problematic_4523_11_56.txt
# NAICS: 4523, No 'Next' button found or an error occurred.
# NAICS: 4523: Total links extracted: 0
# Closed the result tab for NAICS: 4523.
# Clicked the Submit button for NAICS: 5111.
# Switched to the new tab for NAICS: 5111.
# NAICS: 5111, Page 1: Extracted 0 links.
# NAICS: 5111, Page 1: Wrote 0 links to problematic_5111_11_57.txt
# NAICS: 5111, No 'Next' button found or an error occurred.
# NAICS: 5111: Total links extracted: 0
# Closed the result tab for NAICS: 5111.
# Clicked the Submit button for NAICS: 4522.
# Switched to the new tab for NAICS: 4522.
# NAICS: 4522, Page 1: Extracted 0 links.
# NAICS: 4522, Page 1: Wrote 0 links to problematic_4522_11_57.txt
# NAICS: 4522, No 'Next' button found or an error occurred.
# NAICS: 4522: Total links extracted: 0
# Closed the result tab for NAICS: 4522.
# Clicked the Submit button for NAICS: 5152.
# Switched to the new tab for NAICS: 5152.
# NAICS: 5152, Page 1: Extracted 0 links.
# NAICS: 5152, Page 1: Wrote 0 links to problematic_5152_11_57.txt
# NAICS: 5152, No 'Next' button found or an error occurred.
# NAICS: 5152: Total links extracted: 0
# Closed the result tab for NAICS: 5152.
# Clicked the Submit button for NAICS: 4531.
# Switched to the new tab for NAICS: 4531.
# NAICS: 4531, Page 1: Extracted 0 links.
# NAICS: 4531, Page 1: Wrote 0 links to problematic_4531_11_57.txt
# NAICS: 4531, No 'Next' button found or an error occurred.
# NAICS: 4531: Total links extracted: 0
# Closed the result tab for NAICS: 4531.
# Clicked the Submit button for NAICS: 6241.
# Switched to the new tab for NAICS: 6241.
# NAICS: 6241, Page 1: Extracted 100 links.
# NAICS: 6241, Page 1: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 2.
# NAICS: 6241, Page 2: Extracted 100 links.
# NAICS: 6241, Page 2: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 3.
# NAICS: 6241, Page 3: Extracted 100 links.
# NAICS: 6241, Page 3: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 4.
# NAICS: 6241, Page 4: Extracted 100 links.
# NAICS: 6241, Page 4: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 5.
# NAICS: 6241, Page 5: Extracted 100 links.
# NAICS: 6241, Page 5: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 6.
# NAICS: 6241, Page 6: Extracted 100 links.
# NAICS: 6241, Page 6: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 7.
# NAICS: 6241, Page 7: Extracted 100 links.
# NAICS: 6241, Page 7: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 8.
# NAICS: 6241, Page 8: Extracted 100 links.
# NAICS: 6241, Page 8: Wrote 100 links to problematic_6241_11_57.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 9.
# NAICS: 6241, Page 9: Extracted 100 links.
# NAICS: 6241, Page 9: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 10.
# NAICS: 6241, Page 10: Extracted 100 links.
# NAICS: 6241, Page 10: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 11.
# NAICS: 6241, Page 11: Extracted 100 links.
# NAICS: 6241, Page 11: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 12.
# NAICS: 6241, Page 12: Extracted 100 links.
# NAICS: 6241, Page 12: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 13.
# NAICS: 6241, Page 13: Extracted 100 links.
# NAICS: 6241, Page 13: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 14.
# NAICS: 6241, Page 14: Extracted 100 links.
# NAICS: 6241, Page 14: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 15.
# NAICS: 6241, Page 15: Extracted 100 links.
# NAICS: 6241, Page 15: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 16.
# NAICS: 6241, Page 16: Extracted 100 links.
# NAICS: 6241, Page 16: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 17.
# NAICS: 6241, Page 17: Extracted 100 links.
# NAICS: 6241, Page 17: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 18.
# NAICS: 6241, Page 18: Extracted 100 links.
# NAICS: 6241, Page 18: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 19.
# NAICS: 6241, Page 19: Extracted 100 links.
# NAICS: 6241, Page 19: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 20.
# NAICS: 6241, Page 20: Extracted 100 links.
# NAICS: 6241, Page 20: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 21.
# NAICS: 6241, Page 21: Extracted 100 links.
# NAICS: 6241, Page 21: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 22.
# NAICS: 6241, Page 22: Extracted 100 links.
# NAICS: 6241, Page 22: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 23.
# NAICS: 6241, Page 23: Extracted 100 links.
# NAICS: 6241, Page 23: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 24.
# NAICS: 6241, Page 24: Extracted 100 links.
# NAICS: 6241, Page 24: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 25.
# NAICS: 6241, Page 25: Extracted 100 links.
# NAICS: 6241, Page 25: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 26.
# NAICS: 6241, Page 26: Extracted 100 links.
# NAICS: 6241, Page 26: Wrote 100 links to problematic_6241_11_58.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 27.
# NAICS: 6241, Page 27: Extracted 100 links.
# NAICS: 6241, Page 27: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 28.
# NAICS: 6241, Page 28: Extracted 100 links.
# NAICS: 6241, Page 28: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 29.
# NAICS: 6241, Page 29: Extracted 100 links.
# NAICS: 6241, Page 29: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 30.
# NAICS: 6241, Page 30: Extracted 100 links.
# NAICS: 6241, Page 30: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 31.
# NAICS: 6241, Page 31: Extracted 100 links.
# NAICS: 6241, Page 31: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 32.
# NAICS: 6241, Page 32: Extracted 100 links.
# NAICS: 6241, Page 32: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 33.
# NAICS: 6241, Page 33: Extracted 100 links.
# NAICS: 6241, Page 33: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 34.
# NAICS: 6241, Page 34: Extracted 100 links.
# NAICS: 6241, Page 34: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 35.
# NAICS: 6241, Page 35: Extracted 100 links.
# NAICS: 6241, Page 35: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 36.
# NAICS: 6241, Page 36: Extracted 100 links.
# NAICS: 6241, Page 36: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 37.
# NAICS: 6241, Page 37: Extracted 100 links.
# NAICS: 6241, Page 37: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 38.
# NAICS: 6241, Page 38: Extracted 100 links.
# NAICS: 6241, Page 38: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 39.
# NAICS: 6241, Page 39: Extracted 100 links.
# NAICS: 6241, Page 39: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 40.
# NAICS: 6241, Page 40: Extracted 100 links.
# NAICS: 6241, Page 40: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 41.
# NAICS: 6241, Page 41: Extracted 100 links.
# NAICS: 6241, Page 41: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 42.
# NAICS: 6241, Page 42: Extracted 100 links.
# NAICS: 6241, Page 42: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 43.
# NAICS: 6241, Page 43: Extracted 100 links.
# NAICS: 6241, Page 43: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 44.
# NAICS: 6241, Page 44: Extracted 100 links.
# NAICS: 6241, Page 44: Wrote 100 links to problematic_6241_11_59.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 45.
# NAICS: 6241, Page 45: Extracted 100 links.
# NAICS: 6241, Page 45: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 46.
# NAICS: 6241, Page 46: Extracted 100 links.
# NAICS: 6241, Page 46: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 47.
# NAICS: 6241, Page 47: Extracted 100 links.
# NAICS: 6241, Page 47: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 48.
# NAICS: 6241, Page 48: Extracted 100 links.
# NAICS: 6241, Page 48: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 49.
# NAICS: 6241, Page 49: Extracted 100 links.
# NAICS: 6241, Page 49: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 50.
# NAICS: 6241, Page 50: Extracted 100 links.
# NAICS: 6241, Page 50: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 51.
# NAICS: 6241, Page 51: Extracted 100 links.
# NAICS: 6241, Page 51: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 52.
# NAICS: 6241, Page 52: Extracted 100 links.
# NAICS: 6241, Page 52: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 53.
# NAICS: 6241, Page 53: Extracted 100 links.
# NAICS: 6241, Page 53: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 54.
# NAICS: 6241, Page 54: Extracted 100 links.
# NAICS: 6241, Page 54: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 55.
# NAICS: 6241, Page 55: Extracted 100 links.
# NAICS: 6241, Page 55: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 56.
# NAICS: 6241, Page 56: Extracted 100 links.
# NAICS: 6241, Page 56: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 57.
# NAICS: 6241, Page 57: Extracted 100 links.
# NAICS: 6241, Page 57: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 58.
# NAICS: 6241, Page 58: Extracted 100 links.
# NAICS: 6241, Page 58: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 59.
# NAICS: 6241, Page 59: Extracted 100 links.
# NAICS: 6241, Page 59: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 60.
# NAICS: 6241, Page 60: Extracted 100 links.
# NAICS: 6241, Page 60: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 61.
# NAICS: 6241, Page 61: Extracted 100 links.
# NAICS: 6241, Page 61: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 62.
# NAICS: 6241, Page 62: Extracted 100 links.
# NAICS: 6241, Page 62: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 63.
# NAICS: 6241, Page 63: Extracted 100 links.
# NAICS: 6241, Page 63: Wrote 100 links to problematic_6241_12_0.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 64.
# NAICS: 6241, Page 64: Extracted 100 links.
# NAICS: 6241, Page 64: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 65.
# NAICS: 6241, Page 65: Extracted 100 links.
# NAICS: 6241, Page 65: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 66.
# NAICS: 6241, Page 66: Extracted 100 links.
# NAICS: 6241, Page 66: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 67.
# NAICS: 6241, Page 67: Extracted 100 links.
# NAICS: 6241, Page 67: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 68.
# NAICS: 6241, Page 68: Extracted 100 links.
# NAICS: 6241, Page 68: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 69.
# NAICS: 6241, Page 69: Extracted 100 links.
# NAICS: 6241, Page 69: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 70.
# NAICS: 6241, Page 70: Extracted 100 links.
# NAICS: 6241, Page 70: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 71.
# NAICS: 6241, Page 71: Extracted 100 links.
# NAICS: 6241, Page 71: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 72.
# NAICS: 6241, Page 72: Extracted 100 links.
# NAICS: 6241, Page 72: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 73.
# NAICS: 6241, Page 73: Extracted 100 links.
# NAICS: 6241, Page 73: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 74.
# NAICS: 6241, Page 74: Extracted 100 links.
# NAICS: 6241, Page 74: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 75.
# NAICS: 6241, Page 75: Extracted 100 links.
# NAICS: 6241, Page 75: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 76.
# NAICS: 6241, Page 76: Extracted 100 links.
# NAICS: 6241, Page 76: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 77.
# NAICS: 6241, Page 77: Extracted 100 links.
# NAICS: 6241, Page 77: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 78.
# NAICS: 6241, Page 78: Extracted 100 links.
# NAICS: 6241, Page 78: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 79.
# NAICS: 6241, Page 79: Extracted 100 links.
# NAICS: 6241, Page 79: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 80.
# NAICS: 6241, Page 80: Extracted 100 links.
# NAICS: 6241, Page 80: Wrote 100 links to problematic_6241_12_1.txt
# NAICS: 6241, Clicked the 'Next' button to go to page 81.
# NAICS: 6241, Page 81: Extracted 90 links.
# NAICS: 6241, Page 81: Wrote 90 links to problematic_6241_12_2.txt
# NAICS: 6241, No 'Next' button found or an error occurred.
# NAICS: 6241: Total links extracted: 8090
# Closed the result tab for NAICS: 6241.
# Batch 4 completed.
# All tasks from batch 1 to 4 completed. Links are written to tmp files.
# Closed the WebDriver.

# %% [markdown]
# ## Problematic_start_codes

# %%
with open ("problematic_start_codes.txt",'w') as f:
    for c in problematic_start_codes:
        f.write(str(c))
        f.write("\n")

# %%
import math
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import asyncio
from tqdm.notebook import tqdm
from datetime import datetime
import nest_asyncio

# Allow nested event loops in Jupyter Notebook
nest_asyncio.apply()

# Function to split data into batches
def split_into_batches(data, num_batches):
    """
    Splits a list into a specified number of batches.
    """
    batch_size = math.ceil(len(data) / num_batches)
    return [data[i * batch_size:(i + 1) * batch_size] for i in range(num_batches)]

# Async function to fetch links for a single NAICS code
async def fetch_links(driver, naics_code):
    """
    Fetch all 'Detail' links for a given NAICS code.
    Handles pagination and logs progress to a worklog file.
    """
    try:
        # Step 1: Navigate to the Page
        url = "https://accessnc.nccommerce.com/business/business_custom_search_infogroup.html"
        driver.get(url)

        # Wait for the page to load
        await asyncio.sleep(1)

        # Step 2: Select Industry Group (e.g., NAICS Code)
        industry_dropdown = Select(driver.find_element(By.ID, "qnaics"))
        industry_dropdown.select_by_value(naics_code)

        # Step 3: Interact with the Submit Button
        submit_button = driver.find_element(By.CSS_SELECTOR, "div.form-group > button[type='submit'][class='btn btn-primary'][name='submit']")
        driver.execute_script("arguments[0].scrollIntoView(true);", submit_button)
        await asyncio.sleep(1)
        driver.execute_script("arguments[0].click();", submit_button)
        print(f"Clicked the Submit button for NAICS: {naics_code}.")

        # Step 4: Wait for Results to Load and Process the New Tab's HTML
        await asyncio.sleep(5)  # Wait to ensure the response page is fully loaded
        driver.switch_to.window(driver.window_handles[-1])  # Switch to the new tab
        print(f"Switched to the new tab for NAICS: {naics_code}.")

        # Initialize an empty list to store all links
        all_detail_links = []
        page_num = 1  # Initialize page counter

        while True:
            # Capture the HTML content of the current page
            result_html = driver.page_source
            soup = BeautifulSoup(result_html, 'html.parser')

            # Extract all links where the text is "Detail"
            detail_links = [link.get('href') for link in soup.find_all('a', string="Detail")]
            all_detail_links.extend(detail_links)
            print(f"NAICS: {naics_code}, Page {page_num}: Extracted {len(detail_links)} links.")

            # Write links to a temporary file
            timestamp = datetime.now()
            tmp_filename = f"problematic_start_{naics_code}_{timestamp.hour}_{timestamp.minute}.txt"
            with open(tmp_filename, "a") as file:
                for link in detail_links:
                    file.write(link + "\n")
            print(f"NAICS: {naics_code}, Page {page_num}: Wrote {len(detail_links)} links to {tmp_filename}")

            # Log progress to worklog
            with open("worklog.txt", "a") as log_file:
                log_file.write(f"[{timestamp}] NAICS: {naics_code}, Page: {page_num}, Links Extracted: {len(detail_links)}\n")

            break

            # Find and click the "Next" button
            # try:
            #     next_button = driver.find_element(By.CSS_SELECTOR, "a[rel='next']")
            #     if "disabled" in next_button.get_attribute("class"):
            #         print(f"NAICS: {naics_code}, Page {page_num}: No more pages.")
            #         break
            #     next_button.click()
            #     print(f"NAICS: {naics_code}, Clicked the 'Next' button to go to page {page_num + 1}.")
            #     page_num += 1
            #     await asyncio.sleep(2)  # Allow time for the next page to load
            # except Exception:
            #     print(f"NAICS: {naics_code}, No 'Next' button found or an error occurred.")
            #     break

        print(f"NAICS: {naics_code}: Total links extracted: {len(all_detail_links)}")

        # Log final results
        with open("worklog.txt", "a") as log_file:
            log_file.write(f"[{datetime.now()}] Completed NAICS: {naics_code}. Total Links: {len(all_detail_links)}\n")

        # Close the result tab before returning to the main tab
        driver.close()
        await asyncio.sleep(1)  # Ensure tab closure completes
        driver.switch_to.window(driver.window_handles[0])
        print(f"Closed the result tab for NAICS: {naics_code}.")
    except Exception as e:
        print(f"Error processing NAICS: {naics_code}: {e}")

# Async main function
async def main(start_batch, end_batch):
    # Read NAICS codes from the file
    with open("problematic_start_codes.txt", 'r') as f:
        codes = [line.strip() for line in f.readlines()]

    # Split the tasks into batches
    batches = split_into_batches(codes, 4)

    # Validate batch range
    if start_batch < 1 or end_batch > len(batches):
        print(f"Invalid batch range: {start_batch}-{end_batch}. Must be between 1 and {len(batches)}.")
        return

    # Create a WebDriver instance
    driver = webdriver.Chrome()

    try:
        for batch_idx in range(start_batch - 1, end_batch):
            print(f"Processing batch {batch_idx + 1}/{end_batch}...")
            progress_bar = tqdm(total=len(batches[batch_idx]), desc=f"Batch {batch_idx + 1}/{end_batch}")

            # Run tasks sequentially in the current batch to ensure proper tab handling
            for naics_code in batches[batch_idx]:
                await fetch_links(driver, naics_code)
                progress_bar.update(1)

            progress_bar.close()
            print(f"Batch {batch_idx + 1} completed.")
            await asyncio.sleep(5)  # Optional rest between batches

        print(f"All tasks from batch {start_batch} to {end_batch} completed. Links are written to tmp files.")
    finally:
        driver.quit()
        print("Closed the WebDriver.")

# %%
await main(start_batch=1, end_batch=4)
# Out:
# Processing batch 1/4...
# Batch 1/4:   0%|          | 0/10 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 8132.
# Switched to the new tab for NAICS: 8132.
# NAICS: 8132, Page 1: Extracted 100 links.
# NAICS: 8132, Page 1: Wrote 100 links to problematic_start_8132_12_10.txt
# NAICS: 8132: Total links extracted: 100
# Closed the result tab for NAICS: 8132.
# Clicked the Submit button for NAICS: 5615.
# Switched to the new tab for NAICS: 5615.
# NAICS: 5615, Page 1: Extracted 100 links.
# NAICS: 5615, Page 1: Wrote 100 links to problematic_start_5615_12_10.txt
# NAICS: 5615: Total links extracted: 100
# Closed the result tab for NAICS: 5615.
# Clicked the Submit button for NAICS: 8139.
# Switched to the new tab for NAICS: 8139.
# NAICS: 8139, Page 1: Extracted 100 links.
# NAICS: 8139, Page 1: Wrote 100 links to problematic_start_8139_12_10.txt
# NAICS: 8139: Total links extracted: 100
# Closed the result tab for NAICS: 8139.
# Clicked the Submit button for NAICS: 6244.
# Switched to the new tab for NAICS: 6244.
# NAICS: 6244, Page 1: Extracted 100 links.
# NAICS: 6244, Page 1: Wrote 100 links to problematic_start_6244_12_10.txt
# NAICS: 6244: Total links extracted: 100
# Closed the result tab for NAICS: 6244.
# Clicked the Submit button for NAICS: 6221.
# Switched to the new tab for NAICS: 6221.
# NAICS: 6221, Page 1: Extracted 100 links.
# NAICS: 6221, Page 1: Wrote 100 links to problematic_start_6221_12_10.txt
# NAICS: 6221: Total links extracted: 100
# Closed the result tab for NAICS: 6221.
# Clicked the Submit button for NAICS: 4235.
# Switched to the new tab for NAICS: 4235.
# NAICS: 4235, Page 1: Extracted 100 links.
# NAICS: 4235, Page 1: Wrote 100 links to problematic_start_4235_12_10.txt
# NAICS: 4235: Total links extracted: 100
# Closed the result tab for NAICS: 4235.
# Clicked the Submit button for NAICS: 4451.
# Switched to the new tab for NAICS: 4451.
# NAICS: 4451, Page 1: Extracted 100 links.
# NAICS: 4451, Page 1: Wrote 100 links to problematic_start_4451_12_10.txt
# NAICS: 4451: Total links extracted: 100
# Closed the result tab for NAICS: 4451.
# Clicked the Submit button for NAICS: 4233.
# Switched to the new tab for NAICS: 4233.
# NAICS: 4233, Page 1: Extracted 100 links.
# NAICS: 4233, Page 1: Wrote 100 links to problematic_start_4233_12_11.txt
# NAICS: 4233: Total links extracted: 100
# Closed the result tab for NAICS: 4233.
# Clicked the Submit button for NAICS: 5629.
# Switched to the new tab for NAICS: 5629.
# NAICS: 5629, Page 1: Extracted 100 links.
# NAICS: 5629, Page 1: Wrote 100 links to problematic_start_5629_12_11.txt
# NAICS: 5629: Total links extracted: 100
# Closed the result tab for NAICS: 5629.
# Clicked the Submit button for NAICS: 4911.
# Switched to the new tab for NAICS: 4911.
# NAICS: 4911, Page 1: Extracted 100 links.
# NAICS: 4911, Page 1: Wrote 100 links to problematic_start_4911_12_11.txt
# NAICS: 4911: Total links extracted: 100
# Closed the result tab for NAICS: 4911.
# Batch 1 completed.
# Processing batch 2/4...
# Batch 2/4:   0%|          | 0/10 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 7111.
# Switched to the new tab for NAICS: 7111.
# NAICS: 7111, Page 1: Extracted 100 links.
# NAICS: 7111, Page 1: Wrote 100 links to problematic_start_7111_12_11.txt
# NAICS: 7111: Total links extracted: 100
# Closed the result tab for NAICS: 7111.
# Clicked the Submit button for NAICS: 7131.
# Switched to the new tab for NAICS: 7131.
# NAICS: 7131, Page 1: Extracted 100 links.
# NAICS: 7131, Page 1: Wrote 100 links to problematic_start_7131_12_11.txt
# NAICS: 7131: Total links extracted: 100
# Closed the result tab for NAICS: 7131.
# Clicked the Submit button for NAICS: 4441.
# Switched to the new tab for NAICS: 4441.
# NAICS: 4441, Page 1: Extracted 100 links.
# NAICS: 4441, Page 1: Wrote 100 links to problematic_start_4441_12_11.txt
# NAICS: 4441: Total links extracted: 100
# Closed the result tab for NAICS: 4441.
# Clicked the Submit button for NAICS: 9211.
# Switched to the new tab for NAICS: 9211.
# NAICS: 9211, Page 1: Extracted 100 links.
# NAICS: 9211, Page 1: Wrote 100 links to problematic_start_9211_12_11.txt
# NAICS: 9211: Total links extracted: 100
# Closed the result tab for NAICS: 9211.
# Clicked the Submit button for NAICS: 8133.
# Switched to the new tab for NAICS: 8133.
# NAICS: 8133, Page 1: Extracted 100 links.
# NAICS: 8133, Page 1: Wrote 100 links to problematic_start_8133_12_12.txt
# NAICS: 8133: Total links extracted: 100
# Closed the result tab for NAICS: 8133.
# Clicked the Submit button for NAICS: 6241.
# Switched to the new tab for NAICS: 6241.
# NAICS: 6241, Page 1: Extracted 100 links.
# NAICS: 6241, Page 1: Wrote 100 links to problematic_start_6241_12_12.txt
# NAICS: 6241: Total links extracted: 100
# Closed the result tab for NAICS: 6241.
# Clicked the Submit button for NAICS: 7223.
# Switched to the new tab for NAICS: 7223.
# NAICS: 7223, Page 1: Extracted 100 links.
# NAICS: 7223, Page 1: Wrote 100 links to problematic_start_7223_12_12.txt
# NAICS: 7223: Total links extracted: 100
# Closed the result tab for NAICS: 7223.
# Clicked the Submit button for NAICS: 2213.
# Switched to the new tab for NAICS: 2213.
# NAICS: 2213, Page 1: Extracted 100 links.
# NAICS: 2213, Page 1: Wrote 100 links to problematic_start_2213_12_12.txt
# NAICS: 2213: Total links extracted: 100
# Closed the result tab for NAICS: 2213.
# Clicked the Submit button for NAICS: 3371.
# Switched to the new tab for NAICS: 3371.
# NAICS: 3371, Page 1: Extracted 100 links.
# NAICS: 3371, Page 1: Wrote 100 links to problematic_start_3371_12_12.txt
# NAICS: 3371: Total links extracted: 100
# Closed the result tab for NAICS: 3371.
# Clicked the Submit button for NAICS: 9241.
# Switched to the new tab for NAICS: 9241.
# NAICS: 9241, Page 1: Extracted 100 links.
# NAICS: 9241, Page 1: Wrote 100 links to problematic_start_9241_12_12.txt
# NAICS: 9241: Total links extracted: 100
# Closed the result tab for NAICS: 9241.
# Batch 2 completed.
# Processing batch 3/4...
# Batch 3/4:   0%|          | 0/10 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 2123.
# Switched to the new tab for NAICS: 2123.
# NAICS: 2123, Page 1: Extracted 100 links.
# NAICS: 2123, Page 1: Wrote 100 links to problematic_start_2123_12_13.txt
# NAICS: 2123: Total links extracted: 100
# Closed the result tab for NAICS: 2123.
# Clicked the Submit button for NAICS: 4412.
# Switched to the new tab for NAICS: 4412.
# NAICS: 4412, Page 1: Extracted 100 links.
# NAICS: 4412, Page 1: Wrote 100 links to problematic_start_4412_12_13.txt
# NAICS: 4412: Total links extracted: 100
# Closed the result tab for NAICS: 4412.
# Clicked the Submit button for NAICS: 1121.
# Switched to the new tab for NAICS: 1121.
# NAICS: 1121, Page 1: Extracted 100 links.
# NAICS: 1121, Page 1: Wrote 100 links to problematic_start_1121_12_13.txt
# NAICS: 1121: Total links extracted: 100
# Closed the result tab for NAICS: 1121.
# Clicked the Submit button for NAICS: 6216.
# Switched to the new tab for NAICS: 6216.
# NAICS: 6216, Page 1: Extracted 100 links.
# NAICS: 6216, Page 1: Wrote 100 links to problematic_start_6216_12_13.txt
# NAICS: 6216: Total links extracted: 100
# Closed the result tab for NAICS: 6216.
# Clicked the Submit button for NAICS: 3345.
# Switched to the new tab for NAICS: 3345.
# NAICS: 3345, Page 1: Extracted 100 links.
# NAICS: 3345, Page 1: Wrote 100 links to problematic_start_3345_12_13.txt
# NAICS: 3345: Total links extracted: 100
# Closed the result tab for NAICS: 3345.
# Clicked the Submit button for NAICS: 4872.
# Switched to the new tab for NAICS: 4872.
# NAICS: 4872, Page 1: Extracted 100 links.
# NAICS: 4872, Page 1: Wrote 100 links to problematic_start_4872_12_13.txt
# NAICS: 4872: Total links extracted: 100
# Closed the result tab for NAICS: 4872.
# Clicked the Submit button for NAICS: 9231.
# Switched to the new tab for NAICS: 9231.
# NAICS: 9231, Page 1: Extracted 100 links.
# NAICS: 9231, Page 1: Wrote 100 links to problematic_start_9231_12_13.txt
# NAICS: 9231: Total links extracted: 100
# Closed the result tab for NAICS: 9231.
# Clicked the Submit button for NAICS: 3345.
# Switched to the new tab for NAICS: 3345.
# NAICS: 3345, Page 1: Extracted 100 links.
# NAICS: 3345, Page 1: Wrote 100 links to problematic_start_3345_12_13.txt
# NAICS: 3345: Total links extracted: 100
# Closed the result tab for NAICS: 3345.
# Clicked the Submit button for NAICS: 9231.
# Switched to the new tab for NAICS: 9231.
# NAICS: 9231, Page 1: Extracted 100 links.
# NAICS: 9231, Page 1: Wrote 100 links to problematic_start_9231_12_14.txt
# NAICS: 9231: Total links extracted: 100
# Closed the result tab for NAICS: 9231.
# Clicked the Submit button for NAICS: 3353.
# Switched to the new tab for NAICS: 3353.
# NAICS: 3353, Page 1: Extracted 100 links.
# NAICS: 3353, Page 1: Wrote 100 links to problematic_start_3353_12_14.txt
# NAICS: 3353: Total links extracted: 100
# Closed the result tab for NAICS: 3353.
# Batch 3 completed.
# Processing batch 4/4...
# Batch 4/4:   0%|          | 0/10 [00:00<?, ?it/s]
# Clicked the Submit button for NAICS: 3149.
# Switched to the new tab for NAICS: 3149.
# NAICS: 3149, Page 1: Extracted 100 links.
# NAICS: 3149, Page 1: Wrote 100 links to problematic_start_3149_12_14.txt
# NAICS: 3149: Total links extracted: 100
# Closed the result tab for NAICS: 3149.
# Clicked the Submit button for NAICS: 3399.
# Switched to the new tab for NAICS: 3399.
# NAICS: 3399, Page 1: Extracted 100 links.
# NAICS: 3399, Page 1: Wrote 100 links to problematic_start_3399_12_14.txt
# NAICS: 3399: Total links extracted: 100
# Closed the result tab for NAICS: 3399.
# Clicked the Submit button for NAICS: 3279.
# Switched to the new tab for NAICS: 3279.
# NAICS: 3279, Page 1: Extracted 100 links.
# NAICS: 3279, Page 1: Wrote 100 links to problematic_start_3279_12_14.txt
# NAICS: 3279: Total links extracted: 100
# Closed the result tab for NAICS: 3279.
# Clicked the Submit button for NAICS: 4859.
# Switched to the new tab for NAICS: 4859.
# NAICS: 4859, Page 1: Extracted 100 links.
# NAICS: 4859, Page 1: Wrote 100 links to problematic_start_4859_12_14.txt
# NAICS: 4859: Total links extracted: 100
# Closed the result tab for NAICS: 4859.
# Clicked the Submit button for NAICS: 3259.
# Switched to the new tab for NAICS: 3259.
# NAICS: 3259, Page 1: Extracted 100 links.
# NAICS: 3259, Page 1: Wrote 100 links to problematic_start_3259_12_15.txt
# NAICS: 3259: Total links extracted: 100
# Closed the result tab for NAICS: 3259.
# Clicked the Submit button for NAICS: 6213.
# Switched to the new tab for NAICS: 6213.
# NAICS: 6213, Page 1: Extracted 100 links.
# NAICS: 6213, Page 1: Wrote 100 links to problematic_start_6213_12_15.txt
# NAICS: 6213: Total links extracted: 100
# Closed the result tab for NAICS: 6213.
# Clicked the Submit button for NAICS: 4853.
# Switched to the new tab for NAICS: 4853.
# NAICS: 4853, Page 1: Extracted 100 links.
# NAICS: 4853, Page 1: Wrote 100 links to problematic_start_4853_12_15.txt
# NAICS: 4853: Total links extracted: 100
# Closed the result tab for NAICS: 4853.
# Clicked the Submit button for NAICS: 3332.
# Switched to the new tab for NAICS: 3332.
# NAICS: 3332, Page 1: Extracted 100 links.
# NAICS: 3332, Page 1: Wrote 100 links to problematic_start_3332_12_15.txt
# NAICS: 3332: Total links extracted: 100
# Closed the result tab for NAICS: 3332.
# Clicked the Submit button for NAICS: 9221.
# Switched to the new tab for NAICS: 9221.
# NAICS: 9221, Page 1: Extracted 100 links.
# NAICS: 9221, Page 1: Wrote 100 links to problematic_start_9221_12_15.txt
# NAICS: 9221: Total links extracted: 100
# Closed the result tab for NAICS: 9221.
# Clicked the Submit button for NAICS: 4413.
# Switched to the new tab for NAICS: 4413.
# NAICS: 4413, Page 1: Extracted 100 links.
# NAICS: 4413, Page 1: Wrote 100 links to problematic_start_4413_12_15.txt
# NAICS: 4413: Total links extracted: 100
# Closed the result tab for NAICS: 4413.
# Batch 4 completed.
# All tasks from batch 1 to 4 completed. Links are written to tmp files.
# Closed the WebDriver.
